# %% [markdown]
# # Testing performance of queries

# %%
import mysql.connector
import numpy as np
import pandas as pd
import time

client = mysql.connector.connect(user='admin', password='admin', host='localhost', port=3306, database='mysql')
mycursor = client.cursor()

x = 10
times = []

# %%
def sql_query_result(query,query_name):
    mycursor.execute(query)
    myresult1 = mycursor.fetchall()
    for r in myresult1:
        print(r)
    print("Length of the result for",query_name, ": ", myresult1.__len__())

# %%
def sql_query_explain(query):
    explain_query = f"EXPLAIN {query}"
    mycursor.execute(explain_query)
    explanation_result = mycursor.fetchall()
    for row in explanation_result:
        print(row)

# %%
def sql_query_avg_time(query,num, query_name):
    times = []
    for i in range(num):
        time_i = time.time()
        mycursor.execute(query)
        myresult1 = mycursor.fetchall()
        time_f = time.time()
        times.append(time_f-time_i)
        
    avgtime = sum(times)/x
    print('No optimization:  avg total time SQL-Query',query_name ,' = ', avgtime)

# %% [markdown]
# ## Query 3a - 1

# %% [markdown]
# Esta consulta calcula o salário máximo médio para cada empresa e, em seguida, ordena os resultados por ordem decrescente do salário máximo médio.

# %%
query1 = ("SELECT salary_id, AVG(max_salary) AS avg_max_salary "
          "FROM salaries GROUP BY salary_id ORDER BY avg_max_salary DESC")

# %% [markdown]
# #### Result:

# %%
sql_query_result(query1,"3a-1")
# Out:
# (4514, 500000.0)
# (6612, 450000.0)
# (7163, 400000.0)
# (4537, 345000.0)
# (7174, 271200.0)
# (4536, 264000.0)
# (1425, 250000.0)
# (4549, 250000.0)
# (1438, 243300.0)
# (1440, 243300.0)
# (1416, 234563.0)
# (7137, 220000.0)
# (7165, 220000.0)
# (6628, 218500.0)
# (4554, 215000.0)
# (6655, 210000.0)
# (6643, 205500.0)
# (6625, 200000.0)
# (7162, 194400.0)
# (6654, 191000.0)
# (4531, 190000.0)
# (4516, 185300.0)
# (4545, 185300.0)
# (4597, 185300.0)
# (4598, 185300.0)
# (4599, 185300.0)
# (1397, 175200.0)
# (1422, 175125.0)
# (4520, 170443.40625)
# (6657, 165000.0)
# (1419, 162250.0)
# (1420, 162250.0)
# (1421, 162250.0)
# (7127, 160000.0)
# (4517, 157500.0)
# (4526, 157500.0)
# (4527, 157500.0)
# (4547, 157500.0)
# (4566, 157500.0)
# (4567, 157500.0)
# (4568, 157500.0)
# (4600, 157500.0)
# (4601, 157500.0)
# (4602, 157500.0)
# (4603, 157500.0)
# (4604, 157500.0)
# (7147, 155000.0)
# (6623, 151800.0)
# (1426, 150000.0)
# (7126, 150000.0)
# (7141, 145000.0)
# (4575, 144811.0)
# (7130, 140000.0)
# (6645, 139800.0)
# (6646, 139000.0)
# (4570, 135000.0)
# (4504, 133120.0)
# (4546, 132800.0)
# (4565, 132800.0)
# (1439, 130400.0)
# (4569, 130000.0)
# (4573, 130000.0)
# (6637, 130000.0)
# (7133, 130000.0)
# (7134, 130000.0)
# (6650, 129089.0)
# (4582, 126400.0)
# (4557, 125000.0)
# (4523, 124409.609375)
# (4501, 122951.34375)
# (6658, 122500.0)
# (1415, 120000.0)
# (1427, 120000.0)
# (7129, 120000.0)
# (7132, 120000.0)
# (6627, 118000.0)
# (4550, 117000.0)
# (1432, 115000.0)
# (7128, 110000.0)
# (7157, 110000.0)
# (4560, 108191.203125)
# (6613, 105200.0)
# (4591, 101764.0)
# (1408, 100000.0)
# (7124, 100000.0)
# (6626, 95000.0)
# (7170, 95000.0)
# (6642, 92000.0)
# (4521, 91052.0)
# (6640, 90000.0)
# (4577, 85300.0)
# (1406, 85000.0)
# (4505, 85000.0)
# (4524, 85000.0)
# (1393, 80000.0)
# (4581, 80000.0)
# (7131, 80000.0)
# (7159, 75000.0)
# (4511, 73912.796875)
# (6635, 70865.0)
# (7125, 70000.0)
# (1391, 66000.0)
# (1404, 66000.0)
# (1434, 65000.0)
# (4558, 65000.0)
# (4576, 65000.0)
# (1412, 62500.0)
# (7166, 62500.0)
# (1394, 60000.0)
# (1396, 60000.0)
# (1398, 60000.0)
# (1399, 60000.0)
# (1401, 60000.0)
# (1403, 60000.0)
# (4555, 60000.0)
# (4572, 58500.0)
# (4528, 55000.0)
# (4529, 55000.0)
# (4571, 53000.0)
# (4562, 50000.0)
# (7123, 50000.0)
# (4561, 49968.76953125)
# (7146, 48000.0)
# (4509, 46359.23046875)
# (4594, 45000.0)
# (1402, 14954.0)
# (7154, 9945.0)
# (6647, 90.0)
# (4583, 83.0)
# (6660, 77.0)
# (1436, 73.0)
# (4588, 71.25)
# (1435, 63.0)
# (1407, 59.0)
# (4589, 56.349998474121094)
# (1430, 56.0)
# (1390, 54.63999938964844)
# (1405, 53.61000061035156)
# (1392, 51.88999938964844)
# (4578, 50.0)
# (6617, 48.0)
# (6616, 46.2599983215332)
# (4512, 46.0)
# (4513, 46.0)
# (4539, 46.0)
# (4540, 46.0)
# (4564, 46.0)
# (4519, 45.0)
# (4522, 44.77000045776367)
# (4502, 44.54999923706055)
# (7156, 43.790000915527344)
# (1414, 40.0)
# (1429, 39.58000183105469)
# (4530, 38.0)
# (4556, 38.0)
# (6632, 36.56999969482422)
# (6629, 36.29999923706055)
# (6624, 36.060001373291016)
# (6652, 35.0)
# (7161, 35.0)
# (1418, 33.880001068115234)
# (1411, 33.0)
# (7145, 33.0)
# (6651, 32.0)
# (1424, 31.0)
# (6610, 30.540000915527344)
# (6659, 30.540000915527344)
# (1428, 30.0)
# (4548, 30.0)
# (4551, 30.0)
# (7149, 29.520000457763672)
# (6619, 28.799999237060547)
# (4532, 28.0)
# (6639, 28.0)
# (7171, 27.690000534057617)
# (6633, 27.670000076293945)
# (1395, 27.0)
# (1423, 27.0)
# (1413, 26.899999618530273)
# (4503, 25.6299991607666)
# (4538, 25.6299991607666)
# (4590, 25.6299991607666)
# (1437, 25.600000381469727)
# (6638, 25.43000030517578)
# (4574, 25.0)
# (7151, 24.309999465942383)
# (4552, 24.0)
# (6648, 24.0)
# (7138, 23.719999313354492)
# (7140, 23.719999313354492)
# (6636, 23.6299991607666)
# (7142, 23.290000915527344)
# (6611, 23.25)
# (6615, 23.0)
# (6631, 22.559999465942383)
# (7172, 22.5)
# (6618, 22.100000381469727)
# (1431, 22.0)
# (7139, 21.719999313354492)
# (1417, 21.639999389648438)
# (4595, 21.5)
# (6644, 21.0)
# (1410, 20.459999084472656)
# (1400, 20.0)
# (4553, 19.0)
# (6621, 19.0)
# (6614, 18.5)
# (6656, 18.5)
# (7164, 16.8799991607666)
# (4525, 16.5)
# (4533, 16.5)
# (4543, 16.5)
# (4584, 16.5)
# (4596, 16.5)
# (4507, 12.0)
# (4535, 12.0)
# (7136, 11.5)
# (1409, 0.0)
# (1433, 0.0)
# (4506, 0.0)
# (4508, 0.0)
# (4510, 0.0)
# (4515, 0.0)
# (4518, 0.0)
# (4534, 0.0)
# (4541, 0.0)
# (4542, 0.0)
# (4544, 0.0)
# (4559, 0.0)
# (4563, 0.0)
# (4579, 0.0)
# (4580, 0.0)
# (4585, 0.0)
# (4586, 0.0)
# (4587, 0.0)
# (4592, 0.0)
# (4593, 0.0)
# (6609, 0.0)
# (6620, 0.0)
# (6622, 0.0)
# (6630, 0.0)
# (6634, 0.0)
# (6641, 0.0)
# (6649, 0.0)
# (6653, 0.0)
# (7135, 0.0)
# (7143, 0.0)
# (7144, 0.0)
# (7148, 0.0)
# (7150, 0.0)
# (7152, 0.0)
# (7153, 0.0)
# (7155, 0.0)
# (7158, 0.0)
# (7160, 0.0)
# (7167, 0.0)
# (7168, 0.0)
# (7169, 0.0)
# (7173, 0.0)
# Length of the result for 3a-1 :  259

# %% [markdown]
# #### Explained query

# %%
sql_query_explain(query1)
# Out:
# (1, 'SIMPLE', 'salaries', None, 'index', 'PRIMARY,job_id', 'PRIMARY', '8', None, 259, 100.0, 'Using temporary; Using filesort')

# %% [markdown]
# #### Average time

# %%
sql_query_avg_time(query1,x,"3a-1")
# Out:
# No optimization:  avg total time SQL-Query 3a-1  =  0.003800702095031738

# %% [markdown]
# ## Query 3a - 2

# %% [markdown]
# Esta consulta utiliza uma expressão de tabela comum e a função de janela ROW_NUMBER() para classificar as empresas com base no número de ofertas de emprego em cada localização. O resultado final inclui apenas as empresas com o maior número de ofertas de emprego em cada local.

# %%
query2 = ("WITH ranked_postings AS ("
                     "SELECT company_id, location, ROW_NUMBER() OVER (PARTITION BY location ORDER BY COUNT(*) DESC) AS posting_rank "
                     "FROM job_postings GROUP BY company_id, location)"
                     "SELECT company_id, location FROM ranked_postings WHERE posting_rank = 1;")

# %% [markdown]
# #### Result:

# %%
sql_query_result(query2,"3a-2")
# Out:
# (28615633, 'Aberdeen Proving Ground, MD')
# (1013110, 'Aberdeen, MD')
# (3706049, 'Aberdeen, WA')
# (17226, 'Abilene, TX')
# (2700167, 'Abingdon, VA')
# (3625, 'Abo, MO')
# (115116, 'Acampo, CA')
# (25567, 'Acton, MA')
# (3570660, 'Ada, MI')
# (7064, 'Ada, OK')
# (1482552, 'Addison, IL')
# (77301, 'Addison, TX')
# (27180004, 'Adrian, MI')
# (581824, 'Agoura Hills, CA')
# (1386950, 'Aiken, SC')
# (23182, 'Akron, OH')
# (5323150, 'Alabama, United States')
# (18506580, 'Alabaster, AL')
# (98488356, 'Alachua, FL')
# (8437, 'Alamance, NC')
# (18924711, 'Alameda County, CA')
# (808034, 'Alameda, CA')
# (15472, 'Alamo Heights, TX')
# (2646, 'Alamosa, CO')
# (3558, 'Albany, GA')
# (28409, 'Albany, New York Metropolitan Area')
# (1302410, 'Albany, NY')
# (14542824, 'Albany, OR')
# (18009221, 'Albemarle, NC')
# (2943678, 'Albuquerque-Santa Fe Metropolitan Area')
# (1945473, 'Albuquerque, NM')
# (5755, 'Alburtis, PA')
# (10854676, 'Alden, NY')
# (82153, 'Aledo, TX')
# (13309, 'Alexandria City County, VA')
# (6062532, 'Alexandria, LA')
# (1403, 'Alexandria, VA')
# (77301, 'Algonquin, IL')
# (25081, 'Alhambra, CA')
# (113097, 'Alice, TX')
# (9814, 'Aliso Viejo, CA')
# (121618, 'All Seasons Lake Park, OH')
# (165447, 'Allegan, MI')
# (2251, 'Allen, TX')
# (71904349, 'Allendale, NJ')
# (78114, 'Allentown, PA')
# (20009, 'Allenwood, PA')
# (6592, 'Alliance, OH')
# (10640818, 'Alma, MI')
# (3706049, 'Alpena, MI')
# (1103, 'Alpharetta, GA')
# (11758, 'Alsip, IL')
# (4453, 'Altoona, IA')
# (1703, 'Altoona, PA')
# (3706049, 'Alturas, CA')
# (53252, 'Alvin, TX')
# (315817, 'Amarillo, TX')
# (11824180, 'Ambler, PA')
# (3963605, 'American Fork, UT')
# (683310, 'Ames, IA')
# (16995, 'Amesbury, MA')
# (46000, 'Amherst, NH')
# (28923, 'Amherst, NY')
# (86041588, 'Amityville, NY')
# (12890, 'Ammon, ID')
# (6913, 'Amsterdam, NY')
# (13856, 'Anacortes, WA')
# (3570660, 'Anaheim, CA')
# (26923, 'Anchorage, AK')
# (3469, 'Anderson, SC')
# (15451728, 'Andover, KS')
# (53452, 'Andover, MA')
# (3476, 'Andrews, SC')
# (19368, 'Angels Camp, CA')
# (2562, 'Angleton, TX')
# (1526, 'Ankeny, IA')
# (78636, 'Ann Arbor, MI')
# (1403, 'Annapolis Junction, MD')
# (18062, 'Annapolis, MD')
# (68941, 'Anniston, AL')
# (74994575, 'Anoka, MN')
# (2193256, 'Antigo, WI')
# (2910116, 'Antioch, IL')
# (2252, 'Antioch, TN')
# (82808548, 'Anton Chico, NM')
# (690568, 'Apache Junction, AZ')
# (4324, 'Apex, NC')
# (14832, 'Apollo Beach, FL')
# (74161427, 'Apopka, FL')
# (2646, 'Apple Valley, CA')
# (96180361, 'Apple Valley, MN')
# (6233, 'Appleton, WI')
# (4297, 'Appomattox, VA')
# (4111455, 'Arabi, LA')
# (1668, 'Arcata, CA')
# (55185007, 'Arden Hills, MN')
# (18860134, 'Arden, NC')
# (869141, 'Arizona, United States')
# (1464, 'Arkadelphia, AR')
# (162724, 'Arkansas, United States')
# (598372, 'Arlington Heights, IL')
# (1103, 'Arlington, MA')
# (166680, 'Arlington, TX')
# (1403, 'Arlington, VA')
# (372915, 'Armonk, NY')
# (15473, 'Arnold, MO')
# (43093, 'Artesia, MS')
# (373399, 'Arvada, CO')
# (1103, 'Ashburn, VA')
# (28169, 'Asheville, NC')
# (3570660, 'Ashland, MA')
# (70696, 'Ashland, MT')
# (4798, 'Ashland, VA')
# (2646, 'Ashland, WI')
# (33190802, 'Aspen, CO')
# (35561284, 'Atascadero, CA')
# (162828, 'Atchison, KS')
# (7587370, 'Athens, GA')
# (26205, 'Athens, OH')
# (1945473, 'Athens, TX')
# (1374999, 'Athol, ID')
# (163139, 'Atlanta Metropolitan Area')
# (3558, 'Atlanta, GA')
# (64746547, 'Atlantis, FL')
# (164200, 'Attleboro, MA')
# (1236687, 'Atwater, CA')
# (68796640, 'Auburn Hills, MI')
# (5343, 'Auburn, AL')
# (11056, 'Auburn, CA')
# (31065, 'Auburn, GA')
# (20573, 'Auburn, MA')
# (2562, 'Auburn, MI')
# (1945473, 'Auburn, NY')
# (71575605, 'Auburn, WA')
# (11440, 'Audubon, PA')
# (37235, 'Augusta, GA')
# (2137, 'Augusta, ME')
# (3672, 'Aurora, CO')
# (2736008, 'Aurora, Colorado, United States')
# (35504, 'Aurora, IL')
# (10147, 'Aurora, OH')
# (46000, 'Austell, GA')
# (164249, 'Austin Township, MN')
# (11618, 'Austin, MN')
# (163139, 'Austin, Texas Metropolitan Area')
# (3162, 'Austin, TX')
# (25963, 'Avenel, NJ')
# (283807, 'Aventura, FL')
# (66278935, 'Avon Lake, OH')
# (1103, 'Avon, MA')
# (79892817, 'Avon, MN')
# (85320, 'Avon, NY')
# (3570660, 'Avon, OH')
# (596893, 'Avondale, AZ')
# (162828, 'Avondale, LA')
# (828170, 'Ayer, MA')
# (2701866, 'Bagdad, AZ')
# (14542824, 'Baker, MT')
# (1945473, 'Baker, WV')
# (12820, 'Bakersfield, CA')
# (89989306, 'Bal Harbour, FL')
# (65549321, 'Bala-Cynwyd, PA')
# (2721914, 'Baldwin City, KS')
# (18506580, 'Baldwin Park, CA')
# (22309011, 'Ballwin, MO')
# (5127650, 'Baltimore County, MD')
# (1945473, 'Baltimore, MD')
# (18312164, 'Baltimore, OH')
# (1945473, 'Bangor, ME')
# (41004, 'Banner Elk, NC')
# (13353, 'Baraboo, WI')
# (788707, 'Barberton, OH')
# (18758749, 'Bardstown, KY')
# (32380, 'Bargersville, IN')
# (16726, 'Barstow, CA')
# (10420321, 'Bartlesville, OK')
# (598372, 'Bartlett, IL')
# (16101273, 'Bartlett, TN')
# (1235, 'Bartonville, TX')
# (906762, 'Bartow, FL')
# (1103, 'Basking Ridge, NJ')
# (166572, 'Bastrop, TX')
# (23656, 'Batavia, IL')
# (1511, 'Batavia, NY')
# (39249, 'Batavia, OH')
# (66252, 'Batesville, IN')
# (142560, 'Baton Rouge Metropolitan Area')
# (7587370, 'Baton Rouge, LA')
# (2381, 'Battle Creek, MI')
# (2646, 'Baxter, MN')
# (3180238, 'Bay City, MI')
# (9487, 'Bay Minette, AL')
# (19287, 'Bay St Louis, MS')
# (10517709, 'Bayport, NY')
# (48024, 'Baytown, TX')
# (203053, 'Bear, DE')
# (96180361, 'Beaufort, SC')
# (48024, 'Beaumont, TX')
# (11009726, 'Beaver Dam, WI')
# (15208770, 'Beaver, PA')
# (28974109, 'Beavercreek, OH')
# (79383535, 'Beaverton, OR')
# (14088, 'Beckett Ridge, OH')
# (90198358, 'Beckley, WV')
# (3579761, 'Bedford Park, IL')
# (2268831, 'Bedford, MA')
# (3706049, 'Bedford, PA')
# (96180361, 'Bedford, TX')
# (30823, 'Bedminster, NJ')
# (10769, 'Beeville, TX')
# (13181, 'Bel Air, MD')
# (1769216, 'Belcamp, MD')
# (8710, 'Belfast, ME')
# (75621179, 'Bellaire, TX')
# (22309011, 'Belleville, IL')
# (6592, 'Bellevue, OH')
# (37768, 'Bellevue, WA')
# (7032, 'Bellflower, CA')
# (165422, 'Bellingham, WA')
# (18472079, 'Bellmawr, NJ')
# (1160236, 'Bellows Falls, VT')
# (15941879, 'Belmar, NJ')
# (1273631, 'Belmont, CA')
# (3570660, 'Belmont, MA')
# (10420321, 'Beloit, WI')
# (16157996, 'Belton, MO')
# (570101, 'Beltsville, MD')
# (12434, 'Belvidere, IL')
# (6592, 'Bement, IL')
# (4857, 'Bend, OR')
# (936584, 'Benicia, CA')
# (1703, 'Bennington, VT')
# (80431008, 'Bensalem, PA')
# (4622, 'Benson, MN')
# (68463, 'Benton, AR')
# (2646, 'Benton, IL')
# (2646, 'Bentonville, AR')
# (2073870, 'Bergenfield, NJ')
# (890145, 'Berkeley Heights, NJ')
# (2519, 'Berkeley, CA')
# (5905495, 'Berlin, CT')
# (18506580, 'Berlin, NH')
# (9185, 'Berlin, NJ')
# (2168076, 'Berlin, VT')
# (3500602, 'Berlin, WI')
# (294502, 'Bernardsville, NJ')
# (13499, 'Berwyn, PA')
# (8281, 'Bethesda, MD')
# (15344142, 'Bethlehem, PA')
# (6104, 'Bethpage, NY')
# (79806, 'Beverly Hills, CA')
# (3706049, 'Beverly, MA')
# (14571, 'Bickleton, WA')
# (7410, 'Big Rapids, MI')
# (932563, 'Big Sky Meadow Village, MT')
# (587493, 'Big Spring, TX')
# (18506580, 'Big Stone Gap, VA')
# (37900, 'Billerica, MA')
# (14459, 'Billings, MT')
# (25039553, 'Biloxi, MS')
# (14571, 'Binghamton, NY')
# (157346, 'Birch Run, MI')
# (106584, 'Birmingham, AL')
# (3025562, 'Birmingham, MI')
# (28052, 'Biscoe, NC')
# (629227, 'Bishopville, SC')
# (1103, 'Bismarck, ND')
# (6442470, 'Black Mountain, NC')
# (2480405, 'Blacksburg, SC')
# (166811, 'Blacksburg, VA')
# (163025, 'Blaine, MN')
# (10420321, 'Blaine, WA')
# (1684870, 'Blairsville, GA')
# (81954233, 'Bloomfield Hills, MI')
# (88289095, 'Bloomfield, CT')
# (3706049, 'Bloomfield, NM')
# (91534, 'Bloomingdale, GA')
# (9308035, 'Bloomington–Normal, IL')
# (60561, 'Bloomington, IL')
# (104405, 'Bloomington, IN')
# (344707, 'Bloomington, MN')
# (7795, 'Bloomsburg, PA')
# (10358016, 'Bloomsbury, NJ')
# (18348487, 'Blue Ash, OH')
# (13920, 'Blue Bell, PA')
# (1805509, 'Blue Ridge, VA')
# (167757, 'Blue Springs, MO')
# (6592, 'Bluefield, WV')
# (164880, 'Bluffton, IN')
# (45970, 'Bluffton, SC')
# (808034, 'Blythe, CA')
# (23182, 'Boardman, OH')
# (73731, 'Boardman, OR')
# (166714, 'Boca Raton, FL')
# (49042, 'Boerne, TX')
# (3690, 'Boise, ID')
# (10035810, 'Bolingbrook, IL')
# (37902046, 'Bolivar, MO')
# (1283753, 'Bolivia, NC')
# (9185, 'Bonita Springs, FL')
# (22112, 'Boone, NC')
# (25856, 'Booneville, MS')
# (3706049, 'Boscawen, NH')
# (162513, 'Boston Heights, OH')
# (53713122, 'Boston Run, PA')
# (28978143, 'Boston, MA')
# (4060, 'Boston, Massachusetts, United States')
# (27253457, 'Bothell, WA')
# (43093, 'Boulder City, NV')
# (1441, 'Boulder, CO')
# (1867264, 'Bourne, MA')
# (65384923, 'Bowling Green Metropolitan Area')
# (2646, 'Bowling Green, KY')
# (8437, 'Bowling Green, OH')
# (1497, 'Boxborough, MA')
# (4181808, 'Boydton, VA')
# (1286891, 'Boylston, MA')
# (11227630, 'Boynton Beach, FL')
# (1286891, 'Boynton, GA')
# (5996, 'Bozeman, MT')
# (708393, 'Bradenton, FL')
# (71904349, 'Branchburg, NJ')
# (14749, 'Branchville, NJ')
# (79458773, 'Brandon, FL')
# (71904349, 'Branford, CT')
# (7795, 'Braselton, GA')
# (53508, 'Brawley, CA')
# (79560, 'Brea, CA')
# (526607, 'Breckenridge Hills, MO')
# (220336, 'Breckenridge, CO')
# (8017, 'Brecksville, OH')
# (89567861, 'Bremerton, WA')
# (166753, 'Brenham, TX')
# (30755, 'Brentwood, CA')
# (3249631, 'Brentwood, NY')
# (7795, 'Brentwood, TN')
# (1441, 'Bridgeport, AL')
# (2988, 'Bridgeport, CT')
# (61352, 'Bridgeport, TX')
# (2445, 'Bridgeport, WV')
# (1770225, 'Bridgeton, MO')
# (887776, 'Bridgeview, IL')
# (1339209, 'Bridgeville, PA')
# (1680, 'Bridgewater, NJ')
# (1087250, 'Bridgman, MI')
# (1471368, 'Bridgton, ME')
# (164376, 'Brier, WA')
# (4128, 'Brighton, CO')
# (50668, 'Brighton, MI')
# (157237, 'Brimfield, OH')
# (3693158, 'Brisbane, CA')
# (2073870, 'Bristol County, MA')
# (18921814, 'Bristol, CT')
# (65878041, 'Bristol, IN')
# (3109444, 'Bristol, PA')
# (1103, 'Bristol, TN')
# (15473, 'Bristow, VA')
# (2908367, 'Britton, SD')
# (41102, 'Broadview, IL')
# (7413, 'Brockton, MA')
# (40658652, 'Broken Arrow, OK')
# (21337, 'Bronx, NY')
# (25461, 'Brook Park, OH')
# (4918, 'Brookfield, WI')
# (999245, 'Brookline, MA')
# (1293049, 'Brooklyn Park, MN')
# (6104, 'Brooklyn, NY')
# (3252, 'Brooklyn, OH')
# (5195, 'Brookshire, TX')
# (1104193, 'Brooksville, FL')
# (164880, 'Brooktondale, NY')
# (73974, 'Brookville, OH')
# (2238, 'Broomfield, CO')
# (1410985, 'Brownsburg, IN')
# (22309011, 'Brownstown, MI')
# (14542824, 'Brownsville, TX')
# (9460096, 'Brownwood, TX')
# (808034, 'Brunswick, GA')
# (1703, 'Brunswick, ME')
# (76171420, 'Brunswick, TN')
# (4556, 'Bryan, TX')
# (660180, 'Bryant, AR')
# (11056, 'Bryn Mawr, PA')
# (7099708, 'Buckeye Lake, OH')
# (4128, 'Buckeye, AZ')
# (85123, 'Buda, TX')
# (166572, 'Buena Park, CA')
# (2652881, 'Buena, NJ')
# (10420321, 'Buffalo Grove, IL')
# (10894709, 'Buffalo-Niagara Falls Area')
# (164798, 'Buffalo, NY')
# (120240, 'Buffalo, WY')
# (1729578, 'Buford, GA')
# (46000, 'Bullhead City, AZ')
# (6979, 'Buras, LA')
# (29322289, 'Burbank, CA')
# (13074, 'Burien, WA')
# (10667, 'Burlingame, CA')
# (28978143, 'Burlington, MA')
# (18860134, 'Burlington, NC')
# (28149455, 'Burlington, NJ')
# (19107, 'Burlington, VT')
# (4324, 'Burlington, WA')
# (11056, 'Burnsville, MN')
# (1022308, 'Burrillville, RI')
# (12787, 'Butner, NC')
# (4822178, 'Byhalia, MS')
# (165472, 'Byron, GA')
# (10141, 'Cabazon, CA')
# (4324, 'Caddo Mills, TX')
# (1668, 'Cadillac, MI')
# (6593, 'Calabasas, CA')
# (856720, 'Caldwell, ID')
# (3570660, 'Caledonia, MI')
# (14287, 'Calera, AL')
# (315817, 'Calhoun, GA')
# (601919, 'California, United States')
# (163883, 'Calistoga, CA')
# (3681, 'Calvert, AL')
# (1274529, 'Camarillo, CA')
# (3570660, 'Camas, WA')
# (1441, 'Cambridge, MA')
# (64923472, 'Cambridge, MD')
# (1511, 'Cambridge, MN')
# (11402317, 'Camden, NJ')
# (29579, 'Camelback, California, United States')
# (28669777, 'Cameron, TX')
# (3658, 'Camp Hill, PA')
# (634422, 'Campbell, CA')
# (17937, 'Campbell, FL')
# (34683141, 'Canby, OR')
# (2701, 'Candler, NC')
# (258644, 'Cannon Falls, MN')
# (12669435, 'Canon City, CO')
# (3706049, 'Canton, GA')
# (28597931, 'Canton, MA')
# (12842, 'Canton, MI')
# (163828, 'Canton, NC')
# (164245, 'Canton, OH')
# (9185, 'Cantonment, FL')
# (2646, 'Canyon, TX')
# (25039398, 'Cape Canaveral, FL')
# (15691, 'Cape Coral Metropolitan Area')
# (283513, 'Cape Coral, FL')
# (14542824, 'Cape Girardeau, MO')
# (3706049, 'Cape May Court House, NJ')
# (72483, 'Capistrano Beach, CA')
# (981412, 'Capitan, NM')
# (2247, 'Capitol Heights, MD')
# (31815, 'Capitola, CA')
# (79042201, 'Capron, VA')
# (202443, 'Carbondale, PA')
# (62424, 'Cardiff-by-the-Sea, CA')
# (10877849, 'Carlisle, PA')
# (9814, 'Carlsbad, CA')
# (209610, 'Carlsbad, NM')
# (487174, 'Carmel, IN')
# (2646, 'Carmi, IL')
# (1468, 'Carmichaels, PA')
# (4128, 'Carnegie, PA')
# (3180238, 'Caro, MI')
# (55057585, 'Carol Stream, IL')
# (632911, 'Carpinteria, CA')
# (23858, 'Carrollton, GA')
# (4768, 'Carrollton, TX')
# (2137, 'Carson City, NV')
# (808034, 'Cartersville, GA')
# (57978, 'Carthage, MO')
# (28669777, 'Caruthersville, MO')
# (432241, 'Cary, NC')
# (214960, 'Casa Grande, AZ')
# (18506580, 'Casper, WY')
# (86639237, 'Caspian, MI')
# (74985, 'Castle Rock, CO')
# (808034, 'Castro Valley, CA')
# (220336, 'Cathedral City, CA')
# (444038, 'Catskill, NY')
# (4453, 'Cayce, SC')
# (23410, 'Cedar City, UT')
# (3240, 'Cedar Falls, IA')
# (28149455, 'Cedar Grove, NJ')
# (2251, 'Cedar Hill, TX')
# (3099084, 'Cedar Lake, IN')
# (1505, 'Cedar Rapids, IA')
# (808034, 'Centennial, CO')
# (20573, 'Centerville, TN')
# (2646, 'Central City, KY')
# (15241130, 'Central Islip, NY')
# (493453, 'Central, SC')
# (6913, 'Centralia, WA')
# (3706049, 'Centre Hall, PA')
# (15472, 'Centreville, VA')
# (609279, 'Ceres, CA')
# (5153, 'Cerritos, CA')
# (69601172, 'Chadds Ford, PA')
# (378234, 'Chalfont, PA')
# (73013724, 'Chambersburg, PA')
# (22208562, 'Champaign, IL')
# (26923, 'Champlin, MN')
# (104405, 'Chandler, AZ')
# (8034, 'Chanhassen, MN')
# (14255, 'Channahon, IL')
# (1403, 'Chantilly, VA')
# (166587, 'Chapel Hill, NC')
# (157353, 'Chappaqua, NY')
# (2936694, 'Charles City, IA')
# (2908367, 'Charleston, IL')
# (10877848, 'Charleston, SC')
# (51586544, 'Charleston, South Carolina Metropolitan Area')
# (1557409, 'Charleston, South Carolina, United States')
# (1043, 'Charleston, WV')
# (163139, 'Charlotte Metro')
# (814025, 'Charlotte, AR')
# (18425303, 'Charlotte, NC')
# (35651393, 'Charlotte, North Carolina, United States')
# (4298, 'Charlottesville, VA')
# (18106262, 'Charter Oak, CA')
# (10295, 'Chaska, MN')
# (164931, 'Chatham, IL')
# (2855513, 'Chattanooga, TN')
# (3450, 'Chelmsford, MA')
# (6756178, 'Chelsea, MI')
# (13074, 'Cheney, WA')
# (305287, 'Cheraw, SC')
# (4872230, 'Cherry Hill, NJ')
# (1317726, 'Chesapeake, VA')
# (1557409, 'Cheshire, CT')
# (78378963, 'Chester County, PA')
# (64923472, 'Chester, MD')
# (17233, 'Chester, PA')
# (1945473, 'Chester, SC')
# (46000, 'Chester, VA')
# (10974065, 'Chesterfield Township, MI')
# (884316, 'Chesterfield, MI')
# (248599, 'Chesterfield, MO')
# (1931371, 'Chestnut Hill, MA')
# (49042, 'Chevy Chase, MD')
# (70696, 'Cheyenne, WY')
# (2430668, 'Chicago Heights, IL')
# (36749, 'Chicago Ridge, IL')
# (2649, 'Chicago, IL')
# (12332, 'Chico, CA')
# (13542, 'Chicopee, MA')
# (14542824, 'Chillicothe, OH')
# (2646, 'Chilton, WI')
# (30755, 'Chino, CA')
# (42166, 'Chippewa Falls, WI')
# (3677, 'Chisago City, MN')
# (12890, 'Christiana, DE')
# (3617422, 'Christiansburg, VA')
# (14606618, 'Chula Vista, CA')
# (167757, 'Cicero, IL')
# (8781, 'Cincinnati Metropolitan Area')
# (2432, 'Cincinnati, OH')
# (107434, 'Circleville, OH')
# (4453, 'City of Industry, CA')
# (22523, 'City Park, UT')
# (34424, 'Clackamas, OR')
# (1703, 'Claremont, NH')
# (1908498, 'Claremore, OK')
# (10854676, 'Clarence, NY')
# (15434, 'Clarinda, IA')
# (1703, 'Clarion, PA')
# (28597765, 'Clarksboro, NJ')
# (10514179, 'Clarksburg, WV')
# (243836, 'Clarkston, MI')
# (7197, 'Clarksville, TN')
# (2301992, 'Claymont, DE')
# (2701866, 'Claypool, AZ')
# (164376, 'Clayton, MO')
# (41004, 'Clayton, NC')
# (1900, 'Clear Lake, IA')
# (1344, 'Clearwater, FL')
# (71316538, 'Clearwater, Florida, United States')
# (550530, 'Cleburne, TX')
# (1058190, 'Clemson, SC')
# (73202971, 'Clermont, FL')
# (3549, 'Cleveland Heights, OH')
# (45346, 'Cleveland, GA')
# (2203697, 'Cleveland, MS')
# (777243, 'Cleveland, OH')
# (9185, 'Cleveland, TN')
# (6979, 'Cliffwood, NJ')
# (18860134, 'Clifton Park, NY')
# (42134, 'Clifton, NJ')
# (20088, 'Clifton, TN')
# (4019848, 'Clinton Township, MI')
# (35504315, 'Clinton, IA')
# (2646, 'Clinton, IN')
# (32758, 'Clinton, MA')
# (1945473, 'Clinton, MD')
# (3534, 'Clinton, MS')
# (1211063, 'Clinton, NC')
# (12534, 'Clinton, NJ')
# (9676, 'Clinton, OK')
# (9596847, 'Clovis, CA')
# (1211063, 'Clyde, NC')
# (65294553, 'Clyde, NY')
# (8141, 'Coal City, IN')
# (76127808, 'Coatesville, PA')
# (3558, 'Cobb County, GA')
# (6176, 'Coconut Creek, FL')
# (5292867, "Coeur d'Alene, ID")
# (14658457, 'Cofield, NC')
# (19107, 'Colchester, VT')
# (808034, 'Coldwater, MI')
# (2973906, 'College Park, GA')
# (45575, 'College Park, MD')
# (4556, 'College Station, TX')
# (1399, 'Collegeville, PA')
# (82315512, 'Colleyville, TX')
# (72801, 'Collierville, TN')
# (90413667, 'Collins, MS')
# (9643, 'Collinsville, IL')
# (166774, 'Colonial Heights, VA')
# (39203, 'Colorado Springs, CO')
# (601919, 'Colorado, United States')
# (18506580, 'Colton, CA')
# (7947, 'Columbia, MD')
# (5442, 'Columbia, MO')
# (1943848, 'Columbia, MS')
# (23379, 'Columbia, PA')
# (12606850, 'Columbia, SC')
# (78124, 'Columbia, South Carolina Metropolitan Area')
# (7032, 'Columbia, TN')
# (92966191, 'Columbus metropolitan area, OH')
# (19180, 'Columbus, GA')
# (132002, 'Columbus, IN')
# (1943848, 'Columbus, MS')
# (2646, 'Columbus, NE')
# (8390, 'Columbus, OH')
# (200465, 'Columbus, Ohio Metropolitan Area')
# (2712856, 'Columbus, Ohio, United States')
# (5618, 'Commerce, CA')
# (537246, 'Concord, CA')
# (58602, 'Concord, MA')
# (49042, 'Concord, NC')
# (3706049, 'Concord, NH')
# (20088, 'Conneaut, OH')
# (64272643, 'Connecticut, United States')
# (71904349, 'Conover, NC')
# (7479, 'Conroe, TX')
# (17233, 'Conshohocken, PA')
# (14841964, 'Conway, AR')
# (21444, 'Conway, SC')
# (46000, 'Conyers, GA')
# (9499, 'Cool Spring, NC')
# (7929696, 'Coon Rapids, MN')
# (8817, 'Coopersburg, PA')
# (111108, 'Coos Bay, OR')
# (1515366, 'Coppell, TX')
# (15656, 'Coral Gables, FL')
# (14542824, 'Coral Springs, FL')
# (21041, 'Coralville, IA')
# (1463, 'Coraopolis, PA')
# (39540, 'Cordele, GA')
# (1945473, 'Cordova, AK')
# (6738, 'Core, WV')
# (12446, 'Corinth, MS')
# (9499, 'Cornelia, GA')
# (88289095, 'Corning, NY')
# (2074192, 'Corona del Mar, CA')
# (140581, 'Corona, CA')
# (35446044, 'Corpus Christi, TX')
# (165725, 'Corte Madera, CA')
# (6979, 'Cortland, NY')
# (18506580, 'Cortlandt Manor, NY')
# (14542824, 'Corvallis, OR')
# (1286891, 'Corydon, IA')
# (98209783, 'Cos Cob, CT')
# (602239, 'Coshocton, OH')
# (3316709, 'Costa Mesa, CA')
# (165422, 'Cottage Grove, OR')
# (104405, 'Cottleville, MO')
# (5343, 'Cottondale, AL')
# (34218836, 'Cottonwood, AZ')
# (1945473, 'Council Bluffs, IA')
# (14255, 'Country Club Hills, IL')
# (71904349, 'Coventry, RI')
# (468782, 'Covington, GA')
# (72483, 'Covington, KY')
# (3143932, 'Covington, LA')
# (808034, 'Covington, WA')
# (3706049, 'Coxsackie, NY')
# (2247, 'Cranberry Township, PA')
# (1284978, 'Crane, IN')
# (104396, 'Cranford, NJ')
# (2252, 'Cranston, RI')
# (14287, 'Crawford, TX')
# (12820, 'Creedmoor, NC')
# (2646, 'Crescent City, CA')
# (5242206, 'Crescent City, FL')
# (2646, 'Creston, IA')
# (89877420, 'Crestview, FL')
# (2615835, 'Crete, IL')
# (162828, 'Crete, NE')
# (468782, 'Creve Coeur, MO')
# (4031183, 'Cross Junction, VA')
# (15080, 'Cross Lanes, WV')
# (165294, 'Crown Point, IN')
# (1375621, 'Crystal City, MO')
# (113097, 'Crystal City, TX')
# (10420321, 'Crystal Lake, IL')
# (76171420, 'Crystal Springs, MS')
# (53959, 'Cudahy, WI')
# (4297, 'Culpeper, VA')
# (28439179, 'Culver City, CA')
# (3706049, 'Cumberland, MD')
# (5027745, 'Cumming, GA')
# (8299, 'Cupertino, CA')
# (7032, 'Cutler Bay, FL')
# (1263534, 'Cuyahoga Falls, OH')
# (25081, 'Cypress, CA')
# (9401140, 'Cypress, TX')
# (3570660, 'Dacula, GA')
# (34902814, 'Daggett, CA')
# (104405, 'Dakota Dunes, SD')
# (630847, 'Dakota, IL')
# (16995, 'Daleville, VA')
# (28893, 'Dallas County, TX')
# (76947396, 'Dallas-Fort Worth Metroplex')
# (1703, 'Dallas, GA')
# (17882, 'Dallas, Texas, United States')
# (6250, 'Dallas, TX')
# (269675, 'Dallastown, PA')
# (165472, 'Dalton, GA')
# (856720, 'Daly City, CA')
# (9177279, 'Damascus, MD')
# (35571114, 'Danbury, CT')
# (163253, 'Dania, FL')
# (8359, 'Danvers, MA')
# (1945473, 'Danville, IL')
# (7788794, 'Danville, PA')
# (9229, 'Danville, VA')
# (166551, 'Dardanelle, AR')
# (51701193, 'Dartmouth, MA')
# (688958, 'Dauphin County, PA')
# (18506580, 'Davenport, FL')
# (2736008, 'Davenport, IA')
# (64259963, 'Davidson, NC')
# (14542824, 'Davie, FL')
# (533823, 'Dawsonville, GA')
# (15259054, 'Dayton, OH')
# (164527, 'Dayton, TN')
# (861806, 'Daytona Beach, FL')
# (2193256, 'De Pere, WI')
# (68049148, 'De Witt, IA')
# (165299, 'Dearborn Heights, MI')
# (71904349, 'Dearborn, MI')
# (45716, 'Death Valley, CA')
# (2396310, 'Decatur, AL')
# (20009, 'Decatur, GA')
# (5553, 'Decatur, IL')
# (1943848, 'Decatur, MS')
# (4725, 'Decorah, IA')
# (9862, 'Dedham, MA')
# (1224492, 'Deephaven, MN')
# (22523, 'Deer Park, IL')
# (48024, 'Deer Park, TX')
# (49042, 'Deerfield Beach, FL')
# (71350, 'Deerfield, IL')
# (162723, 'DeKalb, IL')
# (2949451, 'Del Mar, CA')
# (82903338, 'DeLand, FL')
# (64980, 'Delano, CA')
# (23300, 'Delaware, OH')
# (162724, 'Delaware, United States')
# (2664556, 'Delmar, NY')
# (1781229, 'Delphi, IN')
# (1666657, 'Delray Beach, FL')
# (14542824, 'Delta, CO')
# (21667, 'Deltona, FL')
# (3706049, 'Demorest, GA')
# (21667, 'Denison, IA')
# (1497977, 'Denison, TX')
# (74994575, 'Denton, MD')
# (7795, 'Denton, TX')
# (89877420, 'Denver City, UT')
# (2652881, 'Denver Metropolitan Area')
# (3135, 'Denver, CO')
# (14611, 'Denver, Colorado, United States')
# (81480274, 'Denver, IN')
# (8807, 'Denver, NC')
# (39472, 'Denville, NJ')
# (3182370, 'Dermott, AR')
# (311841, 'Derry, NH')
# (17233, 'Derwood, MD')
# (3789, 'Des Moines Metropolitan Area')
# (265869, 'Des Moines, IA')
# (72483, 'Des Moines, WA')
# (31896, 'Des Plaines, IL')
# (92750, 'DeSoto, TX')
# (16733, 'Destin, FL')
# (37404866, 'Detroit Metropolitan Area')
# (7357, 'Detroit, MI')
# (23279, 'Devens, MA')
# (11056, 'Dexter, MI')
# (120859, 'Diamond Bar, CA')
# (3600, 'Dickinson, ND')
# (9184151, 'Dickson, TN')
# (14542824, 'Dillon, MT')
# (426121, 'Dimondale, MI')
# (2700167, 'Disputanta, VA')
# (28974109, 'District of Columbia, United States')
# (485407, 'Dobbs Ferry, NY')
# (104895, 'Dodge Center, MN')
# (164621, 'Dodge City, KS')
# (6083, 'Dodgeville, WI')
# (1151910, 'Doral, FL')
# (164880, 'Dorchester, MA')
# (3242, 'Dothan, AL')
# (2646, 'Douglas, GA')
# (7886, 'Douglasville, GA')
# (75997, 'Dover, DE')
# (7795, 'Dover, NH')
# (39472, 'Dover, NJ')
# (6913, 'Dowagiac, MI')
# (3612137, 'Downers Grove, IL')
# (3625, 'Downey, CA')
# (27055364, 'Downingtown, PA')
# (33264, 'Draper, UT')
# (165716, 'Dresden, TN')
# (1943848, 'Dripping Springs, TX')
# (20009, 'Drums, PA')
# (163079, 'Duarte, CA')
# (22561, 'Dublin, CA')
# (28209, 'Dublin, OH')
# (2087, 'Dublin, VA')
# (35504315, 'Dubuque, IA')
# (163690, 'Dudley, MA')
# (22132, 'Dulles Town Center, VA')
# (2470025, 'Dulles, VA')
# (11240, 'Duluth, GA')
# (1511, 'Duluth, MN')
# (3570660, 'Dumfries, VA')
# (2562128, 'Duncan, OK')
# (10954, 'Duncan, SC')
# (3658, 'Duncannon, PA')
# (23769122, 'Duncansville, PA')
# (62923, 'Dunn, NC')
# (30823, 'Dunwoody, GA')
# (10420321, 'Durham, CT')
# (22026, 'Durham, NC')
# (307494, 'Durham, NH')
# (12446, 'Eagan, MN')
# (10667, 'Eagle Mountain, UT')
# (7032, 'Eagle Pass, TX')
# (167757, 'Eagle, ID')
# (80911138, 'East Aurora, NY')
# (3570660, 'East Brunswick, NJ')
# (6176, 'East Dennis, MA')
# (80030090, 'East Durham, NY')
# (12890, 'East Grand Forks, MN')
# (88289095, 'East Hanover, NJ')
# (14632005, 'East Hartford, CT')
# (8795, 'East Lansing, MI')
# (5368909, 'East Longmeadow, MA')
# (167757, 'East Meadow, NY')
# (56313852, 'East Moline, IL')
# (33515668, 'East Norriton, PA')
# (19534, 'East Orange, NJ')
# (163883, 'East Palo Alto, CA')
# (1703, 'East Peoria, IL')
# (20573, 'East Providence, RI')
# (7471, 'East Rutherford, NJ')
# (32727, 'East St Louis, IL')
# (42304017, 'East Stoneham, ME')
# (82090049, 'East Syracuse, NY')
# (49042, 'Easton, MD')
# (3706049, 'Easton, PA')
# (334135, 'Eastpointe, MI')
# (6592, 'Eaton, OH')
# (65294553, 'Eau Claire, WI')
# (4674, 'Eddystone, PA')
# (157346, 'Eden Prairie, MN')
# (157353, 'Edgewater, NJ')
# (1403, 'Edgewood, MD')
# (11834, 'Edgewood, NY')
# (1293049, 'Edina, MN')
# (2640631, 'Edinboro, PA')
# (1557409, 'Edison, NJ')
# (77301, 'Edmond, OK')
# (2619961, 'Edwards, CA')
# (71575605, 'Edwardsville, IL')
# (9185, 'Egg Harbor, NJ')
# (3967883, 'Eglin Air Force Base, FL')
# (34218836, 'El Centro, CA')
# (7032, 'El Cerrito, CA')
# (3570660, 'El Dorado Hills, CA')
# (91161992, 'El Dorado, AR')
# (26873, 'El Monte, CA')
# (18924711, 'El Paso County, TX')
# (4029554, 'El Paso, TX')
# (1505, 'El Segundo, CA')
# (437225, 'Elgin, IL')
# (204770, 'Elgin, SC')
# (82291171, 'Elizabeth City, NC')
# (15626530, 'Elizabethtown, KY')
# (5887, 'Elizabethtown, PA')
# (10420321, 'Elk Grove Village, IL')
# (10696913, 'Elk Grove, CA')
# (2973906, 'Elkhart County, IN')
# (153293, 'Elkhart, IN')
# (11876, 'Elko, NV')
# (1486, 'Elkton, VA')
# (922640, 'Ellenville, NY')
# (16710, 'Ellettsville, IN')
# (49042, 'Ellicott City, MD')
# (77301, 'Ellisville, MO')
# (165034, 'Elma, NY')
# (5112, 'Elmendorf, TX')
# (11825945, 'Elmer, NJ')
# (1442109, 'Elmhurst, IL')
# (1087079, 'Elmira, NY')
# (11758, 'Elmsford, NY')
# (10420321, 'Elmwood Park, IL')
# (14255, 'Elwood, IL')
# (34821, 'Elwyn, PA')
# (4822178, 'Elyria, OH')
# (982614, 'Emeryville, CA')
# (18506580, 'Emmett, ID')
# (3043021, 'Emmitsburg, MD')
# (5749, 'Encinitas, CA')
# (1881, 'Endicott, NY')
# (4997572, 'Enfield, CT')
# (98396367, 'Englewood Cliffs, NJ')
# (1947586, 'Englewood, CO')
# (16163783, 'Englewood, OH')
# (9170, 'Ennis, TX')
# (16690, 'Enon, OH')
# (90413667, 'Enterprise, AL')
# (808034, 'Enumclaw, WA')
# (28498, 'Ephrata, PA')
# (18923058, 'Erie-Meadville Area')
# (65294553, 'Erie, PA')
# (289310, 'Erlanger, KY')
# (683310, 'Escanaba, MI')
# (20009, 'Escondido, CA')
# (112168, 'Essex Junction, VT')
# (13658, 'Estacada, OR')
# (20088, 'Estancia, NM')
# (937112, 'Estero, FL')
# (1945473, 'Euclid, OH')
# (165422, 'Eugene, OR')
# (166572, 'Euless, TX')
# (1945473, 'Eureka, CA')
# (7795, 'Evans, NY')
# (3196, 'Evanston, IL')
# (15259054, 'Evansville, IN')
# (570550, 'Evendale, OH')
# (808034, 'Everett, WA')
# (5067678, 'Ewa Gentry, HI')
# (2203697, 'Ewing, NJ')
# (1901345, 'Excelsior, MN')
# (3242, 'Exeter, CA')
# (92681040, 'Fair Lawn, NJ')
# (1945473, 'Fairbanks, AK')
# (5725, 'Fairborn, OH')
# (56670, 'Fairburn, GA')
# (10420321, 'Fairfax Station, VA')
# (2113831, 'Fairfax, VA')
# (2274551, 'Fairfield, CA')
# (808034, 'Fairfield, CT')
# (2646, 'Fairfield, IA')
# (33264, 'Fairfield, NJ')
# (90198358, 'Fairfield, OH')
# (2646, 'Fairmont, MN')
# (5749, 'Fairview Heights, IL')
# (1681, 'Faison, NC')
# (95985, 'Falls Church, VA')
# (7384, 'Far-A-Field, PA')
# (70560, 'Fargo-Moorhead')
# (1374310, 'Fargo, ND')
# (1235, 'Faribault, MN')
# (295644, 'Farmers Branch, TX')
# (347410, 'Farmersburg, IN')
# (6440, 'Farmingdale, NJ')
# (10599076, 'Farmingdale, NY')
# (69234316, 'Farmington Hills, MI')
# (1286891, 'Farmington, CT')
# (8455, 'Farmington, MI')
# (808034, 'Farmington, NM')
# (22523, 'Farmington, UT')
# (19142259, 'Fayetteville, AR')
# (5749, 'Fayetteville, GA')
# (656981, 'Fayetteville, NC')
# (56119363, 'Feasterville, PA')
# (6487, 'Federal Way, WA')
# (12534, 'Fenton, MO')
# (167757, 'Fernandina Beach, FL')
# (7064, 'Festus, MO')
# (166551, 'Finney County, KS')
# (15259054, 'Fishers, IN')
# (4297, 'Fishersville, VA')
# (25179038, 'Fishkill, NY')
# (34656475, 'Fitchburg, MA')
# (15139, 'Flagstaff, AZ')
# (808034, 'Fleming Island, FL')
# (380752, 'Flemington, NJ')
# (581027, 'Flint, MI')
# (1183247, 'Florence County, SC')
# (60951108, 'Florence, AL')
# (76440728, 'Florence, KY')
# (879871, 'Florence, MA')
# (51586544, 'Florence, SC')
# (586645, 'Florham Park, NJ')
# (14542824, 'Florida, NY')
# (11056, 'Florida, United States')
# (86265278, 'Flower Mound, TX')
# (36569, 'Flowery Branch, GA')
# (72483, 'Flowood, MS')
# (10072, 'Folsom, CA')
# (13353, 'Fond du Lac, WI')
# (64510, 'Fontana, CA')
# (8024, 'Fordland, MO')
# (37768, 'Forest City, NC')
# (6176, 'Forest Hill, MD')
# (1463, 'Forest Home, NY')
# (1511, 'Forest Lake, MN')
# (18043, 'Forest Park, IL')
# (12446, 'Forsyth, IL')
# (894572, 'Fort Belvoir, VA')
# (1403, 'Fort Bragg, North Carolina, United States')
# (3072, 'Fort Collins, CO')
# (14542824, 'Fort Defiance, VA')
# (3672, 'Fort Detrick, MD')
# (164451, 'Fort Dodge, IA')
# (5396873, 'Fort George G. Meade, MD')
# (166572, 'Fort Gratiot, MI')
# (25039398, 'Fort Irwin, CA')
# (15133237, 'Fort Kent, ME')
# (777243, 'Fort Lauderdale, FL')
# (5471, 'Fort Lawn, SC')
# (3994, 'Fort Lee, NJ')
# (31065, 'Fort Leonard Wood, MO')
# (3493, 'Fort Madison, IA')
# (1403, 'Fort Meade, MD')
# (5294, 'Fort Mill, SC')
# (333785, 'Fort Mitchell, KY')
# (1235, 'Fort Morgan, CO')
# (6609, 'Fort Myer Heights, VA')
# (72483, 'Fort Myers Beach, FL')
# (3220813, 'Fort Myers, FL')
# (52642826, 'Fort Pierce, FL')
# (19028770, 'Fort Riley, KS')
# (1185, 'Fort Smith, AR')
# (43093, 'Fort Stockton, TX')
# (808034, 'Fort Thomas, KY')
# (481862, 'Fort Valley, GA')
# (4028380, 'Fort Walton Beach, FL')
# (13181, 'Fort Washington, MD')
# (61252, 'Fort Washington, PA')
# (1505, 'Fort Wayne, IN')
# (94355, 'Fort Worth, TX')
# (163993, 'Foster City, CA')
# (20282677, 'Fountain Valley, CA')
# (15139, 'Fowler, CA')
# (10420321, 'Foxborough (Foxboro), MA')
# (77688, 'Foxborough, MA')
# (5121, 'Framingham, MA')
# (11752085, 'Franconia, VA')
# (86321483, 'Frankfort, KY')
# (1850810, 'Franklin, MA')
# (321986, 'Franklin, NH')
# (1852454, 'Franklin, TN')
# (3242, 'Franklin, VA')
# (2562128, 'Franklin, WI')
# (11056, 'Frederick County, MD')
# (11788646, 'Frederick, MD')
# (8479403, 'Fredericksburg, VA')
# (11088832, 'Fredonia, NY')
# (230463, 'Free Home, GA')
# (580089, 'Freeburg, IL')
# (6913, 'Freedom, CA')
# (9814, 'Freedom, PA')
# (9210946, 'Freehold, NJ')
# (93254, 'Freeland, MI')
# (1344, 'Freeport, IL')
# (37845, 'Freeport, ME')
# (48024, 'Freeport, TX')
# (5107, 'Fremont, CA')
# (808034, 'Fremont, California, United States')
# (53708, 'Fremont, NE')
# (27180004, 'Frenchtown, MI')
# (743843, 'Fresno County, CA')
# (2300, 'Fresno, CA')
# (6979, 'Fridley, MN')
# (383161, 'Friendswood, TX')
# (8221, 'Frisco, TX')
# (5343, 'Front Royal, VA')
# (808034, 'Fullerton, CA')
# (2059, 'Fuquay-Varina, NC')
# (28132450, 'Gadsden, AL')
# (2230, 'Gaffney, SC')
# (248184, 'Gahanna, OH')
# (9286450, 'Gainesville, FL')
# (9499, 'Gainesville, GA')
# (3570660, 'Gainesville, VA')
# (1603, 'Gaithersburg, MD')
# (18009221, 'Galesburg, IL')
# (2375692, 'Galesburg, MI')
# (25017, 'Gallatin, TN')
# (903710, 'Gallup, NM')
# (2271, 'Galt, CA')
# (16263, 'Galveston, TX')
# (9714055, 'Gap, PA')
# (17233, 'Garciasville, TX')
# (69989, 'Garden City, GA')
# (7795, 'Garden City, KS')
# (6913, 'Garden City, MI')
# (3360328, 'Garden City, NY')
# (808034, 'Garden Grove, CA')
# (96254, 'Gardena, CA')
# (95062508, 'Gardner, KS')
# (9814, 'Gardner, MA')
# (28647688, 'Garfield Heights, OH')
# (9391120, 'Garland, TX')
# (163828, 'Garner, NC')
# (581027, 'Gary, IN')
# (96180361, 'Gastonia, NC')
# (35121, 'Gaylord, MN')
# (19637, 'Geismar, LA')
# (5343, 'Geneva, AL')
# (24211, 'Geneva, IL')
# (497515, 'Genoa, OH')
# (2908367, 'Georgetown, DE')
# (2107, 'Georgetown, KY')
# (27152943, 'Georgetown, TX')
# (1016, 'Georgia, United States')
# (77022728, 'Germantown, MD')
# (60836398, 'Germantown, TN')
# (83051748, 'Germantown, WI')
# (18777798, 'Germany')
# (2875, 'Getzville, NY')
# (80829889, 'Gibsonia, PA')
# (13074, 'Gig Harbor, WA')
# (4167, 'Gilbert, AZ')
# (225343, 'Gilbert, PA')
# (1668, 'Gillette, WY')
# (1628878, 'Glasgow, DE')
# (4674, 'Glassboro, NJ')
# (14749, 'Glastonbury, CT')
# (1943848, 'Glen Allen, VA')
# (77499, 'Glen Burnie, MD')
# (696365, 'Glen Carbon, IL')
# (166360, 'Glen, MS')
# (27254190, 'Glendale, AZ')
# (808034, 'Glendale, CA')
# (28647688, 'Glendive, MT')
# (16263, 'Glenmont, NY')
# (2430668, 'Glenpool, OK')
# (3570660, 'Glenside, PA')
# (71982274, 'Glenview, IL')
# (165697, 'Glenwood Springs, CO')
# (2018, 'Gloucester, MA')
# (808034, 'Gloucester, VA')
# (35571114, 'Gold Canyon, AZ')
# (411814, 'Golden Valley, MN')
# (11311, 'Golden, CO')
# (18506580, 'Goldsboro, NC')
# (5275, 'Goleta, CA')
# (2646, 'Gonzales, TX')
# (3015, 'Goodland, KS')
# (19024424, 'Goodlettsville, TN')
# (28646687, 'Goodwell, OK')
# (163079, 'Goodyear, AZ')
# (1087079, 'Goshen, NY')
# (65294553, 'Grafton, OH')
# (422503, 'Graham, TX')
# (40693052, 'Granbury, TX')
# (1703, 'Granby, CO')
# (3706049, 'Grand Blanc, MI')
# (45716, 'Grand Canyon Village, AZ')
# (61984, 'Grand Forks, ND')
# (18506580, 'Grand Island, NE')
# (2736008, 'Grand Junction, CO')
# (82500012, 'Grand Prairie, TX')
# (1375518, 'Grand Rapids Metropolitan Area')
# (29622, 'Grand Rapids metropolitan area, MI')
# (38605, 'Grand Rapids, MI')
# (1511, 'Grand Rapids, MN')
# (3264, 'Grandville, MI')
# (80829889, 'Granger, IN')
# (3706049, 'Grants Pass, OR')
# (4591, 'Grantsburg, WI')
# (10408914, 'Grantsville, UT')
# (72483, 'Grapevine, TX')
# (1207327, 'Grass Valley, CA')
# (1867264, 'Great Barrington, MA')
# (1103, 'Great Falls, MT')
# (6104, 'Great Neck, NY')
# (3714038, 'Greater Bangor Area')
# (17283, 'Greater Birmingham, Alabama Area')
# (601919, 'Greater Bloomington Area')
# (42134, 'Greater Bloomington, Illinois Area')
# (91743578, 'Greater Boston')
# (9499, 'Greater Charlottesville Area')
# (2297840, 'Greater Chattanooga')
# (2684553, 'Greater Chicago Area')
# (9499, 'Greater Clarksville Area')
# (10035810, 'Greater Cleveland')
# (28978381, 'Greater Colorado Springs Area')
# (16183163, 'Greater Corpus Christi Area')
# (14191, 'Greater Dothan')
# (28893, 'Greater Farmington Area')
# (29331, 'Greater Fort Wayne')
# (12709, 'Greater Harrisburg Area')
# (14571, 'Greater Hartford')
# (1389, 'Greater Houston')
# (164664, 'Greater Indianapolis')
# (163640, 'Greater Jackson Area')
# (856962, 'Greater Jacksonville, NC Area')
# (11818084, 'Greater Jefferson City Area')
# (450185, 'Greater Kennewick Area')
# (163578, 'Greater Lansing')
# (2174958, 'Greater Los Angeles, CA')
# (166714, 'Greater Macon')
# (16038, 'Greater Madison Area')
# (35646045, 'Greater Milwaukee')
# (2578499, 'Greater Minneapolis-St. Paul Area')
# (84959254, 'Greater Morgantown Area')
# (754041, 'Greater New Orleans Region')
# (9499, 'Greater Ocala Area')
# (2354064, 'Greater Orlando')
# (10093812, 'Greater Philadelphia')
# (80674419, 'Greater Phoenix Area')
# (67080514, 'Greater Pittsburgh Region')
# (28345, 'Greater Reno Area')
# (206993, 'Greater Richmond Region')
# (9124, 'Greater Sacramento')
# (18054300, 'Greater Seattle Area')
# (6044, 'Greater St. Louis')
# (1146188, 'Greater Tampa Bay Area')
# (9499, 'Greater Tuscaloosa Area')
# (15218920, 'Greater Wilmington Area')
# (214212, 'Greater Yakima Area')
# (49223, 'Greater Yuma, AZ Area')
# (5352294, 'Greeley, CO')
# (7789, 'Green Bay, WI')
# (1100944, 'Green Valley, AZ')
# (455780, 'Greenbelt, MD')
# (808034, 'Greenbrae, CA')
# (3671, 'Greenbrier, AR')
# (17902, 'Greencastle, PA')
# (162912, 'Greendale, IN')
# (1945473, 'Greeneville, TN')
# (1867264, 'Greenfield, MA')
# (10387626, 'Greenfield, OH')
# (2737970, 'Greenfield, WI')
# (91447303, 'Greensboro--Winston-Salem--High Point Area')
# (808034, 'Greensboro, NC')
# (19024424, 'Greensburg, PA')
# (163617, 'Greenville County, SC')
# (33248183, 'Greenville-Spartanburg-Anderson, South Carolina Area')
# (66278935, 'Greenville, NC')
# (808034, 'Greenville, SC')
# (164200, 'Greenville, TX')
# (11009726, 'Greenwich, CT')
# (15472, 'Greenwood Village, CO')
# (2737970, 'Greenwood, IN')
# (6215, 'Greenwood, SC')
# (808034, 'Greer, SC')
# (18691, 'Gresham, OR')
# (5618, 'Gretna, NE')
# (15870, 'Groesbeck, TX')
# (1703, 'Groton, CT')
# (2646, 'Grove City, OH')
# (1471368, 'Groveland, CA')
# (4723171, 'Groveland, MI')
# (49105, 'Groveport, OH')
# (134081, 'Guilderland, NY')
# (10420321, 'Guilford, CT')
# (2709, 'Gulf Breeze, FL')
# (28647688, 'Gunnison, CO')
# (12659, 'Guntersville, AL')
# (1103, 'Gurnee, IL')
# (9487, 'Guthrie, KY')
# (164098, 'Gwinnett County, GA')
# (76500049, 'Gypsum, CO')
# (11818084, 'Hackensack, NJ')
# (18923058, 'Hackleburg, AL')
# (2087, 'Hagerstown, MD')
# (6265, 'Halethorpe, MD')
# (629785, 'Hallandale Beach, FL')
# (2589107, 'Hallock, MN')
# (3706049, 'Hamden, CT')
# (278713, 'Hamilton County, OH')
# (581027, 'Hamilton, OH')
# (10225139, 'Hammond, IN')
# (28597765, 'Hammond, LA')
# (98514983, 'Hampton Roads, Virginia Metropolitan Area')
# (7795, 'Hampton, VA')
# (165586, 'Hancocks Bridge, NJ')
# (7032, 'Hanford, CA')
# (2646, 'Hannibal, MO')
# (96180361, 'Hanover Park, IL')
# (40760236, 'Hanover, MA')
# (2153, 'Hanover, MD')
# (686294, 'Hanover, NH')
# (10820, 'Hanover, PA')
# (11240, 'Happy Valley, OR')
# (5343, 'Harahan, LA')
# (6176, 'Harlingen, TX')
# (444038, 'Harmans, MD')
# (2031248, 'Harriman, TN')
# (74081610, 'Harrington, DE')
# (3460, 'Harrisburg, PA')
# (1945473, 'Harrison, AR')
# (6913, 'Harrison, MI')
# (75348, 'Harrison, NY')
# (493453, 'Harrisonburg, VA')
# (2193256, 'Harrisonville, MO')
# (5553, 'Harrold, SD')
# (12988732, 'Hartford City, IN')
# (7043, 'Hartford County, CT')
# (5064123, 'Hartford, CT')
# (10279209, 'Hartland, WI')
# (167757, 'Hartsville, SC')
# (1373835, 'Harvard, IL')
# (4128, 'Hatfield, PA')
# (211166, 'Hauppauge, NY')
# (10420321, 'Haverhill, MA')
# (76500049, 'Havertown, PA')
# (14542824, 'Hawaii, United States')
# (85123, 'Hawley, MN')
# (7032, 'Hawthorne, CA')
# (484735, 'Hawthorne, NY')
# (46648, 'Hayward, CA')
# (2646, 'Hayward, WI')
# (88277482, 'Hazel Crest, IL')
# (27108872, 'Hazlet, NJ')
# (17882, 'Headquarters, KY')
# (81878, 'Headquarters, NJ')
# (18953305, 'Healdsburg, CA')
# (77318089, 'Heath, OH')
# (3056912, 'Hebron, KY')
# (9881525, 'Hegins, PA')
# (11300257, 'Helena, MT')
# (28595302, 'Helotes, TX')
# (2430668, 'Henderson, CO')
# (2646, 'Henderson, KY')
# (14542824, 'Henderson, NC')
# (7361, 'Henderson, NV')
# (20573, 'Hendersonville, NC')
# (63532172, 'Hendersonville, TN')
# (3781515, 'Henrico, VA')
# (96180361, 'Hephzibah, GA')
# (12787, 'Herlong, CA')
# (1103, 'Hermitage, PA')
# (35571114, 'Hermitage, TN')
# (3476, 'Hernando, MS')
# (8860695, 'Herndon, KS')
# (163139, 'Herndon, VA')
# (3658, 'Hershey, PA')
# (884316, 'Hesston, KS')
# (96180361, 'Hialeah, FL')
# (164113, 'Hickory Hills, IL')
# (41004, 'Hickory, NC')
# (9667, 'Hicksville, NY')
# (76440728, 'High Point, NC')
# (4235104, 'Highland, CA')
# (556848, 'Highlands Ranch, CO')
# (9895824, 'Highwood, IL')
# (24440, 'Hilliard, OH')
# (2106853, 'Hillsboro, OR')
# (6176, 'Hillsboro, TX')
# (28647688, 'Hillsboro, WI')
# (20969, 'Hillsborough County, FL')
# (20009, 'Hillsborough, NC')
# (8621, 'Hillside, IL')
# (1861137, 'Hillside, NJ')
# (7032, 'Hilo, HI')
# (57677390, 'Hilton Head Island, SC')
# (78124, 'Hilton Head Island, South Carolina Area')
# (25856, 'Hilton, NY')
# (2343421, 'Hinds County, MS')
# (35583934, 'Hinesville, GA')
# (517387, 'Hingham, MA')
# (1945473, 'Hiram, GA')
# (164200, 'Hixson, TN')
# (19807, 'Hobart, IN')
# (2192, 'Hobbs, NM')
# (10420321, 'Hoboken, NJ')
# (41854, 'Hodgkins, IL')
# (8619, 'Hoffman Estates, IL')
# (10517709, 'Holbrook, NY')
# (12446, 'Holden, ME')
# (947663, 'Holdenville, OK')
# (6449, 'Holland, MI')
# (4798, 'Holland, OH')
# (819218, 'Hollister, CA')
# (3486, 'Hollywood, FL')
# (988946, 'Hollywood, MD')
# (14650, 'Holmdel, NJ')
# (25552, 'Holton, KS')
# (2532635, 'Holyoke, MA')
# (30953, 'Home Park, Florida, United States')
# (12573, 'Home, KS')
# (162755, 'Homedale, ID')
# (71904349, 'Homer, MI')
# (6497, 'Homestead, FL')
# (71904349, 'Homestead, PA')
# (162644, 'Homewood, AL')
# (46000, 'Homewood, IL')
# (1945473, 'Hondo, TX')
# (3002336, 'Honolulu, HI')
# (1236687, 'Hoopeston, IL')
# (72483, 'Hoover, AL')
# (2193256, 'Hope Mills, NC')
# (2646, 'Hopkinsville, KY')
# (57106, 'Horse Cave, KY')
# (20009, 'Horsham, PA')
# (3796614, 'Hot Springs, AR')
# (9401140, 'Houston, Texas, United States')
# (96677, 'Houston, TX')
# (80862575, 'Howell, MI')
# (23375, 'Huber Heights, OH')
# (242230, 'Hudson Waterfront, NJ')
# (1211063, 'Hudson, FL')
# (3570660, 'Hudson, NH')
# (53193, 'Hudson, NY')
# (10420321, 'Hudson, OH')
# (8667, 'Hudson, WI')
# (16161886, 'Humble, TX')
# (5058, 'Hunt Valley, MD')
# (6472500, 'Huntersville, NC')
# (3135, 'Huntington Beach, CA')
# (6176, 'Huntington Park, CA')
# (436931, 'Huntington Station, NY')
# (6104, 'Huntington, NY')
# (82385, 'Huntington, WV')
# (77153, 'Huntsville-Decatur-Albertville Area')
# (3967883, 'Huntsville, AL')
# (57978, 'Huntsville, AR')
# (7795, 'Huntsville, TX')
# (3671, 'Hurlburt Field, FL')
# (11240, 'Hurst, TX')
# (1668, 'Hutchins, TX')
# (2646, 'Hutchinson, KS')
# (7929696, 'Hutchinson, MN')
# (107699, 'Hyannis, MA')
# (12293, 'Idaho Falls, ID')
# (8239496, 'Idaho, United States')
# (9814, 'Illinois City, IL')
# (4433, 'Illinois, United States')
# (40025, 'Immokalee, FL')
# (3764607, 'Imperial, CA')
# (9732, 'Independence, KS')
# (15259054, 'Independence, KY')
# (166572, 'Independence, MO')
# (708393, 'Independence, OH')
# (64863800, 'India')
# (65361091, 'Indian Head, MD')
# (11319362, 'Indian Springs, NV')
# (167757, 'Indian Trail, NC')
# (35520100, 'Indian Wells, CA')
# (7680, 'Indiana, United States')
# (808034, 'Indianapolis, IN')
# (22338085, 'Indianapolis, Indiana, United States')
# (9826, 'Ingleside, TX')
# (4541, 'Inglewood, CA')
# (3626, 'Inverness, FL')
# (163480, 'Inwood, NY')
# (14542824, 'Iowa City, IA')
# (1016, 'Iowa, United States')
# (20723, 'Irondale, AL')
# (18860134, 'Ironwood, MI')
# (1103, 'Irvine, CA')
# (1557409, 'Irvine, California, United States')
# (1103, 'Irving, TX')
# (19534, 'Iselin, NJ')
# (777243, 'Islip, NY')
# (41161, 'Issaquah, WA')
# (89143472, 'Itasca, IL')
# (37396978, 'Ithaca, NY')
# (49648429, 'Iva, SC')
# (10165687, 'Jackson County, MO')
# (284165, 'Jackson Township, OH')
# (71575605, 'Jackson, GA')
# (1943848, 'Jackson, LA')
# (8936, 'Jackson, MI')
# (3269, 'Jackson, MO')
# (64274685, 'Jackson, MS')
# (10141, 'Jackson, NJ')
# (2425285, 'Jackson, OH')
# (72416, 'Jackson, SC')
# (18425303, 'Jackson, TN')
# (97402272, 'Jacksonville Beach, FL')
# (28332, 'Jacksonville, AL')
# (166572, 'Jacksonville, FL')
# (16892, 'Jacksonville, GA')
# (2664556, 'Jacksonville, IL')
# (36990695, 'Jacksonville, NC')
# (2162, 'Jacksonville, TX')
# (3534, 'Jal, NM')
# (345295, 'Jamaica, NY')
# (165933, 'Jamestown, CA')
# (130095, 'Jamestown, TN')
# (2193256, 'Janesville, WI')
# (79042201, 'Jarratt, VA')
# (2646, 'Jasper, IN')
# (6798963, 'Jeannette, PA')
# (76171420, 'Jefferson City, MO')
# (1681, 'Jefferson County, IL')
# (2908367, 'Jeffersontown, KY')
# (18401, 'Jeffersonville, IN')
# (11240, 'Jensen Beach, FL')
# (8474, 'Jericho, NY')
# (1040158, 'Jerome, ID')
# (1808, 'Jersey City, NJ')
# (254060, 'Jersey, GA')
# (26792, 'Jessup, MD')
# (2433416, 'Jessup, PA')
# (5303168, 'Jesup, GA')
# (5275, 'Johns Creek, GA')
# (14542824, 'Johnson City, TN')
# (1579375, 'Johnston, IA')
# (20573, 'Johnston, RI')
# (38400, 'Johnstown, CO')
# (18176, 'Johnstown, NY')
# (1945473, 'Johnstown, PA')
# (164527, 'Joliet, IL')
# (57978, 'Jonesboro, AR')
# (11227630, 'Jonesboro, GA')
# (2121817, 'Jonesville, MI')
# (305287, 'Joplin, MO')
# (3634748, 'Junction City, KS')
# (2664556, 'Juneau, AK')
# (78741693, 'Juno Beach, FL')
# (269675, 'Jupiter, FL')
# (96081672, 'Jurupa Valley, CA')
# (157239, 'Kahului, HI')
# (153293, 'Kalamazoo, MI')
# (163787, 'Kalispell, MT')
# (7384, 'Kankakee, IL')
# (89863227, 'Kansas City Metropolitan Area')
# (217338, 'Kansas City, KS')
# (28503, 'Kansas City, Missouri, United States')
# (22283894, 'Kansas City, MO')
# (1016, 'Kansas, United States')
# (163883, 'Kapolei, HI')
# (3748, 'Katy, TX')
# (2193256, 'Kaukauna, WI')
# (11522, 'Kaysville, UT')
# (38521, 'Kearney, NE')
# (10420321, 'Kearny, NJ')
# (2664556, 'Keene, NH')
# (1909139, 'Keller, TX')
# (385010, 'Kenai, AK')
# (2396310, 'Kendallville, IN')
# (5235, 'Kenilworth, NJ')
# (6176, 'Kenmore, NY')
# (3240, 'Kennebec, SD')
# (2664556, 'Kennebunk, ME')
# (82153, 'Kenner, LA')
# (66278935, 'Kennesaw, GA')
# (34755301, 'Kennewick, WA')
# (10083903, 'Kenosha, WI')
# (2271, 'Kent, WA')
# (7886, 'Kenton, OH')
# (162724, 'Kentucky, United States')
# (82500012, 'Kentwood, MI')
# (28612966, 'Kermit, TX')
# (4128, 'Kernersville, NC')
# (3706049, 'Kerrville, TX')
# (165422, 'Ketchikan, AK')
# (162755, 'Kettle Falls, WA')
# (19637, 'Killeen-Temple Area')
# (11009726, 'Killeen, TX')
# (32478, 'King City, MO')
# (11402317, 'King County, WA')
# (1403, 'King George, VA')
# (15216893, 'King of Prussia, PA')
# (230282, 'Kingsburg, CA')
# (2646, 'Kingsport, TN')
# (363277, 'Kingston, NY')
# (2736008, 'Kingston, PA')
# (7032, 'Kingstowne, VA')
# (80829889, 'Kingwood, WV')
# (7795, 'Kinnelon, NJ')
# (90413667, 'Kinston, NC')
# (1441, 'Kirkland, WA')
# (5461, 'Kirtland Air Force Base, NM')
# (6732937, 'Kissimmee, FL')
# (450185, 'Klamath Falls, OR')
# (28352, 'Knightdale, NC')
# (166714, 'Knoxville Metropolitan Area')
# (165472, 'Knoxville, TN')
# (80516368, 'Kohala, HI')
# (1799, 'Kohler, WI')
# (1908498, 'Kokomo, IN')
# (2564997, 'Koloa, HI')
# (1945473, 'Kula, HI')
# (22132, 'Kuna, ID')
# (28669777, 'Kutztown, PA')
# (3240, 'La Crosse, WI')
# (1271305, 'La Crosse, Wisconsin, United States')
# (34218836, 'La Grande, OR')
# (10135152, 'La Grange, KY')
# (10141, 'La Jolla, California, United States')
# (35716480, 'La Marque, TX')
# (165938, 'La Mesa, CA')
# (163139, 'La Mirada, CA')
# (48024, 'La Porte, TX')
# (18641359, 'La Puente, CA')
# (35504, 'La Quinta, CA')
# (2162, 'La Vergne, TN')
# (56670, 'La Verne, CA')
# (9402, 'Lacey, WA')
# (14542824, 'Laconia, NH')
# (1324822, 'Ladson, SC')
# (59005249, 'Lady Lake, FL')
# (14383281, 'Lafayette, IN')
# (21921, 'Lafayette, Indiana Metropolitan Area')
# (92578918, 'Lafayette, LA')
# (164860, 'Lago Vista, TX')
# (3706049, 'Laguna Beach, CA')
# (165364, 'Laguna Hills, CA')
# (35504, 'Laguna Niguel, CA')
# (71316538, 'Lake Buena Vista, FL')
# (3654739, 'Lake Charles, LA')
# (157239, 'Lake City, FL')
# (1851642, 'Lake County, IL')
# (594846, 'Lake County, IN')
# (26923, 'Lake Elmo, MN')
# (86475, 'Lake Forest, CA')
# (44730, 'Lake Forest, IL')
# (28647688, 'Lake Havasu City, AZ')
# (3671, 'Lake Hiawatha, NJ')
# (25856, 'Lake in the Hills, IL')
# (3570660, 'Lake Mary, FL')
# (6913, 'Lake Oswego, OR')
# (13353, 'Lake St Louis, MO')
# (29620, 'Lake Villa, IL')
# (10667641, 'Lake Wales, FL')
# (5274161, 'Lake Worth, FL')
# (2911, 'Lake Worth, TX')
# (107365, 'Lakeland, FL')
# (214960, 'Lakeside, AZ')
# (4723171, 'Lakeside, MT')
# (12095, 'Lakeville, MA')
# (162755, 'Lakeville, MN')
# (18312164, 'Lakewood, CO')
# (49042, 'Lakewood, NJ')
# (14542824, 'Lamar, CO')
# (163883, 'Lanai City, HI')
# (64883, 'Lancaster, CA')
# (164527, 'Lancaster, MA')
# (3658, 'Lancaster, PA')
# (18506580, 'Lancaster, SC')
# (4822178, 'Lancaster, TX')
# (2254693, 'Lancaster, WI')
# (1379045, 'Landover, MD')
# (34727, 'Lane County, OR')
# (35529547, 'Langhorne, PA')
# (6281, 'Langston, OK')
# (71904349, 'Lanham, MD')
# (49105, 'Lansdale, PA')
# (43278, 'Lansing, MI')
# (407589, 'Lapeer, MI')
# (96180361, 'LaPlace, LA')
# (424952, 'Laredo, TX')
# (1279498, 'Largo, FL')
# (1403, 'Las Cruces, NM')
# (2121817, 'Las Vegas Metropolitan Area')
# (581824, 'Las Vegas, Nevada, United States')
# (7361, 'Las Vegas, NV')
# (917557, 'Latham, NY')
# (3270028, 'Lathrop, CA')
# (23552, 'Latrobe, PA')
# (7795, 'Laurel, MD')
# (2646, 'Laurel, MT')
# (105203, 'Laurinburg, NC')
# (166643, 'Lawrence, KS')
# (298459, 'Lawrence, MA')
# (32469, 'Lawrenceburg, IN')
# (602239, 'Lawrenceburg, KY')
# (3748, 'Lawrenceville, GA')
# (11818084, 'Lawton Area')
# (760983, 'Lawton, OK')
# (77301, 'Layton, UT')
# (14542824, 'Le Mars, IA')
# (581027, 'League City, TX')
# (16075064, 'Leavenworth, KS')
# (2155460, 'Leawood, KS')
# (2700167, 'Lebanon, IN')
# (11056, 'Lebanon, KY')
# (37902046, 'Lebanon, MO')
# (163348, 'Lebanon, NH')
# (2589107, 'Lebanon, OR')
# (28498, 'Lebanon, PA')
# (71575605, 'Lebanon, TN')
# (8294, 'Lee, MA')
# (19058930, 'Leeds, NY')
# (34867, 'Lees Summit, MO')
# (690568, 'Leesburg, FL')
# (32455, 'Leesburg, GA')
# (2664556, 'Leesburg, VA')
# (69736805, 'Leetonia, OH')
# (26341, 'Leetsdale, PA')
# (9203219, 'Lehi, UT')
# (11518813, 'Leland, NC')
# (162510, 'Lemont, IL')
# (11056, 'Lemoore, CA')
# (422503, 'Lenexa, KS')
# (65294553, 'Lenhartsville, PA')
# (808034, 'Leominster, MA')
# (34341, 'Levittown, NY')
# (15389, 'Lewis Center, OH')
# (19023, 'Lewisberry, PA')
# (18176, 'Lewiston, ID')
# (3706049, 'Lewiston, ME')
# (18860134, 'Lewisville, TX')
# (1403, 'Lexington Park, MD')
# (10831504, 'Lexington, KY')
# (2227, 'Lexington, MA')
# (46000, 'Lexington, NC')
# (2646, 'Lexington, NE')
# (157338, 'Lexington, VA')
# (7550, 'Liberty Lake, WA')
# (89877420, 'Liberty, NC')
# (15721, 'Libertyville, IL')
# (71575605, 'Lima, OH')
# (10420321, 'Lincoln Park, NJ')
# (163535, 'Lincoln, CA')
# (38521, 'Lincoln, NE')
# (1043057, 'Lincoln, Nebraska Metropolitan Area')
# (167024, 'Lincolnshire, IL')
# (2677, 'Lincolnton, NC')
# (2712059, 'Lindon, UT')
# (163253, 'Lino Lakes, MN')
# (139348, 'Linthicum Heights, MD')
# (35666700, 'Linthicum, MD')
# (11486116, 'Lisle, IL')
# (2908367, 'Litchfield Park, AZ')
# (3579761, 'Lithia Springs, GA')
# (23379, 'Lititz, PA')
# (86001745, 'Little Canada, MN')
# (8019, 'Little Chicago, WI')
# (17109, 'Little Elm, TX')
# (2986, 'Little Rock Metropolitan Area')
# (24494, 'Little Rock, AR')
# (3308308, 'Littleton, CO')
# (5040587, 'Littleton, NH')
# (31827, 'Live Oak, TX')
# (4994, 'Livermore, CA')
# (25856, 'Liverpool, NY')
# (1668, 'Livingston, MT')
# (18062, 'Livingston, NJ')
# (80862575, 'Livonia, MI')
# (815722, 'Location, WV')
# (22340991, 'Lockport, NY')
# (4453, 'Locust Grove, GA')
# (77301, 'Lodi, CA')
# (1766026, 'Logan, UT')
# (3706049, 'Loma Linda, CA')
# (1075434, 'Lombard, IL')
# (1211063, 'London, OH')
# (1511, 'Londonderry, NH')
# (3711368, 'Lone Tree, CO')
# (3308308, 'Long Beach, CA')
# (86041588, 'Long Branch, NJ')
# (13334, 'Longmont, CO')
# (483961, 'Longview, TX')
# (165422, 'Longview, WA')
# (7720, 'Longwood, FL')
# (11777418, 'Lonoke, AR')
# (35504, 'Loomis, CA')
# (96180361, 'Lorain, OH')
# (65294553, 'Lorton, VA')
# (2135088, 'Los Alamitos, CA')
# (5327, 'Los Alamos, NM')
# (31953, 'Los Angeles County, CA')
# (91357855, 'Los Angeles Metropolitan Area')
# (2476, 'Los Angeles, CA')
# (937092, 'Los Angeles, California, United States')
# (2646, 'Los Banos, CA')
# (165158, 'Los Gatos, CA')
# (37768, 'Los Lunas, NM')
# (6913, 'Los Osos, CA')
# (11227630, 'Loudon, TN')
# (869141, 'Louisiana, United States')
# (2736008, 'Louisville, KY')
# (3495423, 'Loveland, CO')
# (3260, 'Loves Park, IL')
# (162536, 'Lowell, AR')
# (35657035, 'Lowell, MA')
# ...
# (2664556, 'Skowhegan, ME')
# (13476, 'Sleepy Hollow, NY')
# (9185, 'Slidell, LA')
# (52500806, 'Smackover, AR')
# (28647688, 'Smith County, TX')
# (3706049, 'Smithfield, NC')
# (1307, 'Smithfield, RI')
# (1945473, 'Smithtown, NY')
# (9185, 'Smithville, TN')
# (3558, 'Smyrna, GA')
# (16000406, 'Smyrna, TN')
# (1211063, 'Snellville, GA')
# (3700354, 'Snow Hill, NC')
# (5482, 'Social Circle, GA')
# (808034, 'Soldotna, AK')
# (1393, 'Solon, OH')
# (9210946, 'Somerset County, NJ')
# (20009, 'Somerset, KY')
# (55787, 'Somerset, NJ')
# (34218836, 'Somerset, PA')
# (64865352, 'Somerville, MA')
# (14363, 'Somerville, NJ')
# (2671586, 'Sonoma, CA')
# (11440, 'Souderton, PA')
# (79560, 'South Attleboro, MA')
# (360308, 'South Beloit, IL')
# (74306759, 'South Bend-Mishawaka Region')
# (629227, 'South Bend, IN')
# (76171420, 'South Boston, VA')
# (1041095, 'South Carolina, United States')
# (162724, 'South Dakota, United States')
# (36995, 'South El Monte, CA')
# (8667, 'South Elgin, IL')
# (4324, 'South Hackensack, NJ')
# (3593828, 'South Haven, MI')
# (30065, 'South Jordan, UT')
# (6913, 'South Lake Tahoe, CA')
# (26569406, 'South Milwaukee, WI')
# (1944535, 'South Mountain, PA')
# (6913, 'South Pasadena, CA')
# (88659237, 'South Plainfield, NJ')
# (4060, 'South Portland, ME')
# (167757, 'South Salem, NY')
# (3210501, 'South San Francisco, CA')
# (14528, 'South San Gabriel, CA')
# (72483, 'South Sheffield, AL')
# (20009, 'South St Paul, MN')
# (71904349, 'Southampton, NY')
# (92461464, 'Southampton, PA')
# (7795, 'Southaven, MS')
# (2271, 'Southborough, MA')
# (166572, 'Southern Pines, NC')
# (8795, 'Southfield, MI')
# (5064123, 'Southington, CT')
# (24803, 'Southlake, TX')
# (6176, 'Spanaway, WA')
# (15564, 'Sparks, NV')
# (14140, 'Sparrows Point, MD')
# (1511, 'Sparta, TN')
# (1058190, 'Spartanburg, SC')
# (163025, 'Speedway, IN')
# (7935, 'Spencer, IA')
# (8885, 'Spirit Lake, IA')
# (64639449, 'Spokane Valley, WA')
# (13074, 'Spokane, WA')
# (4062, 'Spring Hill, TN')
# (102847, 'Spring House, PA')
# (911928, 'Spring Park, MN')
# (1025, 'Spring, TX')
# (11009726, 'Springdale, AR')
# (16733, 'Springfield-Branson, Missouri Area')
# (164931, 'Springfield, IL')
# (822071, 'Springfield, MA')
# (7064, 'Springfield, MO')
# (37768, 'Springfield, NE')
# (5112, 'Springfield, OH')
# (165422, 'Springfield, OR')
# (3469, 'Springfield, TN')
# (1403, 'Springfield, VA')
# (167757, 'Springfield, VT')
# (2736008, 'Springville, AL')
# (2480405, 'St Augustine, FL')
# (21542, 'St Charles, MO')
# (4141117, 'St Clair Shores, MI')
# (9185, 'St Clairsville, OH')
# (74464, 'St Cloud, MN')
# (410499, 'St George, UT')
# (1586, 'St Georges, DE')
# (18506580, 'St Helena, CA')
# (209610, 'St James, LA')
# (43278, 'St Johns, MI')
# (77669120, 'St Johnsbury, VT')
# (808034, 'St Joseph, MI')
# (87599, 'St Joseph, MO')
# (72483, 'St Louis Park, MN')
# (808034, 'St Louis, Missouri, United States')
# (7064, 'St Louis, MO')
# (4713, 'St Paul, MN')
# (18425303, 'St Peters, MO')
# (166671, 'St Petersburg, FL')
# (4852, 'St Petersburg, Florida, United States')
# (164880, 'St Regis Falls, NY')
# (9075575, 'St. Louis County, MO')
# (13199621, 'Stafford, TX')
# (41008, 'Stafford, VA')
# (1215629, 'Stamford, CT')
# (1792, 'Stanford, CA')
# (10266947, 'Stanford, KY')
# (2972588, 'Stanly County, NC')
# (12446, 'Star Lake, NY')
# (1943848, 'Starkville, MS')
# (23769122, 'State College, PA')
# (71316538, 'Stateline, NV')
# (6913, 'Staten Island, NY')
# (2252, 'Statesville, NC')
# (5343, 'Steamboat Springs, CO')
# (550530, 'Stephenville, TX')
# (1906, 'Sterling Heights, MI')
# (33266522, 'Sterling Wood, TX')
# (24187, 'Sterling, OH')
# (167757, 'Sterling, VA')
# (167757, 'Stillwater, MN')
# (6281, 'Stillwater, OK')
# (6234, 'Stilwell, OK')
# (3888, 'Stockbridge, GA')
# (25017, 'Stockton, CA')
# (31896, 'Stockton, IL')
# (1431, 'Stone Mountain, GA')
# (71904349, 'Stoneham, MA')
# (93749948, 'Stonington, CT')
# (95724, 'Stony Point, NC')
# (30755, 'Strafford County, NH')
# (30967, 'Stratford, CA')
# (461332, 'Stratford, CT')
# (598372, 'Streamwood, IL')
# (2724823, 'Streetsboro, OH')
# (135342, 'Stuart, FL')
# (80911138, 'Stuarts Draft, VA')
# (837416, 'Sturbridge, MA')
# (64677, 'Sturgeon Bay, WI')
# (545086, 'Sturtevant, WI')
# (2193256, 'Suamico, WI')
# (9201883, 'Sudbury, MA')
# (28014, 'Suffolk County, NY')
# (66105, 'Suffolk, VA')
# (3681, 'Sugar Land, TX')
# (2646, 'Sullivan, IN')
# (7119929, 'Sulphur Springs, TX')
# (14459, 'Sulphur, LA')
# (11818084, 'Sulphur, OK')
# (20009, 'Summerville, SC')
# (11804, 'Summit, NJ')
# (963770, 'Sumner, WA')
# (3534, 'Sumter, SC')
# (2584496, 'Sun City Center, FL')
# (18506580, 'Sun City West, AZ')
# (808034, 'Sun City, AZ')
# (9251256, 'Sun City, KS')
# (315817, 'Sun Valley, CA')
# (2203697, 'Sunfish Lake, MN')
# (163761, 'Sunland Park, NM')
# (1441, 'Sunnyvale, CA')
# (9184151, 'Sunnyvale, TX')
# (166360, 'Sunrise, FL')
# (11518813, 'Supply, NC')
# (96180361, 'Surprise, AZ')
# (18523922, 'Surry, ME')
# (5666, 'Surry, VA')
# (2684081, 'Suwanee, GA')
# (20009, 'Swansboro, NC')
# (1642, 'Swiftwater, PA')
# (49455, 'Sycamore, IL')
# (28647688, 'Sylva, NC')
# (97402272, 'Syosset, NY')
# (932766, 'Syracuse, NY')
# (13074, 'Tacoma, WA')
# (862993, 'Takoma Park, MD')
# (622196, 'Talala, OK')
# (38015, 'Tallahassee, FL')
# (1955819, 'Tallapoosa, GA')
# (10967, 'Tallassee, AL')
# (79030151, 'Tamarac, FL')
# (86813252, 'Tampa, FL')
# (1618718, 'Tampa, Florida, United States')
# (5927, 'Taneytown, MD')
# (349545, 'Tanner, AL')
# (9266728, 'Tappahannock, VA')
# (80711640, 'Tarboro, NC')
# (13476, 'Tarrytown, NY')
# (1703, 'Taunton, MA')
# (9185, 'Taylor, MI')
# (6250, 'Taylor, TX')
# (18506580, 'Taylorville, IL')
# (38897, 'Teaneck, NJ')
# (166551, 'Tecumseh, NE')
# (56042106, 'Telford, PA')
# (80516368, 'Telluride, CO')
# (21232722, 'Temecula, CA')
# (1115, 'Tempe, AZ')
# (1103, 'Temple Terrace, FL')
# (5887, 'Temple, GA')
# (6250, 'Temple, TX')
# (869141, 'Tennessee, United States')
# (7149222, 'Terra Bella, CA')
# (307494, 'Terre Haute, IN')
# (96180361, 'Terrell, TX')
# (7795, 'Teterboro, NJ')
# (163883, 'Teton Village, WY')
# (3476, 'Tewksbury, MA')
# (3915, 'Texarkana, AR')
# (10769, 'Texarkana, TX')
# (6979, 'Texas City, TX')
# (1025, 'Texas, United States')
# (285650, 'The Woodlands, TX')
# (3335, 'Thief River Falls, MN')
# (1600946, 'Thiells, NY')
# (1940159, 'Thomasville, GA')
# (3706049, 'Thompson, CT')
# (4026714, 'Thornton, CO')
# (1226771, 'Thornville, OH')
# (4030966, 'Thorofare, NJ')
# (14632005, 'Thousand Oaks, CA')
# (253213, 'Thousand Oaks, California, United States')
# (6617639, 'Thousand Palms, CA')
# (16710, 'Three Bridges, NJ')
# (3617422, 'Tifton, GA')
# (3025557, 'Tigard, OR')
# (7260, 'Timonium, MD')
# (44292, 'Tinley Park, IL')
# (777243, 'Tinton Falls, NJ')
# (1910700, 'Tipp City, OH')
# (4798, 'Titusville, FL')
# (383000, 'Toledo, OH')
# (2162, 'Tolleson, AZ')
# (12095, 'Tomah, WI')
# (9401140, 'Tomball, TX')
# (9229, 'Toms River, NJ')
# (124802, 'Tonawanda, NY')
# (30498, 'Tooele, UT')
# (3240, 'Topeka, KS')
# (6176, 'Toppenish, WA')
# (46000, 'Topsham, ME')
# (1344, 'Torrance, CA')
# (5064123, 'Torrington, CT')
# (165416, 'Touchet, WA')
# (14542824, 'Townshend, VT')
# (13626, 'Township of Cherry Hill, NJ')
# (455780, 'Towson, MD')
# (7058, 'Tracy, CA')
# (808034, 'Travelers Rest, SC')
# (4026801, 'Traverse City, MI')
# (1403, 'Travis Field, CA')
# (9229, 'Tremont, PA')
# (10854676, 'Trenton, GA')
# (14796450, 'Trenton, NJ')
# (2383821, 'Trenton, OH')
# (3961, 'Triangle, NC')
# (2584472, 'Trinity, FL')
# (22208562, 'Troy, AL')
# (1259, 'Troy, MI')
# (71555983, 'Troy, NY')
# (9652, 'Troy, OH')
# (122279, 'Truckee, CA')
# (11229, 'Trussville, AL')
# (18691, 'Tualatin, OR')
# (14113, 'Tucker, GA')
# (1505, 'Tucson, AZ')
# (67572051, 'Tukwila, WA')
# (12890, 'Tulalip, WA')
# (80164640, 'Tulare County, CA')
# (77301, 'Tulare, CA')
# (1945473, 'Tullahoma, TN')
# (162514, 'Tulsa, OK')
# (167757, 'Tumwater, WA')
# (10954, 'Tunnel Hill, GA')
# (295604, 'Turlock, CA')
# (299305, 'Turners Falls, MA')
# (11056, 'Tuscaloosa, AL')
# (17916205, 'Tustin, CA')
# (348709, 'Twin Falls, ID')
# (35224, 'Twinsburg, OH')
# (10769, 'Tyler, TX')
# (1943848, 'Tylertown, MS')
# (2658876, 'Tysons Corner, VA')
# (22132, 'Union City, CA')
# (81950505, 'Union Springs, AL')
# (1297738, 'Union, NJ')
# (27432, 'Union, SC')
# (224075, 'Uniondale, NY')
# (8031, 'United States')
# (1016, 'United, PA')
# (1703, 'Universal City, CA')
# (4674, 'University Park, IL')
# (1703027, 'Upper Marlboro, MD')
# (157353, 'Upper St Clair, PA')
# (2650, 'Urbana, IL')
# (1110827, 'Urbandale, IA')
# (70603, 'Utah County, UT')
# (127645, 'Utah, United States')
# (7042786, 'Utica, NY')
# (133721, 'Uxbridge, MA')
# (1103, 'Vacaville, CA')
# (20009, 'Valdese, NC')
# (46521, 'Valdosta, GA')
# (10853673, 'Vallejo, CA')
# (17885819, 'Valley City, ND')
# (884316, 'Valley City, OH')
# (10214501, 'Van Alstyne, TX')
# (8390, 'Van Wert, OH')
# (4822178, 'Vance, AL')
# (84418, 'Vancouver, WA')
# (6148675, 'Vashon, WA')
# (736659, 'Venice, FL')
# (718282, 'Ventura County, CA')
# (1010140, 'Venus, FL')
# (11695727, 'Vergennes, VT')
# (2908367, 'Vermillion, SD')
# (1613038, 'Vermont, United States')
# (3626487, 'Vernon Hills, IL')
# (27758, 'Vernon, CA')
# (3706049, 'Vernon, TX')
# (1945473, 'Vernon, VT')
# (25856, 'Vernon, WI')
# (25856, 'Verona, PA')
# (725927, 'Verona, WI')
# (84659, 'Vicksburg, MS')
# (30755, 'Victor, NY')
# (8948083, 'Victorville, CA')
# (156470, 'Vienna, VA')
# (10420321, 'Villa Park, IL')
# (6176, 'Virginia Beach, VA')
# (74031056, 'Virginia, MN')
# (4898, 'Virginia, United States')
# (167757, 'Visalia, CA')
# (23279, 'Vista, CA')
# (491462, 'Volusia County, FL')
# (33227880, 'Voorhees, NJ')
# (1945473, 'Wabasso, MN')
# (6250, 'Waco, TX')
# (167757, 'Waconia, MN')
# (52950123, 'Wadesboro, NC')
# (2972588, 'Wake County, NC')
# (96180361, 'Wake Forest, NC')
# (22756, 'Wakefield, MA')
# (6265, 'Walbridge, OH')
# (46000, 'Waldorf, MD')
# (5750, 'Waldwick, NJ')
# (157262, 'Walkertown, NC')
# (205651, 'Wall Township, NJ')
# (28332, 'Walla Walla, WA')
# (48915, 'Waller, TX')
# (12770, 'Wallingford, CT')
# (3706049, 'Wallingford, Pennsylvania, United States')
# (1308355, 'Wallops Island, VA')
# (163139, 'Walnut Creek, CA')
# (598521, 'Walsenburg, CO')
# (77633193, 'Waltham, MA')
# (139348, 'Walton, KY')
# (822071, 'Ware, MA')
# (4167, 'Warminster, PA')
# (2193256, 'Warner Robins, GA')
# (140581, 'Warren, MA')
# (1472, 'Warren, MI')
# (12951519, 'Warren, NJ')
# (888619, 'Warren, OH')
# (11152, 'Warren, OR')
# (3037367, 'Warren, RI')
# (1689, 'Warrendale, PA')
# (165944, 'Warrensville Heights, OH')
# (2721914, 'Warrenton, MO')
# (1211063, 'Warrenton, VA')
# (12861, 'Warrenville, IL')
# (30167, 'Warrington, PA')
# (1975865, 'Warsaw, IN')
# (27973, 'Warsaw, VA')
# (79560, 'Warwick, RI')
# (11455, 'Wasco, OR')
# (3493, 'Waseca, MN')
# (7065, 'Washington County, TN')
# (42595, 'Washington DC-Baltimore Area')
# (163139, 'Washington, DC')
# (2646, 'Washington, IA')
# (7064, 'Washington, MO')
# (3706049, 'Washington, NC')
# (6592912, 'Washington, PA')
# (18312164, 'Washington, United States')
# (5749, 'Washington, UT')
# (104405, 'Wasilla, AK')
# (11266342, 'Waterbury, CT')
# (5064123, 'Waterford, CT')
# (766876, 'Waterloo, IA')
# (15862365, 'Watertown, MA')
# (10778, 'Watertown, NY')
# (455602, 'Watertown, SD')
# (8484, 'Watertown, WI')
# (2664556, 'Waterville, ME')
# (164880, 'Watsonville, CA')
# (3222, 'Waukegan, IL')
# (2121817, 'Waukesha, WI')
# (3240, 'Wausau, WI')
# (157346, 'Wauwatosa, WI')
# (40693052, 'Waveland, MS')
# (166551, 'Waverly, NE')
# (167757, 'Waxhaw, NC')
# (65907467, 'Waycross, GA')
# (30755, 'Wayne, NJ')
# (33421, 'Wayne, PA')
# (20573, 'Waynesville, MO')
# (28352, 'Weatherford, OK')
# (3570660, 'Weatherford, TX')
# (164249, 'Webster City, IA')
# (66270, 'Welch, MN')
# (5274161, 'Weld County, CO')
# (4075, 'Wellesley, MA')
# (10967, 'Wellington, KS')
# (7032, 'Wenatchee, WA')
# (327513, 'Wenona, IL')
# (6870363, 'Wentzville, MO')
# (60059619, 'Wernersville, PA')
# (1188909, 'Weslaco, TX')
# (7795, 'Wesley Chapel, FL')
# (4872007, 'West Babylon, NY')
# (8936, 'West Bloomfield Township, MI')
# (2913, 'West Bridgewater, MA')
# (18506580, 'West Burlington, IA')
# (1593346, 'West Chester, OH')
# (13499, 'West Chester, PA')
# (3776, 'West Chicago, IL')
# (74718032, 'West Columbia, SC')
# (26873, 'West Covina, CA')
# (9370513, 'West Coxsackie, NY')
# (6326422, 'West Des Moines, IA')
# (22534, 'West Fargo, ND')
# (56670, 'West Greenwich, RI')
# (44580, 'West Hartford, CT')
# (4255, 'West Henrietta, NY')
# (3517767, 'West Hollywood, CA')
# (4060, 'West Jefferson, OH')
# (1441, 'West Jordan, UT')
# (73013724, 'West Lafayette, IN')
# (2227, 'West Lebanon, NH')
# (1103, 'West Long Branch, NJ')
# (18860134, 'West McLean, VA')
# (79011799, 'West New York, NJ')
# (75053811, 'West Nyack, NY')
# (10442082, 'West Palm Beach, FL')
# (1284978, 'West Palm Beach, Florida, United States')
# (808034, 'West Plains, MO')
# (2848937, 'West Point, PA')
# (10035810, 'West Point, VA')
# (258644, 'West Rancho Dominguez, CA')
# (26283799, 'West Reading, PA')
# (380752, 'West Sacramento, CA')
# (18527534, 'West Valley City, UT')
# (165908, 'West Virginia, United States')
# (164376, 'Westborough, MA')
# (14070878, 'Westby, WI')
# (3476, 'Westchester County, NY')
# (2343541, 'Western, NY')
# (82565734, 'Westerville, OH')
# (945354, 'Westfield, IN')
# (1703, 'Westfield, MA')
# (1557409, 'Westford, MA')
# (3340388, 'Westlake Village, CA')
# (20573, 'Westlake, OH')
# (1307, 'Westlake, TX')
# (25856, 'Westland, MI')
# (20573, 'Westminster, CO')
# (25856, 'Westmont, IL')
# (5196975, 'Weston, FL')
# (3706049, 'Weston, WV')
# (851980, 'Westwood, KS')
# (16726, 'Westwood, MA')
# (11648, 'Wethersfield, CT')
# (14796450, 'Wharton, NJ')
# (157237, 'Whately, MA')
# (2564886, 'Wheatland, WY')
# (3505052, 'Wheaton, MD')
# (521948, 'Wheeling, IL')
# (12890, 'Wheeling, WV')
# (54788, 'Whippany, NJ')
# (316602, 'Whippleville, NY')
# (162755, 'White City, OR')
# (10341654, 'White House, TN')
# (1668, 'White Marsh Station, MD')
# (104405, 'White Pine, TN')
# (938659, 'White Plains, NY')
# (2664323, 'White Sands, NM')
# (167757, 'White Settlement, TX')
# (3557082, 'Whitehall, MI')
# (82302944, 'Whiting, WI')
# (21890, 'Whitmore Lake, MI')
# (30755, 'Whittier, CA')
# (259898, 'Wichita Falls, TX')
# (36769, 'Wichita, KS')
# (18506580, 'Wilkes-Barre, PA')
# (40888889, 'Willard, OH')
# (3549, 'Williamsburg, KY')
# (24385, 'Williamsburg, VA')
# (79988879, 'Williamson County, TX')
# (78336991, 'Williamsport, MD')
# (5749, 'Williamsport, PA')
# (12446, 'Williamstown, NY')
# (26587222, 'Williamsville, NY')
# (444038, 'Willimantic, CT')
# (165109, 'Willis, TX')
# (40658652, 'Williston, ND')
# (63171, 'Willmar, MN')
# (92750, 'Wilmer, TX')
# (1603, 'Wilmington, DE')
# (80181, 'Wilmington, Delaware, United States')
# (2396274, 'Wilmington, MA')
# (581027, 'Wilmington, NC')
# (10137, 'Wilmington, OH')
# (1471368, 'Wilmington, VT')
# (14840050, 'Wilson, NC')
# (11695727, 'Wilsonville, OR')
# (29849, 'Wilton Manors, FL')
# (3894, 'Wilton, CT')
# (134081, 'Wilton, NY')
# (9750, 'Wimberley, TX')
# (10854663, 'Winamac, IN')
# (602239, 'Winchester, KY')
# (28978143, 'Winchester, MA')
# (167757, 'Winchester, TN')
# (78606, 'Winchester, VA')
# (2555454, 'Winder, GA')
# (15220229, 'Windsor Mill, MD')
# (2951796, 'Windsor, CO')
# (3589, 'Windsor, WI')
# (1611410, 'Winn, MI')
# (10420321, 'Winnetka, IL')
# (6963, 'Winona, MN')
# (9759, 'Winston-Salem, NC')
# (135468, 'Winston, GA')
# (6176, 'Winter Garden, FL')
# (3697729, 'Winter Haven, FL')
# (2297786, 'Winter Park, FL')
# (14611, 'Winter Park, Florida, United States')
# (585138, 'Wisconsin Dells, WI')
# (32727, 'Wisconsin Rapids, WI')
# (26586, 'Wisconsin, United States')
# (5887, 'Wittmann, AZ')
# (2576930, 'Wixom, MI')
# (12192, 'Woburn, MA')
# (36704, 'Woodbridge, NJ')
# (1103, 'Woodbridge, VA')
# (8602, 'Woodburn, OR')
# (911928, 'Woodbury, MN')
# (16279, 'Woodcliff Lake, NJ')
# (21337, 'Woodhull, NY')
# (142571, 'Woodinville, WA')
# (522560, 'Woodland, CA')
# (7032, 'Woodlawn, MD')
# (56119363, 'Woodlyn, PA')
# (3570660, 'Woodridge, IL')
# (18425303, 'Woodside, NY')
# (10141, 'Woodstock, GA')
# (2664556, 'Woodward, OK')
# (808034, 'Worcester, MA')
# (232381, 'Wrentham, MA')
# (2633, 'Wyandotte, MI')
# (6250, 'Wylie, TX')
# (1224492, 'Wyoming, MN')
# (869141, 'Wyoming, United States')
# (3658, 'Wyomissing, PA')
# (71339867, 'Wytheville, VA')
# (12601, 'Yakima, WA')
# (9185, 'Yanceyville, NC')
# (139348, 'Yankton, SD')
# (163741, 'Yaphank, NY')
# (1867264, 'Yarmouth, MA')
# (5034592, 'Yelm, WA')
# (660180, 'Yerington, NV')
# (11227630, 'Yonkers, NY')
# (14542824, 'York, ME')
# (166837, 'York, PA')
# (164880, 'York, SC')
# (1009, 'Yorktown Heights, NY')
# (5666, 'Youngstown, OH')
# (55170, 'Youngsville, NC')
# (165725, 'Yountville, CA')
# (40687781, 'Ypsilanti, MI')
# (2604972, 'Yuba City, CA')
# (3570660, 'Yucaipa, CA')
# (601919, 'Yukon, OK')
# (324747, 'Yuma, AZ')
# (77301, 'Zachary, LA')
# (2646, 'Zanesville, OH')
# (7425, 'Zeeland, MI')
# (2857644, 'Zwolle, LA')
# Length of the result for 3a-2 :  3431

# %% [markdown]
# #### Explained query

# %%
sql_query_explain(query2)
# Out:
# (1, 'PRIMARY', '<derived2>', None, 'ref', '<auto_key0>', '<auto_key0>', '8', 'const', 10, 100.0, None)
# (2, 'DERIVED', 'job_postings', None, 'ALL', None, None, None, None, 15830, 100.0, 'Using temporary; Using filesort')

# %% [markdown]
# #### Average time

# %%
sql_query_avg_time(query2,x,"3a-2")
# Out:
# No optimization:  avg total time SQL-Query 3a-2  =  0.22435481548309327

# %% [markdown]
# ## Query 3b - 1

# %% [markdown]
# Esta consulta recupera informações sobre empresas, incluindo o seu ID, nome, número de empregados e o número de ofertas de emprego em que o título contém "er". Também filtra as empresas com mais de 5 ofertas de emprego e ordena os resultados pela contagem de ofertas por ordem decrescente. A utilização de LEFT JOINs garante que as empresas sem entradas correspondentes nas tabelas benefits ou employee_counts continuam a ser incluídas nos resultados.

# %%
query3 = ("SELECT c.company_id, c.name as company_name, ec.employee_count, COUNT(*) as job_count "
                     "FROM job_postings jp "
                     "LEFT JOIN companies c ON jp.company_id = c.company_id "
                     "LEFT JOIN benefits b ON jp.job_id = b.job_id "
                     "LEFT JOIN employee_counts ec ON c.company_id = ec.company_id "
                     "WHERE jp.title LIKE '%er' GROUP BY c.company_id, c.name, ec.employee_count "
                     "HAVING job_count > 5 ORDER BY job_count DESC;")

# %% [markdown]
# #### Result:

# %%
sql_query_result(query3,"3b-1")
# Out:
# (163139, 'Cogent Communications', 2258, 60)
# (163139, 'Cogent Communications', 2255, 60)
# (163139, 'Cogent Communications', 2250, 60)
# (10420321, 'The Mom Project', 897, 43)
# (10420321, 'The Mom Project', 902, 43)
# (11056, 'Insight Global', 13096, 33)
# (11056, 'Insight Global', 13698, 33)
# (11056, 'Insight Global', 13787, 33)
# (11056, 'Insight Global', 13801, 33)
# (11056, 'Insight Global', 13804, 33)
# (18860134, 'Jobot', 2148, 31)
# (18860134, 'Jobot', 2781, 31)
# (18860134, 'Jobot', 2783, 31)
# (18860134, 'Jobot', 2774, 31)
# (49042, 'Five Star Senior Living', 2882, 26)
# (49042, 'Five Star Senior Living', 2905, 26)
# (49042, 'Five Star Senior Living', 2904, 26)
# (7795, 'Petco', 15497, 25)
# (7795, 'Petco', 15848, 25)
# (7795, 'Petco', 15841, 25)
# (1403, 'Booz Allen Hamilton', 38277, 24)
# (1403, 'Booz Allen Hamilton', 35963, 24)
# (1403, 'Booz Allen Hamilton', 35961, 24)
# (1403, 'Booz Allen Hamilton', 35400, 24)
# (77301, "Raising Cane's Chicken Fingers", 10158, 24)
# (77301, "Raising Cane's Chicken Fingers", 10861, 24)
# (77301, "Raising Cane's Chicken Fingers", 10863, 24)
# (1681, 'Robert Half', 32197, 23)
# (1681, 'Robert Half', 32147, 23)
# (1681, 'Robert Half', 29381, 23)
# (1681, 'Robert Half', 29389, 23)
# (1681, 'Robert Half', 29388, 23)
# (1681, 'Robert Half', 29372, 23)
# (1103, 'Verizon', 95609, 23)
# (1103, 'Verizon', 92691, 23)
# (1103, 'Verizon', 92690, 23)
# (1103, 'Verizon', 92240, 23)
# (1344, 'Honeywell', 127293, 23)
# (1344, 'Honeywell', 128397, 23)
# (1344, 'Honeywell', 128388, 23)
# (1344, 'Honeywell', 127620, 23)
# (71904349, 'Actalent', 5857, 22)
# (71904349, 'Actalent', 5853, 22)
# (601919, 'Genesys', 7397, 20)
# (601919, 'Genesys', 7486, 20)
# (25856, 'Tradesmen International', 4968, 18)
# (25856, 'Tradesmen International', 5043, 18)
# (25856, 'Tradesmen International', 5042, 18)
# (25856, 'Tradesmen International', 5044, 18)
# (64666, 'Ombudsman Educational Services', 333, 15)
# (64666, 'Ombudsman Educational Services', 331, 15)
# (72483, 'Aimbridge Hospitality', 7529, 15)
# (72483, 'Aimbridge Hospitality', 7624, 15)
# (72483, 'Aimbridge Hospitality', 7626, 15)
# (72483, 'Aimbridge Hospitality', 7628, 15)
# (2396310, 'Randstad USA', 8074, 15)
# (2396310, 'Randstad USA', 8089, 15)
# (4060, 'Cushman & Wakefield', 40637, 14)
# (4060, 'Cushman & Wakefield', 40700, 14)
# (4060, 'Cushman & Wakefield', 40688, 14)
# (1557409, 'Crown Castle', 5635, 14)
# (1557409, 'Crown Castle', 5541, 14)
# (3240, 'Farmers Insurance', 53065, 14)
# (3240, 'Farmers Insurance', 53116, 14)
# (3240, 'Farmers Insurance', 53102, 14)
# (18312164, 'Bravado', 184, 13)
# (18312164, 'Bravado', 189, 13)
# (18312164, 'Bravado', 192, 13)
# (65294553, 'Brightpath Associates LLC', 59, 13)
# (65294553, 'Brightpath Associates LLC', 61, 13)
# (65294553, 'Brightpath Associates LLC', 70, 13)
# (65294553, 'Brightpath Associates LLC', 69, 13)
# (9814, 'Eastridge Workforce Solutions', 950, 12)
# (5235, 'LHH', 12457, 11)
# (5235, 'LHH', 12904, 11)
# (5235, 'LHH', 13020, 11)
# (5235, 'LHH', 13014, 11)
# (5235, 'LHH', 12986, 11)
# (7587370, 'GrayWolf', 134, 11)
# (20009, 'Bimbo Bakeries USA', 9406, 11)
# (20009, 'Bimbo Bakeries USA', 9537, 11)
# (20009, 'Bimbo Bakeries USA', 9541, 11)
# (20009, 'Bimbo Bakeries USA', 9540, 11)
# (162724, 'Blackbaud', 3473, 10)
# (73013724, 'J. Galt', 251, 10)
# (73013724, 'J. Galt', 363, 10)
# (73013724, 'J. Galt', 358, 10)
# (1939425, 'Midwest Holding Inc.', 80, 9)
# (157237, 'Newell Brands', 12746, 9)
# (157237, 'Newell Brands', 12747, 9)
# (157237, 'Newell Brands', 12902, 9)
# (307886, 'Canadian Solar Inc.', 1696, 9)
# (26923, 'Holiday Stationstores', 1054, 9)
# (26923, 'Holiday Stationstores', 1084, 9)
# (26923, 'Holiday Stationstores', 1085, 9)
# (12890, "Cabela's", 6957, 9)
# (12890, "Cabela's", 7020, 9)
# (12890, "Cabela's", 7010, 9)
# (17246, 'Relevante, Inc.', 165, 9)
# (17246, 'Relevante, Inc.', 173, 9)
# (163253, 'Creative Circle', 1857, 9)
# (163253, 'Creative Circle', 1866, 9)
# (163253, 'Creative Circle', 1863, 9)
# (167757, 'The Job Network', 73, 9)
# (167757, 'The Job Network', 74, 9)
# (18043, 'Addison Group', 1955, 8)
# (18043, 'Addison Group', 1950, 8)
# (18043, 'Addison Group', 1911, 8)
# (18043, 'Addison Group', 1907, 8)
# (1505, 'Raytheon', 43440, 8)
# (1505, 'Raytheon', 44251, 8)
# (1505, 'Raytheon', 44249, 8)
# (1505, 'Raytheon', 44244, 8)
# (1505, 'Raytheon', 44247, 8)
# (3690, 'Micron Technology', 26043, 8)
# (3690, 'Micron Technology', 26044, 8)
# (1511, 'Mondelēz International', 39265, 8)
# (1511, 'Mondelēz International', 39920, 8)
# (1511, 'Mondelēz International', 39914, 8)
# (11204, 'Hill International, Inc.', 5465, 8)
# (2193256, 'GFL Environmental Inc.', 5366, 8)
# (2193256, 'GFL Environmental Inc.', 5579, 8)
# (2193256, 'GFL Environmental Inc.', 5582, 8)
# (1463, 'ADP', 83579, 8)
# (1463, 'ADP', 92657, 8)
# (1463, 'ADP', 92645, 8)
# (2121817, 'DSJ Global', 343, 8)
# (2121817, 'DSJ Global', 349, 8)
# (2121817, 'DSJ Global', 383, 8)
# (76171420, 'Hitachi Energy', 20416, 8)
# (76171420, 'Hitachi Energy', 21428, 8)
# (73024, 'Billingsley Company', 239, 8)
# (7929696, 'Flynn Group', 1246, 8)
# (2973906, 'Leidos', 32014, 8)
# (2973906, 'Leidos', 31816, 8)
# (9185, 'Advance Auto Parts', 19759, 8)
# (9185, 'Advance Auto Parts', 20244, 8)
# (9185, 'Advance Auto Parts', 20242, 8)
# (79383535, 'Akkodis', 21144, 7)
# (79383535, 'Akkodis', 21147, 7)
# (79383535, 'Akkodis', 21618, 7)
# (79383535, 'Akkodis', 21617, 7)
# (86694680, 'Ascendion', 1954, 7)
# (86694680, 'Ascendion', 2102, 7)
# (86694680, 'Ascendion', 2104, 7)
# (5343, 'Sysco', 26619, 7)
# (5343, 'Sysco', 26634, 7)
# (5343, 'Sysco', 26979, 7)
# (5343, 'Sysco', 26987, 7)
# (15762, 'Page Southerland Page, Inc.', 1721, 7)
# (15762, 'Page Southerland Page, Inc.', 1755, 7)
# (15762, 'Page Southerland Page, Inc.', 1754, 7)
# (7032, 'Ross Stores, Inc.', 29845, 7)
# (7032, 'Ross Stores, Inc.', 29859, 7)
# (7032, 'Ross Stores, Inc.', 30790, 7)
# (7032, 'Ross Stores, Inc.', 30789, 7)
# (7032, 'Ross Stores, Inc.', 30778, 7)
# (218019, 'Great Hearts Academies', 1182, 6)
# (784586, 'Improve Group', 67, 6)
# (8117, 'The Judge Group', 2309, 6)
# (8117, 'The Judge Group', 2296, 6)
# (8117, 'The Judge Group', 2292, 6)
# (8117, 'The Judge Group', 2286, 6)
# (641035, 'Sun West Mortgage Company, Inc.', 645, 6)
# (641035, 'Sun West Mortgage Company, Inc.', 649, 6)
# (149485, 'WBE (W. Bradley Electric)', 176, 6)
# (2562, 'Dow', 43847, 6)
# (2562, 'Dow', 43989, 6)
# (5352294, 'Raas Infotek', 186, 6)
# (5352294, 'Raas Infotek', 185, 6)
# (163883, 'Four Seasons Hotels and Resorts', 30545, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31195, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31207, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31206, 6)
# (4822178, 'FactoryFix', 87, 6)
# (4822178, 'FactoryFix', 95, 6)
# (4822178, 'FactoryFix', 94, 6)
# (493453, 'The Scion Group', 822, 6)
# (493453, 'The Scion Group', 832, 6)
# (493453, 'The Scion Group', 833, 6)
# (26873, 'El Pollo Loco, Inc.', 2626, 6)
# (4167, 'PNC', 66604, 6)
# (4167, 'PNC', 66609, 6)
# (4167, 'PNC', 66942, 6)
# (4167, 'PNC', 66940, 6)
# (2247, 'Johnson Controls', 65962, 6)
# (2247, 'Johnson Controls', 65982, 6)
# (2247, 'Johnson Controls', 65981, 6)
# (2247, 'Johnson Controls', 65702, 6)
# (6765, 'Perkins Coie LLP', 2909, 6)
# (154713, 'OptionMetrics', 51, 6)
# (88289095, 'Magnit', 2353, 6)
# (88289095, 'Magnit', 2562, 6)
# (88289095, 'Magnit', 2570, 6)
# (88289095, 'Magnit', 2567, 6)
# (2615835, 'Piper Companies', 187, 6)
# (1025, 'Hewlett Packard Enterprise', 70995, 6)
# (1025, 'Hewlett Packard Enterprise', 72453, 6)
# (1025, 'Hewlett Packard Enterprise', 72445, 6)
# (1025, 'Hewlett Packard Enterprise', 71428, 6)
# (777243, 'Ascendo Resources', 357, 6)
# (777243, 'Ascendo Resources', 329, 6)
# (1943848, 'Healthcare Services Group, Inc', 4159, 6)
# (1943848, 'Healthcare Services Group, Inc', 4160, 6)
# Length of the result for 3b-1 :  204

# %% [markdown]
# #### Explained query

# %%
sql_query_explain(query3)
# Out:
# (1, 'SIMPLE', 'jp', None, 'ALL', None, None, None, None, 15830, 11.11, 'Using where; Using temporary; Using filesort')
# (1, 'SIMPLE', 'c', None, 'eq_ref', 'PRIMARY', 'PRIMARY', '8', 'mysql.jp.company_id', 1, 100.0, None)
# (1, 'SIMPLE', 'b', None, 'ref', 'job_id', 'job_id', '9', 'mysql.jp.job_id', 2, 100.0, 'Using index')
# (1, 'SIMPLE', 'ec', None, 'ref', 'company_id', 'company_id', '9', 'mysql.c.company_id', 1, 100.0, None)

# %% [markdown]
# #### Average time

# %%
sql_query_avg_time(query3,x,"3b-1")
# Out:
# No optimization:  avg total time SQL-Query 3b-1  =  0.11321542263031006

# %% [markdown]
# ## Query 3b - 2

# %% [markdown]
# Essa consulta calcula os valores médio, mínimo e máximo da coluna max_salary da tabela salaries, considerando apenas as linhas em que os anúncios de emprego correspondentes têm um max_salary maior que 5000. O RIGHT JOIN garante que todas as linhas da tabela job_postings sejam incluídas, e as linhas correspondentes da tabela salaries sejam incluídas com valores NULL se não houver correspondência.

# %%
query4 = ("SELECT avg(jp.max_salary), min(jp.max_salary), max(jp.max_salary) FROM salaries s "
                     "RIGHT JOIN job_postings jp on s.job_id = jp.job_id "
                     "WHERE jp.max_salary > 5000;")

# %% [markdown]
# #### Result:

# %%
sql_query_result(query4,"3b-2")
# Out:
# (135784.2010912389, 5474.0, 1100000.0)
# Length of the result for 3b-2 :  1

# %% [markdown]
# #### Explained query

# %%
sql_query_explain(query4)
# Out:
# (1, 'SIMPLE', 'jp', None, 'ALL', None, None, None, None, 15830, 33.33, 'Using where')
# (1, 'SIMPLE', 's', None, 'ref', 'job_id', 'job_id', '9', 'mysql.jp.job_id', 1, 100.0, 'Using index')

# %% [markdown]
# #### Average time

# %%
sql_query_avg_time(query4,x,"3b-2")
# Out:
# No optimization:  avg total time SQL-Query 3b-2  =  0.028089284896850586
