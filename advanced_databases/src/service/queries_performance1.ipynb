# %% [markdown]
# # Testing performance of queries

# %%
import mysql.connector
import numpy as np
import pandas as pd
import time
from pymongo import MongoClient
import pprint


mongo_client = MongoClient('mongodb://root:rootpassword@localhost:27017/admin')
db = mongo_client.admin
salaries_collection = db.salaries
jobs_collection = db.job_postings


client = mysql.connector.connect(user='admin', password='admin', host='localhost', port=3306, database='mysql')
mycursor = client.cursor()


x = 10
times = []

# %%
def sql_query_result(query,query_name):
    time_i = time.time()
    mycursor.execute(query)
    time_f = time.time()
    myresult1 = mycursor.fetchall()
    for r in myresult1:
        print(r)
    print("Length of the result for",query_name, ": ", myresult1.__len__())
    print("SQL Execution time:", (time_f-time_i))
    
def mongo_query_result(query,collection,query_name):
    time_i = time.time()
    doc = collection.aggregate(query)
    time_f = time.time()
    result = list(doc)
    for row in result:
        print(row)
    print("Length of the result for",query_name, ": ", result.__len__())
    print("Mongo Execution time:", (time_f-time_i))

# %%
def sql_query_explain(query):
    explain_query = f"EXPLAIN {query}"
    mycursor.execute(explain_query)
    explanation_result = mycursor.fetchall()
    for row in explanation_result:
        print(row)
        
def mongo_query_explain(query,collection):
    pprint.pprint(collection.aggregate(query).explain())

# %%
def sql_query_avg_time(query,num, query_name):
    times = []
    for i in range(num):
        time_i = time.time()
        mycursor.execute(query)
        mycursor.fetchall()
        time_f = time.time()
        times.append(time_f-time_i)
        
    avgtime = sum(times)/x
    print('Avg total time SQL-Query',query_name ,' = ', avgtime)
    
def mongo_query_avg_time(query,collection,num,query_name):
    times = []
    for i in range(num):
        time_i = time.time()
        doc = collection.aggregate(query)
        time_f = time.time()
        times.append(time_f-time_i)
        
    avgtime = sum(times)/x
    print('Avg total time Mongo-Query',query_name ,' = ', avgtime)

# %% [markdown]
# ## Query 3a - 1

# %% [markdown]
# Esta consulta busca o salários que são pagos anualmente, com um valor superior a 10000 e com um salário máximo superior a 50000.

# %%
name = "3a-1"

sql_query1 = ("SELECT salary_id, max_salary, min_salary FROM salaries sa "
              "WHERE pay_period = 'yearly' and max_salary > 50000 and min_salary > 10000 "
              "GROUP BY salary_id, max_salary;")

mongo_query1 = [
    {"$match": {
            "pay_period": "YEARLY",
            "max_salary": {"$gt": 50000},
            "min_salary": {"$gt": 10000}
        }
    },
    {"$group": {
            "_id": {
                "salary_id": "$salary_id",
                "max_salary": "$max_salary"
            },
            "min_salary": {"$first": "$min_salary"}
        }
    },
    {"$project": {
            "_id": 0,
            "salary_id": "$_id.salary_id",
            "max_salary": "$_id.max_salary",
            "min_salary": "$min_salary"
        }
    }
]

sqlquery_index = "CREATE index index_salary ON salaries(salary_id,max_salary)"
sqlquery_index2 = "CREATE index index_salary2 ON salaries(pay_period, max_salary, min_salary)"

drop_index = "DROP INDEX index_salary ON salaries;"
drop_index2 = "DROP INDEX index_salary2 ON salaries;"

mongoquery_index = [("pay_period",1), ("max_salary",1),('min_salary',1)]
#salary_id and

# %% [markdown]
# #### Result:

# %% [markdown]
# ##### SQL

# %%
sql_query_result(sql_query1,name)
sql_query_explain(sql_query1)
sql_query_avg_time(sql_query1,x,name)
# Out:
# (1391, 66000.0, 60000.0)
# (1393, 80000.0, 70000.0)
# (1394, 60000.0, 50000.0)
# (1396, 60000.0, 55000.0)
# (1397, 175200.0, 109500.0)
# (1398, 60000.0, 55000.0)
# (1399, 60000.0, 55000.0)
# (1401, 60000.0, 55000.0)
# (1403, 60000.0, 55000.0)
# (1404, 66000.0, 60000.0)
# (1406, 85000.0, 65000.0)
# (1408, 100000.0, 80000.0)
# (1412, 62500.0, 50000.0)
# (1415, 120000.0, 105000.0)
# (1416, 234563.0, 156340.0)
# (1419, 162250.0, 106000.0)
# (1420, 162250.0, 106000.0)
# (1421, 162250.0, 106000.0)
# (1422, 175125.0, 85000.0)
# (1425, 250000.0, 175000.0)
# (1426, 150000.0, 75996.0)
# (1427, 120000.0, 100000.0)
# (1432, 115000.0, 100000.0)
# (1434, 65000.0, 55000.0)
# (1438, 243300.0, 127600.0)
# (1439, 130400.0, 80000.0)
# (1440, 243300.0, 127600.0)
# (4501, 122951.0, 73770.8)
# (4504, 133120.0, 111900.0)
# (4505, 85000.0, 55000.0)
# (4511, 73912.8, 58500.0)
# (4514, 500000.0, 100000.0)
# (4516, 185300.0, 136000.0)
# (4517, 157500.0, 117200.0)
# (4520, 170443.0, 108057.0)
# (4521, 91052.0, 63935.0)
# (4523, 124410.0, 109276.0)
# (4524, 85000.0, 69200.0)
# (4526, 157500.0, 117200.0)
# (4527, 157500.0, 117200.0)
# (4528, 55000.0, 42000.0)
# (4529, 55000.0, 50000.0)
# (4531, 190000.0, 175000.0)
# (4536, 264000.0, 80000.0)
# (4537, 345000.0, 315000.0)
# (4545, 185300.0, 136000.0)
# (4546, 132800.0, 101900.0)
# (4547, 157500.0, 117200.0)
# (4549, 250000.0, 200000.0)
# (4550, 117000.0, 90000.0)
# (4554, 215000.0, 175000.0)
# (4555, 60000.0, 56000.0)
# (4557, 125000.0, 120000.0)
# (4558, 65000.0, 57000.0)
# (4560, 108191.0, 86767.2)
# (4565, 132800.0, 101900.0)
# (4566, 157500.0, 117200.0)
# (4567, 157500.0, 117200.0)
# (4568, 157500.0, 117200.0)
# (4569, 130000.0, 120000.0)
# (4570, 135000.0, 114750.0)
# (4571, 53000.0, 50000.0)
# (4572, 58500.0, 50000.0)
# (4573, 130000.0, 110500.0)
# (4575, 144811.0, 103436.0)
# (4576, 65000.0, 57000.0)
# (4577, 85300.0, 17484.0)
# (4581, 80000.0, 70000.0)
# (4582, 126400.0, 88500.0)
# (4591, 101764.0, 100000.0)
# (4597, 185300.0, 136000.0)
# (4598, 185300.0, 136000.0)
# (4599, 185300.0, 136000.0)
# (4600, 157500.0, 117200.0)
# (4601, 157500.0, 117200.0)
# (4602, 157500.0, 117200.0)
# (4603, 157500.0, 117200.0)
# (4604, 157500.0, 117200.0)
# (6612, 450000.0, 350000.0)
# (6613, 105200.0, 46700.0)
# (6623, 151800.0, 94200.0)
# (6625, 200000.0, 136000.0)
# (6626, 95000.0, 63000.0)
# (6627, 118000.0, 78000.0)
# (6628, 218500.0, 148600.0)
# (6635, 70865.0, 47240.0)
# (6637, 130000.0, 130000.0)
# (6640, 90000.0, 63200.0)
# (6642, 92000.0, 62000.0)
# (6643, 205500.0, 139800.0)
# (6645, 139800.0, 95100.0)
# (6646, 139000.0, 65000.0)
# (6650, 129089.0, 93883.0)
# (6654, 191000.0, 124000.0)
# (6655, 210000.0, 126000.0)
# (6657, 165000.0, 130796.0)
# (6658, 122500.0, 87500.0)
# (7124, 100000.0, 70000.0)
# (7125, 70000.0, 60000.0)
# (7126, 150000.0, 125000.0)
# (7127, 160000.0, 90000.0)
# (7128, 110000.0, 80000.0)
# (7129, 120000.0, 75000.0)
# (7130, 140000.0, 120000.0)
# (7131, 80000.0, 60000.0)
# (7132, 120000.0, 90000.0)
# (7133, 130000.0, 100000.0)
# (7134, 130000.0, 95000.0)
# (7137, 220000.0, 166900.0)
# (7141, 145000.0, 107000.0)
# (7147, 155000.0, 130500.0)
# (7157, 110000.0, 90000.0)
# (7159, 75000.0, 50000.0)
# (7162, 194400.0, 116600.0)
# (7163, 400000.0, 102800.0)
# (7165, 220000.0, 180000.0)
# (7166, 62500.0, 42500.0)
# (7170, 95000.0, 85000.0)
# (7174, 271200.0, 220300.0)
# Length of the result for 3a-1 :  119
# SQL Execution time: 0.010532140731811523
# (1, 'SIMPLE', 'sa', None, 'ALL', None, None, None, None, 259, 1.11, 'Using where')
# Avg total time SQL-Query 3a-1  =  0.00583195686340332

# %% [markdown]
# With optimization

# %%
print()
#mycursor.execute(sqlquery_index)
mycursor.execute(sqlquery_index2)
print("After optimization")
sql_query_result(sql_query1,name)
sql_query_explain(sql_query1)
sql_query_avg_time(sql_query1,x,name)
#ONLY RUN IF INDEX EXISTS
#mycursor.execute(drop_index)
mycursor.execute(drop_index2)
# Out:
# After optimization
# (4571, 53000.0, 50000.0)
# (4528, 55000.0, 42000.0)
# (4529, 55000.0, 50000.0)
# (4572, 58500.0, 50000.0)
# (1394, 60000.0, 50000.0)
# (1396, 60000.0, 55000.0)
# (1398, 60000.0, 55000.0)
# (1399, 60000.0, 55000.0)
# (1401, 60000.0, 55000.0)
# (1403, 60000.0, 55000.0)
# (4555, 60000.0, 56000.0)
# (7166, 62500.0, 42500.0)
# (1412, 62500.0, 50000.0)
# (1434, 65000.0, 55000.0)
# (4558, 65000.0, 57000.0)
# (4576, 65000.0, 57000.0)
# (1391, 66000.0, 60000.0)
# (1404, 66000.0, 60000.0)
# (7125, 70000.0, 60000.0)
# (6635, 70865.0, 47240.0)
# (4511, 73912.8, 58500.0)
# (7159, 75000.0, 50000.0)
# (7131, 80000.0, 60000.0)
# (1393, 80000.0, 70000.0)
# (4581, 80000.0, 70000.0)
# (4505, 85000.0, 55000.0)
# (1406, 85000.0, 65000.0)
# (4524, 85000.0, 69200.0)
# (4577, 85300.0, 17484.0)
# (6640, 90000.0, 63200.0)
# (4521, 91052.0, 63935.0)
# (6642, 92000.0, 62000.0)
# (6626, 95000.0, 63000.0)
# (7170, 95000.0, 85000.0)
# (7124, 100000.0, 70000.0)
# (1408, 100000.0, 80000.0)
# (4591, 101764.0, 100000.0)
# (6613, 105200.0, 46700.0)
# (4560, 108191.0, 86767.2)
# (7128, 110000.0, 80000.0)
# (7157, 110000.0, 90000.0)
# (1432, 115000.0, 100000.0)
# (4550, 117000.0, 90000.0)
# (6627, 118000.0, 78000.0)
# (7129, 120000.0, 75000.0)
# (7132, 120000.0, 90000.0)
# (1427, 120000.0, 100000.0)
# (1415, 120000.0, 105000.0)
# (6658, 122500.0, 87500.0)
# (4501, 122951.0, 73770.8)
# (4523, 124410.0, 109276.0)
# (4557, 125000.0, 120000.0)
# (4582, 126400.0, 88500.0)
# (6650, 129089.0, 93883.0)
# (7134, 130000.0, 95000.0)
# (7133, 130000.0, 100000.0)
# (4573, 130000.0, 110500.0)
# (4569, 130000.0, 120000.0)
# (6637, 130000.0, 130000.0)
# (1439, 130400.0, 80000.0)
# (4546, 132800.0, 101900.0)
# (4565, 132800.0, 101900.0)
# (4504, 133120.0, 111900.0)
# (4570, 135000.0, 114750.0)
# (6646, 139000.0, 65000.0)
# (6645, 139800.0, 95100.0)
# (7130, 140000.0, 120000.0)
# (4575, 144811.0, 103436.0)
# (7141, 145000.0, 107000.0)
# (1426, 150000.0, 75996.0)
# (7126, 150000.0, 125000.0)
# (6623, 151800.0, 94200.0)
# (7147, 155000.0, 130500.0)
# (4517, 157500.0, 117200.0)
# (4526, 157500.0, 117200.0)
# (4527, 157500.0, 117200.0)
# (4547, 157500.0, 117200.0)
# (4566, 157500.0, 117200.0)
# (4567, 157500.0, 117200.0)
# (4568, 157500.0, 117200.0)
# (4600, 157500.0, 117200.0)
# (4601, 157500.0, 117200.0)
# (4602, 157500.0, 117200.0)
# (4603, 157500.0, 117200.0)
# (4604, 157500.0, 117200.0)
# (7127, 160000.0, 90000.0)
# (1419, 162250.0, 106000.0)
# (1420, 162250.0, 106000.0)
# (1421, 162250.0, 106000.0)
# (6657, 165000.0, 130796.0)
# (4520, 170443.0, 108057.0)
# (1422, 175125.0, 85000.0)
# (1397, 175200.0, 109500.0)
# (4516, 185300.0, 136000.0)
# (4545, 185300.0, 136000.0)
# (4597, 185300.0, 136000.0)
# (4598, 185300.0, 136000.0)
# (4599, 185300.0, 136000.0)
# (4531, 190000.0, 175000.0)
# (6654, 191000.0, 124000.0)
# (7162, 194400.0, 116600.0)
# (6625, 200000.0, 136000.0)
# (6643, 205500.0, 139800.0)
# (6655, 210000.0, 126000.0)
# (4554, 215000.0, 175000.0)
# (6628, 218500.0, 148600.0)
# (7137, 220000.0, 166900.0)
# (7165, 220000.0, 180000.0)
# (1416, 234563.0, 156340.0)
# (1438, 243300.0, 127600.0)
# (1440, 243300.0, 127600.0)
# (1425, 250000.0, 175000.0)
# (4549, 250000.0, 200000.0)
# (4536, 264000.0, 80000.0)
# (7174, 271200.0, 220300.0)
# (4537, 345000.0, 315000.0)
# (7163, 400000.0, 102800.0)
# (6612, 450000.0, 350000.0)
# (4514, 500000.0, 100000.0)
# Length of the result for 3a-1 :  119
# SQL Execution time: 0.004030704498291016
# (1, 'SIMPLE', 'sa', None, 'range', 'index_salary2', 'index_salary2', '1028', None, 119, 33.33, 'Using where; Using index')
# Avg total time SQL-Query 3a-1  =  0.00576314926147461

# %% [markdown]
# ##### Mongo

# %%
mongo_query_result(mongo_query1,salaries_collection,name)
mongo_query_avg_time(mongo_query1,salaries_collection,x,name)
# Out:
# {'salary_id': 1399, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 4577, 'max_salary': 85300.0, 'min_salary': 17484.0}
# {'salary_id': 7124, 'max_salary': 100000.0, 'min_salary': 70000.0}
# {'salary_id': 1434, 'max_salary': 65000.0, 'min_salary': 55000.0}
# {'salary_id': 7130, 'max_salary': 140000.0, 'min_salary': 120000.0}
# {'salary_id': 4568, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1422, 'max_salary': 175125.0, 'min_salary': 85000.0}
# {'salary_id': 1406, 'max_salary': 85000.0, 'min_salary': 65000.0}
# {'salary_id': 6654, 'max_salary': 191000.0, 'min_salary': 124000.0}
# {'salary_id': 4511, 'max_salary': 73912.8, 'min_salary': 58500.0}
# {'salary_id': 1398, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 6655, 'max_salary': 210000.0, 'min_salary': 126000.0}
# {'salary_id': 6657, 'max_salary': 165000.0, 'min_salary': 130796.0}
# {'salary_id': 1391, 'max_salary': 66000.0, 'min_salary': 60000.0}
# {'salary_id': 4547, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4576, 'max_salary': 65000.0, 'min_salary': 57000.0}
# {'salary_id': 4529, 'max_salary': 55000.0, 'min_salary': 50000.0}
# {'salary_id': 4546, 'max_salary': 132800.0, 'min_salary': 101900.0}
# {'salary_id': 1425, 'max_salary': 250000.0, 'min_salary': 175000.0}
# {'salary_id': 4520, 'max_salary': 170443.0, 'min_salary': 108057.0}
# {'salary_id': 7127, 'max_salary': 160000.0, 'min_salary': 90000.0}
# {'salary_id': 6625, 'max_salary': 200000.0, 'min_salary': 136000.0}
# {'salary_id': 7166, 'max_salary': 62500.0, 'min_salary': 42500.0}
# {'salary_id': 4599, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7129, 'max_salary': 120000.0, 'min_salary': 75000.0}
# {'salary_id': 4527, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4591, 'max_salary': 101764.0, 'min_salary': 100000.0}
# {'salary_id': 4575, 'max_salary': 144811.0, 'min_salary': 103436.0}
# {'salary_id': 1393, 'max_salary': 80000.0, 'min_salary': 70000.0}
# {'salary_id': 4523, 'max_salary': 124410.0, 'min_salary': 109276.0}
# {'salary_id': 4598, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7174, 'max_salary': 271200.0, 'min_salary': 220300.0}
# {'salary_id': 7170, 'max_salary': 95000.0, 'min_salary': 85000.0}
# {'salary_id': 4516, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 6643, 'max_salary': 205500.0, 'min_salary': 139800.0}
# {'salary_id': 4582, 'max_salary': 126400.0, 'min_salary': 88500.0}
# {'salary_id': 4572, 'max_salary': 58500.0, 'min_salary': 50000.0}
# {'salary_id': 6623, 'max_salary': 151800.0, 'min_salary': 94200.0}
# {'salary_id': 4566, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1420, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 6640, 'max_salary': 90000.0, 'min_salary': 63200.0}
# {'salary_id': 1440, 'max_salary': 243300.0, 'min_salary': 127600.0}
# {'salary_id': 1421, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 4536, 'max_salary': 264000.0, 'min_salary': 80000.0}
# {'salary_id': 4567, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 6627, 'max_salary': 118000.0, 'min_salary': 78000.0}
# {'salary_id': 6646, 'max_salary': 139000.0, 'min_salary': 65000.0}
# {'salary_id': 7147, 'max_salary': 155000.0, 'min_salary': 130500.0}
# {'salary_id': 1403, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 4602, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 6626, 'max_salary': 95000.0, 'min_salary': 63000.0}
# {'salary_id': 1439, 'max_salary': 130400.0, 'min_salary': 80000.0}
# {'salary_id': 4524, 'max_salary': 85000.0, 'min_salary': 69200.0}
# {'salary_id': 4565, 'max_salary': 132800.0, 'min_salary': 101900.0}
# {'salary_id': 4521, 'max_salary': 91052.0, 'min_salary': 63935.0}
# {'salary_id': 4573, 'max_salary': 130000.0, 'min_salary': 110500.0}
# {'salary_id': 7141, 'max_salary': 145000.0, 'min_salary': 107000.0}
# {'salary_id': 1397, 'max_salary': 175200.0, 'min_salary': 109500.0}
# {'salary_id': 1412, 'max_salary': 62500.0, 'min_salary': 50000.0}
# {'salary_id': 7159, 'max_salary': 75000.0, 'min_salary': 50000.0}
# {'salary_id': 7162, 'max_salary': 194400.0, 'min_salary': 116600.0}
# {'salary_id': 4597, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 6628, 'max_salary': 218500.0, 'min_salary': 148600.0}
# {'salary_id': 6637, 'max_salary': 130000.0, 'min_salary': 130000.0}
# {'salary_id': 7133, 'max_salary': 130000.0, 'min_salary': 100000.0}
# {'salary_id': 6613, 'max_salary': 105200.0, 'min_salary': 46700.0}
# {'salary_id': 1408, 'max_salary': 100000.0, 'min_salary': 80000.0}
# {'salary_id': 7163, 'max_salary': 400000.0, 'min_salary': 102800.0}
# {'salary_id': 1426, 'max_salary': 150000.0, 'min_salary': 75996.0}
# {'salary_id': 4531, 'max_salary': 190000.0, 'min_salary': 175000.0}
# {'salary_id': 6645, 'max_salary': 139800.0, 'min_salary': 95100.0}
# {'salary_id': 7131, 'max_salary': 80000.0, 'min_salary': 60000.0}
# {'salary_id': 6658, 'max_salary': 122500.0, 'min_salary': 87500.0}
# {'salary_id': 7134, 'max_salary': 130000.0, 'min_salary': 95000.0}
# {'salary_id': 4517, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4570, 'max_salary': 135000.0, 'min_salary': 114750.0}
# {'salary_id': 4603, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4554, 'max_salary': 215000.0, 'min_salary': 175000.0}
# {'salary_id': 7128, 'max_salary': 110000.0, 'min_salary': 80000.0}
# {'salary_id': 6612, 'max_salary': 450000.0, 'min_salary': 350000.0}
# {'salary_id': 1438, 'max_salary': 243300.0, 'min_salary': 127600.0}
# {'salary_id': 1404, 'max_salary': 66000.0, 'min_salary': 60000.0}
# {'salary_id': 4600, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1427, 'max_salary': 120000.0, 'min_salary': 100000.0}
# {'salary_id': 1415, 'max_salary': 120000.0, 'min_salary': 105000.0}
# {'salary_id': 7165, 'max_salary': 220000.0, 'min_salary': 180000.0}
# {'salary_id': 7125, 'max_salary': 70000.0, 'min_salary': 60000.0}
# {'salary_id': 4526, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4501, 'max_salary': 122951.0, 'min_salary': 73770.8}
# {'salary_id': 4528, 'max_salary': 55000.0, 'min_salary': 42000.0}
# {'salary_id': 1394, 'max_salary': 60000.0, 'min_salary': 50000.0}
# {'salary_id': 1396, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 6650, 'max_salary': 129089.0, 'min_salary': 93883.0}
# {'salary_id': 4560, 'max_salary': 108191.0, 'min_salary': 86767.2}
# {'salary_id': 4604, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1419, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 4514, 'max_salary': 500000.0, 'min_salary': 100000.0}
# {'salary_id': 4537, 'max_salary': 345000.0, 'min_salary': 315000.0}
# {'salary_id': 4558, 'max_salary': 65000.0, 'min_salary': 57000.0}
# {'salary_id': 4581, 'max_salary': 80000.0, 'min_salary': 70000.0}
# {'salary_id': 4571, 'max_salary': 53000.0, 'min_salary': 50000.0}
# {'salary_id': 6642, 'max_salary': 92000.0, 'min_salary': 62000.0}
# {'salary_id': 4550, 'max_salary': 117000.0, 'min_salary': 90000.0}
# {'salary_id': 4549, 'max_salary': 250000.0, 'min_salary': 200000.0}
# {'salary_id': 4555, 'max_salary': 60000.0, 'min_salary': 56000.0}
# {'salary_id': 6635, 'max_salary': 70865.0, 'min_salary': 47240.0}
# {'salary_id': 1432, 'max_salary': 115000.0, 'min_salary': 100000.0}
# {'salary_id': 1401, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 1416, 'max_salary': 234563.0, 'min_salary': 156340.0}
# {'salary_id': 4505, 'max_salary': 85000.0, 'min_salary': 55000.0}
# {'salary_id': 7126, 'max_salary': 150000.0, 'min_salary': 125000.0}
# {'salary_id': 4601, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 7137, 'max_salary': 220000.0, 'min_salary': 166900.0}
# {'salary_id': 4504, 'max_salary': 133120.0, 'min_salary': 111900.0}
# {'salary_id': 4557, 'max_salary': 125000.0, 'min_salary': 120000.0}
# {'salary_id': 4569, 'max_salary': 130000.0, 'min_salary': 120000.0}
# {'salary_id': 4545, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7157, 'max_salary': 110000.0, 'min_salary': 90000.0}
# {'salary_id': 7132, 'max_salary': 120000.0, 'min_salary': 90000.0}
# Length of the result for 3a-1 :  119
# Mongo Execution time: 0.09665179252624512
# Avg total time Mongo-Query 3a-1  =  0.013785266876220703

# %% [markdown]
# With optimization

# %%
salaries_collection.create_index(mongoquery_index, name = "index1")
print(salaries_collection.index_information())

mongo_query_result(mongo_query1,salaries_collection,name)
mongo_query_avg_time(mongo_query1,salaries_collection,x,name)
salaries_collection.drop_index('index1')
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}, 'index1': {'v': 2, 'key': [('pay_period', 1), ('max_salary', 1), ('min_salary', 1)]}}
# {'salary_id': 1399, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 4577, 'max_salary': 85300.0, 'min_salary': 17484.0}
# {'salary_id': 7124, 'max_salary': 100000.0, 'min_salary': 70000.0}
# {'salary_id': 1434, 'max_salary': 65000.0, 'min_salary': 55000.0}
# {'salary_id': 7130, 'max_salary': 140000.0, 'min_salary': 120000.0}
# {'salary_id': 4568, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1422, 'max_salary': 175125.0, 'min_salary': 85000.0}
# {'salary_id': 1406, 'max_salary': 85000.0, 'min_salary': 65000.0}
# {'salary_id': 6654, 'max_salary': 191000.0, 'min_salary': 124000.0}
# {'salary_id': 4511, 'max_salary': 73912.8, 'min_salary': 58500.0}
# {'salary_id': 1398, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 6657, 'max_salary': 165000.0, 'min_salary': 130796.0}
# {'salary_id': 6655, 'max_salary': 210000.0, 'min_salary': 126000.0}
# {'salary_id': 1391, 'max_salary': 66000.0, 'min_salary': 60000.0}
# {'salary_id': 4547, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4576, 'max_salary': 65000.0, 'min_salary': 57000.0}
# {'salary_id': 4529, 'max_salary': 55000.0, 'min_salary': 50000.0}
# {'salary_id': 4546, 'max_salary': 132800.0, 'min_salary': 101900.0}
# {'salary_id': 1425, 'max_salary': 250000.0, 'min_salary': 175000.0}
# {'salary_id': 4520, 'max_salary': 170443.0, 'min_salary': 108057.0}
# {'salary_id': 7127, 'max_salary': 160000.0, 'min_salary': 90000.0}
# {'salary_id': 7166, 'max_salary': 62500.0, 'min_salary': 42500.0}
# {'salary_id': 6625, 'max_salary': 200000.0, 'min_salary': 136000.0}
# {'salary_id': 4599, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7129, 'max_salary': 120000.0, 'min_salary': 75000.0}
# {'salary_id': 4527, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4591, 'max_salary': 101764.0, 'min_salary': 100000.0}
# {'salary_id': 4575, 'max_salary': 144811.0, 'min_salary': 103436.0}
# {'salary_id': 1393, 'max_salary': 80000.0, 'min_salary': 70000.0}
# {'salary_id': 4523, 'max_salary': 124410.0, 'min_salary': 109276.0}
# {'salary_id': 4598, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7174, 'max_salary': 271200.0, 'min_salary': 220300.0}
# {'salary_id': 7170, 'max_salary': 95000.0, 'min_salary': 85000.0}
# {'salary_id': 4516, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 6643, 'max_salary': 205500.0, 'min_salary': 139800.0}
# {'salary_id': 4582, 'max_salary': 126400.0, 'min_salary': 88500.0}
# {'salary_id': 6623, 'max_salary': 151800.0, 'min_salary': 94200.0}
# {'salary_id': 4572, 'max_salary': 58500.0, 'min_salary': 50000.0}
# {'salary_id': 4566, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1420, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 6640, 'max_salary': 90000.0, 'min_salary': 63200.0}
# {'salary_id': 1440, 'max_salary': 243300.0, 'min_salary': 127600.0}
# {'salary_id': 4567, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1421, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 4536, 'max_salary': 264000.0, 'min_salary': 80000.0}
# {'salary_id': 6627, 'max_salary': 118000.0, 'min_salary': 78000.0}
# {'salary_id': 6646, 'max_salary': 139000.0, 'min_salary': 65000.0}
# {'salary_id': 7147, 'max_salary': 155000.0, 'min_salary': 130500.0}
# {'salary_id': 1403, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 4602, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 6626, 'max_salary': 95000.0, 'min_salary': 63000.0}
# {'salary_id': 1439, 'max_salary': 130400.0, 'min_salary': 80000.0}
# {'salary_id': 4524, 'max_salary': 85000.0, 'min_salary': 69200.0}
# {'salary_id': 4565, 'max_salary': 132800.0, 'min_salary': 101900.0}
# {'salary_id': 4521, 'max_salary': 91052.0, 'min_salary': 63935.0}
# {'salary_id': 4573, 'max_salary': 130000.0, 'min_salary': 110500.0}
# {'salary_id': 7141, 'max_salary': 145000.0, 'min_salary': 107000.0}
# {'salary_id': 1397, 'max_salary': 175200.0, 'min_salary': 109500.0}
# {'salary_id': 1412, 'max_salary': 62500.0, 'min_salary': 50000.0}
# {'salary_id': 7159, 'max_salary': 75000.0, 'min_salary': 50000.0}
# {'salary_id': 7162, 'max_salary': 194400.0, 'min_salary': 116600.0}
# {'salary_id': 4597, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 6637, 'max_salary': 130000.0, 'min_salary': 130000.0}
# {'salary_id': 6628, 'max_salary': 218500.0, 'min_salary': 148600.0}
# {'salary_id': 7133, 'max_salary': 130000.0, 'min_salary': 100000.0}
# {'salary_id': 6613, 'max_salary': 105200.0, 'min_salary': 46700.0}
# {'salary_id': 1408, 'max_salary': 100000.0, 'min_salary': 80000.0}
# {'salary_id': 7163, 'max_salary': 400000.0, 'min_salary': 102800.0}
# {'salary_id': 1426, 'max_salary': 150000.0, 'min_salary': 75996.0}
# {'salary_id': 7131, 'max_salary': 80000.0, 'min_salary': 60000.0}
# {'salary_id': 6645, 'max_salary': 139800.0, 'min_salary': 95100.0}
# {'salary_id': 4531, 'max_salary': 190000.0, 'min_salary': 175000.0}
# {'salary_id': 6658, 'max_salary': 122500.0, 'min_salary': 87500.0}
# {'salary_id': 7134, 'max_salary': 130000.0, 'min_salary': 95000.0}
# {'salary_id': 4517, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4570, 'max_salary': 135000.0, 'min_salary': 114750.0}
# {'salary_id': 4603, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4554, 'max_salary': 215000.0, 'min_salary': 175000.0}
# {'salary_id': 7128, 'max_salary': 110000.0, 'min_salary': 80000.0}
# {'salary_id': 6612, 'max_salary': 450000.0, 'min_salary': 350000.0}
# {'salary_id': 1438, 'max_salary': 243300.0, 'min_salary': 127600.0}
# {'salary_id': 1404, 'max_salary': 66000.0, 'min_salary': 60000.0}
# {'salary_id': 4600, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 1427, 'max_salary': 120000.0, 'min_salary': 100000.0}
# {'salary_id': 1415, 'max_salary': 120000.0, 'min_salary': 105000.0}
# {'salary_id': 7165, 'max_salary': 220000.0, 'min_salary': 180000.0}
# {'salary_id': 7125, 'max_salary': 70000.0, 'min_salary': 60000.0}
# {'salary_id': 4526, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4501, 'max_salary': 122951.0, 'min_salary': 73770.8}
# {'salary_id': 6650, 'max_salary': 129089.0, 'min_salary': 93883.0}
# {'salary_id': 4528, 'max_salary': 55000.0, 'min_salary': 42000.0}
# {'salary_id': 1396, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 1394, 'max_salary': 60000.0, 'min_salary': 50000.0}
# {'salary_id': 4560, 'max_salary': 108191.0, 'min_salary': 86767.2}
# {'salary_id': 4604, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 4558, 'max_salary': 65000.0, 'min_salary': 57000.0}
# {'salary_id': 1419, 'max_salary': 162250.0, 'min_salary': 106000.0}
# {'salary_id': 4537, 'max_salary': 345000.0, 'min_salary': 315000.0}
# {'salary_id': 4581, 'max_salary': 80000.0, 'min_salary': 70000.0}
# {'salary_id': 4514, 'max_salary': 500000.0, 'min_salary': 100000.0}
# {'salary_id': 4571, 'max_salary': 53000.0, 'min_salary': 50000.0}
# {'salary_id': 6642, 'max_salary': 92000.0, 'min_salary': 62000.0}
# {'salary_id': 4550, 'max_salary': 117000.0, 'min_salary': 90000.0}
# {'salary_id': 4549, 'max_salary': 250000.0, 'min_salary': 200000.0}
# {'salary_id': 4555, 'max_salary': 60000.0, 'min_salary': 56000.0}
# {'salary_id': 6635, 'max_salary': 70865.0, 'min_salary': 47240.0}
# {'salary_id': 1432, 'max_salary': 115000.0, 'min_salary': 100000.0}
# {'salary_id': 1401, 'max_salary': 60000.0, 'min_salary': 55000.0}
# {'salary_id': 1416, 'max_salary': 234563.0, 'min_salary': 156340.0}
# {'salary_id': 4505, 'max_salary': 85000.0, 'min_salary': 55000.0}
# {'salary_id': 7126, 'max_salary': 150000.0, 'min_salary': 125000.0}
# {'salary_id': 4601, 'max_salary': 157500.0, 'min_salary': 117200.0}
# {'salary_id': 7137, 'max_salary': 220000.0, 'min_salary': 166900.0}
# {'salary_id': 4557, 'max_salary': 125000.0, 'min_salary': 120000.0}
# {'salary_id': 4504, 'max_salary': 133120.0, 'min_salary': 111900.0}
# {'salary_id': 4569, 'max_salary': 130000.0, 'min_salary': 120000.0}
# {'salary_id': 4545, 'max_salary': 185300.0, 'min_salary': 136000.0}
# {'salary_id': 7157, 'max_salary': 110000.0, 'min_salary': 90000.0}
# {'salary_id': 7132, 'max_salary': 120000.0, 'min_salary': 90000.0}
# Length of the result for 3a-1 :  119
# Mongo Execution time: 0.01770639419555664
# Avg total time Mongo-Query 3a-1  =  0.006117701530456543

# %% [markdown]
# ## Query 3a - 2

# %% [markdown]
# Esta consulta utiliza uma expressão de tabela comum e a função de janela ROW_NUMBER() para classificar as empresas com base no número de ofertas de emprego em cada localização. O resultado final inclui apenas as empresas com o maior número de ofertas de emprego em cada local.

# %%
name = "3a-2"
sql_query2 = ("WITH ranked_postings AS ("
              "SELECT company_id, location, ROW_NUMBER() OVER (PARTITION BY location ORDER BY COUNT(*) DESC) AS posting_rank "
              "FROM job_postings GROUP BY company_id, location)"
              "SELECT company_id, location FROM ranked_postings WHERE posting_rank = 1;")

sql_query2_index = "CREATE INDEX location_index ON job_postings (location(255));"

drop_index = "DROP INDEX location_index ON job_postings"

index_definition = [
    ("location", 1),
    ("count", -1)
]
jobs_collection.create_index(index_definition)

mongo_query2 = [
    {"$group": {"_id": {"company_id": "$company_id", "location": "$location"},
                "count": {"$sum": 1}
                }
     },
    {"$sort": {"_id.location": 1, "count": -1}},
    {"$group": {"_id": "$_id.location",
                "topCompany": {"$first": "$_id.company_id"}}
     },
    {"$project": {"_id": 0, "company_id": "$topCompany", "location": "$_id"}}
]

# %% [markdown]
# #### Result:

# %% [markdown]
# ##### SQL

# %%
sql_query_result(sql_query2,name)
sql_query_explain(sql_query2)
sql_query_avg_time(sql_query2,x,name)
# Out:
# (28615633, 'Aberdeen Proving Ground, MD')
# (1013110, 'Aberdeen, MD')
# (3706049, 'Aberdeen, WA')
# (17226, 'Abilene, TX')
# (2700167, 'Abingdon, VA')
# (3625, 'Abo, MO')
# (115116, 'Acampo, CA')
# (25567, 'Acton, MA')
# (3570660, 'Ada, MI')
# (7064, 'Ada, OK')
# (1482552, 'Addison, IL')
# (77301, 'Addison, TX')
# (27180004, 'Adrian, MI')
# (581824, 'Agoura Hills, CA')
# (1386950, 'Aiken, SC')
# (23182, 'Akron, OH')
# (5323150, 'Alabama, United States')
# (18506580, 'Alabaster, AL')
# (98488356, 'Alachua, FL')
# (8437, 'Alamance, NC')
# (18924711, 'Alameda County, CA')
# (808034, 'Alameda, CA')
# (15472, 'Alamo Heights, TX')
# (2646, 'Alamosa, CO')
# (3558, 'Albany, GA')
# (28409, 'Albany, New York Metropolitan Area')
# (1302410, 'Albany, NY')
# (14542824, 'Albany, OR')
# (18009221, 'Albemarle, NC')
# (2943678, 'Albuquerque-Santa Fe Metropolitan Area')
# (1945473, 'Albuquerque, NM')
# (5755, 'Alburtis, PA')
# (10854676, 'Alden, NY')
# (82153, 'Aledo, TX')
# (13309, 'Alexandria City County, VA')
# (6062532, 'Alexandria, LA')
# (1403, 'Alexandria, VA')
# (77301, 'Algonquin, IL')
# (25081, 'Alhambra, CA')
# (113097, 'Alice, TX')
# (9814, 'Aliso Viejo, CA')
# (121618, 'All Seasons Lake Park, OH')
# (165447, 'Allegan, MI')
# (2251, 'Allen, TX')
# (71904349, 'Allendale, NJ')
# (78114, 'Allentown, PA')
# (20009, 'Allenwood, PA')
# (6592, 'Alliance, OH')
# (10640818, 'Alma, MI')
# (3706049, 'Alpena, MI')
# (1103, 'Alpharetta, GA')
# (11758, 'Alsip, IL')
# (4453, 'Altoona, IA')
# (1703, 'Altoona, PA')
# (3706049, 'Alturas, CA')
# (53252, 'Alvin, TX')
# (315817, 'Amarillo, TX')
# (11824180, 'Ambler, PA')
# (3963605, 'American Fork, UT')
# (683310, 'Ames, IA')
# (16995, 'Amesbury, MA')
# (46000, 'Amherst, NH')
# (28923, 'Amherst, NY')
# (86041588, 'Amityville, NY')
# (12890, 'Ammon, ID')
# (6913, 'Amsterdam, NY')
# (13856, 'Anacortes, WA')
# (3570660, 'Anaheim, CA')
# (26923, 'Anchorage, AK')
# (3469, 'Anderson, SC')
# (15451728, 'Andover, KS')
# (53452, 'Andover, MA')
# (3476, 'Andrews, SC')
# (19368, 'Angels Camp, CA')
# (2562, 'Angleton, TX')
# (1526, 'Ankeny, IA')
# (78636, 'Ann Arbor, MI')
# (1403, 'Annapolis Junction, MD')
# (18062, 'Annapolis, MD')
# (68941, 'Anniston, AL')
# (74994575, 'Anoka, MN')
# (2193256, 'Antigo, WI')
# (2910116, 'Antioch, IL')
# (2252, 'Antioch, TN')
# (82808548, 'Anton Chico, NM')
# (690568, 'Apache Junction, AZ')
# (4324, 'Apex, NC')
# (14832, 'Apollo Beach, FL')
# (74161427, 'Apopka, FL')
# (2646, 'Apple Valley, CA')
# (96180361, 'Apple Valley, MN')
# (6233, 'Appleton, WI')
# (4297, 'Appomattox, VA')
# (4111455, 'Arabi, LA')
# (1668, 'Arcata, CA')
# (55185007, 'Arden Hills, MN')
# (18860134, 'Arden, NC')
# (869141, 'Arizona, United States')
# (1464, 'Arkadelphia, AR')
# (162724, 'Arkansas, United States')
# (598372, 'Arlington Heights, IL')
# (1103, 'Arlington, MA')
# (166680, 'Arlington, TX')
# (1403, 'Arlington, VA')
# (372915, 'Armonk, NY')
# (15473, 'Arnold, MO')
# (43093, 'Artesia, MS')
# (373399, 'Arvada, CO')
# (1103, 'Ashburn, VA')
# (28169, 'Asheville, NC')
# (3570660, 'Ashland, MA')
# (70696, 'Ashland, MT')
# (4798, 'Ashland, VA')
# (2646, 'Ashland, WI')
# (33190802, 'Aspen, CO')
# (35561284, 'Atascadero, CA')
# (162828, 'Atchison, KS')
# (7587370, 'Athens, GA')
# (26205, 'Athens, OH')
# (1945473, 'Athens, TX')
# (1374999, 'Athol, ID')
# (163139, 'Atlanta Metropolitan Area')
# (3558, 'Atlanta, GA')
# (64746547, 'Atlantis, FL')
# (164200, 'Attleboro, MA')
# (1236687, 'Atwater, CA')
# (68796640, 'Auburn Hills, MI')
# (5343, 'Auburn, AL')
# (11056, 'Auburn, CA')
# (31065, 'Auburn, GA')
# (20573, 'Auburn, MA')
# (2562, 'Auburn, MI')
# (1945473, 'Auburn, NY')
# (71575605, 'Auburn, WA')
# (11440, 'Audubon, PA')
# (37235, 'Augusta, GA')
# (2137, 'Augusta, ME')
# (3672, 'Aurora, CO')
# (2736008, 'Aurora, Colorado, United States')
# (35504, 'Aurora, IL')
# (10147, 'Aurora, OH')
# (46000, 'Austell, GA')
# (164249, 'Austin Township, MN')
# (11618, 'Austin, MN')
# (163139, 'Austin, Texas Metropolitan Area')
# (3162, 'Austin, TX')
# (25963, 'Avenel, NJ')
# (283807, 'Aventura, FL')
# (66278935, 'Avon Lake, OH')
# (1103, 'Avon, MA')
# (79892817, 'Avon, MN')
# (85320, 'Avon, NY')
# (3570660, 'Avon, OH')
# (596893, 'Avondale, AZ')
# (162828, 'Avondale, LA')
# (828170, 'Ayer, MA')
# (2701866, 'Bagdad, AZ')
# (14542824, 'Baker, MT')
# (1945473, 'Baker, WV')
# (12820, 'Bakersfield, CA')
# (89989306, 'Bal Harbour, FL')
# (65549321, 'Bala-Cynwyd, PA')
# (2721914, 'Baldwin City, KS')
# (18506580, 'Baldwin Park, CA')
# (22309011, 'Ballwin, MO')
# (5127650, 'Baltimore County, MD')
# (1945473, 'Baltimore, MD')
# (18312164, 'Baltimore, OH')
# (1945473, 'Bangor, ME')
# (41004, 'Banner Elk, NC')
# (13353, 'Baraboo, WI')
# (788707, 'Barberton, OH')
# (18758749, 'Bardstown, KY')
# (32380, 'Bargersville, IN')
# (16726, 'Barstow, CA')
# (10420321, 'Bartlesville, OK')
# (598372, 'Bartlett, IL')
# (16101273, 'Bartlett, TN')
# (1235, 'Bartonville, TX')
# (906762, 'Bartow, FL')
# (1103, 'Basking Ridge, NJ')
# (166572, 'Bastrop, TX')
# (23656, 'Batavia, IL')
# (1511, 'Batavia, NY')
# (39249, 'Batavia, OH')
# (66252, 'Batesville, IN')
# (142560, 'Baton Rouge Metropolitan Area')
# (7587370, 'Baton Rouge, LA')
# (2381, 'Battle Creek, MI')
# (2646, 'Baxter, MN')
# (3180238, 'Bay City, MI')
# (9487, 'Bay Minette, AL')
# (19287, 'Bay St Louis, MS')
# (10517709, 'Bayport, NY')
# (48024, 'Baytown, TX')
# (203053, 'Bear, DE')
# (96180361, 'Beaufort, SC')
# (48024, 'Beaumont, TX')
# (11009726, 'Beaver Dam, WI')
# (15208770, 'Beaver, PA')
# (28974109, 'Beavercreek, OH')
# (79383535, 'Beaverton, OR')
# (14088, 'Beckett Ridge, OH')
# (90198358, 'Beckley, WV')
# (3579761, 'Bedford Park, IL')
# (2268831, 'Bedford, MA')
# (3706049, 'Bedford, PA')
# (96180361, 'Bedford, TX')
# (30823, 'Bedminster, NJ')
# (10769, 'Beeville, TX')
# (13181, 'Bel Air, MD')
# (1769216, 'Belcamp, MD')
# (8710, 'Belfast, ME')
# (75621179, 'Bellaire, TX')
# (22309011, 'Belleville, IL')
# (6592, 'Bellevue, OH')
# (37768, 'Bellevue, WA')
# (7032, 'Bellflower, CA')
# (165422, 'Bellingham, WA')
# (18472079, 'Bellmawr, NJ')
# (1160236, 'Bellows Falls, VT')
# (15941879, 'Belmar, NJ')
# (1273631, 'Belmont, CA')
# (3570660, 'Belmont, MA')
# (10420321, 'Beloit, WI')
# (16157996, 'Belton, MO')
# (570101, 'Beltsville, MD')
# (12434, 'Belvidere, IL')
# (6592, 'Bement, IL')
# (4857, 'Bend, OR')
# (936584, 'Benicia, CA')
# (1703, 'Bennington, VT')
# (80431008, 'Bensalem, PA')
# (4622, 'Benson, MN')
# (68463, 'Benton, AR')
# (2646, 'Benton, IL')
# (2646, 'Bentonville, AR')
# (2073870, 'Bergenfield, NJ')
# (890145, 'Berkeley Heights, NJ')
# (2519, 'Berkeley, CA')
# (5905495, 'Berlin, CT')
# (18506580, 'Berlin, NH')
# (9185, 'Berlin, NJ')
# (2168076, 'Berlin, VT')
# (3500602, 'Berlin, WI')
# (294502, 'Bernardsville, NJ')
# (13499, 'Berwyn, PA')
# (8281, 'Bethesda, MD')
# (15344142, 'Bethlehem, PA')
# (6104, 'Bethpage, NY')
# (79806, 'Beverly Hills, CA')
# (3706049, 'Beverly, MA')
# (14571, 'Bickleton, WA')
# (7410, 'Big Rapids, MI')
# (932563, 'Big Sky Meadow Village, MT')
# (587493, 'Big Spring, TX')
# (18506580, 'Big Stone Gap, VA')
# (37900, 'Billerica, MA')
# (14459, 'Billings, MT')
# (25039553, 'Biloxi, MS')
# (14571, 'Binghamton, NY')
# (157346, 'Birch Run, MI')
# (106584, 'Birmingham, AL')
# (3025562, 'Birmingham, MI')
# (28052, 'Biscoe, NC')
# (629227, 'Bishopville, SC')
# (1103, 'Bismarck, ND')
# (6442470, 'Black Mountain, NC')
# (2480405, 'Blacksburg, SC')
# (166811, 'Blacksburg, VA')
# (163025, 'Blaine, MN')
# (10420321, 'Blaine, WA')
# (1684870, 'Blairsville, GA')
# (81954233, 'Bloomfield Hills, MI')
# (88289095, 'Bloomfield, CT')
# (3706049, 'Bloomfield, NM')
# (91534, 'Bloomingdale, GA')
# (9308035, 'Bloomington–Normal, IL')
# (60561, 'Bloomington, IL')
# (104405, 'Bloomington, IN')
# (344707, 'Bloomington, MN')
# (7795, 'Bloomsburg, PA')
# (10358016, 'Bloomsbury, NJ')
# (18348487, 'Blue Ash, OH')
# (13920, 'Blue Bell, PA')
# (1805509, 'Blue Ridge, VA')
# (167757, 'Blue Springs, MO')
# (6592, 'Bluefield, WV')
# (164880, 'Bluffton, IN')
# (45970, 'Bluffton, SC')
# (808034, 'Blythe, CA')
# (23182, 'Boardman, OH')
# (73731, 'Boardman, OR')
# (166714, 'Boca Raton, FL')
# (49042, 'Boerne, TX')
# (3690, 'Boise, ID')
# (10035810, 'Bolingbrook, IL')
# (37902046, 'Bolivar, MO')
# (1283753, 'Bolivia, NC')
# (9185, 'Bonita Springs, FL')
# (22112, 'Boone, NC')
# (25856, 'Booneville, MS')
# (3706049, 'Boscawen, NH')
# (162513, 'Boston Heights, OH')
# (53713122, 'Boston Run, PA')
# (28978143, 'Boston, MA')
# (4060, 'Boston, Massachusetts, United States')
# (27253457, 'Bothell, WA')
# (43093, 'Boulder City, NV')
# (1441, 'Boulder, CO')
# (1867264, 'Bourne, MA')
# (65384923, 'Bowling Green Metropolitan Area')
# (2646, 'Bowling Green, KY')
# (8437, 'Bowling Green, OH')
# (1497, 'Boxborough, MA')
# (4181808, 'Boydton, VA')
# (1286891, 'Boylston, MA')
# (11227630, 'Boynton Beach, FL')
# (1286891, 'Boynton, GA')
# (5996, 'Bozeman, MT')
# (708393, 'Bradenton, FL')
# (71904349, 'Branchburg, NJ')
# (14749, 'Branchville, NJ')
# (79458773, 'Brandon, FL')
# (71904349, 'Branford, CT')
# (7795, 'Braselton, GA')
# (53508, 'Brawley, CA')
# (79560, 'Brea, CA')
# (526607, 'Breckenridge Hills, MO')
# (220336, 'Breckenridge, CO')
# (8017, 'Brecksville, OH')
# (89567861, 'Bremerton, WA')
# (166753, 'Brenham, TX')
# (30755, 'Brentwood, CA')
# (3249631, 'Brentwood, NY')
# (7795, 'Brentwood, TN')
# (1441, 'Bridgeport, AL')
# (2988, 'Bridgeport, CT')
# (61352, 'Bridgeport, TX')
# (2445, 'Bridgeport, WV')
# (1770225, 'Bridgeton, MO')
# (887776, 'Bridgeview, IL')
# (1339209, 'Bridgeville, PA')
# (1680, 'Bridgewater, NJ')
# (1087250, 'Bridgman, MI')
# (1471368, 'Bridgton, ME')
# (164376, 'Brier, WA')
# (4128, 'Brighton, CO')
# (50668, 'Brighton, MI')
# (157237, 'Brimfield, OH')
# (3693158, 'Brisbane, CA')
# (2073870, 'Bristol County, MA')
# (18921814, 'Bristol, CT')
# (65878041, 'Bristol, IN')
# (3109444, 'Bristol, PA')
# (1103, 'Bristol, TN')
# (15473, 'Bristow, VA')
# (2908367, 'Britton, SD')
# (41102, 'Broadview, IL')
# (7413, 'Brockton, MA')
# (40658652, 'Broken Arrow, OK')
# (21337, 'Bronx, NY')
# (25461, 'Brook Park, OH')
# (4918, 'Brookfield, WI')
# (999245, 'Brookline, MA')
# (1293049, 'Brooklyn Park, MN')
# (6104, 'Brooklyn, NY')
# (3252, 'Brooklyn, OH')
# (5195, 'Brookshire, TX')
# (1104193, 'Brooksville, FL')
# (164880, 'Brooktondale, NY')
# (73974, 'Brookville, OH')
# (2238, 'Broomfield, CO')
# (1410985, 'Brownsburg, IN')
# (22309011, 'Brownstown, MI')
# (14542824, 'Brownsville, TX')
# (9460096, 'Brownwood, TX')
# (808034, 'Brunswick, GA')
# (1703, 'Brunswick, ME')
# (76171420, 'Brunswick, TN')
# (4556, 'Bryan, TX')
# (660180, 'Bryant, AR')
# (11056, 'Bryn Mawr, PA')
# (7099708, 'Buckeye Lake, OH')
# (4128, 'Buckeye, AZ')
# (85123, 'Buda, TX')
# (166572, 'Buena Park, CA')
# (2652881, 'Buena, NJ')
# (10420321, 'Buffalo Grove, IL')
# (10894709, 'Buffalo-Niagara Falls Area')
# (164798, 'Buffalo, NY')
# (120240, 'Buffalo, WY')
# (1729578, 'Buford, GA')
# (46000, 'Bullhead City, AZ')
# (6979, 'Buras, LA')
# (29322289, 'Burbank, CA')
# (13074, 'Burien, WA')
# (10667, 'Burlingame, CA')
# (28978143, 'Burlington, MA')
# (18860134, 'Burlington, NC')
# (28149455, 'Burlington, NJ')
# (19107, 'Burlington, VT')
# (4324, 'Burlington, WA')
# (11056, 'Burnsville, MN')
# (1022308, 'Burrillville, RI')
# (12787, 'Butner, NC')
# (4822178, 'Byhalia, MS')
# (165472, 'Byron, GA')
# (10141, 'Cabazon, CA')
# (4324, 'Caddo Mills, TX')
# (1668, 'Cadillac, MI')
# (6593, 'Calabasas, CA')
# (856720, 'Caldwell, ID')
# (3570660, 'Caledonia, MI')
# (14287, 'Calera, AL')
# (315817, 'Calhoun, GA')
# (601919, 'California, United States')
# (163883, 'Calistoga, CA')
# (3681, 'Calvert, AL')
# (1274529, 'Camarillo, CA')
# (3570660, 'Camas, WA')
# (1441, 'Cambridge, MA')
# (64923472, 'Cambridge, MD')
# (1511, 'Cambridge, MN')
# (11402317, 'Camden, NJ')
# (29579, 'Camelback, California, United States')
# (28669777, 'Cameron, TX')
# (3658, 'Camp Hill, PA')
# (634422, 'Campbell, CA')
# (17937, 'Campbell, FL')
# (34683141, 'Canby, OR')
# (2701, 'Candler, NC')
# (258644, 'Cannon Falls, MN')
# (12669435, 'Canon City, CO')
# (3706049, 'Canton, GA')
# (28597931, 'Canton, MA')
# (12842, 'Canton, MI')
# (163828, 'Canton, NC')
# (164245, 'Canton, OH')
# (9185, 'Cantonment, FL')
# (2646, 'Canyon, TX')
# (25039398, 'Cape Canaveral, FL')
# (15691, 'Cape Coral Metropolitan Area')
# (283513, 'Cape Coral, FL')
# (14542824, 'Cape Girardeau, MO')
# (3706049, 'Cape May Court House, NJ')
# (72483, 'Capistrano Beach, CA')
# (981412, 'Capitan, NM')
# (2247, 'Capitol Heights, MD')
# (31815, 'Capitola, CA')
# (79042201, 'Capron, VA')
# (202443, 'Carbondale, PA')
# (62424, 'Cardiff-by-the-Sea, CA')
# (10877849, 'Carlisle, PA')
# (9814, 'Carlsbad, CA')
# (209610, 'Carlsbad, NM')
# (487174, 'Carmel, IN')
# (2646, 'Carmi, IL')
# (1468, 'Carmichaels, PA')
# (4128, 'Carnegie, PA')
# (3180238, 'Caro, MI')
# (55057585, 'Carol Stream, IL')
# (632911, 'Carpinteria, CA')
# (23858, 'Carrollton, GA')
# (4768, 'Carrollton, TX')
# (2137, 'Carson City, NV')
# (808034, 'Cartersville, GA')
# (57978, 'Carthage, MO')
# (28669777, 'Caruthersville, MO')
# (432241, 'Cary, NC')
# (214960, 'Casa Grande, AZ')
# (18506580, 'Casper, WY')
# (86639237, 'Caspian, MI')
# (74985, 'Castle Rock, CO')
# (808034, 'Castro Valley, CA')
# (220336, 'Cathedral City, CA')
# (444038, 'Catskill, NY')
# (4453, 'Cayce, SC')
# (23410, 'Cedar City, UT')
# (3240, 'Cedar Falls, IA')
# (28149455, 'Cedar Grove, NJ')
# (2251, 'Cedar Hill, TX')
# (3099084, 'Cedar Lake, IN')
# (1505, 'Cedar Rapids, IA')
# (808034, 'Centennial, CO')
# (20573, 'Centerville, TN')
# (2646, 'Central City, KY')
# (15241130, 'Central Islip, NY')
# (493453, 'Central, SC')
# (6913, 'Centralia, WA')
# (3706049, 'Centre Hall, PA')
# (15472, 'Centreville, VA')
# (609279, 'Ceres, CA')
# (5153, 'Cerritos, CA')
# (69601172, 'Chadds Ford, PA')
# (378234, 'Chalfont, PA')
# (73013724, 'Chambersburg, PA')
# (22208562, 'Champaign, IL')
# (26923, 'Champlin, MN')
# (104405, 'Chandler, AZ')
# (8034, 'Chanhassen, MN')
# (14255, 'Channahon, IL')
# (1403, 'Chantilly, VA')
# (166587, 'Chapel Hill, NC')
# (157353, 'Chappaqua, NY')
# (2936694, 'Charles City, IA')
# (2908367, 'Charleston, IL')
# (10877848, 'Charleston, SC')
# (51586544, 'Charleston, South Carolina Metropolitan Area')
# (1557409, 'Charleston, South Carolina, United States')
# (1043, 'Charleston, WV')
# (163139, 'Charlotte Metro')
# (814025, 'Charlotte, AR')
# (18425303, 'Charlotte, NC')
# (35651393, 'Charlotte, North Carolina, United States')
# (4298, 'Charlottesville, VA')
# (18106262, 'Charter Oak, CA')
# (10295, 'Chaska, MN')
# (164931, 'Chatham, IL')
# (2855513, 'Chattanooga, TN')
# (3450, 'Chelmsford, MA')
# (6756178, 'Chelsea, MI')
# (13074, 'Cheney, WA')
# (305287, 'Cheraw, SC')
# (4872230, 'Cherry Hill, NJ')
# (1317726, 'Chesapeake, VA')
# (1557409, 'Cheshire, CT')
# (78378963, 'Chester County, PA')
# (64923472, 'Chester, MD')
# (17233, 'Chester, PA')
# (1945473, 'Chester, SC')
# (46000, 'Chester, VA')
# (10974065, 'Chesterfield Township, MI')
# (884316, 'Chesterfield, MI')
# (248599, 'Chesterfield, MO')
# (1931371, 'Chestnut Hill, MA')
# (49042, 'Chevy Chase, MD')
# (70696, 'Cheyenne, WY')
# (2430668, 'Chicago Heights, IL')
# (36749, 'Chicago Ridge, IL')
# (2649, 'Chicago, IL')
# (12332, 'Chico, CA')
# (13542, 'Chicopee, MA')
# (14542824, 'Chillicothe, OH')
# (2646, 'Chilton, WI')
# (30755, 'Chino, CA')
# (42166, 'Chippewa Falls, WI')
# (3677, 'Chisago City, MN')
# (12890, 'Christiana, DE')
# (3617422, 'Christiansburg, VA')
# (14606618, 'Chula Vista, CA')
# (167757, 'Cicero, IL')
# (8781, 'Cincinnati Metropolitan Area')
# (2432, 'Cincinnati, OH')
# (107434, 'Circleville, OH')
# (4453, 'City of Industry, CA')
# (22523, 'City Park, UT')
# (34424, 'Clackamas, OR')
# (1703, 'Claremont, NH')
# (1908498, 'Claremore, OK')
# (10854676, 'Clarence, NY')
# (15434, 'Clarinda, IA')
# (1703, 'Clarion, PA')
# (28597765, 'Clarksboro, NJ')
# (10514179, 'Clarksburg, WV')
# (243836, 'Clarkston, MI')
# (7197, 'Clarksville, TN')
# (2301992, 'Claymont, DE')
# (2701866, 'Claypool, AZ')
# (164376, 'Clayton, MO')
# (41004, 'Clayton, NC')
# (1900, 'Clear Lake, IA')
# (1344, 'Clearwater, FL')
# (71316538, 'Clearwater, Florida, United States')
# (550530, 'Cleburne, TX')
# (1058190, 'Clemson, SC')
# (73202971, 'Clermont, FL')
# (3549, 'Cleveland Heights, OH')
# (45346, 'Cleveland, GA')
# (2203697, 'Cleveland, MS')
# (777243, 'Cleveland, OH')
# (9185, 'Cleveland, TN')
# (6979, 'Cliffwood, NJ')
# (18860134, 'Clifton Park, NY')
# (42134, 'Clifton, NJ')
# (20088, 'Clifton, TN')
# (4019848, 'Clinton Township, MI')
# (35504315, 'Clinton, IA')
# (2646, 'Clinton, IN')
# (32758, 'Clinton, MA')
# (1945473, 'Clinton, MD')
# (3534, 'Clinton, MS')
# (1211063, 'Clinton, NC')
# (12534, 'Clinton, NJ')
# (9676, 'Clinton, OK')
# (9596847, 'Clovis, CA')
# (1211063, 'Clyde, NC')
# (65294553, 'Clyde, NY')
# (8141, 'Coal City, IN')
# (76127808, 'Coatesville, PA')
# (3558, 'Cobb County, GA')
# (6176, 'Coconut Creek, FL')
# (5292867, "Coeur d'Alene, ID")
# (14658457, 'Cofield, NC')
# (19107, 'Colchester, VT')
# (808034, 'Coldwater, MI')
# (2973906, 'College Park, GA')
# (45575, 'College Park, MD')
# (4556, 'College Station, TX')
# (1399, 'Collegeville, PA')
# (82315512, 'Colleyville, TX')
# (72801, 'Collierville, TN')
# (90413667, 'Collins, MS')
# (9643, 'Collinsville, IL')
# (166774, 'Colonial Heights, VA')
# (39203, 'Colorado Springs, CO')
# (601919, 'Colorado, United States')
# (18506580, 'Colton, CA')
# (7947, 'Columbia, MD')
# (5442, 'Columbia, MO')
# (1943848, 'Columbia, MS')
# (23379, 'Columbia, PA')
# (12606850, 'Columbia, SC')
# (78124, 'Columbia, South Carolina Metropolitan Area')
# (7032, 'Columbia, TN')
# (92966191, 'Columbus metropolitan area, OH')
# (19180, 'Columbus, GA')
# (132002, 'Columbus, IN')
# (1943848, 'Columbus, MS')
# (2646, 'Columbus, NE')
# (8390, 'Columbus, OH')
# (200465, 'Columbus, Ohio Metropolitan Area')
# (2712856, 'Columbus, Ohio, United States')
# (5618, 'Commerce, CA')
# (537246, 'Concord, CA')
# (58602, 'Concord, MA')
# (49042, 'Concord, NC')
# (3706049, 'Concord, NH')
# (20088, 'Conneaut, OH')
# (64272643, 'Connecticut, United States')
# (71904349, 'Conover, NC')
# (7479, 'Conroe, TX')
# (17233, 'Conshohocken, PA')
# (14841964, 'Conway, AR')
# (21444, 'Conway, SC')
# (46000, 'Conyers, GA')
# (9499, 'Cool Spring, NC')
# (7929696, 'Coon Rapids, MN')
# (8817, 'Coopersburg, PA')
# (111108, 'Coos Bay, OR')
# (1515366, 'Coppell, TX')
# (15656, 'Coral Gables, FL')
# (14542824, 'Coral Springs, FL')
# (21041, 'Coralville, IA')
# (1463, 'Coraopolis, PA')
# (39540, 'Cordele, GA')
# (1945473, 'Cordova, AK')
# (6738, 'Core, WV')
# (12446, 'Corinth, MS')
# (9499, 'Cornelia, GA')
# (88289095, 'Corning, NY')
# (2074192, 'Corona del Mar, CA')
# (140581, 'Corona, CA')
# (35446044, 'Corpus Christi, TX')
# (165725, 'Corte Madera, CA')
# (6979, 'Cortland, NY')
# (18506580, 'Cortlandt Manor, NY')
# (14542824, 'Corvallis, OR')
# (1286891, 'Corydon, IA')
# (98209783, 'Cos Cob, CT')
# (602239, 'Coshocton, OH')
# (3316709, 'Costa Mesa, CA')
# (165422, 'Cottage Grove, OR')
# (104405, 'Cottleville, MO')
# (5343, 'Cottondale, AL')
# (34218836, 'Cottonwood, AZ')
# (1945473, 'Council Bluffs, IA')
# (14255, 'Country Club Hills, IL')
# (71904349, 'Coventry, RI')
# (468782, 'Covington, GA')
# (72483, 'Covington, KY')
# (3143932, 'Covington, LA')
# (808034, 'Covington, WA')
# (3706049, 'Coxsackie, NY')
# (2247, 'Cranberry Township, PA')
# (1284978, 'Crane, IN')
# (104396, 'Cranford, NJ')
# (2252, 'Cranston, RI')
# (14287, 'Crawford, TX')
# (12820, 'Creedmoor, NC')
# (2646, 'Crescent City, CA')
# (5242206, 'Crescent City, FL')
# (2646, 'Creston, IA')
# (89877420, 'Crestview, FL')
# (2615835, 'Crete, IL')
# (162828, 'Crete, NE')
# (468782, 'Creve Coeur, MO')
# (4031183, 'Cross Junction, VA')
# (15080, 'Cross Lanes, WV')
# (165294, 'Crown Point, IN')
# (1375621, 'Crystal City, MO')
# (113097, 'Crystal City, TX')
# (10420321, 'Crystal Lake, IL')
# (76171420, 'Crystal Springs, MS')
# (53959, 'Cudahy, WI')
# (4297, 'Culpeper, VA')
# (28439179, 'Culver City, CA')
# (3706049, 'Cumberland, MD')
# (5027745, 'Cumming, GA')
# (8299, 'Cupertino, CA')
# (7032, 'Cutler Bay, FL')
# (1263534, 'Cuyahoga Falls, OH')
# (25081, 'Cypress, CA')
# (9401140, 'Cypress, TX')
# (3570660, 'Dacula, GA')
# (34902814, 'Daggett, CA')
# (104405, 'Dakota Dunes, SD')
# (630847, 'Dakota, IL')
# (16995, 'Daleville, VA')
# (28893, 'Dallas County, TX')
# (76947396, 'Dallas-Fort Worth Metroplex')
# (1703, 'Dallas, GA')
# (17882, 'Dallas, Texas, United States')
# (6250, 'Dallas, TX')
# (269675, 'Dallastown, PA')
# (165472, 'Dalton, GA')
# (856720, 'Daly City, CA')
# (9177279, 'Damascus, MD')
# (35571114, 'Danbury, CT')
# (163253, 'Dania, FL')
# (8359, 'Danvers, MA')
# (1945473, 'Danville, IL')
# (7788794, 'Danville, PA')
# (9229, 'Danville, VA')
# (166551, 'Dardanelle, AR')
# (51701193, 'Dartmouth, MA')
# (688958, 'Dauphin County, PA')
# (18506580, 'Davenport, FL')
# (2736008, 'Davenport, IA')
# (64259963, 'Davidson, NC')
# (14542824, 'Davie, FL')
# (533823, 'Dawsonville, GA')
# (15259054, 'Dayton, OH')
# (164527, 'Dayton, TN')
# (861806, 'Daytona Beach, FL')
# (2193256, 'De Pere, WI')
# (68049148, 'De Witt, IA')
# (165299, 'Dearborn Heights, MI')
# (71904349, 'Dearborn, MI')
# (45716, 'Death Valley, CA')
# (2396310, 'Decatur, AL')
# (20009, 'Decatur, GA')
# (5553, 'Decatur, IL')
# (1943848, 'Decatur, MS')
# (4725, 'Decorah, IA')
# (9862, 'Dedham, MA')
# (1224492, 'Deephaven, MN')
# (22523, 'Deer Park, IL')
# (48024, 'Deer Park, TX')
# (49042, 'Deerfield Beach, FL')
# (71350, 'Deerfield, IL')
# (162723, 'DeKalb, IL')
# (2949451, 'Del Mar, CA')
# (82903338, 'DeLand, FL')
# (64980, 'Delano, CA')
# (23300, 'Delaware, OH')
# (162724, 'Delaware, United States')
# (2664556, 'Delmar, NY')
# (1781229, 'Delphi, IN')
# (1666657, 'Delray Beach, FL')
# (14542824, 'Delta, CO')
# (21667, 'Deltona, FL')
# (3706049, 'Demorest, GA')
# (21667, 'Denison, IA')
# (1497977, 'Denison, TX')
# (74994575, 'Denton, MD')
# (7795, 'Denton, TX')
# (89877420, 'Denver City, UT')
# (2652881, 'Denver Metropolitan Area')
# (3135, 'Denver, CO')
# (14611, 'Denver, Colorado, United States')
# (81480274, 'Denver, IN')
# (8807, 'Denver, NC')
# (39472, 'Denville, NJ')
# (3182370, 'Dermott, AR')
# (311841, 'Derry, NH')
# (17233, 'Derwood, MD')
# (3789, 'Des Moines Metropolitan Area')
# (265869, 'Des Moines, IA')
# (72483, 'Des Moines, WA')
# (31896, 'Des Plaines, IL')
# (92750, 'DeSoto, TX')
# (16733, 'Destin, FL')
# (37404866, 'Detroit Metropolitan Area')
# (7357, 'Detroit, MI')
# (23279, 'Devens, MA')
# (11056, 'Dexter, MI')
# (120859, 'Diamond Bar, CA')
# (3600, 'Dickinson, ND')
# (9184151, 'Dickson, TN')
# (14542824, 'Dillon, MT')
# (426121, 'Dimondale, MI')
# (2700167, 'Disputanta, VA')
# (28974109, 'District of Columbia, United States')
# (485407, 'Dobbs Ferry, NY')
# (104895, 'Dodge Center, MN')
# (164621, 'Dodge City, KS')
# (6083, 'Dodgeville, WI')
# (1151910, 'Doral, FL')
# (164880, 'Dorchester, MA')
# (3242, 'Dothan, AL')
# (2646, 'Douglas, GA')
# (7886, 'Douglasville, GA')
# (75997, 'Dover, DE')
# (7795, 'Dover, NH')
# (39472, 'Dover, NJ')
# (6913, 'Dowagiac, MI')
# (3612137, 'Downers Grove, IL')
# (3625, 'Downey, CA')
# (27055364, 'Downingtown, PA')
# (33264, 'Draper, UT')
# (165716, 'Dresden, TN')
# (1943848, 'Dripping Springs, TX')
# (20009, 'Drums, PA')
# (163079, 'Duarte, CA')
# (22561, 'Dublin, CA')
# (28209, 'Dublin, OH')
# (2087, 'Dublin, VA')
# (35504315, 'Dubuque, IA')
# (163690, 'Dudley, MA')
# (22132, 'Dulles Town Center, VA')
# (2470025, 'Dulles, VA')
# (11240, 'Duluth, GA')
# (1511, 'Duluth, MN')
# (3570660, 'Dumfries, VA')
# (2562128, 'Duncan, OK')
# (10954, 'Duncan, SC')
# (3658, 'Duncannon, PA')
# (23769122, 'Duncansville, PA')
# (62923, 'Dunn, NC')
# (30823, 'Dunwoody, GA')
# (10420321, 'Durham, CT')
# (22026, 'Durham, NC')
# (307494, 'Durham, NH')
# (12446, 'Eagan, MN')
# (10667, 'Eagle Mountain, UT')
# (7032, 'Eagle Pass, TX')
# (167757, 'Eagle, ID')
# (80911138, 'East Aurora, NY')
# (3570660, 'East Brunswick, NJ')
# (6176, 'East Dennis, MA')
# (80030090, 'East Durham, NY')
# (12890, 'East Grand Forks, MN')
# (88289095, 'East Hanover, NJ')
# (14632005, 'East Hartford, CT')
# (8795, 'East Lansing, MI')
# (5368909, 'East Longmeadow, MA')
# (167757, 'East Meadow, NY')
# (56313852, 'East Moline, IL')
# (33515668, 'East Norriton, PA')
# (19534, 'East Orange, NJ')
# (163883, 'East Palo Alto, CA')
# (1703, 'East Peoria, IL')
# (20573, 'East Providence, RI')
# (7471, 'East Rutherford, NJ')
# (32727, 'East St Louis, IL')
# (42304017, 'East Stoneham, ME')
# (82090049, 'East Syracuse, NY')
# (49042, 'Easton, MD')
# (3706049, 'Easton, PA')
# (334135, 'Eastpointe, MI')
# (6592, 'Eaton, OH')
# (65294553, 'Eau Claire, WI')
# (4674, 'Eddystone, PA')
# (157346, 'Eden Prairie, MN')
# (157353, 'Edgewater, NJ')
# (1403, 'Edgewood, MD')
# (11834, 'Edgewood, NY')
# (1293049, 'Edina, MN')
# (2640631, 'Edinboro, PA')
# (1557409, 'Edison, NJ')
# (77301, 'Edmond, OK')
# (2619961, 'Edwards, CA')
# (71575605, 'Edwardsville, IL')
# (9185, 'Egg Harbor, NJ')
# (3967883, 'Eglin Air Force Base, FL')
# (34218836, 'El Centro, CA')
# (7032, 'El Cerrito, CA')
# (3570660, 'El Dorado Hills, CA')
# (91161992, 'El Dorado, AR')
# (26873, 'El Monte, CA')
# (18924711, 'El Paso County, TX')
# (4029554, 'El Paso, TX')
# (1505, 'El Segundo, CA')
# (437225, 'Elgin, IL')
# (204770, 'Elgin, SC')
# (82291171, 'Elizabeth City, NC')
# (15626530, 'Elizabethtown, KY')
# (5887, 'Elizabethtown, PA')
# (10420321, 'Elk Grove Village, IL')
# (10696913, 'Elk Grove, CA')
# (2973906, 'Elkhart County, IN')
# (153293, 'Elkhart, IN')
# (11876, 'Elko, NV')
# (1486, 'Elkton, VA')
# (922640, 'Ellenville, NY')
# (16710, 'Ellettsville, IN')
# (49042, 'Ellicott City, MD')
# (77301, 'Ellisville, MO')
# (165034, 'Elma, NY')
# (5112, 'Elmendorf, TX')
# (11825945, 'Elmer, NJ')
# (1442109, 'Elmhurst, IL')
# (1087079, 'Elmira, NY')
# (11758, 'Elmsford, NY')
# (10420321, 'Elmwood Park, IL')
# (14255, 'Elwood, IL')
# (34821, 'Elwyn, PA')
# (4822178, 'Elyria, OH')
# (982614, 'Emeryville, CA')
# (18506580, 'Emmett, ID')
# (3043021, 'Emmitsburg, MD')
# (5749, 'Encinitas, CA')
# (1881, 'Endicott, NY')
# (4997572, 'Enfield, CT')
# (98396367, 'Englewood Cliffs, NJ')
# (1947586, 'Englewood, CO')
# (16163783, 'Englewood, OH')
# (9170, 'Ennis, TX')
# (16690, 'Enon, OH')
# (90413667, 'Enterprise, AL')
# (808034, 'Enumclaw, WA')
# (28498, 'Ephrata, PA')
# (18923058, 'Erie-Meadville Area')
# (65294553, 'Erie, PA')
# (289310, 'Erlanger, KY')
# (683310, 'Escanaba, MI')
# (20009, 'Escondido, CA')
# (112168, 'Essex Junction, VT')
# (13658, 'Estacada, OR')
# (20088, 'Estancia, NM')
# (937112, 'Estero, FL')
# (1945473, 'Euclid, OH')
# (165422, 'Eugene, OR')
# (166572, 'Euless, TX')
# (1945473, 'Eureka, CA')
# (7795, 'Evans, NY')
# (3196, 'Evanston, IL')
# (15259054, 'Evansville, IN')
# (570550, 'Evendale, OH')
# (808034, 'Everett, WA')
# (5067678, 'Ewa Gentry, HI')
# (2203697, 'Ewing, NJ')
# (1901345, 'Excelsior, MN')
# (3242, 'Exeter, CA')
# (92681040, 'Fair Lawn, NJ')
# (1945473, 'Fairbanks, AK')
# (5725, 'Fairborn, OH')
# (56670, 'Fairburn, GA')
# (10420321, 'Fairfax Station, VA')
# (2113831, 'Fairfax, VA')
# (2274551, 'Fairfield, CA')
# (808034, 'Fairfield, CT')
# (2646, 'Fairfield, IA')
# (33264, 'Fairfield, NJ')
# (90198358, 'Fairfield, OH')
# (2646, 'Fairmont, MN')
# (5749, 'Fairview Heights, IL')
# (1681, 'Faison, NC')
# (95985, 'Falls Church, VA')
# (7384, 'Far-A-Field, PA')
# (70560, 'Fargo-Moorhead')
# (1374310, 'Fargo, ND')
# (1235, 'Faribault, MN')
# (295644, 'Farmers Branch, TX')
# (347410, 'Farmersburg, IN')
# (6440, 'Farmingdale, NJ')
# (10599076, 'Farmingdale, NY')
# (69234316, 'Farmington Hills, MI')
# (1286891, 'Farmington, CT')
# (8455, 'Farmington, MI')
# (808034, 'Farmington, NM')
# (22523, 'Farmington, UT')
# (19142259, 'Fayetteville, AR')
# (5749, 'Fayetteville, GA')
# (656981, 'Fayetteville, NC')
# (56119363, 'Feasterville, PA')
# (6487, 'Federal Way, WA')
# (12534, 'Fenton, MO')
# (167757, 'Fernandina Beach, FL')
# (7064, 'Festus, MO')
# (166551, 'Finney County, KS')
# (15259054, 'Fishers, IN')
# (4297, 'Fishersville, VA')
# (25179038, 'Fishkill, NY')
# (34656475, 'Fitchburg, MA')
# (15139, 'Flagstaff, AZ')
# (808034, 'Fleming Island, FL')
# (380752, 'Flemington, NJ')
# (581027, 'Flint, MI')
# (1183247, 'Florence County, SC')
# (60951108, 'Florence, AL')
# (76440728, 'Florence, KY')
# (879871, 'Florence, MA')
# (51586544, 'Florence, SC')
# (586645, 'Florham Park, NJ')
# (14542824, 'Florida, NY')
# (11056, 'Florida, United States')
# (86265278, 'Flower Mound, TX')
# (36569, 'Flowery Branch, GA')
# (72483, 'Flowood, MS')
# (10072, 'Folsom, CA')
# (13353, 'Fond du Lac, WI')
# (64510, 'Fontana, CA')
# (8024, 'Fordland, MO')
# (37768, 'Forest City, NC')
# (6176, 'Forest Hill, MD')
# (1463, 'Forest Home, NY')
# (1511, 'Forest Lake, MN')
# (18043, 'Forest Park, IL')
# (12446, 'Forsyth, IL')
# (894572, 'Fort Belvoir, VA')
# (1403, 'Fort Bragg, North Carolina, United States')
# (3072, 'Fort Collins, CO')
# (14542824, 'Fort Defiance, VA')
# (3672, 'Fort Detrick, MD')
# (164451, 'Fort Dodge, IA')
# (5396873, 'Fort George G. Meade, MD')
# (166572, 'Fort Gratiot, MI')
# (25039398, 'Fort Irwin, CA')
# (15133237, 'Fort Kent, ME')
# (777243, 'Fort Lauderdale, FL')
# (5471, 'Fort Lawn, SC')
# (3994, 'Fort Lee, NJ')
# (31065, 'Fort Leonard Wood, MO')
# (3493, 'Fort Madison, IA')
# (1403, 'Fort Meade, MD')
# (5294, 'Fort Mill, SC')
# (333785, 'Fort Mitchell, KY')
# (1235, 'Fort Morgan, CO')
# (6609, 'Fort Myer Heights, VA')
# (72483, 'Fort Myers Beach, FL')
# (3220813, 'Fort Myers, FL')
# (52642826, 'Fort Pierce, FL')
# (19028770, 'Fort Riley, KS')
# (1185, 'Fort Smith, AR')
# (43093, 'Fort Stockton, TX')
# (808034, 'Fort Thomas, KY')
# (481862, 'Fort Valley, GA')
# (4028380, 'Fort Walton Beach, FL')
# (13181, 'Fort Washington, MD')
# (61252, 'Fort Washington, PA')
# (1505, 'Fort Wayne, IN')
# (94355, 'Fort Worth, TX')
# (163993, 'Foster City, CA')
# (20282677, 'Fountain Valley, CA')
# (15139, 'Fowler, CA')
# (10420321, 'Foxborough (Foxboro), MA')
# (77688, 'Foxborough, MA')
# (5121, 'Framingham, MA')
# (11752085, 'Franconia, VA')
# (86321483, 'Frankfort, KY')
# (1850810, 'Franklin, MA')
# (321986, 'Franklin, NH')
# (1852454, 'Franklin, TN')
# (3242, 'Franklin, VA')
# (2562128, 'Franklin, WI')
# (11056, 'Frederick County, MD')
# (11788646, 'Frederick, MD')
# (8479403, 'Fredericksburg, VA')
# (11088832, 'Fredonia, NY')
# (230463, 'Free Home, GA')
# (580089, 'Freeburg, IL')
# (6913, 'Freedom, CA')
# (9814, 'Freedom, PA')
# (9210946, 'Freehold, NJ')
# (93254, 'Freeland, MI')
# (1344, 'Freeport, IL')
# (37845, 'Freeport, ME')
# (48024, 'Freeport, TX')
# (5107, 'Fremont, CA')
# (808034, 'Fremont, California, United States')
# (53708, 'Fremont, NE')
# (27180004, 'Frenchtown, MI')
# (743843, 'Fresno County, CA')
# (2300, 'Fresno, CA')
# (6979, 'Fridley, MN')
# (383161, 'Friendswood, TX')
# (8221, 'Frisco, TX')
# (5343, 'Front Royal, VA')
# (808034, 'Fullerton, CA')
# (2059, 'Fuquay-Varina, NC')
# (28132450, 'Gadsden, AL')
# (2230, 'Gaffney, SC')
# (248184, 'Gahanna, OH')
# (9286450, 'Gainesville, FL')
# (9499, 'Gainesville, GA')
# (3570660, 'Gainesville, VA')
# (1603, 'Gaithersburg, MD')
# (18009221, 'Galesburg, IL')
# (2375692, 'Galesburg, MI')
# (25017, 'Gallatin, TN')
# (903710, 'Gallup, NM')
# (2271, 'Galt, CA')
# (16263, 'Galveston, TX')
# (9714055, 'Gap, PA')
# (17233, 'Garciasville, TX')
# (69989, 'Garden City, GA')
# (7795, 'Garden City, KS')
# (6913, 'Garden City, MI')
# (3360328, 'Garden City, NY')
# (808034, 'Garden Grove, CA')
# (96254, 'Gardena, CA')
# (95062508, 'Gardner, KS')
# (9814, 'Gardner, MA')
# (28647688, 'Garfield Heights, OH')
# (9391120, 'Garland, TX')
# (163828, 'Garner, NC')
# (581027, 'Gary, IN')
# (96180361, 'Gastonia, NC')
# (35121, 'Gaylord, MN')
# (19637, 'Geismar, LA')
# (5343, 'Geneva, AL')
# (24211, 'Geneva, IL')
# (497515, 'Genoa, OH')
# (2908367, 'Georgetown, DE')
# (2107, 'Georgetown, KY')
# (27152943, 'Georgetown, TX')
# (1016, 'Georgia, United States')
# (77022728, 'Germantown, MD')
# (60836398, 'Germantown, TN')
# (83051748, 'Germantown, WI')
# (18777798, 'Germany')
# (2875, 'Getzville, NY')
# (80829889, 'Gibsonia, PA')
# (13074, 'Gig Harbor, WA')
# (4167, 'Gilbert, AZ')
# (225343, 'Gilbert, PA')
# (1668, 'Gillette, WY')
# (1628878, 'Glasgow, DE')
# (4674, 'Glassboro, NJ')
# (14749, 'Glastonbury, CT')
# (1943848, 'Glen Allen, VA')
# (77499, 'Glen Burnie, MD')
# (696365, 'Glen Carbon, IL')
# (166360, 'Glen, MS')
# (27254190, 'Glendale, AZ')
# (808034, 'Glendale, CA')
# (28647688, 'Glendive, MT')
# (16263, 'Glenmont, NY')
# (2430668, 'Glenpool, OK')
# (3570660, 'Glenside, PA')
# (71982274, 'Glenview, IL')
# (165697, 'Glenwood Springs, CO')
# (2018, 'Gloucester, MA')
# (808034, 'Gloucester, VA')
# (35571114, 'Gold Canyon, AZ')
# (411814, 'Golden Valley, MN')
# (11311, 'Golden, CO')
# (18506580, 'Goldsboro, NC')
# (5275, 'Goleta, CA')
# (2646, 'Gonzales, TX')
# (3015, 'Goodland, KS')
# (19024424, 'Goodlettsville, TN')
# (28646687, 'Goodwell, OK')
# (163079, 'Goodyear, AZ')
# (1087079, 'Goshen, NY')
# (65294553, 'Grafton, OH')
# (422503, 'Graham, TX')
# (40693052, 'Granbury, TX')
# (1703, 'Granby, CO')
# (3706049, 'Grand Blanc, MI')
# (45716, 'Grand Canyon Village, AZ')
# (61984, 'Grand Forks, ND')
# (18506580, 'Grand Island, NE')
# (2736008, 'Grand Junction, CO')
# (82500012, 'Grand Prairie, TX')
# (1375518, 'Grand Rapids Metropolitan Area')
# (29622, 'Grand Rapids metropolitan area, MI')
# (38605, 'Grand Rapids, MI')
# (1511, 'Grand Rapids, MN')
# (3264, 'Grandville, MI')
# (80829889, 'Granger, IN')
# (3706049, 'Grants Pass, OR')
# (4591, 'Grantsburg, WI')
# (10408914, 'Grantsville, UT')
# (72483, 'Grapevine, TX')
# (1207327, 'Grass Valley, CA')
# (1867264, 'Great Barrington, MA')
# (1103, 'Great Falls, MT')
# (6104, 'Great Neck, NY')
# (3714038, 'Greater Bangor Area')
# (17283, 'Greater Birmingham, Alabama Area')
# (601919, 'Greater Bloomington Area')
# (42134, 'Greater Bloomington, Illinois Area')
# (91743578, 'Greater Boston')
# (9499, 'Greater Charlottesville Area')
# (2297840, 'Greater Chattanooga')
# (2684553, 'Greater Chicago Area')
# (9499, 'Greater Clarksville Area')
# (10035810, 'Greater Cleveland')
# (28978381, 'Greater Colorado Springs Area')
# (16183163, 'Greater Corpus Christi Area')
# (14191, 'Greater Dothan')
# (28893, 'Greater Farmington Area')
# (29331, 'Greater Fort Wayne')
# (12709, 'Greater Harrisburg Area')
# (14571, 'Greater Hartford')
# (1389, 'Greater Houston')
# (164664, 'Greater Indianapolis')
# (163640, 'Greater Jackson Area')
# (856962, 'Greater Jacksonville, NC Area')
# (11818084, 'Greater Jefferson City Area')
# (450185, 'Greater Kennewick Area')
# (163578, 'Greater Lansing')
# (2174958, 'Greater Los Angeles, CA')
# (166714, 'Greater Macon')
# (16038, 'Greater Madison Area')
# (35646045, 'Greater Milwaukee')
# (2578499, 'Greater Minneapolis-St. Paul Area')
# (84959254, 'Greater Morgantown Area')
# (754041, 'Greater New Orleans Region')
# (9499, 'Greater Ocala Area')
# (2354064, 'Greater Orlando')
# (10093812, 'Greater Philadelphia')
# (80674419, 'Greater Phoenix Area')
# (67080514, 'Greater Pittsburgh Region')
# (28345, 'Greater Reno Area')
# (206993, 'Greater Richmond Region')
# (9124, 'Greater Sacramento')
# (18054300, 'Greater Seattle Area')
# (6044, 'Greater St. Louis')
# (1146188, 'Greater Tampa Bay Area')
# (9499, 'Greater Tuscaloosa Area')
# (15218920, 'Greater Wilmington Area')
# (214212, 'Greater Yakima Area')
# (49223, 'Greater Yuma, AZ Area')
# (5352294, 'Greeley, CO')
# (7789, 'Green Bay, WI')
# (1100944, 'Green Valley, AZ')
# (455780, 'Greenbelt, MD')
# (808034, 'Greenbrae, CA')
# (3671, 'Greenbrier, AR')
# (17902, 'Greencastle, PA')
# (162912, 'Greendale, IN')
# (1945473, 'Greeneville, TN')
# (1867264, 'Greenfield, MA')
# (10387626, 'Greenfield, OH')
# (2737970, 'Greenfield, WI')
# (91447303, 'Greensboro--Winston-Salem--High Point Area')
# (808034, 'Greensboro, NC')
# (19024424, 'Greensburg, PA')
# (163617, 'Greenville County, SC')
# (33248183, 'Greenville-Spartanburg-Anderson, South Carolina Area')
# (66278935, 'Greenville, NC')
# (808034, 'Greenville, SC')
# (164200, 'Greenville, TX')
# (11009726, 'Greenwich, CT')
# (15472, 'Greenwood Village, CO')
# (2737970, 'Greenwood, IN')
# (6215, 'Greenwood, SC')
# (808034, 'Greer, SC')
# (18691, 'Gresham, OR')
# (5618, 'Gretna, NE')
# (15870, 'Groesbeck, TX')
# (1703, 'Groton, CT')
# (2646, 'Grove City, OH')
# (1471368, 'Groveland, CA')
# (4723171, 'Groveland, MI')
# (49105, 'Groveport, OH')
# (134081, 'Guilderland, NY')
# (10420321, 'Guilford, CT')
# (2709, 'Gulf Breeze, FL')
# (28647688, 'Gunnison, CO')
# (12659, 'Guntersville, AL')
# (1103, 'Gurnee, IL')
# (9487, 'Guthrie, KY')
# (164098, 'Gwinnett County, GA')
# (76500049, 'Gypsum, CO')
# (11818084, 'Hackensack, NJ')
# (18923058, 'Hackleburg, AL')
# (2087, 'Hagerstown, MD')
# (6265, 'Halethorpe, MD')
# (629785, 'Hallandale Beach, FL')
# (2589107, 'Hallock, MN')
# (3706049, 'Hamden, CT')
# (278713, 'Hamilton County, OH')
# (581027, 'Hamilton, OH')
# (10225139, 'Hammond, IN')
# (28597765, 'Hammond, LA')
# (98514983, 'Hampton Roads, Virginia Metropolitan Area')
# (7795, 'Hampton, VA')
# (165586, 'Hancocks Bridge, NJ')
# (7032, 'Hanford, CA')
# (2646, 'Hannibal, MO')
# (96180361, 'Hanover Park, IL')
# (40760236, 'Hanover, MA')
# (2153, 'Hanover, MD')
# (686294, 'Hanover, NH')
# (10820, 'Hanover, PA')
# (11240, 'Happy Valley, OR')
# (5343, 'Harahan, LA')
# (6176, 'Harlingen, TX')
# (444038, 'Harmans, MD')
# (2031248, 'Harriman, TN')
# (74081610, 'Harrington, DE')
# (3460, 'Harrisburg, PA')
# (1945473, 'Harrison, AR')
# (6913, 'Harrison, MI')
# (75348, 'Harrison, NY')
# (493453, 'Harrisonburg, VA')
# (2193256, 'Harrisonville, MO')
# (5553, 'Harrold, SD')
# (12988732, 'Hartford City, IN')
# (7043, 'Hartford County, CT')
# (5064123, 'Hartford, CT')
# (10279209, 'Hartland, WI')
# (167757, 'Hartsville, SC')
# (1373835, 'Harvard, IL')
# (4128, 'Hatfield, PA')
# (211166, 'Hauppauge, NY')
# (10420321, 'Haverhill, MA')
# (76500049, 'Havertown, PA')
# (14542824, 'Hawaii, United States')
# (85123, 'Hawley, MN')
# (7032, 'Hawthorne, CA')
# (484735, 'Hawthorne, NY')
# (46648, 'Hayward, CA')
# (2646, 'Hayward, WI')
# (88277482, 'Hazel Crest, IL')
# (27108872, 'Hazlet, NJ')
# (17882, 'Headquarters, KY')
# (81878, 'Headquarters, NJ')
# (18953305, 'Healdsburg, CA')
# (77318089, 'Heath, OH')
# (3056912, 'Hebron, KY')
# (9881525, 'Hegins, PA')
# (11300257, 'Helena, MT')
# (28595302, 'Helotes, TX')
# (2430668, 'Henderson, CO')
# (2646, 'Henderson, KY')
# (14542824, 'Henderson, NC')
# (7361, 'Henderson, NV')
# (20573, 'Hendersonville, NC')
# (63532172, 'Hendersonville, TN')
# (3781515, 'Henrico, VA')
# (96180361, 'Hephzibah, GA')
# (12787, 'Herlong, CA')
# (1103, 'Hermitage, PA')
# (35571114, 'Hermitage, TN')
# (3476, 'Hernando, MS')
# (8860695, 'Herndon, KS')
# (163139, 'Herndon, VA')
# (3658, 'Hershey, PA')
# (884316, 'Hesston, KS')
# (96180361, 'Hialeah, FL')
# (164113, 'Hickory Hills, IL')
# (41004, 'Hickory, NC')
# (9667, 'Hicksville, NY')
# (76440728, 'High Point, NC')
# (4235104, 'Highland, CA')
# (556848, 'Highlands Ranch, CO')
# (9895824, 'Highwood, IL')
# (24440, 'Hilliard, OH')
# (2106853, 'Hillsboro, OR')
# (6176, 'Hillsboro, TX')
# (28647688, 'Hillsboro, WI')
# (20969, 'Hillsborough County, FL')
# (20009, 'Hillsborough, NC')
# (8621, 'Hillside, IL')
# (1861137, 'Hillside, NJ')
# (7032, 'Hilo, HI')
# (57677390, 'Hilton Head Island, SC')
# (78124, 'Hilton Head Island, South Carolina Area')
# (25856, 'Hilton, NY')
# (2343421, 'Hinds County, MS')
# (35583934, 'Hinesville, GA')
# (517387, 'Hingham, MA')
# (1945473, 'Hiram, GA')
# (164200, 'Hixson, TN')
# (19807, 'Hobart, IN')
# (2192, 'Hobbs, NM')
# (10420321, 'Hoboken, NJ')
# (41854, 'Hodgkins, IL')
# (8619, 'Hoffman Estates, IL')
# (10517709, 'Holbrook, NY')
# (12446, 'Holden, ME')
# (947663, 'Holdenville, OK')
# (6449, 'Holland, MI')
# (4798, 'Holland, OH')
# (819218, 'Hollister, CA')
# (3486, 'Hollywood, FL')
# (988946, 'Hollywood, MD')
# (14650, 'Holmdel, NJ')
# (25552, 'Holton, KS')
# (2532635, 'Holyoke, MA')
# (30953, 'Home Park, Florida, United States')
# (12573, 'Home, KS')
# (162755, 'Homedale, ID')
# (71904349, 'Homer, MI')
# (6497, 'Homestead, FL')
# (71904349, 'Homestead, PA')
# (162644, 'Homewood, AL')
# (46000, 'Homewood, IL')
# (1945473, 'Hondo, TX')
# (3002336, 'Honolulu, HI')
# (1236687, 'Hoopeston, IL')
# (72483, 'Hoover, AL')
# (2193256, 'Hope Mills, NC')
# (2646, 'Hopkinsville, KY')
# (57106, 'Horse Cave, KY')
# (20009, 'Horsham, PA')
# (3796614, 'Hot Springs, AR')
# (9401140, 'Houston, Texas, United States')
# (96677, 'Houston, TX')
# (80862575, 'Howell, MI')
# (23375, 'Huber Heights, OH')
# (242230, 'Hudson Waterfront, NJ')
# (1211063, 'Hudson, FL')
# (3570660, 'Hudson, NH')
# (53193, 'Hudson, NY')
# (10420321, 'Hudson, OH')
# (8667, 'Hudson, WI')
# (16161886, 'Humble, TX')
# (5058, 'Hunt Valley, MD')
# (6472500, 'Huntersville, NC')
# (3135, 'Huntington Beach, CA')
# (6176, 'Huntington Park, CA')
# (436931, 'Huntington Station, NY')
# (6104, 'Huntington, NY')
# (82385, 'Huntington, WV')
# (77153, 'Huntsville-Decatur-Albertville Area')
# (3967883, 'Huntsville, AL')
# (57978, 'Huntsville, AR')
# (7795, 'Huntsville, TX')
# (3671, 'Hurlburt Field, FL')
# (11240, 'Hurst, TX')
# (1668, 'Hutchins, TX')
# (2646, 'Hutchinson, KS')
# (7929696, 'Hutchinson, MN')
# (107699, 'Hyannis, MA')
# (12293, 'Idaho Falls, ID')
# (8239496, 'Idaho, United States')
# (9814, 'Illinois City, IL')
# (4433, 'Illinois, United States')
# (40025, 'Immokalee, FL')
# (3764607, 'Imperial, CA')
# (9732, 'Independence, KS')
# (15259054, 'Independence, KY')
# (166572, 'Independence, MO')
# (708393, 'Independence, OH')
# (64863800, 'India')
# (65361091, 'Indian Head, MD')
# (11319362, 'Indian Springs, NV')
# (167757, 'Indian Trail, NC')
# (35520100, 'Indian Wells, CA')
# (7680, 'Indiana, United States')
# (808034, 'Indianapolis, IN')
# (22338085, 'Indianapolis, Indiana, United States')
# (9826, 'Ingleside, TX')
# (4541, 'Inglewood, CA')
# (3626, 'Inverness, FL')
# (163480, 'Inwood, NY')
# (14542824, 'Iowa City, IA')
# (1016, 'Iowa, United States')
# (20723, 'Irondale, AL')
# (18860134, 'Ironwood, MI')
# (1103, 'Irvine, CA')
# (1557409, 'Irvine, California, United States')
# (1103, 'Irving, TX')
# (19534, 'Iselin, NJ')
# (777243, 'Islip, NY')
# (41161, 'Issaquah, WA')
# (89143472, 'Itasca, IL')
# (37396978, 'Ithaca, NY')
# (49648429, 'Iva, SC')
# (10165687, 'Jackson County, MO')
# (284165, 'Jackson Township, OH')
# (71575605, 'Jackson, GA')
# (1943848, 'Jackson, LA')
# (8936, 'Jackson, MI')
# (3269, 'Jackson, MO')
# (64274685, 'Jackson, MS')
# (10141, 'Jackson, NJ')
# (2425285, 'Jackson, OH')
# (72416, 'Jackson, SC')
# (18425303, 'Jackson, TN')
# (97402272, 'Jacksonville Beach, FL')
# (28332, 'Jacksonville, AL')
# (166572, 'Jacksonville, FL')
# (16892, 'Jacksonville, GA')
# (2664556, 'Jacksonville, IL')
# (36990695, 'Jacksonville, NC')
# (2162, 'Jacksonville, TX')
# (3534, 'Jal, NM')
# (345295, 'Jamaica, NY')
# (165933, 'Jamestown, CA')
# (130095, 'Jamestown, TN')
# (2193256, 'Janesville, WI')
# (79042201, 'Jarratt, VA')
# (2646, 'Jasper, IN')
# (6798963, 'Jeannette, PA')
# (76171420, 'Jefferson City, MO')
# (1681, 'Jefferson County, IL')
# (2908367, 'Jeffersontown, KY')
# (18401, 'Jeffersonville, IN')
# (11240, 'Jensen Beach, FL')
# (8474, 'Jericho, NY')
# (1040158, 'Jerome, ID')
# (1808, 'Jersey City, NJ')
# (254060, 'Jersey, GA')
# (26792, 'Jessup, MD')
# (2433416, 'Jessup, PA')
# (5303168, 'Jesup, GA')
# (5275, 'Johns Creek, GA')
# (14542824, 'Johnson City, TN')
# (1579375, 'Johnston, IA')
# (20573, 'Johnston, RI')
# (38400, 'Johnstown, CO')
# (18176, 'Johnstown, NY')
# (1945473, 'Johnstown, PA')
# (164527, 'Joliet, IL')
# (57978, 'Jonesboro, AR')
# (11227630, 'Jonesboro, GA')
# (2121817, 'Jonesville, MI')
# (305287, 'Joplin, MO')
# (3634748, 'Junction City, KS')
# (2664556, 'Juneau, AK')
# (78741693, 'Juno Beach, FL')
# (269675, 'Jupiter, FL')
# (96081672, 'Jurupa Valley, CA')
# (157239, 'Kahului, HI')
# (153293, 'Kalamazoo, MI')
# (163787, 'Kalispell, MT')
# (7384, 'Kankakee, IL')
# (89863227, 'Kansas City Metropolitan Area')
# (217338, 'Kansas City, KS')
# (28503, 'Kansas City, Missouri, United States')
# (22283894, 'Kansas City, MO')
# (1016, 'Kansas, United States')
# (163883, 'Kapolei, HI')
# (3748, 'Katy, TX')
# (2193256, 'Kaukauna, WI')
# (11522, 'Kaysville, UT')
# (38521, 'Kearney, NE')
# (10420321, 'Kearny, NJ')
# (2664556, 'Keene, NH')
# (1909139, 'Keller, TX')
# (385010, 'Kenai, AK')
# (2396310, 'Kendallville, IN')
# (5235, 'Kenilworth, NJ')
# (6176, 'Kenmore, NY')
# (3240, 'Kennebec, SD')
# (2664556, 'Kennebunk, ME')
# (82153, 'Kenner, LA')
# (66278935, 'Kennesaw, GA')
# (34755301, 'Kennewick, WA')
# (10083903, 'Kenosha, WI')
# (2271, 'Kent, WA')
# (7886, 'Kenton, OH')
# (162724, 'Kentucky, United States')
# (82500012, 'Kentwood, MI')
# (28612966, 'Kermit, TX')
# (4128, 'Kernersville, NC')
# (3706049, 'Kerrville, TX')
# (165422, 'Ketchikan, AK')
# (162755, 'Kettle Falls, WA')
# (19637, 'Killeen-Temple Area')
# (11009726, 'Killeen, TX')
# (32478, 'King City, MO')
# (11402317, 'King County, WA')
# (1403, 'King George, VA')
# (15216893, 'King of Prussia, PA')
# (230282, 'Kingsburg, CA')
# (2646, 'Kingsport, TN')
# (363277, 'Kingston, NY')
# (2736008, 'Kingston, PA')
# (7032, 'Kingstowne, VA')
# (80829889, 'Kingwood, WV')
# (7795, 'Kinnelon, NJ')
# (90413667, 'Kinston, NC')
# (1441, 'Kirkland, WA')
# (5461, 'Kirtland Air Force Base, NM')
# (6732937, 'Kissimmee, FL')
# (450185, 'Klamath Falls, OR')
# (28352, 'Knightdale, NC')
# (166714, 'Knoxville Metropolitan Area')
# (165472, 'Knoxville, TN')
# (80516368, 'Kohala, HI')
# (1799, 'Kohler, WI')
# (1908498, 'Kokomo, IN')
# (2564997, 'Koloa, HI')
# (1945473, 'Kula, HI')
# (22132, 'Kuna, ID')
# (28669777, 'Kutztown, PA')
# (3240, 'La Crosse, WI')
# (1271305, 'La Crosse, Wisconsin, United States')
# (34218836, 'La Grande, OR')
# (10135152, 'La Grange, KY')
# (10141, 'La Jolla, California, United States')
# (35716480, 'La Marque, TX')
# (165938, 'La Mesa, CA')
# (163139, 'La Mirada, CA')
# (48024, 'La Porte, TX')
# (18641359, 'La Puente, CA')
# (35504, 'La Quinta, CA')
# (2162, 'La Vergne, TN')
# (56670, 'La Verne, CA')
# (9402, 'Lacey, WA')
# (14542824, 'Laconia, NH')
# (1324822, 'Ladson, SC')
# (59005249, 'Lady Lake, FL')
# (14383281, 'Lafayette, IN')
# (21921, 'Lafayette, Indiana Metropolitan Area')
# (92578918, 'Lafayette, LA')
# (164860, 'Lago Vista, TX')
# (3706049, 'Laguna Beach, CA')
# (165364, 'Laguna Hills, CA')
# (35504, 'Laguna Niguel, CA')
# (71316538, 'Lake Buena Vista, FL')
# (3654739, 'Lake Charles, LA')
# (157239, 'Lake City, FL')
# (1851642, 'Lake County, IL')
# (594846, 'Lake County, IN')
# (26923, 'Lake Elmo, MN')
# (86475, 'Lake Forest, CA')
# (44730, 'Lake Forest, IL')
# (28647688, 'Lake Havasu City, AZ')
# (3671, 'Lake Hiawatha, NJ')
# (25856, 'Lake in the Hills, IL')
# (3570660, 'Lake Mary, FL')
# (6913, 'Lake Oswego, OR')
# (13353, 'Lake St Louis, MO')
# (29620, 'Lake Villa, IL')
# (10667641, 'Lake Wales, FL')
# (5274161, 'Lake Worth, FL')
# (2911, 'Lake Worth, TX')
# (107365, 'Lakeland, FL')
# (214960, 'Lakeside, AZ')
# (4723171, 'Lakeside, MT')
# (12095, 'Lakeville, MA')
# (162755, 'Lakeville, MN')
# (18312164, 'Lakewood, CO')
# (49042, 'Lakewood, NJ')
# (14542824, 'Lamar, CO')
# (163883, 'Lanai City, HI')
# (64883, 'Lancaster, CA')
# (164527, 'Lancaster, MA')
# (3658, 'Lancaster, PA')
# (18506580, 'Lancaster, SC')
# (4822178, 'Lancaster, TX')
# (2254693, 'Lancaster, WI')
# (1379045, 'Landover, MD')
# (34727, 'Lane County, OR')
# (35529547, 'Langhorne, PA')
# (6281, 'Langston, OK')
# (71904349, 'Lanham, MD')
# (49105, 'Lansdale, PA')
# (43278, 'Lansing, MI')
# (407589, 'Lapeer, MI')
# (96180361, 'LaPlace, LA')
# (424952, 'Laredo, TX')
# (1279498, 'Largo, FL')
# (1403, 'Las Cruces, NM')
# (2121817, 'Las Vegas Metropolitan Area')
# (581824, 'Las Vegas, Nevada, United States')
# (7361, 'Las Vegas, NV')
# (917557, 'Latham, NY')
# (3270028, 'Lathrop, CA')
# (23552, 'Latrobe, PA')
# (7795, 'Laurel, MD')
# (2646, 'Laurel, MT')
# (105203, 'Laurinburg, NC')
# (166643, 'Lawrence, KS')
# (298459, 'Lawrence, MA')
# (32469, 'Lawrenceburg, IN')
# (602239, 'Lawrenceburg, KY')
# (3748, 'Lawrenceville, GA')
# (11818084, 'Lawton Area')
# (760983, 'Lawton, OK')
# (77301, 'Layton, UT')
# (14542824, 'Le Mars, IA')
# (581027, 'League City, TX')
# (16075064, 'Leavenworth, KS')
# (2155460, 'Leawood, KS')
# (2700167, 'Lebanon, IN')
# (11056, 'Lebanon, KY')
# (37902046, 'Lebanon, MO')
# (163348, 'Lebanon, NH')
# (2589107, 'Lebanon, OR')
# (28498, 'Lebanon, PA')
# (71575605, 'Lebanon, TN')
# (8294, 'Lee, MA')
# (19058930, 'Leeds, NY')
# (34867, 'Lees Summit, MO')
# (690568, 'Leesburg, FL')
# (32455, 'Leesburg, GA')
# (2664556, 'Leesburg, VA')
# (69736805, 'Leetonia, OH')
# (26341, 'Leetsdale, PA')
# (9203219, 'Lehi, UT')
# (11518813, 'Leland, NC')
# (162510, 'Lemont, IL')
# (11056, 'Lemoore, CA')
# (422503, 'Lenexa, KS')
# (65294553, 'Lenhartsville, PA')
# (808034, 'Leominster, MA')
# (34341, 'Levittown, NY')
# (15389, 'Lewis Center, OH')
# (19023, 'Lewisberry, PA')
# (18176, 'Lewiston, ID')
# (3706049, 'Lewiston, ME')
# (18860134, 'Lewisville, TX')
# (1403, 'Lexington Park, MD')
# (10831504, 'Lexington, KY')
# (2227, 'Lexington, MA')
# (46000, 'Lexington, NC')
# (2646, 'Lexington, NE')
# (157338, 'Lexington, VA')
# (7550, 'Liberty Lake, WA')
# (89877420, 'Liberty, NC')
# (15721, 'Libertyville, IL')
# (71575605, 'Lima, OH')
# (10420321, 'Lincoln Park, NJ')
# (163535, 'Lincoln, CA')
# (38521, 'Lincoln, NE')
# (1043057, 'Lincoln, Nebraska Metropolitan Area')
# (167024, 'Lincolnshire, IL')
# (2677, 'Lincolnton, NC')
# (2712059, 'Lindon, UT')
# (163253, 'Lino Lakes, MN')
# (139348, 'Linthicum Heights, MD')
# (35666700, 'Linthicum, MD')
# (11486116, 'Lisle, IL')
# (2908367, 'Litchfield Park, AZ')
# (3579761, 'Lithia Springs, GA')
# (23379, 'Lititz, PA')
# (86001745, 'Little Canada, MN')
# (8019, 'Little Chicago, WI')
# (17109, 'Little Elm, TX')
# (2986, 'Little Rock Metropolitan Area')
# (24494, 'Little Rock, AR')
# (3308308, 'Littleton, CO')
# (5040587, 'Littleton, NH')
# (31827, 'Live Oak, TX')
# (4994, 'Livermore, CA')
# (25856, 'Liverpool, NY')
# (1668, 'Livingston, MT')
# (18062, 'Livingston, NJ')
# (80862575, 'Livonia, MI')
# (815722, 'Location, WV')
# (22340991, 'Lockport, NY')
# (4453, 'Locust Grove, GA')
# (77301, 'Lodi, CA')
# (1766026, 'Logan, UT')
# (3706049, 'Loma Linda, CA')
# (1075434, 'Lombard, IL')
# (1211063, 'London, OH')
# (1511, 'Londonderry, NH')
# (3711368, 'Lone Tree, CO')
# (3308308, 'Long Beach, CA')
# (86041588, 'Long Branch, NJ')
# (13334, 'Longmont, CO')
# (483961, 'Longview, TX')
# (165422, 'Longview, WA')
# (7720, 'Longwood, FL')
# (11777418, 'Lonoke, AR')
# (35504, 'Loomis, CA')
# (96180361, 'Lorain, OH')
# (65294553, 'Lorton, VA')
# (2135088, 'Los Alamitos, CA')
# (5327, 'Los Alamos, NM')
# (31953, 'Los Angeles County, CA')
# (91357855, 'Los Angeles Metropolitan Area')
# (2476, 'Los Angeles, CA')
# (937092, 'Los Angeles, California, United States')
# (2646, 'Los Banos, CA')
# (165158, 'Los Gatos, CA')
# (37768, 'Los Lunas, NM')
# (6913, 'Los Osos, CA')
# (11227630, 'Loudon, TN')
# (869141, 'Louisiana, United States')
# (2736008, 'Louisville, KY')
# (3495423, 'Loveland, CO')
# (3260, 'Loves Park, IL')
# (162536, 'Lowell, AR')
# (35657035, 'Lowell, MA')
# ...
# (3700354, 'Snow Hill, NC')
# (5482, 'Social Circle, GA')
# (808034, 'Soldotna, AK')
# (1393, 'Solon, OH')
# (9210946, 'Somerset County, NJ')
# (20009, 'Somerset, KY')
# (55787, 'Somerset, NJ')
# (34218836, 'Somerset, PA')
# (64865352, 'Somerville, MA')
# (14363, 'Somerville, NJ')
# (2671586, 'Sonoma, CA')
# (11440, 'Souderton, PA')
# (79560, 'South Attleboro, MA')
# (360308, 'South Beloit, IL')
# (74306759, 'South Bend-Mishawaka Region')
# (629227, 'South Bend, IN')
# (76171420, 'South Boston, VA')
# (1041095, 'South Carolina, United States')
# (162724, 'South Dakota, United States')
# (36995, 'South El Monte, CA')
# (8667, 'South Elgin, IL')
# (4324, 'South Hackensack, NJ')
# (3593828, 'South Haven, MI')
# (30065, 'South Jordan, UT')
# (6913, 'South Lake Tahoe, CA')
# (26569406, 'South Milwaukee, WI')
# (1944535, 'South Mountain, PA')
# (6913, 'South Pasadena, CA')
# (88659237, 'South Plainfield, NJ')
# (4060, 'South Portland, ME')
# (167757, 'South Salem, NY')
# (3210501, 'South San Francisco, CA')
# (14528, 'South San Gabriel, CA')
# (72483, 'South Sheffield, AL')
# (20009, 'South St Paul, MN')
# (71904349, 'Southampton, NY')
# (92461464, 'Southampton, PA')
# (7795, 'Southaven, MS')
# (2271, 'Southborough, MA')
# (166572, 'Southern Pines, NC')
# (8795, 'Southfield, MI')
# (5064123, 'Southington, CT')
# (24803, 'Southlake, TX')
# (6176, 'Spanaway, WA')
# (15564, 'Sparks, NV')
# (14140, 'Sparrows Point, MD')
# (1511, 'Sparta, TN')
# (1058190, 'Spartanburg, SC')
# (163025, 'Speedway, IN')
# (7935, 'Spencer, IA')
# (8885, 'Spirit Lake, IA')
# (64639449, 'Spokane Valley, WA')
# (13074, 'Spokane, WA')
# (4062, 'Spring Hill, TN')
# (102847, 'Spring House, PA')
# (911928, 'Spring Park, MN')
# (1025, 'Spring, TX')
# (11009726, 'Springdale, AR')
# (16733, 'Springfield-Branson, Missouri Area')
# (164931, 'Springfield, IL')
# (822071, 'Springfield, MA')
# (7064, 'Springfield, MO')
# (37768, 'Springfield, NE')
# (5112, 'Springfield, OH')
# (165422, 'Springfield, OR')
# (3469, 'Springfield, TN')
# (1403, 'Springfield, VA')
# (167757, 'Springfield, VT')
# (2736008, 'Springville, AL')
# (2480405, 'St Augustine, FL')
# (21542, 'St Charles, MO')
# (4141117, 'St Clair Shores, MI')
# (9185, 'St Clairsville, OH')
# (74464, 'St Cloud, MN')
# (410499, 'St George, UT')
# (1586, 'St Georges, DE')
# (18506580, 'St Helena, CA')
# (209610, 'St James, LA')
# (43278, 'St Johns, MI')
# (77669120, 'St Johnsbury, VT')
# (808034, 'St Joseph, MI')
# (87599, 'St Joseph, MO')
# (72483, 'St Louis Park, MN')
# (808034, 'St Louis, Missouri, United States')
# (7064, 'St Louis, MO')
# (4713, 'St Paul, MN')
# (18425303, 'St Peters, MO')
# (166671, 'St Petersburg, FL')
# (4852, 'St Petersburg, Florida, United States')
# (164880, 'St Regis Falls, NY')
# (9075575, 'St. Louis County, MO')
# (13199621, 'Stafford, TX')
# (41008, 'Stafford, VA')
# (1215629, 'Stamford, CT')
# (1792, 'Stanford, CA')
# (10266947, 'Stanford, KY')
# (2972588, 'Stanly County, NC')
# (12446, 'Star Lake, NY')
# (1943848, 'Starkville, MS')
# (23769122, 'State College, PA')
# (71316538, 'Stateline, NV')
# (6913, 'Staten Island, NY')
# (2252, 'Statesville, NC')
# (5343, 'Steamboat Springs, CO')
# (550530, 'Stephenville, TX')
# (1906, 'Sterling Heights, MI')
# (33266522, 'Sterling Wood, TX')
# (24187, 'Sterling, OH')
# (167757, 'Sterling, VA')
# (167757, 'Stillwater, MN')
# (6281, 'Stillwater, OK')
# (6234, 'Stilwell, OK')
# (3888, 'Stockbridge, GA')
# (25017, 'Stockton, CA')
# (31896, 'Stockton, IL')
# (1431, 'Stone Mountain, GA')
# (71904349, 'Stoneham, MA')
# (93749948, 'Stonington, CT')
# (95724, 'Stony Point, NC')
# (30755, 'Strafford County, NH')
# (30967, 'Stratford, CA')
# (461332, 'Stratford, CT')
# (598372, 'Streamwood, IL')
# (2724823, 'Streetsboro, OH')
# (135342, 'Stuart, FL')
# (80911138, 'Stuarts Draft, VA')
# (837416, 'Sturbridge, MA')
# (64677, 'Sturgeon Bay, WI')
# (545086, 'Sturtevant, WI')
# (2193256, 'Suamico, WI')
# (9201883, 'Sudbury, MA')
# (28014, 'Suffolk County, NY')
# (66105, 'Suffolk, VA')
# (3681, 'Sugar Land, TX')
# (2646, 'Sullivan, IN')
# (7119929, 'Sulphur Springs, TX')
# (14459, 'Sulphur, LA')
# (11818084, 'Sulphur, OK')
# (20009, 'Summerville, SC')
# (11804, 'Summit, NJ')
# (963770, 'Sumner, WA')
# (3534, 'Sumter, SC')
# (2584496, 'Sun City Center, FL')
# (18506580, 'Sun City West, AZ')
# (808034, 'Sun City, AZ')
# (9251256, 'Sun City, KS')
# (315817, 'Sun Valley, CA')
# (2203697, 'Sunfish Lake, MN')
# (163761, 'Sunland Park, NM')
# (1441, 'Sunnyvale, CA')
# (9184151, 'Sunnyvale, TX')
# (166360, 'Sunrise, FL')
# (11518813, 'Supply, NC')
# (96180361, 'Surprise, AZ')
# (18523922, 'Surry, ME')
# (5666, 'Surry, VA')
# (2684081, 'Suwanee, GA')
# (20009, 'Swansboro, NC')
# (1642, 'Swiftwater, PA')
# (49455, 'Sycamore, IL')
# (28647688, 'Sylva, NC')
# (97402272, 'Syosset, NY')
# (932766, 'Syracuse, NY')
# (13074, 'Tacoma, WA')
# (862993, 'Takoma Park, MD')
# (622196, 'Talala, OK')
# (38015, 'Tallahassee, FL')
# (1955819, 'Tallapoosa, GA')
# (10967, 'Tallassee, AL')
# (79030151, 'Tamarac, FL')
# (86813252, 'Tampa, FL')
# (1618718, 'Tampa, Florida, United States')
# (5927, 'Taneytown, MD')
# (349545, 'Tanner, AL')
# (9266728, 'Tappahannock, VA')
# (80711640, 'Tarboro, NC')
# (13476, 'Tarrytown, NY')
# (1703, 'Taunton, MA')
# (9185, 'Taylor, MI')
# (6250, 'Taylor, TX')
# (18506580, 'Taylorville, IL')
# (38897, 'Teaneck, NJ')
# (166551, 'Tecumseh, NE')
# (56042106, 'Telford, PA')
# (80516368, 'Telluride, CO')
# (21232722, 'Temecula, CA')
# (1115, 'Tempe, AZ')
# (1103, 'Temple Terrace, FL')
# (5887, 'Temple, GA')
# (6250, 'Temple, TX')
# (869141, 'Tennessee, United States')
# (7149222, 'Terra Bella, CA')
# (307494, 'Terre Haute, IN')
# (96180361, 'Terrell, TX')
# (7795, 'Teterboro, NJ')
# (163883, 'Teton Village, WY')
# (3476, 'Tewksbury, MA')
# (3915, 'Texarkana, AR')
# (10769, 'Texarkana, TX')
# (6979, 'Texas City, TX')
# (1025, 'Texas, United States')
# (285650, 'The Woodlands, TX')
# (3335, 'Thief River Falls, MN')
# (1600946, 'Thiells, NY')
# (1940159, 'Thomasville, GA')
# (3706049, 'Thompson, CT')
# (4026714, 'Thornton, CO')
# (1226771, 'Thornville, OH')
# (4030966, 'Thorofare, NJ')
# (14632005, 'Thousand Oaks, CA')
# (253213, 'Thousand Oaks, California, United States')
# (6617639, 'Thousand Palms, CA')
# (16710, 'Three Bridges, NJ')
# (3617422, 'Tifton, GA')
# (3025557, 'Tigard, OR')
# (7260, 'Timonium, MD')
# (44292, 'Tinley Park, IL')
# (777243, 'Tinton Falls, NJ')
# (1910700, 'Tipp City, OH')
# (4798, 'Titusville, FL')
# (383000, 'Toledo, OH')
# (2162, 'Tolleson, AZ')
# (12095, 'Tomah, WI')
# (9401140, 'Tomball, TX')
# (9229, 'Toms River, NJ')
# (124802, 'Tonawanda, NY')
# (30498, 'Tooele, UT')
# (3240, 'Topeka, KS')
# (6176, 'Toppenish, WA')
# (46000, 'Topsham, ME')
# (1344, 'Torrance, CA')
# (5064123, 'Torrington, CT')
# (165416, 'Touchet, WA')
# (14542824, 'Townshend, VT')
# (13626, 'Township of Cherry Hill, NJ')
# (455780, 'Towson, MD')
# (7058, 'Tracy, CA')
# (808034, 'Travelers Rest, SC')
# (4026801, 'Traverse City, MI')
# (1403, 'Travis Field, CA')
# (9229, 'Tremont, PA')
# (10854676, 'Trenton, GA')
# (14796450, 'Trenton, NJ')
# (2383821, 'Trenton, OH')
# (3961, 'Triangle, NC')
# (2584472, 'Trinity, FL')
# (22208562, 'Troy, AL')
# (1259, 'Troy, MI')
# (71555983, 'Troy, NY')
# (9652, 'Troy, OH')
# (122279, 'Truckee, CA')
# (11229, 'Trussville, AL')
# (18691, 'Tualatin, OR')
# (14113, 'Tucker, GA')
# (1505, 'Tucson, AZ')
# (67572051, 'Tukwila, WA')
# (12890, 'Tulalip, WA')
# (80164640, 'Tulare County, CA')
# (77301, 'Tulare, CA')
# (1945473, 'Tullahoma, TN')
# (162514, 'Tulsa, OK')
# (167757, 'Tumwater, WA')
# (10954, 'Tunnel Hill, GA')
# (295604, 'Turlock, CA')
# (299305, 'Turners Falls, MA')
# (11056, 'Tuscaloosa, AL')
# (17916205, 'Tustin, CA')
# (348709, 'Twin Falls, ID')
# (35224, 'Twinsburg, OH')
# (10769, 'Tyler, TX')
# (1943848, 'Tylertown, MS')
# (2658876, 'Tysons Corner, VA')
# (22132, 'Union City, CA')
# (81950505, 'Union Springs, AL')
# (1297738, 'Union, NJ')
# (27432, 'Union, SC')
# (224075, 'Uniondale, NY')
# (8031, 'United States')
# (1016, 'United, PA')
# (1703, 'Universal City, CA')
# (4674, 'University Park, IL')
# (1703027, 'Upper Marlboro, MD')
# (157353, 'Upper St Clair, PA')
# (2650, 'Urbana, IL')
# (1110827, 'Urbandale, IA')
# (70603, 'Utah County, UT')
# (127645, 'Utah, United States')
# (7042786, 'Utica, NY')
# (133721, 'Uxbridge, MA')
# (1103, 'Vacaville, CA')
# (20009, 'Valdese, NC')
# (46521, 'Valdosta, GA')
# (10853673, 'Vallejo, CA')
# (17885819, 'Valley City, ND')
# (884316, 'Valley City, OH')
# (10214501, 'Van Alstyne, TX')
# (8390, 'Van Wert, OH')
# (4822178, 'Vance, AL')
# (84418, 'Vancouver, WA')
# (6148675, 'Vashon, WA')
# (736659, 'Venice, FL')
# (718282, 'Ventura County, CA')
# (1010140, 'Venus, FL')
# (11695727, 'Vergennes, VT')
# (2908367, 'Vermillion, SD')
# (1613038, 'Vermont, United States')
# (3626487, 'Vernon Hills, IL')
# (27758, 'Vernon, CA')
# (3706049, 'Vernon, TX')
# (1945473, 'Vernon, VT')
# (25856, 'Vernon, WI')
# (25856, 'Verona, PA')
# (725927, 'Verona, WI')
# (84659, 'Vicksburg, MS')
# (30755, 'Victor, NY')
# (8948083, 'Victorville, CA')
# (156470, 'Vienna, VA')
# (10420321, 'Villa Park, IL')
# (6176, 'Virginia Beach, VA')
# (74031056, 'Virginia, MN')
# (4898, 'Virginia, United States')
# (167757, 'Visalia, CA')
# (23279, 'Vista, CA')
# (491462, 'Volusia County, FL')
# (33227880, 'Voorhees, NJ')
# (1945473, 'Wabasso, MN')
# (6250, 'Waco, TX')
# (167757, 'Waconia, MN')
# (52950123, 'Wadesboro, NC')
# (2972588, 'Wake County, NC')
# (96180361, 'Wake Forest, NC')
# (22756, 'Wakefield, MA')
# (6265, 'Walbridge, OH')
# (46000, 'Waldorf, MD')
# (5750, 'Waldwick, NJ')
# (157262, 'Walkertown, NC')
# (205651, 'Wall Township, NJ')
# (28332, 'Walla Walla, WA')
# (48915, 'Waller, TX')
# (12770, 'Wallingford, CT')
# (3706049, 'Wallingford, Pennsylvania, United States')
# (1308355, 'Wallops Island, VA')
# (163139, 'Walnut Creek, CA')
# (598521, 'Walsenburg, CO')
# (77633193, 'Waltham, MA')
# (139348, 'Walton, KY')
# (822071, 'Ware, MA')
# (4167, 'Warminster, PA')
# (2193256, 'Warner Robins, GA')
# (140581, 'Warren, MA')
# (1472, 'Warren, MI')
# (12951519, 'Warren, NJ')
# (888619, 'Warren, OH')
# (11152, 'Warren, OR')
# (3037367, 'Warren, RI')
# (1689, 'Warrendale, PA')
# (165944, 'Warrensville Heights, OH')
# (2721914, 'Warrenton, MO')
# (1211063, 'Warrenton, VA')
# (12861, 'Warrenville, IL')
# (30167, 'Warrington, PA')
# (1975865, 'Warsaw, IN')
# (27973, 'Warsaw, VA')
# (79560, 'Warwick, RI')
# (11455, 'Wasco, OR')
# (3493, 'Waseca, MN')
# (7065, 'Washington County, TN')
# (42595, 'Washington DC-Baltimore Area')
# (163139, 'Washington, DC')
# (2646, 'Washington, IA')
# (7064, 'Washington, MO')
# (3706049, 'Washington, NC')
# (6592912, 'Washington, PA')
# (18312164, 'Washington, United States')
# (5749, 'Washington, UT')
# (104405, 'Wasilla, AK')
# (11266342, 'Waterbury, CT')
# (5064123, 'Waterford, CT')
# (766876, 'Waterloo, IA')
# (15862365, 'Watertown, MA')
# (10778, 'Watertown, NY')
# (455602, 'Watertown, SD')
# (8484, 'Watertown, WI')
# (2664556, 'Waterville, ME')
# (164880, 'Watsonville, CA')
# (3222, 'Waukegan, IL')
# (2121817, 'Waukesha, WI')
# (3240, 'Wausau, WI')
# (157346, 'Wauwatosa, WI')
# (40693052, 'Waveland, MS')
# (166551, 'Waverly, NE')
# (167757, 'Waxhaw, NC')
# (65907467, 'Waycross, GA')
# (30755, 'Wayne, NJ')
# (33421, 'Wayne, PA')
# (20573, 'Waynesville, MO')
# (28352, 'Weatherford, OK')
# (3570660, 'Weatherford, TX')
# (164249, 'Webster City, IA')
# (66270, 'Welch, MN')
# (5274161, 'Weld County, CO')
# (4075, 'Wellesley, MA')
# (10967, 'Wellington, KS')
# (7032, 'Wenatchee, WA')
# (327513, 'Wenona, IL')
# (6870363, 'Wentzville, MO')
# (60059619, 'Wernersville, PA')
# (1188909, 'Weslaco, TX')
# (7795, 'Wesley Chapel, FL')
# (4872007, 'West Babylon, NY')
# (8936, 'West Bloomfield Township, MI')
# (2913, 'West Bridgewater, MA')
# (18506580, 'West Burlington, IA')
# (1593346, 'West Chester, OH')
# (13499, 'West Chester, PA')
# (3776, 'West Chicago, IL')
# (74718032, 'West Columbia, SC')
# (26873, 'West Covina, CA')
# (9370513, 'West Coxsackie, NY')
# (6326422, 'West Des Moines, IA')
# (22534, 'West Fargo, ND')
# (56670, 'West Greenwich, RI')
# (44580, 'West Hartford, CT')
# (4255, 'West Henrietta, NY')
# (3517767, 'West Hollywood, CA')
# (4060, 'West Jefferson, OH')
# (1441, 'West Jordan, UT')
# (73013724, 'West Lafayette, IN')
# (2227, 'West Lebanon, NH')
# (1103, 'West Long Branch, NJ')
# (18860134, 'West McLean, VA')
# (79011799, 'West New York, NJ')
# (75053811, 'West Nyack, NY')
# (10442082, 'West Palm Beach, FL')
# (1284978, 'West Palm Beach, Florida, United States')
# (808034, 'West Plains, MO')
# (2848937, 'West Point, PA')
# (10035810, 'West Point, VA')
# (258644, 'West Rancho Dominguez, CA')
# (26283799, 'West Reading, PA')
# (380752, 'West Sacramento, CA')
# (18527534, 'West Valley City, UT')
# (165908, 'West Virginia, United States')
# (164376, 'Westborough, MA')
# (14070878, 'Westby, WI')
# (3476, 'Westchester County, NY')
# (2343541, 'Western, NY')
# (82565734, 'Westerville, OH')
# (945354, 'Westfield, IN')
# (1703, 'Westfield, MA')
# (1557409, 'Westford, MA')
# (3340388, 'Westlake Village, CA')
# (20573, 'Westlake, OH')
# (1307, 'Westlake, TX')
# (25856, 'Westland, MI')
# (20573, 'Westminster, CO')
# (25856, 'Westmont, IL')
# (5196975, 'Weston, FL')
# (3706049, 'Weston, WV')
# (851980, 'Westwood, KS')
# (16726, 'Westwood, MA')
# (11648, 'Wethersfield, CT')
# (14796450, 'Wharton, NJ')
# (157237, 'Whately, MA')
# (2564886, 'Wheatland, WY')
# (3505052, 'Wheaton, MD')
# (521948, 'Wheeling, IL')
# (12890, 'Wheeling, WV')
# (54788, 'Whippany, NJ')
# (316602, 'Whippleville, NY')
# (162755, 'White City, OR')
# (10341654, 'White House, TN')
# (1668, 'White Marsh Station, MD')
# (104405, 'White Pine, TN')
# (938659, 'White Plains, NY')
# (2664323, 'White Sands, NM')
# (167757, 'White Settlement, TX')
# (3557082, 'Whitehall, MI')
# (82302944, 'Whiting, WI')
# (21890, 'Whitmore Lake, MI')
# (30755, 'Whittier, CA')
# (259898, 'Wichita Falls, TX')
# (36769, 'Wichita, KS')
# (18506580, 'Wilkes-Barre, PA')
# (40888889, 'Willard, OH')
# (3549, 'Williamsburg, KY')
# (24385, 'Williamsburg, VA')
# (79988879, 'Williamson County, TX')
# (78336991, 'Williamsport, MD')
# (5749, 'Williamsport, PA')
# (12446, 'Williamstown, NY')
# (26587222, 'Williamsville, NY')
# (444038, 'Willimantic, CT')
# (165109, 'Willis, TX')
# (40658652, 'Williston, ND')
# (63171, 'Willmar, MN')
# (92750, 'Wilmer, TX')
# (1603, 'Wilmington, DE')
# (80181, 'Wilmington, Delaware, United States')
# (2396274, 'Wilmington, MA')
# (581027, 'Wilmington, NC')
# (10137, 'Wilmington, OH')
# (1471368, 'Wilmington, VT')
# (14840050, 'Wilson, NC')
# (11695727, 'Wilsonville, OR')
# (29849, 'Wilton Manors, FL')
# (3894, 'Wilton, CT')
# (134081, 'Wilton, NY')
# (9750, 'Wimberley, TX')
# (10854663, 'Winamac, IN')
# (602239, 'Winchester, KY')
# (28978143, 'Winchester, MA')
# (167757, 'Winchester, TN')
# (78606, 'Winchester, VA')
# (2555454, 'Winder, GA')
# (15220229, 'Windsor Mill, MD')
# (2951796, 'Windsor, CO')
# (3589, 'Windsor, WI')
# (1611410, 'Winn, MI')
# (10420321, 'Winnetka, IL')
# (6963, 'Winona, MN')
# (9759, 'Winston-Salem, NC')
# (135468, 'Winston, GA')
# (6176, 'Winter Garden, FL')
# (3697729, 'Winter Haven, FL')
# (2297786, 'Winter Park, FL')
# (14611, 'Winter Park, Florida, United States')
# (585138, 'Wisconsin Dells, WI')
# (32727, 'Wisconsin Rapids, WI')
# (26586, 'Wisconsin, United States')
# (5887, 'Wittmann, AZ')
# (2576930, 'Wixom, MI')
# (12192, 'Woburn, MA')
# (36704, 'Woodbridge, NJ')
# (1103, 'Woodbridge, VA')
# (8602, 'Woodburn, OR')
# (911928, 'Woodbury, MN')
# (16279, 'Woodcliff Lake, NJ')
# (21337, 'Woodhull, NY')
# (142571, 'Woodinville, WA')
# (522560, 'Woodland, CA')
# (7032, 'Woodlawn, MD')
# (56119363, 'Woodlyn, PA')
# (3570660, 'Woodridge, IL')
# (18425303, 'Woodside, NY')
# (10141, 'Woodstock, GA')
# (2664556, 'Woodward, OK')
# (808034, 'Worcester, MA')
# (232381, 'Wrentham, MA')
# (2633, 'Wyandotte, MI')
# (6250, 'Wylie, TX')
# (1224492, 'Wyoming, MN')
# (869141, 'Wyoming, United States')
# (3658, 'Wyomissing, PA')
# (71339867, 'Wytheville, VA')
# (12601, 'Yakima, WA')
# (9185, 'Yanceyville, NC')
# (139348, 'Yankton, SD')
# (163741, 'Yaphank, NY')
# (1867264, 'Yarmouth, MA')
# (5034592, 'Yelm, WA')
# (660180, 'Yerington, NV')
# (11227630, 'Yonkers, NY')
# (14542824, 'York, ME')
# (166837, 'York, PA')
# (164880, 'York, SC')
# (1009, 'Yorktown Heights, NY')
# (5666, 'Youngstown, OH')
# (55170, 'Youngsville, NC')
# (165725, 'Yountville, CA')
# (40687781, 'Ypsilanti, MI')
# (2604972, 'Yuba City, CA')
# (3570660, 'Yucaipa, CA')
# (601919, 'Yukon, OK')
# (324747, 'Yuma, AZ')
# (77301, 'Zachary, LA')
# (2646, 'Zanesville, OH')
# (7425, 'Zeeland, MI')
# (2857644, 'Zwolle, LA')
# Length of the result for 3a-2 :  3431
# SQL Execution time: 0.4422004222869873
# (1, 'PRIMARY', '<derived2>', None, 'ref', '<auto_key0>', '<auto_key0>', '8', 'const', 10, 100.0, None)
# (2, 'DERIVED', 'job_postings', None, 'ALL', None, None, None, None, 17672, 100.0, 'Using temporary; Using filesort')
# Avg total time SQL-Query 3a-2  =  0.6597513437271119

# %% [markdown]
# With optimization

# %%
print()
mycursor.execute(sql_query2_index)
print("After optimization")
sql_query_result(sql_query2,name)
sql_query_explain(sql_query2)
sql_query_avg_time(sql_query2,x,name)
#ONLY RUN IF INDEX EXISTS
mycursor.execute(drop_index)
#mycursor.execute(drop_index2)
# Out:
# After optimization
# (28615633, 'Aberdeen Proving Ground, MD')
# (1013110, 'Aberdeen, MD')
# (3706049, 'Aberdeen, WA')
# (17226, 'Abilene, TX')
# (2700167, 'Abingdon, VA')
# (3625, 'Abo, MO')
# (115116, 'Acampo, CA')
# (25567, 'Acton, MA')
# (3570660, 'Ada, MI')
# (7064, 'Ada, OK')
# (1482552, 'Addison, IL')
# (77301, 'Addison, TX')
# (27180004, 'Adrian, MI')
# (581824, 'Agoura Hills, CA')
# (1386950, 'Aiken, SC')
# (23182, 'Akron, OH')
# (5323150, 'Alabama, United States')
# (18506580, 'Alabaster, AL')
# (98488356, 'Alachua, FL')
# (8437, 'Alamance, NC')
# (18924711, 'Alameda County, CA')
# (808034, 'Alameda, CA')
# (15472, 'Alamo Heights, TX')
# (2646, 'Alamosa, CO')
# (3558, 'Albany, GA')
# (28409, 'Albany, New York Metropolitan Area')
# (1302410, 'Albany, NY')
# (14542824, 'Albany, OR')
# (18009221, 'Albemarle, NC')
# (2943678, 'Albuquerque-Santa Fe Metropolitan Area')
# (1945473, 'Albuquerque, NM')
# (5755, 'Alburtis, PA')
# (10854676, 'Alden, NY')
# (82153, 'Aledo, TX')
# (13309, 'Alexandria City County, VA')
# (6062532, 'Alexandria, LA')
# (1403, 'Alexandria, VA')
# (77301, 'Algonquin, IL')
# (25081, 'Alhambra, CA')
# (113097, 'Alice, TX')
# (9814, 'Aliso Viejo, CA')
# (121618, 'All Seasons Lake Park, OH')
# (165447, 'Allegan, MI')
# (2251, 'Allen, TX')
# (71904349, 'Allendale, NJ')
# (78114, 'Allentown, PA')
# (20009, 'Allenwood, PA')
# (6592, 'Alliance, OH')
# (10640818, 'Alma, MI')
# (3706049, 'Alpena, MI')
# (1103, 'Alpharetta, GA')
# (11758, 'Alsip, IL')
# (4453, 'Altoona, IA')
# (1703, 'Altoona, PA')
# (3706049, 'Alturas, CA')
# (53252, 'Alvin, TX')
# (315817, 'Amarillo, TX')
# (11824180, 'Ambler, PA')
# (3963605, 'American Fork, UT')
# (683310, 'Ames, IA')
# (16995, 'Amesbury, MA')
# (46000, 'Amherst, NH')
# (28923, 'Amherst, NY')
# (86041588, 'Amityville, NY')
# (12890, 'Ammon, ID')
# (6913, 'Amsterdam, NY')
# (13856, 'Anacortes, WA')
# (3570660, 'Anaheim, CA')
# (26923, 'Anchorage, AK')
# (3469, 'Anderson, SC')
# (15451728, 'Andover, KS')
# (53452, 'Andover, MA')
# (3476, 'Andrews, SC')
# (19368, 'Angels Camp, CA')
# (2562, 'Angleton, TX')
# (1526, 'Ankeny, IA')
# (78636, 'Ann Arbor, MI')
# (1403, 'Annapolis Junction, MD')
# (18062, 'Annapolis, MD')
# (68941, 'Anniston, AL')
# (74994575, 'Anoka, MN')
# (2193256, 'Antigo, WI')
# (2910116, 'Antioch, IL')
# (2252, 'Antioch, TN')
# (82808548, 'Anton Chico, NM')
# (690568, 'Apache Junction, AZ')
# (4324, 'Apex, NC')
# (14832, 'Apollo Beach, FL')
# (74161427, 'Apopka, FL')
# (2646, 'Apple Valley, CA')
# (96180361, 'Apple Valley, MN')
# (6233, 'Appleton, WI')
# (4297, 'Appomattox, VA')
# (4111455, 'Arabi, LA')
# (1668, 'Arcata, CA')
# (55185007, 'Arden Hills, MN')
# (18860134, 'Arden, NC')
# (869141, 'Arizona, United States')
# (1464, 'Arkadelphia, AR')
# (162724, 'Arkansas, United States')
# (598372, 'Arlington Heights, IL')
# (1103, 'Arlington, MA')
# (166680, 'Arlington, TX')
# (1403, 'Arlington, VA')
# (372915, 'Armonk, NY')
# (15473, 'Arnold, MO')
# (43093, 'Artesia, MS')
# (373399, 'Arvada, CO')
# (1103, 'Ashburn, VA')
# (28169, 'Asheville, NC')
# (3570660, 'Ashland, MA')
# (70696, 'Ashland, MT')
# (4798, 'Ashland, VA')
# (2646, 'Ashland, WI')
# (33190802, 'Aspen, CO')
# (35561284, 'Atascadero, CA')
# (162828, 'Atchison, KS')
# (7587370, 'Athens, GA')
# (26205, 'Athens, OH')
# (1945473, 'Athens, TX')
# (1374999, 'Athol, ID')
# (163139, 'Atlanta Metropolitan Area')
# (3558, 'Atlanta, GA')
# (64746547, 'Atlantis, FL')
# (164200, 'Attleboro, MA')
# (1236687, 'Atwater, CA')
# (68796640, 'Auburn Hills, MI')
# (5343, 'Auburn, AL')
# (11056, 'Auburn, CA')
# (31065, 'Auburn, GA')
# (20573, 'Auburn, MA')
# (2562, 'Auburn, MI')
# (1945473, 'Auburn, NY')
# (71575605, 'Auburn, WA')
# (11440, 'Audubon, PA')
# (37235, 'Augusta, GA')
# (2137, 'Augusta, ME')
# (3672, 'Aurora, CO')
# (2736008, 'Aurora, Colorado, United States')
# (35504, 'Aurora, IL')
# (10147, 'Aurora, OH')
# (46000, 'Austell, GA')
# (164249, 'Austin Township, MN')
# (11618, 'Austin, MN')
# (163139, 'Austin, Texas Metropolitan Area')
# (3162, 'Austin, TX')
# (25963, 'Avenel, NJ')
# (283807, 'Aventura, FL')
# (66278935, 'Avon Lake, OH')
# (1103, 'Avon, MA')
# (79892817, 'Avon, MN')
# (85320, 'Avon, NY')
# (3570660, 'Avon, OH')
# (596893, 'Avondale, AZ')
# (162828, 'Avondale, LA')
# (828170, 'Ayer, MA')
# (2701866, 'Bagdad, AZ')
# (14542824, 'Baker, MT')
# (1945473, 'Baker, WV')
# (12820, 'Bakersfield, CA')
# (89989306, 'Bal Harbour, FL')
# (65549321, 'Bala-Cynwyd, PA')
# (2721914, 'Baldwin City, KS')
# (18506580, 'Baldwin Park, CA')
# (22309011, 'Ballwin, MO')
# (5127650, 'Baltimore County, MD')
# (1945473, 'Baltimore, MD')
# (18312164, 'Baltimore, OH')
# (1945473, 'Bangor, ME')
# (41004, 'Banner Elk, NC')
# (13353, 'Baraboo, WI')
# (788707, 'Barberton, OH')
# (18758749, 'Bardstown, KY')
# (32380, 'Bargersville, IN')
# (16726, 'Barstow, CA')
# (10420321, 'Bartlesville, OK')
# (598372, 'Bartlett, IL')
# (16101273, 'Bartlett, TN')
# (1235, 'Bartonville, TX')
# (906762, 'Bartow, FL')
# (1103, 'Basking Ridge, NJ')
# (166572, 'Bastrop, TX')
# (23656, 'Batavia, IL')
# (1511, 'Batavia, NY')
# (39249, 'Batavia, OH')
# (66252, 'Batesville, IN')
# (142560, 'Baton Rouge Metropolitan Area')
# (7587370, 'Baton Rouge, LA')
# (2381, 'Battle Creek, MI')
# (2646, 'Baxter, MN')
# (3180238, 'Bay City, MI')
# (9487, 'Bay Minette, AL')
# (19287, 'Bay St Louis, MS')
# (10517709, 'Bayport, NY')
# (48024, 'Baytown, TX')
# (203053, 'Bear, DE')
# (96180361, 'Beaufort, SC')
# (48024, 'Beaumont, TX')
# (11009726, 'Beaver Dam, WI')
# (15208770, 'Beaver, PA')
# (28974109, 'Beavercreek, OH')
# (79383535, 'Beaverton, OR')
# (14088, 'Beckett Ridge, OH')
# (90198358, 'Beckley, WV')
# (3579761, 'Bedford Park, IL')
# (2268831, 'Bedford, MA')
# (3706049, 'Bedford, PA')
# (96180361, 'Bedford, TX')
# (30823, 'Bedminster, NJ')
# (10769, 'Beeville, TX')
# (13181, 'Bel Air, MD')
# (1769216, 'Belcamp, MD')
# (8710, 'Belfast, ME')
# (75621179, 'Bellaire, TX')
# (22309011, 'Belleville, IL')
# (6592, 'Bellevue, OH')
# (37768, 'Bellevue, WA')
# (7032, 'Bellflower, CA')
# (165422, 'Bellingham, WA')
# (18472079, 'Bellmawr, NJ')
# (1160236, 'Bellows Falls, VT')
# (15941879, 'Belmar, NJ')
# (1273631, 'Belmont, CA')
# (3570660, 'Belmont, MA')
# (10420321, 'Beloit, WI')
# (16157996, 'Belton, MO')
# (570101, 'Beltsville, MD')
# (12434, 'Belvidere, IL')
# (6592, 'Bement, IL')
# (4857, 'Bend, OR')
# (936584, 'Benicia, CA')
# (1703, 'Bennington, VT')
# (80431008, 'Bensalem, PA')
# (4622, 'Benson, MN')
# (68463, 'Benton, AR')
# (2646, 'Benton, IL')
# (2646, 'Bentonville, AR')
# (2073870, 'Bergenfield, NJ')
# (890145, 'Berkeley Heights, NJ')
# (2519, 'Berkeley, CA')
# (5905495, 'Berlin, CT')
# (18506580, 'Berlin, NH')
# (9185, 'Berlin, NJ')
# (2168076, 'Berlin, VT')
# (3500602, 'Berlin, WI')
# (294502, 'Bernardsville, NJ')
# (13499, 'Berwyn, PA')
# (8281, 'Bethesda, MD')
# (15344142, 'Bethlehem, PA')
# (6104, 'Bethpage, NY')
# (79806, 'Beverly Hills, CA')
# (3706049, 'Beverly, MA')
# (14571, 'Bickleton, WA')
# (7410, 'Big Rapids, MI')
# (932563, 'Big Sky Meadow Village, MT')
# (587493, 'Big Spring, TX')
# (18506580, 'Big Stone Gap, VA')
# (37900, 'Billerica, MA')
# (14459, 'Billings, MT')
# (25039553, 'Biloxi, MS')
# (14571, 'Binghamton, NY')
# (157346, 'Birch Run, MI')
# (106584, 'Birmingham, AL')
# (3025562, 'Birmingham, MI')
# (28052, 'Biscoe, NC')
# (629227, 'Bishopville, SC')
# (1103, 'Bismarck, ND')
# (6442470, 'Black Mountain, NC')
# (2480405, 'Blacksburg, SC')
# (166811, 'Blacksburg, VA')
# (163025, 'Blaine, MN')
# (10420321, 'Blaine, WA')
# (1684870, 'Blairsville, GA')
# (81954233, 'Bloomfield Hills, MI')
# (88289095, 'Bloomfield, CT')
# (3706049, 'Bloomfield, NM')
# (91534, 'Bloomingdale, GA')
# (9308035, 'Bloomington–Normal, IL')
# (60561, 'Bloomington, IL')
# (104405, 'Bloomington, IN')
# (344707, 'Bloomington, MN')
# (7795, 'Bloomsburg, PA')
# (10358016, 'Bloomsbury, NJ')
# (18348487, 'Blue Ash, OH')
# (13920, 'Blue Bell, PA')
# (1805509, 'Blue Ridge, VA')
# (167757, 'Blue Springs, MO')
# (6592, 'Bluefield, WV')
# (164880, 'Bluffton, IN')
# (45970, 'Bluffton, SC')
# (808034, 'Blythe, CA')
# (23182, 'Boardman, OH')
# (73731, 'Boardman, OR')
# (166714, 'Boca Raton, FL')
# (49042, 'Boerne, TX')
# (3690, 'Boise, ID')
# (10035810, 'Bolingbrook, IL')
# (37902046, 'Bolivar, MO')
# (1283753, 'Bolivia, NC')
# (9185, 'Bonita Springs, FL')
# (22112, 'Boone, NC')
# (25856, 'Booneville, MS')
# (3706049, 'Boscawen, NH')
# (162513, 'Boston Heights, OH')
# (53713122, 'Boston Run, PA')
# (28978143, 'Boston, MA')
# (4060, 'Boston, Massachusetts, United States')
# (27253457, 'Bothell, WA')
# (43093, 'Boulder City, NV')
# (1441, 'Boulder, CO')
# (1867264, 'Bourne, MA')
# (65384923, 'Bowling Green Metropolitan Area')
# (2646, 'Bowling Green, KY')
# (8437, 'Bowling Green, OH')
# (1497, 'Boxborough, MA')
# (4181808, 'Boydton, VA')
# (1286891, 'Boylston, MA')
# (11227630, 'Boynton Beach, FL')
# (1286891, 'Boynton, GA')
# (5996, 'Bozeman, MT')
# (708393, 'Bradenton, FL')
# (71904349, 'Branchburg, NJ')
# (14749, 'Branchville, NJ')
# (79458773, 'Brandon, FL')
# (71904349, 'Branford, CT')
# (7795, 'Braselton, GA')
# (53508, 'Brawley, CA')
# (79560, 'Brea, CA')
# (526607, 'Breckenridge Hills, MO')
# (220336, 'Breckenridge, CO')
# (8017, 'Brecksville, OH')
# (89567861, 'Bremerton, WA')
# (166753, 'Brenham, TX')
# (30755, 'Brentwood, CA')
# (3249631, 'Brentwood, NY')
# (7795, 'Brentwood, TN')
# (1441, 'Bridgeport, AL')
# (2988, 'Bridgeport, CT')
# (61352, 'Bridgeport, TX')
# (2445, 'Bridgeport, WV')
# (1770225, 'Bridgeton, MO')
# (887776, 'Bridgeview, IL')
# (1339209, 'Bridgeville, PA')
# (1680, 'Bridgewater, NJ')
# (1087250, 'Bridgman, MI')
# (1471368, 'Bridgton, ME')
# (164376, 'Brier, WA')
# (4128, 'Brighton, CO')
# (50668, 'Brighton, MI')
# (157237, 'Brimfield, OH')
# (3693158, 'Brisbane, CA')
# (2073870, 'Bristol County, MA')
# (18921814, 'Bristol, CT')
# (65878041, 'Bristol, IN')
# (3109444, 'Bristol, PA')
# (1103, 'Bristol, TN')
# (15473, 'Bristow, VA')
# (2908367, 'Britton, SD')
# (41102, 'Broadview, IL')
# (7413, 'Brockton, MA')
# (40658652, 'Broken Arrow, OK')
# (21337, 'Bronx, NY')
# (25461, 'Brook Park, OH')
# (4918, 'Brookfield, WI')
# (999245, 'Brookline, MA')
# (1293049, 'Brooklyn Park, MN')
# (6104, 'Brooklyn, NY')
# (3252, 'Brooklyn, OH')
# (5195, 'Brookshire, TX')
# (1104193, 'Brooksville, FL')
# (164880, 'Brooktondale, NY')
# (73974, 'Brookville, OH')
# (2238, 'Broomfield, CO')
# (1410985, 'Brownsburg, IN')
# (22309011, 'Brownstown, MI')
# (14542824, 'Brownsville, TX')
# (9460096, 'Brownwood, TX')
# (808034, 'Brunswick, GA')
# (1703, 'Brunswick, ME')
# (76171420, 'Brunswick, TN')
# (4556, 'Bryan, TX')
# (660180, 'Bryant, AR')
# (11056, 'Bryn Mawr, PA')
# (7099708, 'Buckeye Lake, OH')
# (4128, 'Buckeye, AZ')
# (85123, 'Buda, TX')
# (166572, 'Buena Park, CA')
# (2652881, 'Buena, NJ')
# (10420321, 'Buffalo Grove, IL')
# (10894709, 'Buffalo-Niagara Falls Area')
# (164798, 'Buffalo, NY')
# (120240, 'Buffalo, WY')
# (1729578, 'Buford, GA')
# (46000, 'Bullhead City, AZ')
# (6979, 'Buras, LA')
# (29322289, 'Burbank, CA')
# (13074, 'Burien, WA')
# (10667, 'Burlingame, CA')
# (28978143, 'Burlington, MA')
# (18860134, 'Burlington, NC')
# (28149455, 'Burlington, NJ')
# (19107, 'Burlington, VT')
# (4324, 'Burlington, WA')
# (11056, 'Burnsville, MN')
# (1022308, 'Burrillville, RI')
# (12787, 'Butner, NC')
# (4822178, 'Byhalia, MS')
# (165472, 'Byron, GA')
# (10141, 'Cabazon, CA')
# (4324, 'Caddo Mills, TX')
# (1668, 'Cadillac, MI')
# (6593, 'Calabasas, CA')
# (856720, 'Caldwell, ID')
# (3570660, 'Caledonia, MI')
# (14287, 'Calera, AL')
# (315817, 'Calhoun, GA')
# (601919, 'California, United States')
# (163883, 'Calistoga, CA')
# (3681, 'Calvert, AL')
# (1274529, 'Camarillo, CA')
# (3570660, 'Camas, WA')
# (1441, 'Cambridge, MA')
# (64923472, 'Cambridge, MD')
# (1511, 'Cambridge, MN')
# (11402317, 'Camden, NJ')
# (29579, 'Camelback, California, United States')
# (28669777, 'Cameron, TX')
# (3658, 'Camp Hill, PA')
# (634422, 'Campbell, CA')
# (17937, 'Campbell, FL')
# (34683141, 'Canby, OR')
# (2701, 'Candler, NC')
# (258644, 'Cannon Falls, MN')
# (12669435, 'Canon City, CO')
# (3706049, 'Canton, GA')
# (28597931, 'Canton, MA')
# (12842, 'Canton, MI')
# (163828, 'Canton, NC')
# (164245, 'Canton, OH')
# (9185, 'Cantonment, FL')
# (2646, 'Canyon, TX')
# (25039398, 'Cape Canaveral, FL')
# (15691, 'Cape Coral Metropolitan Area')
# (283513, 'Cape Coral, FL')
# (14542824, 'Cape Girardeau, MO')
# (3706049, 'Cape May Court House, NJ')
# (72483, 'Capistrano Beach, CA')
# (981412, 'Capitan, NM')
# (2247, 'Capitol Heights, MD')
# (31815, 'Capitola, CA')
# (79042201, 'Capron, VA')
# (202443, 'Carbondale, PA')
# (62424, 'Cardiff-by-the-Sea, CA')
# (10877849, 'Carlisle, PA')
# (9814, 'Carlsbad, CA')
# (209610, 'Carlsbad, NM')
# (487174, 'Carmel, IN')
# (2646, 'Carmi, IL')
# (1468, 'Carmichaels, PA')
# (4128, 'Carnegie, PA')
# (3180238, 'Caro, MI')
# (55057585, 'Carol Stream, IL')
# (632911, 'Carpinteria, CA')
# (23858, 'Carrollton, GA')
# (4768, 'Carrollton, TX')
# (2137, 'Carson City, NV')
# (808034, 'Cartersville, GA')
# (57978, 'Carthage, MO')
# (28669777, 'Caruthersville, MO')
# (432241, 'Cary, NC')
# (214960, 'Casa Grande, AZ')
# (18506580, 'Casper, WY')
# (86639237, 'Caspian, MI')
# (74985, 'Castle Rock, CO')
# (808034, 'Castro Valley, CA')
# (220336, 'Cathedral City, CA')
# (444038, 'Catskill, NY')
# (4453, 'Cayce, SC')
# (23410, 'Cedar City, UT')
# (3240, 'Cedar Falls, IA')
# (28149455, 'Cedar Grove, NJ')
# (2251, 'Cedar Hill, TX')
# (3099084, 'Cedar Lake, IN')
# (1505, 'Cedar Rapids, IA')
# (808034, 'Centennial, CO')
# (20573, 'Centerville, TN')
# (2646, 'Central City, KY')
# (15241130, 'Central Islip, NY')
# (493453, 'Central, SC')
# (6913, 'Centralia, WA')
# (3706049, 'Centre Hall, PA')
# (15472, 'Centreville, VA')
# (609279, 'Ceres, CA')
# (5153, 'Cerritos, CA')
# (69601172, 'Chadds Ford, PA')
# (378234, 'Chalfont, PA')
# (73013724, 'Chambersburg, PA')
# (22208562, 'Champaign, IL')
# (26923, 'Champlin, MN')
# (104405, 'Chandler, AZ')
# (8034, 'Chanhassen, MN')
# (14255, 'Channahon, IL')
# (1403, 'Chantilly, VA')
# (166587, 'Chapel Hill, NC')
# (157353, 'Chappaqua, NY')
# (2936694, 'Charles City, IA')
# (2908367, 'Charleston, IL')
# (10877848, 'Charleston, SC')
# (51586544, 'Charleston, South Carolina Metropolitan Area')
# (1557409, 'Charleston, South Carolina, United States')
# (1043, 'Charleston, WV')
# (163139, 'Charlotte Metro')
# (814025, 'Charlotte, AR')
# (18425303, 'Charlotte, NC')
# (35651393, 'Charlotte, North Carolina, United States')
# (4298, 'Charlottesville, VA')
# (18106262, 'Charter Oak, CA')
# (10295, 'Chaska, MN')
# (164931, 'Chatham, IL')
# (2855513, 'Chattanooga, TN')
# (3450, 'Chelmsford, MA')
# (6756178, 'Chelsea, MI')
# (13074, 'Cheney, WA')
# (305287, 'Cheraw, SC')
# (4872230, 'Cherry Hill, NJ')
# (1317726, 'Chesapeake, VA')
# (1557409, 'Cheshire, CT')
# (78378963, 'Chester County, PA')
# (64923472, 'Chester, MD')
# (17233, 'Chester, PA')
# (1945473, 'Chester, SC')
# (46000, 'Chester, VA')
# (10974065, 'Chesterfield Township, MI')
# (884316, 'Chesterfield, MI')
# (248599, 'Chesterfield, MO')
# (1931371, 'Chestnut Hill, MA')
# (49042, 'Chevy Chase, MD')
# (70696, 'Cheyenne, WY')
# (2430668, 'Chicago Heights, IL')
# (36749, 'Chicago Ridge, IL')
# (2649, 'Chicago, IL')
# (12332, 'Chico, CA')
# (13542, 'Chicopee, MA')
# (14542824, 'Chillicothe, OH')
# (2646, 'Chilton, WI')
# (30755, 'Chino, CA')
# (42166, 'Chippewa Falls, WI')
# (3677, 'Chisago City, MN')
# (12890, 'Christiana, DE')
# (3617422, 'Christiansburg, VA')
# (14606618, 'Chula Vista, CA')
# (167757, 'Cicero, IL')
# (8781, 'Cincinnati Metropolitan Area')
# (2432, 'Cincinnati, OH')
# (107434, 'Circleville, OH')
# (4453, 'City of Industry, CA')
# (22523, 'City Park, UT')
# (34424, 'Clackamas, OR')
# (1703, 'Claremont, NH')
# (1908498, 'Claremore, OK')
# (10854676, 'Clarence, NY')
# (15434, 'Clarinda, IA')
# (1703, 'Clarion, PA')
# (28597765, 'Clarksboro, NJ')
# (10514179, 'Clarksburg, WV')
# (243836, 'Clarkston, MI')
# (7197, 'Clarksville, TN')
# (2301992, 'Claymont, DE')
# (2701866, 'Claypool, AZ')
# (164376, 'Clayton, MO')
# (41004, 'Clayton, NC')
# (1900, 'Clear Lake, IA')
# (1344, 'Clearwater, FL')
# (71316538, 'Clearwater, Florida, United States')
# (550530, 'Cleburne, TX')
# (1058190, 'Clemson, SC')
# (73202971, 'Clermont, FL')
# (3549, 'Cleveland Heights, OH')
# (45346, 'Cleveland, GA')
# (2203697, 'Cleveland, MS')
# (777243, 'Cleveland, OH')
# (9185, 'Cleveland, TN')
# (6979, 'Cliffwood, NJ')
# (18860134, 'Clifton Park, NY')
# (42134, 'Clifton, NJ')
# (20088, 'Clifton, TN')
# (4019848, 'Clinton Township, MI')
# (35504315, 'Clinton, IA')
# (2646, 'Clinton, IN')
# (32758, 'Clinton, MA')
# (1945473, 'Clinton, MD')
# (3534, 'Clinton, MS')
# (1211063, 'Clinton, NC')
# (12534, 'Clinton, NJ')
# (9676, 'Clinton, OK')
# (9596847, 'Clovis, CA')
# (1211063, 'Clyde, NC')
# (65294553, 'Clyde, NY')
# (8141, 'Coal City, IN')
# (76127808, 'Coatesville, PA')
# (3558, 'Cobb County, GA')
# (6176, 'Coconut Creek, FL')
# (5292867, "Coeur d'Alene, ID")
# (14658457, 'Cofield, NC')
# (19107, 'Colchester, VT')
# (808034, 'Coldwater, MI')
# (2973906, 'College Park, GA')
# (45575, 'College Park, MD')
# (4556, 'College Station, TX')
# (1399, 'Collegeville, PA')
# (82315512, 'Colleyville, TX')
# (72801, 'Collierville, TN')
# (90413667, 'Collins, MS')
# (9643, 'Collinsville, IL')
# (166774, 'Colonial Heights, VA')
# (39203, 'Colorado Springs, CO')
# (601919, 'Colorado, United States')
# (18506580, 'Colton, CA')
# (7947, 'Columbia, MD')
# (5442, 'Columbia, MO')
# (1943848, 'Columbia, MS')
# (23379, 'Columbia, PA')
# (12606850, 'Columbia, SC')
# (78124, 'Columbia, South Carolina Metropolitan Area')
# (7032, 'Columbia, TN')
# (92966191, 'Columbus metropolitan area, OH')
# (19180, 'Columbus, GA')
# (132002, 'Columbus, IN')
# (1943848, 'Columbus, MS')
# (2646, 'Columbus, NE')
# (8390, 'Columbus, OH')
# (200465, 'Columbus, Ohio Metropolitan Area')
# (2712856, 'Columbus, Ohio, United States')
# (5618, 'Commerce, CA')
# (537246, 'Concord, CA')
# (58602, 'Concord, MA')
# (49042, 'Concord, NC')
# (3706049, 'Concord, NH')
# (20088, 'Conneaut, OH')
# (64272643, 'Connecticut, United States')
# (71904349, 'Conover, NC')
# (7479, 'Conroe, TX')
# (17233, 'Conshohocken, PA')
# (14841964, 'Conway, AR')
# (21444, 'Conway, SC')
# (46000, 'Conyers, GA')
# (9499, 'Cool Spring, NC')
# (7929696, 'Coon Rapids, MN')
# (8817, 'Coopersburg, PA')
# (111108, 'Coos Bay, OR')
# (1515366, 'Coppell, TX')
# (15656, 'Coral Gables, FL')
# (14542824, 'Coral Springs, FL')
# (21041, 'Coralville, IA')
# (1463, 'Coraopolis, PA')
# (39540, 'Cordele, GA')
# (1945473, 'Cordova, AK')
# (6738, 'Core, WV')
# (12446, 'Corinth, MS')
# (9499, 'Cornelia, GA')
# (88289095, 'Corning, NY')
# (2074192, 'Corona del Mar, CA')
# (140581, 'Corona, CA')
# (35446044, 'Corpus Christi, TX')
# (165725, 'Corte Madera, CA')
# (6979, 'Cortland, NY')
# (18506580, 'Cortlandt Manor, NY')
# (14542824, 'Corvallis, OR')
# (1286891, 'Corydon, IA')
# (98209783, 'Cos Cob, CT')
# (602239, 'Coshocton, OH')
# (3316709, 'Costa Mesa, CA')
# (165422, 'Cottage Grove, OR')
# (104405, 'Cottleville, MO')
# (5343, 'Cottondale, AL')
# (34218836, 'Cottonwood, AZ')
# (1945473, 'Council Bluffs, IA')
# (14255, 'Country Club Hills, IL')
# (71904349, 'Coventry, RI')
# (468782, 'Covington, GA')
# (72483, 'Covington, KY')
# (3143932, 'Covington, LA')
# (808034, 'Covington, WA')
# (3706049, 'Coxsackie, NY')
# (2247, 'Cranberry Township, PA')
# (1284978, 'Crane, IN')
# (104396, 'Cranford, NJ')
# (2252, 'Cranston, RI')
# (14287, 'Crawford, TX')
# (12820, 'Creedmoor, NC')
# (2646, 'Crescent City, CA')
# (5242206, 'Crescent City, FL')
# (2646, 'Creston, IA')
# (89877420, 'Crestview, FL')
# (2615835, 'Crete, IL')
# (162828, 'Crete, NE')
# (468782, 'Creve Coeur, MO')
# (4031183, 'Cross Junction, VA')
# (15080, 'Cross Lanes, WV')
# (165294, 'Crown Point, IN')
# (1375621, 'Crystal City, MO')
# (113097, 'Crystal City, TX')
# (10420321, 'Crystal Lake, IL')
# (76171420, 'Crystal Springs, MS')
# (53959, 'Cudahy, WI')
# (4297, 'Culpeper, VA')
# (28439179, 'Culver City, CA')
# (3706049, 'Cumberland, MD')
# (5027745, 'Cumming, GA')
# (8299, 'Cupertino, CA')
# (7032, 'Cutler Bay, FL')
# (1263534, 'Cuyahoga Falls, OH')
# (25081, 'Cypress, CA')
# (9401140, 'Cypress, TX')
# (3570660, 'Dacula, GA')
# (34902814, 'Daggett, CA')
# (104405, 'Dakota Dunes, SD')
# (630847, 'Dakota, IL')
# (16995, 'Daleville, VA')
# (28893, 'Dallas County, TX')
# (76947396, 'Dallas-Fort Worth Metroplex')
# (1703, 'Dallas, GA')
# (17882, 'Dallas, Texas, United States')
# (6250, 'Dallas, TX')
# (269675, 'Dallastown, PA')
# (165472, 'Dalton, GA')
# (856720, 'Daly City, CA')
# (9177279, 'Damascus, MD')
# (35571114, 'Danbury, CT')
# (163253, 'Dania, FL')
# (8359, 'Danvers, MA')
# (1945473, 'Danville, IL')
# (7788794, 'Danville, PA')
# (9229, 'Danville, VA')
# (166551, 'Dardanelle, AR')
# (51701193, 'Dartmouth, MA')
# (688958, 'Dauphin County, PA')
# (18506580, 'Davenport, FL')
# (2736008, 'Davenport, IA')
# (64259963, 'Davidson, NC')
# (14542824, 'Davie, FL')
# (533823, 'Dawsonville, GA')
# (15259054, 'Dayton, OH')
# (164527, 'Dayton, TN')
# (861806, 'Daytona Beach, FL')
# (2193256, 'De Pere, WI')
# (68049148, 'De Witt, IA')
# (165299, 'Dearborn Heights, MI')
# (71904349, 'Dearborn, MI')
# (45716, 'Death Valley, CA')
# (2396310, 'Decatur, AL')
# (20009, 'Decatur, GA')
# (5553, 'Decatur, IL')
# (1943848, 'Decatur, MS')
# (4725, 'Decorah, IA')
# (9862, 'Dedham, MA')
# (1224492, 'Deephaven, MN')
# (22523, 'Deer Park, IL')
# (48024, 'Deer Park, TX')
# (49042, 'Deerfield Beach, FL')
# (71350, 'Deerfield, IL')
# (162723, 'DeKalb, IL')
# (2949451, 'Del Mar, CA')
# (82903338, 'DeLand, FL')
# (64980, 'Delano, CA')
# (23300, 'Delaware, OH')
# (162724, 'Delaware, United States')
# (2664556, 'Delmar, NY')
# (1781229, 'Delphi, IN')
# (1666657, 'Delray Beach, FL')
# (14542824, 'Delta, CO')
# (21667, 'Deltona, FL')
# (3706049, 'Demorest, GA')
# (21667, 'Denison, IA')
# (1497977, 'Denison, TX')
# (74994575, 'Denton, MD')
# (7795, 'Denton, TX')
# (89877420, 'Denver City, UT')
# (2652881, 'Denver Metropolitan Area')
# (3135, 'Denver, CO')
# (14611, 'Denver, Colorado, United States')
# (81480274, 'Denver, IN')
# (8807, 'Denver, NC')
# (39472, 'Denville, NJ')
# (3182370, 'Dermott, AR')
# (311841, 'Derry, NH')
# (17233, 'Derwood, MD')
# (3789, 'Des Moines Metropolitan Area')
# (265869, 'Des Moines, IA')
# (72483, 'Des Moines, WA')
# (31896, 'Des Plaines, IL')
# (92750, 'DeSoto, TX')
# (16733, 'Destin, FL')
# (37404866, 'Detroit Metropolitan Area')
# (7357, 'Detroit, MI')
# (23279, 'Devens, MA')
# (11056, 'Dexter, MI')
# (120859, 'Diamond Bar, CA')
# (3600, 'Dickinson, ND')
# (9184151, 'Dickson, TN')
# (14542824, 'Dillon, MT')
# (426121, 'Dimondale, MI')
# (2700167, 'Disputanta, VA')
# (28974109, 'District of Columbia, United States')
# (485407, 'Dobbs Ferry, NY')
# (104895, 'Dodge Center, MN')
# (164621, 'Dodge City, KS')
# (6083, 'Dodgeville, WI')
# (1151910, 'Doral, FL')
# (164880, 'Dorchester, MA')
# (3242, 'Dothan, AL')
# (2646, 'Douglas, GA')
# (7886, 'Douglasville, GA')
# (75997, 'Dover, DE')
# (7795, 'Dover, NH')
# (39472, 'Dover, NJ')
# (6913, 'Dowagiac, MI')
# (3612137, 'Downers Grove, IL')
# (3625, 'Downey, CA')
# (27055364, 'Downingtown, PA')
# (33264, 'Draper, UT')
# (165716, 'Dresden, TN')
# (1943848, 'Dripping Springs, TX')
# (20009, 'Drums, PA')
# (163079, 'Duarte, CA')
# (22561, 'Dublin, CA')
# (28209, 'Dublin, OH')
# (2087, 'Dublin, VA')
# (35504315, 'Dubuque, IA')
# (163690, 'Dudley, MA')
# (22132, 'Dulles Town Center, VA')
# (2470025, 'Dulles, VA')
# (11240, 'Duluth, GA')
# (1511, 'Duluth, MN')
# (3570660, 'Dumfries, VA')
# (2562128, 'Duncan, OK')
# (10954, 'Duncan, SC')
# (3658, 'Duncannon, PA')
# (23769122, 'Duncansville, PA')
# (62923, 'Dunn, NC')
# (30823, 'Dunwoody, GA')
# (10420321, 'Durham, CT')
# (22026, 'Durham, NC')
# (307494, 'Durham, NH')
# (12446, 'Eagan, MN')
# (10667, 'Eagle Mountain, UT')
# (7032, 'Eagle Pass, TX')
# (167757, 'Eagle, ID')
# (80911138, 'East Aurora, NY')
# (3570660, 'East Brunswick, NJ')
# (6176, 'East Dennis, MA')
# (80030090, 'East Durham, NY')
# (12890, 'East Grand Forks, MN')
# (88289095, 'East Hanover, NJ')
# (14632005, 'East Hartford, CT')
# (8795, 'East Lansing, MI')
# (5368909, 'East Longmeadow, MA')
# (167757, 'East Meadow, NY')
# (56313852, 'East Moline, IL')
# (33515668, 'East Norriton, PA')
# (19534, 'East Orange, NJ')
# (163883, 'East Palo Alto, CA')
# (1703, 'East Peoria, IL')
# (20573, 'East Providence, RI')
# (7471, 'East Rutherford, NJ')
# (32727, 'East St Louis, IL')
# (42304017, 'East Stoneham, ME')
# (82090049, 'East Syracuse, NY')
# (49042, 'Easton, MD')
# (3706049, 'Easton, PA')
# (334135, 'Eastpointe, MI')
# (6592, 'Eaton, OH')
# (65294553, 'Eau Claire, WI')
# (4674, 'Eddystone, PA')
# (157346, 'Eden Prairie, MN')
# (157353, 'Edgewater, NJ')
# (1403, 'Edgewood, MD')
# (11834, 'Edgewood, NY')
# (1293049, 'Edina, MN')
# (2640631, 'Edinboro, PA')
# (1557409, 'Edison, NJ')
# (77301, 'Edmond, OK')
# (2619961, 'Edwards, CA')
# (71575605, 'Edwardsville, IL')
# (9185, 'Egg Harbor, NJ')
# (3967883, 'Eglin Air Force Base, FL')
# (34218836, 'El Centro, CA')
# (7032, 'El Cerrito, CA')
# (3570660, 'El Dorado Hills, CA')
# (91161992, 'El Dorado, AR')
# (26873, 'El Monte, CA')
# (18924711, 'El Paso County, TX')
# (4029554, 'El Paso, TX')
# (1505, 'El Segundo, CA')
# (437225, 'Elgin, IL')
# (204770, 'Elgin, SC')
# (82291171, 'Elizabeth City, NC')
# (15626530, 'Elizabethtown, KY')
# (5887, 'Elizabethtown, PA')
# (10420321, 'Elk Grove Village, IL')
# (10696913, 'Elk Grove, CA')
# (2973906, 'Elkhart County, IN')
# (153293, 'Elkhart, IN')
# (11876, 'Elko, NV')
# (1486, 'Elkton, VA')
# (922640, 'Ellenville, NY')
# (16710, 'Ellettsville, IN')
# (49042, 'Ellicott City, MD')
# (77301, 'Ellisville, MO')
# (165034, 'Elma, NY')
# (5112, 'Elmendorf, TX')
# (11825945, 'Elmer, NJ')
# (1442109, 'Elmhurst, IL')
# (1087079, 'Elmira, NY')
# (11758, 'Elmsford, NY')
# (10420321, 'Elmwood Park, IL')
# (14255, 'Elwood, IL')
# (34821, 'Elwyn, PA')
# (4822178, 'Elyria, OH')
# (982614, 'Emeryville, CA')
# (18506580, 'Emmett, ID')
# (3043021, 'Emmitsburg, MD')
# (5749, 'Encinitas, CA')
# (1881, 'Endicott, NY')
# (4997572, 'Enfield, CT')
# (98396367, 'Englewood Cliffs, NJ')
# (1947586, 'Englewood, CO')
# (16163783, 'Englewood, OH')
# (9170, 'Ennis, TX')
# (16690, 'Enon, OH')
# (90413667, 'Enterprise, AL')
# (808034, 'Enumclaw, WA')
# (28498, 'Ephrata, PA')
# (18923058, 'Erie-Meadville Area')
# (65294553, 'Erie, PA')
# (289310, 'Erlanger, KY')
# (683310, 'Escanaba, MI')
# (20009, 'Escondido, CA')
# (112168, 'Essex Junction, VT')
# (13658, 'Estacada, OR')
# (20088, 'Estancia, NM')
# (937112, 'Estero, FL')
# (1945473, 'Euclid, OH')
# (165422, 'Eugene, OR')
# (166572, 'Euless, TX')
# (1945473, 'Eureka, CA')
# (7795, 'Evans, NY')
# (3196, 'Evanston, IL')
# (15259054, 'Evansville, IN')
# (570550, 'Evendale, OH')
# (808034, 'Everett, WA')
# (5067678, 'Ewa Gentry, HI')
# (2203697, 'Ewing, NJ')
# (1901345, 'Excelsior, MN')
# (3242, 'Exeter, CA')
# (92681040, 'Fair Lawn, NJ')
# (1945473, 'Fairbanks, AK')
# (5725, 'Fairborn, OH')
# (56670, 'Fairburn, GA')
# (10420321, 'Fairfax Station, VA')
# (2113831, 'Fairfax, VA')
# (2274551, 'Fairfield, CA')
# (808034, 'Fairfield, CT')
# (2646, 'Fairfield, IA')
# (33264, 'Fairfield, NJ')
# (90198358, 'Fairfield, OH')
# (2646, 'Fairmont, MN')
# (5749, 'Fairview Heights, IL')
# (1681, 'Faison, NC')
# (95985, 'Falls Church, VA')
# (7384, 'Far-A-Field, PA')
# (70560, 'Fargo-Moorhead')
# (1374310, 'Fargo, ND')
# (1235, 'Faribault, MN')
# (295644, 'Farmers Branch, TX')
# (347410, 'Farmersburg, IN')
# (6440, 'Farmingdale, NJ')
# (10599076, 'Farmingdale, NY')
# (69234316, 'Farmington Hills, MI')
# (1286891, 'Farmington, CT')
# (8455, 'Farmington, MI')
# (808034, 'Farmington, NM')
# (22523, 'Farmington, UT')
# (19142259, 'Fayetteville, AR')
# (5749, 'Fayetteville, GA')
# (656981, 'Fayetteville, NC')
# (56119363, 'Feasterville, PA')
# (6487, 'Federal Way, WA')
# (12534, 'Fenton, MO')
# (167757, 'Fernandina Beach, FL')
# (7064, 'Festus, MO')
# (166551, 'Finney County, KS')
# (15259054, 'Fishers, IN')
# (4297, 'Fishersville, VA')
# (25179038, 'Fishkill, NY')
# (34656475, 'Fitchburg, MA')
# (15139, 'Flagstaff, AZ')
# (808034, 'Fleming Island, FL')
# (380752, 'Flemington, NJ')
# (581027, 'Flint, MI')
# (1183247, 'Florence County, SC')
# (60951108, 'Florence, AL')
# (76440728, 'Florence, KY')
# (879871, 'Florence, MA')
# (51586544, 'Florence, SC')
# (586645, 'Florham Park, NJ')
# (14542824, 'Florida, NY')
# (11056, 'Florida, United States')
# (86265278, 'Flower Mound, TX')
# (36569, 'Flowery Branch, GA')
# (72483, 'Flowood, MS')
# (10072, 'Folsom, CA')
# (13353, 'Fond du Lac, WI')
# (64510, 'Fontana, CA')
# (8024, 'Fordland, MO')
# (37768, 'Forest City, NC')
# (6176, 'Forest Hill, MD')
# (1463, 'Forest Home, NY')
# (1511, 'Forest Lake, MN')
# (18043, 'Forest Park, IL')
# (12446, 'Forsyth, IL')
# (894572, 'Fort Belvoir, VA')
# (1403, 'Fort Bragg, North Carolina, United States')
# (3072, 'Fort Collins, CO')
# (14542824, 'Fort Defiance, VA')
# (3672, 'Fort Detrick, MD')
# (164451, 'Fort Dodge, IA')
# (5396873, 'Fort George G. Meade, MD')
# (166572, 'Fort Gratiot, MI')
# (25039398, 'Fort Irwin, CA')
# (15133237, 'Fort Kent, ME')
# (777243, 'Fort Lauderdale, FL')
# (5471, 'Fort Lawn, SC')
# (3994, 'Fort Lee, NJ')
# (31065, 'Fort Leonard Wood, MO')
# (3493, 'Fort Madison, IA')
# (1403, 'Fort Meade, MD')
# (5294, 'Fort Mill, SC')
# (333785, 'Fort Mitchell, KY')
# (1235, 'Fort Morgan, CO')
# (6609, 'Fort Myer Heights, VA')
# (72483, 'Fort Myers Beach, FL')
# (3220813, 'Fort Myers, FL')
# (52642826, 'Fort Pierce, FL')
# (19028770, 'Fort Riley, KS')
# (1185, 'Fort Smith, AR')
# (43093, 'Fort Stockton, TX')
# (808034, 'Fort Thomas, KY')
# (481862, 'Fort Valley, GA')
# (4028380, 'Fort Walton Beach, FL')
# (13181, 'Fort Washington, MD')
# (61252, 'Fort Washington, PA')
# (1505, 'Fort Wayne, IN')
# (94355, 'Fort Worth, TX')
# (163993, 'Foster City, CA')
# (20282677, 'Fountain Valley, CA')
# (15139, 'Fowler, CA')
# (10420321, 'Foxborough (Foxboro), MA')
# (77688, 'Foxborough, MA')
# (5121, 'Framingham, MA')
# (11752085, 'Franconia, VA')
# (86321483, 'Frankfort, KY')
# (1850810, 'Franklin, MA')
# (321986, 'Franklin, NH')
# (1852454, 'Franklin, TN')
# (3242, 'Franklin, VA')
# (2562128, 'Franklin, WI')
# (11056, 'Frederick County, MD')
# (11788646, 'Frederick, MD')
# (8479403, 'Fredericksburg, VA')
# (11088832, 'Fredonia, NY')
# (230463, 'Free Home, GA')
# (580089, 'Freeburg, IL')
# (6913, 'Freedom, CA')
# (9814, 'Freedom, PA')
# (9210946, 'Freehold, NJ')
# (93254, 'Freeland, MI')
# (1344, 'Freeport, IL')
# (37845, 'Freeport, ME')
# (48024, 'Freeport, TX')
# (5107, 'Fremont, CA')
# (808034, 'Fremont, California, United States')
# (53708, 'Fremont, NE')
# (27180004, 'Frenchtown, MI')
# (743843, 'Fresno County, CA')
# (2300, 'Fresno, CA')
# (6979, 'Fridley, MN')
# (383161, 'Friendswood, TX')
# (8221, 'Frisco, TX')
# (5343, 'Front Royal, VA')
# (808034, 'Fullerton, CA')
# (2059, 'Fuquay-Varina, NC')
# (28132450, 'Gadsden, AL')
# (2230, 'Gaffney, SC')
# (248184, 'Gahanna, OH')
# (9286450, 'Gainesville, FL')
# (9499, 'Gainesville, GA')
# (3570660, 'Gainesville, VA')
# (1603, 'Gaithersburg, MD')
# (18009221, 'Galesburg, IL')
# (2375692, 'Galesburg, MI')
# (25017, 'Gallatin, TN')
# (903710, 'Gallup, NM')
# (2271, 'Galt, CA')
# (16263, 'Galveston, TX')
# (9714055, 'Gap, PA')
# (17233, 'Garciasville, TX')
# (69989, 'Garden City, GA')
# (7795, 'Garden City, KS')
# (6913, 'Garden City, MI')
# (3360328, 'Garden City, NY')
# (808034, 'Garden Grove, CA')
# (96254, 'Gardena, CA')
# (95062508, 'Gardner, KS')
# (9814, 'Gardner, MA')
# (28647688, 'Garfield Heights, OH')
# (9391120, 'Garland, TX')
# (163828, 'Garner, NC')
# (581027, 'Gary, IN')
# (96180361, 'Gastonia, NC')
# (35121, 'Gaylord, MN')
# (19637, 'Geismar, LA')
# (5343, 'Geneva, AL')
# (24211, 'Geneva, IL')
# (497515, 'Genoa, OH')
# (2908367, 'Georgetown, DE')
# (2107, 'Georgetown, KY')
# (27152943, 'Georgetown, TX')
# (1016, 'Georgia, United States')
# (77022728, 'Germantown, MD')
# (60836398, 'Germantown, TN')
# (83051748, 'Germantown, WI')
# (18777798, 'Germany')
# (2875, 'Getzville, NY')
# (80829889, 'Gibsonia, PA')
# (13074, 'Gig Harbor, WA')
# (4167, 'Gilbert, AZ')
# (225343, 'Gilbert, PA')
# (1668, 'Gillette, WY')
# (1628878, 'Glasgow, DE')
# (4674, 'Glassboro, NJ')
# (14749, 'Glastonbury, CT')
# (1943848, 'Glen Allen, VA')
# (77499, 'Glen Burnie, MD')
# (696365, 'Glen Carbon, IL')
# (166360, 'Glen, MS')
# (27254190, 'Glendale, AZ')
# (808034, 'Glendale, CA')
# (28647688, 'Glendive, MT')
# (16263, 'Glenmont, NY')
# (2430668, 'Glenpool, OK')
# (3570660, 'Glenside, PA')
# (71982274, 'Glenview, IL')
# (165697, 'Glenwood Springs, CO')
# (2018, 'Gloucester, MA')
# (808034, 'Gloucester, VA')
# (35571114, 'Gold Canyon, AZ')
# (411814, 'Golden Valley, MN')
# (11311, 'Golden, CO')
# (18506580, 'Goldsboro, NC')
# (5275, 'Goleta, CA')
# (2646, 'Gonzales, TX')
# (3015, 'Goodland, KS')
# (19024424, 'Goodlettsville, TN')
# (28646687, 'Goodwell, OK')
# (163079, 'Goodyear, AZ')
# (1087079, 'Goshen, NY')
# (65294553, 'Grafton, OH')
# (422503, 'Graham, TX')
# (40693052, 'Granbury, TX')
# (1703, 'Granby, CO')
# (3706049, 'Grand Blanc, MI')
# (45716, 'Grand Canyon Village, AZ')
# (61984, 'Grand Forks, ND')
# (18506580, 'Grand Island, NE')
# (2736008, 'Grand Junction, CO')
# (82500012, 'Grand Prairie, TX')
# (1375518, 'Grand Rapids Metropolitan Area')
# (29622, 'Grand Rapids metropolitan area, MI')
# (38605, 'Grand Rapids, MI')
# (1511, 'Grand Rapids, MN')
# (3264, 'Grandville, MI')
# (80829889, 'Granger, IN')
# (3706049, 'Grants Pass, OR')
# (4591, 'Grantsburg, WI')
# (10408914, 'Grantsville, UT')
# (72483, 'Grapevine, TX')
# (1207327, 'Grass Valley, CA')
# (1867264, 'Great Barrington, MA')
# (1103, 'Great Falls, MT')
# (6104, 'Great Neck, NY')
# (3714038, 'Greater Bangor Area')
# (17283, 'Greater Birmingham, Alabama Area')
# (601919, 'Greater Bloomington Area')
# (42134, 'Greater Bloomington, Illinois Area')
# (91743578, 'Greater Boston')
# (9499, 'Greater Charlottesville Area')
# (2297840, 'Greater Chattanooga')
# (2684553, 'Greater Chicago Area')
# (9499, 'Greater Clarksville Area')
# (10035810, 'Greater Cleveland')
# (28978381, 'Greater Colorado Springs Area')
# (16183163, 'Greater Corpus Christi Area')
# (14191, 'Greater Dothan')
# (28893, 'Greater Farmington Area')
# (29331, 'Greater Fort Wayne')
# (12709, 'Greater Harrisburg Area')
# (14571, 'Greater Hartford')
# (1389, 'Greater Houston')
# (164664, 'Greater Indianapolis')
# (163640, 'Greater Jackson Area')
# (856962, 'Greater Jacksonville, NC Area')
# (11818084, 'Greater Jefferson City Area')
# (450185, 'Greater Kennewick Area')
# (163578, 'Greater Lansing')
# (2174958, 'Greater Los Angeles, CA')
# (166714, 'Greater Macon')
# (16038, 'Greater Madison Area')
# (35646045, 'Greater Milwaukee')
# (2578499, 'Greater Minneapolis-St. Paul Area')
# (84959254, 'Greater Morgantown Area')
# (754041, 'Greater New Orleans Region')
# (9499, 'Greater Ocala Area')
# (2354064, 'Greater Orlando')
# (10093812, 'Greater Philadelphia')
# (80674419, 'Greater Phoenix Area')
# (67080514, 'Greater Pittsburgh Region')
# (28345, 'Greater Reno Area')
# (206993, 'Greater Richmond Region')
# (9124, 'Greater Sacramento')
# (18054300, 'Greater Seattle Area')
# (6044, 'Greater St. Louis')
# (1146188, 'Greater Tampa Bay Area')
# (9499, 'Greater Tuscaloosa Area')
# (15218920, 'Greater Wilmington Area')
# (214212, 'Greater Yakima Area')
# (49223, 'Greater Yuma, AZ Area')
# (5352294, 'Greeley, CO')
# (7789, 'Green Bay, WI')
# (1100944, 'Green Valley, AZ')
# (455780, 'Greenbelt, MD')
# (808034, 'Greenbrae, CA')
# (3671, 'Greenbrier, AR')
# (17902, 'Greencastle, PA')
# (162912, 'Greendale, IN')
# (1945473, 'Greeneville, TN')
# (1867264, 'Greenfield, MA')
# (10387626, 'Greenfield, OH')
# (2737970, 'Greenfield, WI')
# (91447303, 'Greensboro--Winston-Salem--High Point Area')
# (808034, 'Greensboro, NC')
# (19024424, 'Greensburg, PA')
# (163617, 'Greenville County, SC')
# (33248183, 'Greenville-Spartanburg-Anderson, South Carolina Area')
# (66278935, 'Greenville, NC')
# (808034, 'Greenville, SC')
# (164200, 'Greenville, TX')
# (11009726, 'Greenwich, CT')
# (15472, 'Greenwood Village, CO')
# (2737970, 'Greenwood, IN')
# (6215, 'Greenwood, SC')
# (808034, 'Greer, SC')
# (18691, 'Gresham, OR')
# (5618, 'Gretna, NE')
# (15870, 'Groesbeck, TX')
# (1703, 'Groton, CT')
# (2646, 'Grove City, OH')
# (1471368, 'Groveland, CA')
# (4723171, 'Groveland, MI')
# (49105, 'Groveport, OH')
# (134081, 'Guilderland, NY')
# (10420321, 'Guilford, CT')
# (2709, 'Gulf Breeze, FL')
# (28647688, 'Gunnison, CO')
# (12659, 'Guntersville, AL')
# (1103, 'Gurnee, IL')
# (9487, 'Guthrie, KY')
# (164098, 'Gwinnett County, GA')
# (76500049, 'Gypsum, CO')
# (11818084, 'Hackensack, NJ')
# (18923058, 'Hackleburg, AL')
# (2087, 'Hagerstown, MD')
# (6265, 'Halethorpe, MD')
# (629785, 'Hallandale Beach, FL')
# (2589107, 'Hallock, MN')
# (3706049, 'Hamden, CT')
# (278713, 'Hamilton County, OH')
# (581027, 'Hamilton, OH')
# (10225139, 'Hammond, IN')
# (28597765, 'Hammond, LA')
# (98514983, 'Hampton Roads, Virginia Metropolitan Area')
# (7795, 'Hampton, VA')
# (165586, 'Hancocks Bridge, NJ')
# (7032, 'Hanford, CA')
# (2646, 'Hannibal, MO')
# (96180361, 'Hanover Park, IL')
# (40760236, 'Hanover, MA')
# (2153, 'Hanover, MD')
# (686294, 'Hanover, NH')
# (10820, 'Hanover, PA')
# (11240, 'Happy Valley, OR')
# (5343, 'Harahan, LA')
# (6176, 'Harlingen, TX')
# (444038, 'Harmans, MD')
# (2031248, 'Harriman, TN')
# (74081610, 'Harrington, DE')
# (3460, 'Harrisburg, PA')
# (1945473, 'Harrison, AR')
# (6913, 'Harrison, MI')
# (75348, 'Harrison, NY')
# (493453, 'Harrisonburg, VA')
# (2193256, 'Harrisonville, MO')
# (5553, 'Harrold, SD')
# (12988732, 'Hartford City, IN')
# (7043, 'Hartford County, CT')
# (5064123, 'Hartford, CT')
# (10279209, 'Hartland, WI')
# (167757, 'Hartsville, SC')
# (1373835, 'Harvard, IL')
# (4128, 'Hatfield, PA')
# (211166, 'Hauppauge, NY')
# (10420321, 'Haverhill, MA')
# (76500049, 'Havertown, PA')
# (14542824, 'Hawaii, United States')
# (85123, 'Hawley, MN')
# (7032, 'Hawthorne, CA')
# (484735, 'Hawthorne, NY')
# (46648, 'Hayward, CA')
# (2646, 'Hayward, WI')
# (88277482, 'Hazel Crest, IL')
# (27108872, 'Hazlet, NJ')
# (17882, 'Headquarters, KY')
# (81878, 'Headquarters, NJ')
# (18953305, 'Healdsburg, CA')
# (77318089, 'Heath, OH')
# (3056912, 'Hebron, KY')
# (9881525, 'Hegins, PA')
# (11300257, 'Helena, MT')
# (28595302, 'Helotes, TX')
# (2430668, 'Henderson, CO')
# (2646, 'Henderson, KY')
# (14542824, 'Henderson, NC')
# (7361, 'Henderson, NV')
# (20573, 'Hendersonville, NC')
# (63532172, 'Hendersonville, TN')
# (3781515, 'Henrico, VA')
# (96180361, 'Hephzibah, GA')
# (12787, 'Herlong, CA')
# (1103, 'Hermitage, PA')
# (35571114, 'Hermitage, TN')
# (3476, 'Hernando, MS')
# (8860695, 'Herndon, KS')
# (163139, 'Herndon, VA')
# (3658, 'Hershey, PA')
# (884316, 'Hesston, KS')
# (96180361, 'Hialeah, FL')
# (164113, 'Hickory Hills, IL')
# (41004, 'Hickory, NC')
# (9667, 'Hicksville, NY')
# (76440728, 'High Point, NC')
# (4235104, 'Highland, CA')
# (556848, 'Highlands Ranch, CO')
# (9895824, 'Highwood, IL')
# (24440, 'Hilliard, OH')
# (2106853, 'Hillsboro, OR')
# (6176, 'Hillsboro, TX')
# (28647688, 'Hillsboro, WI')
# (20969, 'Hillsborough County, FL')
# (20009, 'Hillsborough, NC')
# (8621, 'Hillside, IL')
# (1861137, 'Hillside, NJ')
# (7032, 'Hilo, HI')
# (57677390, 'Hilton Head Island, SC')
# (78124, 'Hilton Head Island, South Carolina Area')
# (25856, 'Hilton, NY')
# (2343421, 'Hinds County, MS')
# (35583934, 'Hinesville, GA')
# (517387, 'Hingham, MA')
# (1945473, 'Hiram, GA')
# (164200, 'Hixson, TN')
# (19807, 'Hobart, IN')
# (2192, 'Hobbs, NM')
# (10420321, 'Hoboken, NJ')
# (41854, 'Hodgkins, IL')
# (8619, 'Hoffman Estates, IL')
# (10517709, 'Holbrook, NY')
# (12446, 'Holden, ME')
# (947663, 'Holdenville, OK')
# (6449, 'Holland, MI')
# (4798, 'Holland, OH')
# (819218, 'Hollister, CA')
# (3486, 'Hollywood, FL')
# (988946, 'Hollywood, MD')
# (14650, 'Holmdel, NJ')
# (25552, 'Holton, KS')
# (2532635, 'Holyoke, MA')
# (30953, 'Home Park, Florida, United States')
# (12573, 'Home, KS')
# (162755, 'Homedale, ID')
# (71904349, 'Homer, MI')
# (6497, 'Homestead, FL')
# (71904349, 'Homestead, PA')
# (162644, 'Homewood, AL')
# (46000, 'Homewood, IL')
# (1945473, 'Hondo, TX')
# (3002336, 'Honolulu, HI')
# (1236687, 'Hoopeston, IL')
# (72483, 'Hoover, AL')
# (2193256, 'Hope Mills, NC')
# (2646, 'Hopkinsville, KY')
# (57106, 'Horse Cave, KY')
# (20009, 'Horsham, PA')
# (3796614, 'Hot Springs, AR')
# (9401140, 'Houston, Texas, United States')
# (96677, 'Houston, TX')
# (80862575, 'Howell, MI')
# (23375, 'Huber Heights, OH')
# (242230, 'Hudson Waterfront, NJ')
# (1211063, 'Hudson, FL')
# (3570660, 'Hudson, NH')
# (53193, 'Hudson, NY')
# (10420321, 'Hudson, OH')
# (8667, 'Hudson, WI')
# (16161886, 'Humble, TX')
# (5058, 'Hunt Valley, MD')
# (6472500, 'Huntersville, NC')
# (3135, 'Huntington Beach, CA')
# (6176, 'Huntington Park, CA')
# (436931, 'Huntington Station, NY')
# (6104, 'Huntington, NY')
# (82385, 'Huntington, WV')
# (77153, 'Huntsville-Decatur-Albertville Area')
# (3967883, 'Huntsville, AL')
# (57978, 'Huntsville, AR')
# (7795, 'Huntsville, TX')
# (3671, 'Hurlburt Field, FL')
# (11240, 'Hurst, TX')
# (1668, 'Hutchins, TX')
# (2646, 'Hutchinson, KS')
# (7929696, 'Hutchinson, MN')
# (107699, 'Hyannis, MA')
# (12293, 'Idaho Falls, ID')
# (8239496, 'Idaho, United States')
# (9814, 'Illinois City, IL')
# (4433, 'Illinois, United States')
# (40025, 'Immokalee, FL')
# (3764607, 'Imperial, CA')
# (9732, 'Independence, KS')
# (15259054, 'Independence, KY')
# (166572, 'Independence, MO')
# (708393, 'Independence, OH')
# (64863800, 'India')
# (65361091, 'Indian Head, MD')
# (11319362, 'Indian Springs, NV')
# (167757, 'Indian Trail, NC')
# (35520100, 'Indian Wells, CA')
# (7680, 'Indiana, United States')
# (808034, 'Indianapolis, IN')
# (22338085, 'Indianapolis, Indiana, United States')
# (9826, 'Ingleside, TX')
# (4541, 'Inglewood, CA')
# (3626, 'Inverness, FL')
# (163480, 'Inwood, NY')
# (14542824, 'Iowa City, IA')
# (1016, 'Iowa, United States')
# (20723, 'Irondale, AL')
# (18860134, 'Ironwood, MI')
# (1103, 'Irvine, CA')
# (1557409, 'Irvine, California, United States')
# (1103, 'Irving, TX')
# (19534, 'Iselin, NJ')
# (777243, 'Islip, NY')
# (41161, 'Issaquah, WA')
# (89143472, 'Itasca, IL')
# (37396978, 'Ithaca, NY')
# (49648429, 'Iva, SC')
# (10165687, 'Jackson County, MO')
# (284165, 'Jackson Township, OH')
# (71575605, 'Jackson, GA')
# (1943848, 'Jackson, LA')
# (8936, 'Jackson, MI')
# (3269, 'Jackson, MO')
# (64274685, 'Jackson, MS')
# (10141, 'Jackson, NJ')
# (2425285, 'Jackson, OH')
# (72416, 'Jackson, SC')
# (18425303, 'Jackson, TN')
# (97402272, 'Jacksonville Beach, FL')
# (28332, 'Jacksonville, AL')
# (166572, 'Jacksonville, FL')
# (16892, 'Jacksonville, GA')
# (2664556, 'Jacksonville, IL')
# (36990695, 'Jacksonville, NC')
# (2162, 'Jacksonville, TX')
# (3534, 'Jal, NM')
# (345295, 'Jamaica, NY')
# (165933, 'Jamestown, CA')
# (130095, 'Jamestown, TN')
# (2193256, 'Janesville, WI')
# (79042201, 'Jarratt, VA')
# (2646, 'Jasper, IN')
# (6798963, 'Jeannette, PA')
# (76171420, 'Jefferson City, MO')
# (1681, 'Jefferson County, IL')
# (2908367, 'Jeffersontown, KY')
# (18401, 'Jeffersonville, IN')
# (11240, 'Jensen Beach, FL')
# (8474, 'Jericho, NY')
# (1040158, 'Jerome, ID')
# (1808, 'Jersey City, NJ')
# (254060, 'Jersey, GA')
# (26792, 'Jessup, MD')
# (2433416, 'Jessup, PA')
# (5303168, 'Jesup, GA')
# (5275, 'Johns Creek, GA')
# (14542824, 'Johnson City, TN')
# (1579375, 'Johnston, IA')
# (20573, 'Johnston, RI')
# (38400, 'Johnstown, CO')
# (18176, 'Johnstown, NY')
# (1945473, 'Johnstown, PA')
# (164527, 'Joliet, IL')
# (57978, 'Jonesboro, AR')
# (11227630, 'Jonesboro, GA')
# (2121817, 'Jonesville, MI')
# (305287, 'Joplin, MO')
# (3634748, 'Junction City, KS')
# (2664556, 'Juneau, AK')
# (78741693, 'Juno Beach, FL')
# (269675, 'Jupiter, FL')
# (96081672, 'Jurupa Valley, CA')
# (157239, 'Kahului, HI')
# (153293, 'Kalamazoo, MI')
# (163787, 'Kalispell, MT')
# (7384, 'Kankakee, IL')
# (89863227, 'Kansas City Metropolitan Area')
# (217338, 'Kansas City, KS')
# (28503, 'Kansas City, Missouri, United States')
# (22283894, 'Kansas City, MO')
# (1016, 'Kansas, United States')
# (163883, 'Kapolei, HI')
# (3748, 'Katy, TX')
# (2193256, 'Kaukauna, WI')
# (11522, 'Kaysville, UT')
# (38521, 'Kearney, NE')
# (10420321, 'Kearny, NJ')
# (2664556, 'Keene, NH')
# (1909139, 'Keller, TX')
# (385010, 'Kenai, AK')
# (2396310, 'Kendallville, IN')
# (5235, 'Kenilworth, NJ')
# (6176, 'Kenmore, NY')
# (3240, 'Kennebec, SD')
# (2664556, 'Kennebunk, ME')
# (82153, 'Kenner, LA')
# (66278935, 'Kennesaw, GA')
# (34755301, 'Kennewick, WA')
# (10083903, 'Kenosha, WI')
# (2271, 'Kent, WA')
# (7886, 'Kenton, OH')
# (162724, 'Kentucky, United States')
# (82500012, 'Kentwood, MI')
# (28612966, 'Kermit, TX')
# (4128, 'Kernersville, NC')
# (3706049, 'Kerrville, TX')
# (165422, 'Ketchikan, AK')
# (162755, 'Kettle Falls, WA')
# (19637, 'Killeen-Temple Area')
# (11009726, 'Killeen, TX')
# (32478, 'King City, MO')
# (11402317, 'King County, WA')
# (1403, 'King George, VA')
# (15216893, 'King of Prussia, PA')
# (230282, 'Kingsburg, CA')
# (2646, 'Kingsport, TN')
# (363277, 'Kingston, NY')
# (2736008, 'Kingston, PA')
# (7032, 'Kingstowne, VA')
# (80829889, 'Kingwood, WV')
# (7795, 'Kinnelon, NJ')
# (90413667, 'Kinston, NC')
# (1441, 'Kirkland, WA')
# (5461, 'Kirtland Air Force Base, NM')
# (6732937, 'Kissimmee, FL')
# (450185, 'Klamath Falls, OR')
# (28352, 'Knightdale, NC')
# (166714, 'Knoxville Metropolitan Area')
# (165472, 'Knoxville, TN')
# (80516368, 'Kohala, HI')
# (1799, 'Kohler, WI')
# (1908498, 'Kokomo, IN')
# (2564997, 'Koloa, HI')
# (1945473, 'Kula, HI')
# (22132, 'Kuna, ID')
# (28669777, 'Kutztown, PA')
# (3240, 'La Crosse, WI')
# (1271305, 'La Crosse, Wisconsin, United States')
# (34218836, 'La Grande, OR')
# (10135152, 'La Grange, KY')
# (10141, 'La Jolla, California, United States')
# (35716480, 'La Marque, TX')
# (165938, 'La Mesa, CA')
# (163139, 'La Mirada, CA')
# (48024, 'La Porte, TX')
# (18641359, 'La Puente, CA')
# (35504, 'La Quinta, CA')
# (2162, 'La Vergne, TN')
# (56670, 'La Verne, CA')
# (9402, 'Lacey, WA')
# (14542824, 'Laconia, NH')
# (1324822, 'Ladson, SC')
# (59005249, 'Lady Lake, FL')
# (14383281, 'Lafayette, IN')
# (21921, 'Lafayette, Indiana Metropolitan Area')
# (92578918, 'Lafayette, LA')
# (164860, 'Lago Vista, TX')
# (3706049, 'Laguna Beach, CA')
# (165364, 'Laguna Hills, CA')
# (35504, 'Laguna Niguel, CA')
# (71316538, 'Lake Buena Vista, FL')
# (3654739, 'Lake Charles, LA')
# (157239, 'Lake City, FL')
# (1851642, 'Lake County, IL')
# (594846, 'Lake County, IN')
# (26923, 'Lake Elmo, MN')
# (86475, 'Lake Forest, CA')
# (44730, 'Lake Forest, IL')
# (28647688, 'Lake Havasu City, AZ')
# (3671, 'Lake Hiawatha, NJ')
# (25856, 'Lake in the Hills, IL')
# (3570660, 'Lake Mary, FL')
# (6913, 'Lake Oswego, OR')
# (13353, 'Lake St Louis, MO')
# (29620, 'Lake Villa, IL')
# (10667641, 'Lake Wales, FL')
# (5274161, 'Lake Worth, FL')
# (2911, 'Lake Worth, TX')
# (107365, 'Lakeland, FL')
# (214960, 'Lakeside, AZ')
# (4723171, 'Lakeside, MT')
# (12095, 'Lakeville, MA')
# (162755, 'Lakeville, MN')
# (18312164, 'Lakewood, CO')
# (49042, 'Lakewood, NJ')
# (14542824, 'Lamar, CO')
# (163883, 'Lanai City, HI')
# (64883, 'Lancaster, CA')
# (164527, 'Lancaster, MA')
# (3658, 'Lancaster, PA')
# (18506580, 'Lancaster, SC')
# (4822178, 'Lancaster, TX')
# (2254693, 'Lancaster, WI')
# (1379045, 'Landover, MD')
# (34727, 'Lane County, OR')
# (35529547, 'Langhorne, PA')
# (6281, 'Langston, OK')
# (71904349, 'Lanham, MD')
# (49105, 'Lansdale, PA')
# (43278, 'Lansing, MI')
# (407589, 'Lapeer, MI')
# (96180361, 'LaPlace, LA')
# (424952, 'Laredo, TX')
# (1279498, 'Largo, FL')
# (1403, 'Las Cruces, NM')
# (2121817, 'Las Vegas Metropolitan Area')
# (581824, 'Las Vegas, Nevada, United States')
# (7361, 'Las Vegas, NV')
# (917557, 'Latham, NY')
# (3270028, 'Lathrop, CA')
# (23552, 'Latrobe, PA')
# (7795, 'Laurel, MD')
# (2646, 'Laurel, MT')
# (105203, 'Laurinburg, NC')
# (166643, 'Lawrence, KS')
# (298459, 'Lawrence, MA')
# (32469, 'Lawrenceburg, IN')
# (602239, 'Lawrenceburg, KY')
# (3748, 'Lawrenceville, GA')
# (11818084, 'Lawton Area')
# (760983, 'Lawton, OK')
# (77301, 'Layton, UT')
# (14542824, 'Le Mars, IA')
# (581027, 'League City, TX')
# (16075064, 'Leavenworth, KS')
# (2155460, 'Leawood, KS')
# (2700167, 'Lebanon, IN')
# (11056, 'Lebanon, KY')
# (37902046, 'Lebanon, MO')
# (163348, 'Lebanon, NH')
# (2589107, 'Lebanon, OR')
# (28498, 'Lebanon, PA')
# (71575605, 'Lebanon, TN')
# (8294, 'Lee, MA')
# (19058930, 'Leeds, NY')
# (34867, 'Lees Summit, MO')
# (690568, 'Leesburg, FL')
# (32455, 'Leesburg, GA')
# (2664556, 'Leesburg, VA')
# (69736805, 'Leetonia, OH')
# (26341, 'Leetsdale, PA')
# (9203219, 'Lehi, UT')
# (11518813, 'Leland, NC')
# (162510, 'Lemont, IL')
# (11056, 'Lemoore, CA')
# (422503, 'Lenexa, KS')
# (65294553, 'Lenhartsville, PA')
# (808034, 'Leominster, MA')
# (34341, 'Levittown, NY')
# (15389, 'Lewis Center, OH')
# (19023, 'Lewisberry, PA')
# (18176, 'Lewiston, ID')
# (3706049, 'Lewiston, ME')
# (18860134, 'Lewisville, TX')
# (1403, 'Lexington Park, MD')
# (10831504, 'Lexington, KY')
# (2227, 'Lexington, MA')
# (46000, 'Lexington, NC')
# (2646, 'Lexington, NE')
# (157338, 'Lexington, VA')
# (7550, 'Liberty Lake, WA')
# (89877420, 'Liberty, NC')
# (15721, 'Libertyville, IL')
# (71575605, 'Lima, OH')
# (10420321, 'Lincoln Park, NJ')
# (163535, 'Lincoln, CA')
# (38521, 'Lincoln, NE')
# (1043057, 'Lincoln, Nebraska Metropolitan Area')
# (167024, 'Lincolnshire, IL')
# (2677, 'Lincolnton, NC')
# (2712059, 'Lindon, UT')
# (163253, 'Lino Lakes, MN')
# (139348, 'Linthicum Heights, MD')
# (35666700, 'Linthicum, MD')
# (11486116, 'Lisle, IL')
# (2908367, 'Litchfield Park, AZ')
# (3579761, 'Lithia Springs, GA')
# (23379, 'Lititz, PA')
# (86001745, 'Little Canada, MN')
# (8019, 'Little Chicago, WI')
# (17109, 'Little Elm, TX')
# (2986, 'Little Rock Metropolitan Area')
# (24494, 'Little Rock, AR')
# (3308308, 'Littleton, CO')
# (5040587, 'Littleton, NH')
# (31827, 'Live Oak, TX')
# (4994, 'Livermore, CA')
# (25856, 'Liverpool, NY')
# (1668, 'Livingston, MT')
# (18062, 'Livingston, NJ')
# (80862575, 'Livonia, MI')
# (815722, 'Location, WV')
# (22340991, 'Lockport, NY')
# (4453, 'Locust Grove, GA')
# (77301, 'Lodi, CA')
# (1766026, 'Logan, UT')
# (3706049, 'Loma Linda, CA')
# (1075434, 'Lombard, IL')
# (1211063, 'London, OH')
# (1511, 'Londonderry, NH')
# (3711368, 'Lone Tree, CO')
# (3308308, 'Long Beach, CA')
# (86041588, 'Long Branch, NJ')
# (13334, 'Longmont, CO')
# (483961, 'Longview, TX')
# (165422, 'Longview, WA')
# (7720, 'Longwood, FL')
# (11777418, 'Lonoke, AR')
# (35504, 'Loomis, CA')
# (96180361, 'Lorain, OH')
# (65294553, 'Lorton, VA')
# (2135088, 'Los Alamitos, CA')
# (5327, 'Los Alamos, NM')
# (31953, 'Los Angeles County, CA')
# (91357855, 'Los Angeles Metropolitan Area')
# (2476, 'Los Angeles, CA')
# (937092, 'Los Angeles, California, United States')
# (2646, 'Los Banos, CA')
# (165158, 'Los Gatos, CA')
# (37768, 'Los Lunas, NM')
# (6913, 'Los Osos, CA')
# (11227630, 'Loudon, TN')
# (869141, 'Louisiana, United States')
# (2736008, 'Louisville, KY')
# (3495423, 'Loveland, CO')
# (3260, 'Loves Park, IL')
# (162536, 'Lowell, AR')
# ...
# (3700354, 'Snow Hill, NC')
# (5482, 'Social Circle, GA')
# (808034, 'Soldotna, AK')
# (1393, 'Solon, OH')
# (9210946, 'Somerset County, NJ')
# (20009, 'Somerset, KY')
# (55787, 'Somerset, NJ')
# (34218836, 'Somerset, PA')
# (64865352, 'Somerville, MA')
# (14363, 'Somerville, NJ')
# (2671586, 'Sonoma, CA')
# (11440, 'Souderton, PA')
# (79560, 'South Attleboro, MA')
# (360308, 'South Beloit, IL')
# (74306759, 'South Bend-Mishawaka Region')
# (629227, 'South Bend, IN')
# (76171420, 'South Boston, VA')
# (1041095, 'South Carolina, United States')
# (162724, 'South Dakota, United States')
# (36995, 'South El Monte, CA')
# (8667, 'South Elgin, IL')
# (4324, 'South Hackensack, NJ')
# (3593828, 'South Haven, MI')
# (30065, 'South Jordan, UT')
# (6913, 'South Lake Tahoe, CA')
# (26569406, 'South Milwaukee, WI')
# (1944535, 'South Mountain, PA')
# (6913, 'South Pasadena, CA')
# (88659237, 'South Plainfield, NJ')
# (4060, 'South Portland, ME')
# (167757, 'South Salem, NY')
# (3210501, 'South San Francisco, CA')
# (14528, 'South San Gabriel, CA')
# (72483, 'South Sheffield, AL')
# (20009, 'South St Paul, MN')
# (71904349, 'Southampton, NY')
# (92461464, 'Southampton, PA')
# (7795, 'Southaven, MS')
# (2271, 'Southborough, MA')
# (166572, 'Southern Pines, NC')
# (8795, 'Southfield, MI')
# (5064123, 'Southington, CT')
# (24803, 'Southlake, TX')
# (6176, 'Spanaway, WA')
# (15564, 'Sparks, NV')
# (14140, 'Sparrows Point, MD')
# (1511, 'Sparta, TN')
# (1058190, 'Spartanburg, SC')
# (163025, 'Speedway, IN')
# (7935, 'Spencer, IA')
# (8885, 'Spirit Lake, IA')
# (64639449, 'Spokane Valley, WA')
# (13074, 'Spokane, WA')
# (4062, 'Spring Hill, TN')
# (102847, 'Spring House, PA')
# (911928, 'Spring Park, MN')
# (1025, 'Spring, TX')
# (11009726, 'Springdale, AR')
# (16733, 'Springfield-Branson, Missouri Area')
# (164931, 'Springfield, IL')
# (822071, 'Springfield, MA')
# (7064, 'Springfield, MO')
# (37768, 'Springfield, NE')
# (5112, 'Springfield, OH')
# (165422, 'Springfield, OR')
# (3469, 'Springfield, TN')
# (1403, 'Springfield, VA')
# (167757, 'Springfield, VT')
# (2736008, 'Springville, AL')
# (2480405, 'St Augustine, FL')
# (21542, 'St Charles, MO')
# (4141117, 'St Clair Shores, MI')
# (9185, 'St Clairsville, OH')
# (74464, 'St Cloud, MN')
# (410499, 'St George, UT')
# (1586, 'St Georges, DE')
# (18506580, 'St Helena, CA')
# (209610, 'St James, LA')
# (43278, 'St Johns, MI')
# (77669120, 'St Johnsbury, VT')
# (808034, 'St Joseph, MI')
# (87599, 'St Joseph, MO')
# (72483, 'St Louis Park, MN')
# (808034, 'St Louis, Missouri, United States')
# (7064, 'St Louis, MO')
# (4713, 'St Paul, MN')
# (18425303, 'St Peters, MO')
# (166671, 'St Petersburg, FL')
# (4852, 'St Petersburg, Florida, United States')
# (164880, 'St Regis Falls, NY')
# (9075575, 'St. Louis County, MO')
# (13199621, 'Stafford, TX')
# (41008, 'Stafford, VA')
# (1215629, 'Stamford, CT')
# (1792, 'Stanford, CA')
# (10266947, 'Stanford, KY')
# (2972588, 'Stanly County, NC')
# (12446, 'Star Lake, NY')
# (1943848, 'Starkville, MS')
# (23769122, 'State College, PA')
# (71316538, 'Stateline, NV')
# (6913, 'Staten Island, NY')
# (2252, 'Statesville, NC')
# (5343, 'Steamboat Springs, CO')
# (550530, 'Stephenville, TX')
# (1906, 'Sterling Heights, MI')
# (33266522, 'Sterling Wood, TX')
# (24187, 'Sterling, OH')
# (167757, 'Sterling, VA')
# (167757, 'Stillwater, MN')
# (6281, 'Stillwater, OK')
# (6234, 'Stilwell, OK')
# (3888, 'Stockbridge, GA')
# (25017, 'Stockton, CA')
# (31896, 'Stockton, IL')
# (1431, 'Stone Mountain, GA')
# (71904349, 'Stoneham, MA')
# (93749948, 'Stonington, CT')
# (95724, 'Stony Point, NC')
# (30755, 'Strafford County, NH')
# (30967, 'Stratford, CA')
# (461332, 'Stratford, CT')
# (598372, 'Streamwood, IL')
# (2724823, 'Streetsboro, OH')
# (135342, 'Stuart, FL')
# (80911138, 'Stuarts Draft, VA')
# (837416, 'Sturbridge, MA')
# (64677, 'Sturgeon Bay, WI')
# (545086, 'Sturtevant, WI')
# (2193256, 'Suamico, WI')
# (9201883, 'Sudbury, MA')
# (28014, 'Suffolk County, NY')
# (66105, 'Suffolk, VA')
# (3681, 'Sugar Land, TX')
# (2646, 'Sullivan, IN')
# (7119929, 'Sulphur Springs, TX')
# (14459, 'Sulphur, LA')
# (11818084, 'Sulphur, OK')
# (20009, 'Summerville, SC')
# (11804, 'Summit, NJ')
# (963770, 'Sumner, WA')
# (3534, 'Sumter, SC')
# (2584496, 'Sun City Center, FL')
# (18506580, 'Sun City West, AZ')
# (808034, 'Sun City, AZ')
# (9251256, 'Sun City, KS')
# (315817, 'Sun Valley, CA')
# (2203697, 'Sunfish Lake, MN')
# (163761, 'Sunland Park, NM')
# (1441, 'Sunnyvale, CA')
# (9184151, 'Sunnyvale, TX')
# (166360, 'Sunrise, FL')
# (11518813, 'Supply, NC')
# (96180361, 'Surprise, AZ')
# (18523922, 'Surry, ME')
# (5666, 'Surry, VA')
# (2684081, 'Suwanee, GA')
# (20009, 'Swansboro, NC')
# (1642, 'Swiftwater, PA')
# (49455, 'Sycamore, IL')
# (28647688, 'Sylva, NC')
# (97402272, 'Syosset, NY')
# (932766, 'Syracuse, NY')
# (13074, 'Tacoma, WA')
# (862993, 'Takoma Park, MD')
# (622196, 'Talala, OK')
# (38015, 'Tallahassee, FL')
# (1955819, 'Tallapoosa, GA')
# (10967, 'Tallassee, AL')
# (79030151, 'Tamarac, FL')
# (86813252, 'Tampa, FL')
# (1618718, 'Tampa, Florida, United States')
# (5927, 'Taneytown, MD')
# (349545, 'Tanner, AL')
# (9266728, 'Tappahannock, VA')
# (80711640, 'Tarboro, NC')
# (13476, 'Tarrytown, NY')
# (1703, 'Taunton, MA')
# (9185, 'Taylor, MI')
# (6250, 'Taylor, TX')
# (18506580, 'Taylorville, IL')
# (38897, 'Teaneck, NJ')
# (166551, 'Tecumseh, NE')
# (56042106, 'Telford, PA')
# (80516368, 'Telluride, CO')
# (21232722, 'Temecula, CA')
# (1115, 'Tempe, AZ')
# (1103, 'Temple Terrace, FL')
# (5887, 'Temple, GA')
# (6250, 'Temple, TX')
# (869141, 'Tennessee, United States')
# (7149222, 'Terra Bella, CA')
# (307494, 'Terre Haute, IN')
# (96180361, 'Terrell, TX')
# (7795, 'Teterboro, NJ')
# (163883, 'Teton Village, WY')
# (3476, 'Tewksbury, MA')
# (3915, 'Texarkana, AR')
# (10769, 'Texarkana, TX')
# (6979, 'Texas City, TX')
# (1025, 'Texas, United States')
# (285650, 'The Woodlands, TX')
# (3335, 'Thief River Falls, MN')
# (1600946, 'Thiells, NY')
# (1940159, 'Thomasville, GA')
# (3706049, 'Thompson, CT')
# (4026714, 'Thornton, CO')
# (1226771, 'Thornville, OH')
# (4030966, 'Thorofare, NJ')
# (14632005, 'Thousand Oaks, CA')
# (253213, 'Thousand Oaks, California, United States')
# (6617639, 'Thousand Palms, CA')
# (16710, 'Three Bridges, NJ')
# (3617422, 'Tifton, GA')
# (3025557, 'Tigard, OR')
# (7260, 'Timonium, MD')
# (44292, 'Tinley Park, IL')
# (777243, 'Tinton Falls, NJ')
# (1910700, 'Tipp City, OH')
# (4798, 'Titusville, FL')
# (383000, 'Toledo, OH')
# (2162, 'Tolleson, AZ')
# (12095, 'Tomah, WI')
# (9401140, 'Tomball, TX')
# (9229, 'Toms River, NJ')
# (124802, 'Tonawanda, NY')
# (30498, 'Tooele, UT')
# (3240, 'Topeka, KS')
# (6176, 'Toppenish, WA')
# (46000, 'Topsham, ME')
# (1344, 'Torrance, CA')
# (5064123, 'Torrington, CT')
# (165416, 'Touchet, WA')
# (14542824, 'Townshend, VT')
# (13626, 'Township of Cherry Hill, NJ')
# (455780, 'Towson, MD')
# (7058, 'Tracy, CA')
# (808034, 'Travelers Rest, SC')
# (4026801, 'Traverse City, MI')
# (1403, 'Travis Field, CA')
# (9229, 'Tremont, PA')
# (10854676, 'Trenton, GA')
# (14796450, 'Trenton, NJ')
# (2383821, 'Trenton, OH')
# (3961, 'Triangle, NC')
# (2584472, 'Trinity, FL')
# (22208562, 'Troy, AL')
# (1259, 'Troy, MI')
# (71555983, 'Troy, NY')
# (9652, 'Troy, OH')
# (122279, 'Truckee, CA')
# (11229, 'Trussville, AL')
# (18691, 'Tualatin, OR')
# (14113, 'Tucker, GA')
# (1505, 'Tucson, AZ')
# (67572051, 'Tukwila, WA')
# (12890, 'Tulalip, WA')
# (80164640, 'Tulare County, CA')
# (77301, 'Tulare, CA')
# (1945473, 'Tullahoma, TN')
# (162514, 'Tulsa, OK')
# (167757, 'Tumwater, WA')
# (10954, 'Tunnel Hill, GA')
# (295604, 'Turlock, CA')
# (299305, 'Turners Falls, MA')
# (11056, 'Tuscaloosa, AL')
# (17916205, 'Tustin, CA')
# (348709, 'Twin Falls, ID')
# (35224, 'Twinsburg, OH')
# (10769, 'Tyler, TX')
# (1943848, 'Tylertown, MS')
# (2658876, 'Tysons Corner, VA')
# (22132, 'Union City, CA')
# (81950505, 'Union Springs, AL')
# (1297738, 'Union, NJ')
# (27432, 'Union, SC')
# (224075, 'Uniondale, NY')
# (8031, 'United States')
# (1016, 'United, PA')
# (1703, 'Universal City, CA')
# (4674, 'University Park, IL')
# (1703027, 'Upper Marlboro, MD')
# (157353, 'Upper St Clair, PA')
# (2650, 'Urbana, IL')
# (1110827, 'Urbandale, IA')
# (70603, 'Utah County, UT')
# (127645, 'Utah, United States')
# (7042786, 'Utica, NY')
# (133721, 'Uxbridge, MA')
# (1103, 'Vacaville, CA')
# (20009, 'Valdese, NC')
# (46521, 'Valdosta, GA')
# (10853673, 'Vallejo, CA')
# (17885819, 'Valley City, ND')
# (884316, 'Valley City, OH')
# (10214501, 'Van Alstyne, TX')
# (8390, 'Van Wert, OH')
# (4822178, 'Vance, AL')
# (84418, 'Vancouver, WA')
# (6148675, 'Vashon, WA')
# (736659, 'Venice, FL')
# (718282, 'Ventura County, CA')
# (1010140, 'Venus, FL')
# (11695727, 'Vergennes, VT')
# (2908367, 'Vermillion, SD')
# (1613038, 'Vermont, United States')
# (3626487, 'Vernon Hills, IL')
# (27758, 'Vernon, CA')
# (3706049, 'Vernon, TX')
# (1945473, 'Vernon, VT')
# (25856, 'Vernon, WI')
# (25856, 'Verona, PA')
# (725927, 'Verona, WI')
# (84659, 'Vicksburg, MS')
# (30755, 'Victor, NY')
# (8948083, 'Victorville, CA')
# (156470, 'Vienna, VA')
# (10420321, 'Villa Park, IL')
# (6176, 'Virginia Beach, VA')
# (74031056, 'Virginia, MN')
# (4898, 'Virginia, United States')
# (167757, 'Visalia, CA')
# (23279, 'Vista, CA')
# (491462, 'Volusia County, FL')
# (33227880, 'Voorhees, NJ')
# (1945473, 'Wabasso, MN')
# (6250, 'Waco, TX')
# (167757, 'Waconia, MN')
# (52950123, 'Wadesboro, NC')
# (2972588, 'Wake County, NC')
# (96180361, 'Wake Forest, NC')
# (22756, 'Wakefield, MA')
# (6265, 'Walbridge, OH')
# (46000, 'Waldorf, MD')
# (5750, 'Waldwick, NJ')
# (157262, 'Walkertown, NC')
# (205651, 'Wall Township, NJ')
# (28332, 'Walla Walla, WA')
# (48915, 'Waller, TX')
# (12770, 'Wallingford, CT')
# (3706049, 'Wallingford, Pennsylvania, United States')
# (1308355, 'Wallops Island, VA')
# (163139, 'Walnut Creek, CA')
# (598521, 'Walsenburg, CO')
# (77633193, 'Waltham, MA')
# (139348, 'Walton, KY')
# (822071, 'Ware, MA')
# (4167, 'Warminster, PA')
# (2193256, 'Warner Robins, GA')
# (140581, 'Warren, MA')
# (1472, 'Warren, MI')
# (12951519, 'Warren, NJ')
# (888619, 'Warren, OH')
# (11152, 'Warren, OR')
# (3037367, 'Warren, RI')
# (1689, 'Warrendale, PA')
# (165944, 'Warrensville Heights, OH')
# (2721914, 'Warrenton, MO')
# (1211063, 'Warrenton, VA')
# (12861, 'Warrenville, IL')
# (30167, 'Warrington, PA')
# (1975865, 'Warsaw, IN')
# (27973, 'Warsaw, VA')
# (79560, 'Warwick, RI')
# (11455, 'Wasco, OR')
# (3493, 'Waseca, MN')
# (7065, 'Washington County, TN')
# (42595, 'Washington DC-Baltimore Area')
# (163139, 'Washington, DC')
# (2646, 'Washington, IA')
# (7064, 'Washington, MO')
# (3706049, 'Washington, NC')
# (6592912, 'Washington, PA')
# (18312164, 'Washington, United States')
# (5749, 'Washington, UT')
# (104405, 'Wasilla, AK')
# (11266342, 'Waterbury, CT')
# (5064123, 'Waterford, CT')
# (766876, 'Waterloo, IA')
# (15862365, 'Watertown, MA')
# (10778, 'Watertown, NY')
# (455602, 'Watertown, SD')
# (8484, 'Watertown, WI')
# (2664556, 'Waterville, ME')
# (164880, 'Watsonville, CA')
# (3222, 'Waukegan, IL')
# (2121817, 'Waukesha, WI')
# (3240, 'Wausau, WI')
# (157346, 'Wauwatosa, WI')
# (40693052, 'Waveland, MS')
# (166551, 'Waverly, NE')
# (167757, 'Waxhaw, NC')
# (65907467, 'Waycross, GA')
# (30755, 'Wayne, NJ')
# (33421, 'Wayne, PA')
# (20573, 'Waynesville, MO')
# (28352, 'Weatherford, OK')
# (3570660, 'Weatherford, TX')
# (164249, 'Webster City, IA')
# (66270, 'Welch, MN')
# (5274161, 'Weld County, CO')
# (4075, 'Wellesley, MA')
# (10967, 'Wellington, KS')
# (7032, 'Wenatchee, WA')
# (327513, 'Wenona, IL')
# (6870363, 'Wentzville, MO')
# (60059619, 'Wernersville, PA')
# (1188909, 'Weslaco, TX')
# (7795, 'Wesley Chapel, FL')
# (4872007, 'West Babylon, NY')
# (8936, 'West Bloomfield Township, MI')
# (2913, 'West Bridgewater, MA')
# (18506580, 'West Burlington, IA')
# (1593346, 'West Chester, OH')
# (13499, 'West Chester, PA')
# (3776, 'West Chicago, IL')
# (74718032, 'West Columbia, SC')
# (26873, 'West Covina, CA')
# (9370513, 'West Coxsackie, NY')
# (6326422, 'West Des Moines, IA')
# (22534, 'West Fargo, ND')
# (56670, 'West Greenwich, RI')
# (44580, 'West Hartford, CT')
# (4255, 'West Henrietta, NY')
# (3517767, 'West Hollywood, CA')
# (4060, 'West Jefferson, OH')
# (1441, 'West Jordan, UT')
# (73013724, 'West Lafayette, IN')
# (2227, 'West Lebanon, NH')
# (1103, 'West Long Branch, NJ')
# (18860134, 'West McLean, VA')
# (79011799, 'West New York, NJ')
# (75053811, 'West Nyack, NY')
# (10442082, 'West Palm Beach, FL')
# (1284978, 'West Palm Beach, Florida, United States')
# (808034, 'West Plains, MO')
# (2848937, 'West Point, PA')
# (10035810, 'West Point, VA')
# (258644, 'West Rancho Dominguez, CA')
# (26283799, 'West Reading, PA')
# (380752, 'West Sacramento, CA')
# (18527534, 'West Valley City, UT')
# (165908, 'West Virginia, United States')
# (164376, 'Westborough, MA')
# (14070878, 'Westby, WI')
# (3476, 'Westchester County, NY')
# (2343541, 'Western, NY')
# (82565734, 'Westerville, OH')
# (945354, 'Westfield, IN')
# (1703, 'Westfield, MA')
# (1557409, 'Westford, MA')
# (3340388, 'Westlake Village, CA')
# (20573, 'Westlake, OH')
# (1307, 'Westlake, TX')
# (25856, 'Westland, MI')
# (20573, 'Westminster, CO')
# (25856, 'Westmont, IL')
# (5196975, 'Weston, FL')
# (3706049, 'Weston, WV')
# (851980, 'Westwood, KS')
# (16726, 'Westwood, MA')
# (11648, 'Wethersfield, CT')
# (14796450, 'Wharton, NJ')
# (157237, 'Whately, MA')
# (2564886, 'Wheatland, WY')
# (3505052, 'Wheaton, MD')
# (521948, 'Wheeling, IL')
# (12890, 'Wheeling, WV')
# (54788, 'Whippany, NJ')
# (316602, 'Whippleville, NY')
# (162755, 'White City, OR')
# (10341654, 'White House, TN')
# (1668, 'White Marsh Station, MD')
# (104405, 'White Pine, TN')
# (938659, 'White Plains, NY')
# (2664323, 'White Sands, NM')
# (167757, 'White Settlement, TX')
# (3557082, 'Whitehall, MI')
# (82302944, 'Whiting, WI')
# (21890, 'Whitmore Lake, MI')
# (30755, 'Whittier, CA')
# (259898, 'Wichita Falls, TX')
# (36769, 'Wichita, KS')
# (18506580, 'Wilkes-Barre, PA')
# (40888889, 'Willard, OH')
# (3549, 'Williamsburg, KY')
# (24385, 'Williamsburg, VA')
# (79988879, 'Williamson County, TX')
# (78336991, 'Williamsport, MD')
# (5749, 'Williamsport, PA')
# (12446, 'Williamstown, NY')
# (26587222, 'Williamsville, NY')
# (444038, 'Willimantic, CT')
# (165109, 'Willis, TX')
# (40658652, 'Williston, ND')
# (63171, 'Willmar, MN')
# (92750, 'Wilmer, TX')
# (1603, 'Wilmington, DE')
# (80181, 'Wilmington, Delaware, United States')
# (2396274, 'Wilmington, MA')
# (581027, 'Wilmington, NC')
# (10137, 'Wilmington, OH')
# (1471368, 'Wilmington, VT')
# (14840050, 'Wilson, NC')
# (11695727, 'Wilsonville, OR')
# (29849, 'Wilton Manors, FL')
# (3894, 'Wilton, CT')
# (134081, 'Wilton, NY')
# (9750, 'Wimberley, TX')
# (10854663, 'Winamac, IN')
# (602239, 'Winchester, KY')
# (28978143, 'Winchester, MA')
# (167757, 'Winchester, TN')
# (78606, 'Winchester, VA')
# (2555454, 'Winder, GA')
# (15220229, 'Windsor Mill, MD')
# (2951796, 'Windsor, CO')
# (3589, 'Windsor, WI')
# (1611410, 'Winn, MI')
# (10420321, 'Winnetka, IL')
# (6963, 'Winona, MN')
# (9759, 'Winston-Salem, NC')
# (135468, 'Winston, GA')
# (6176, 'Winter Garden, FL')
# (3697729, 'Winter Haven, FL')
# (2297786, 'Winter Park, FL')
# (14611, 'Winter Park, Florida, United States')
# (585138, 'Wisconsin Dells, WI')
# (32727, 'Wisconsin Rapids, WI')
# (26586, 'Wisconsin, United States')
# (5887, 'Wittmann, AZ')
# (2576930, 'Wixom, MI')
# (12192, 'Woburn, MA')
# (36704, 'Woodbridge, NJ')
# (1103, 'Woodbridge, VA')
# (8602, 'Woodburn, OR')
# (911928, 'Woodbury, MN')
# (16279, 'Woodcliff Lake, NJ')
# (21337, 'Woodhull, NY')
# (142571, 'Woodinville, WA')
# (522560, 'Woodland, CA')
# (7032, 'Woodlawn, MD')
# (56119363, 'Woodlyn, PA')
# (3570660, 'Woodridge, IL')
# (18425303, 'Woodside, NY')
# (10141, 'Woodstock, GA')
# (2664556, 'Woodward, OK')
# (808034, 'Worcester, MA')
# (232381, 'Wrentham, MA')
# (2633, 'Wyandotte, MI')
# (6250, 'Wylie, TX')
# (1224492, 'Wyoming, MN')
# (869141, 'Wyoming, United States')
# (3658, 'Wyomissing, PA')
# (71339867, 'Wytheville, VA')
# (12601, 'Yakima, WA')
# (9185, 'Yanceyville, NC')
# (139348, 'Yankton, SD')
# (163741, 'Yaphank, NY')
# (1867264, 'Yarmouth, MA')
# (5034592, 'Yelm, WA')
# (660180, 'Yerington, NV')
# (11227630, 'Yonkers, NY')
# (14542824, 'York, ME')
# (166837, 'York, PA')
# (164880, 'York, SC')
# (1009, 'Yorktown Heights, NY')
# (5666, 'Youngstown, OH')
# (55170, 'Youngsville, NC')
# (165725, 'Yountville, CA')
# (40687781, 'Ypsilanti, MI')
# (2604972, 'Yuba City, CA')
# (3570660, 'Yucaipa, CA')
# (601919, 'Yukon, OK')
# (324747, 'Yuma, AZ')
# (77301, 'Zachary, LA')
# (2646, 'Zanesville, OH')
# (7425, 'Zeeland, MI')
# (2857644, 'Zwolle, LA')
# Length of the result for 3a-2 :  3431
# SQL Execution time: 0.2502269744873047
# (1, 'PRIMARY', '<derived2>', None, 'ref', '<auto_key0>', '<auto_key0>', '8', 'const', 10, 100.0, None)
# (2, 'DERIVED', 'job_postings', None, 'ALL', None, None, None, None, 17672, 100.0, 'Using temporary; Using filesort')
# Avg total time SQL-Query 3a-2  =  0.2879339694976807

# %% [markdown]
# ##### Mongo

# %%
mongo_query_result(mongo_query2,jobs_collection,name)
mongo_query_avg_time(mongo_query2,jobs_collection,x,name)
# Out:
# {'company_id': 9862, 'location': 'Berkeley Heights, NJ'}
# {'company_id': 28647688, 'location': 'Hillsboro, WI'}
# {'company_id': 5327, 'location': 'Los Alamos, NM'}
# {'company_id': 40876740, 'location': 'Oxford, OH'}
# {'company_id': 48024, 'location': 'Port Sulphur, LA'}
# {'company_id': 49649, 'location': 'New Haven County, CT'}
# {'company_id': 17233, 'location': 'Preston, CT'}
# {'company_id': 1703, 'location': 'Universal City, CA'}
# {'company_id': 634462, 'location': 'Monroe, NC'}
# {'company_id': 1511, 'location': 'Sparta, TN'}
# {'company_id': 29620, 'location': 'Lake Villa, IL'}
# {'company_id': 157237, 'location': 'Whately, MA'}
# {'company_id': 157239, 'location': 'Lake City, FL'}
# {'company_id': 7550, 'location': 'Liberty Lake, WA'}
# {'company_id': 27180004, 'location': 'Frenchtown, MI'}
# {'company_id': 79560, 'location': 'South Attleboro, MA'}
# {'company_id': 7963, 'location': 'North Grafton, MA'}
# {'company_id': 455780, 'location': 'Greenbelt, MD'}
# {'company_id': 2646, 'location': 'Clinton, IN'}
# {'company_id': 111108, 'location': 'Coos Bay, OR'}
# {'company_id': 163079, 'location': 'Goodyear, AZ'}
# {'company_id': 52500806, 'location': 'Smackover, AR'}
# {'company_id': 5393454, 'location': 'Rockland County, NY'}
# {'company_id': 1103, 'location': 'Great Falls, MT'}
# {'company_id': 490432, 'location': 'Salt Lake County, UT'}
# {'company_id': 2700167, 'location': 'Abingdon, VA'}
# {'company_id': 1943848, 'location': 'Columbia, MS'}
# {'company_id': 5303168, 'location': 'Jesup, GA'}
# {'company_id': 74708, 'location': 'Murrieta, CA'}
# {'company_id': 2684553, 'location': 'Greater Chicago Area'}
# {'company_id': 64761959, 'location': 'Sebring, FL'}
# {'company_id': 1307, 'location': 'Westlake, TX'}
# {'company_id': 1675576, 'location': 'Wyomissing, PA'}
# {'company_id': 204770, 'location': 'Okeechobee, FL'}
# {'company_id': 9499, 'location': 'Sanford, NC'}
# {'company_id': 1403, 'location': 'Arlington, VA'}
# {'company_id': 121082, 'location': 'Marinette, WI'}
# {'company_id': 8239496, 'location': 'Idaho, United States'}
# {'company_id': 869141, 'location': 'Nevada, United States'}
# {'company_id': 2192, 'location': 'Hobbs, NM'}
# {'company_id': 18176, 'location': 'Johnstown, NY'}
# {'company_id': 81950505, 'location': 'Union Springs, AL'}
# {'company_id': 4768, 'location': 'Monterey Park, CA'}
# {'company_id': 163993, 'location': 'Parsippany, NJ'}
# {'company_id': 20009, 'location': 'Horsham, PA'}
# {'company_id': 2721914, 'location': 'Port Austin, MI'}
# {'company_id': 72483, 'location': 'Fort Myers Beach, FL'}
# {'company_id': 80829889, 'location': 'Kingwood, WV'}
# {'company_id': 81886402, 'location': 'Petaluma, CA'}
# {'company_id': 3579761, 'location': 'Bedford Park, IL'}
# {'company_id': 12842, 'location': 'Canton, MI'}
# {'company_id': 9070, 'location': 'Pembroke, KY'}
# {'company_id': 265869, 'location': 'Des Moines, IA'}
# {'company_id': 96081672, 'location': 'Jurupa Valley, CA'}
# {'company_id': 28647688, 'location': 'Melrose, MA'}
# {'company_id': 165422, 'location': 'Eugene, OR'}
# {'company_id': 164931, 'location': 'Chatham, IL'}
# {'company_id': 4122221, 'location': 'Milford, CT'}
# {'company_id': 1703, 'location': 'Philadelphia, PA'}
# {'company_id': 18312164, 'location': 'Nassau County, NY'}
# {'company_id': 1357658, 'location': 'Richland, WA'}
# {'company_id': 18280, 'location': 'Palmer, MA'}
# {'company_id': 8390, 'location': 'Pickerington, OH'}
# {'company_id': 3706049, 'location': 'Riverside, CA'}
# {'company_id': 1496767, 'location': 'Rome, GA'}
# {'company_id': 18040365, 'location': 'Sacramento, CA'}
# {'company_id': 38897, 'location': 'Teaneck, NJ'}
# {'company_id': 19368, 'location': 'Angels Camp, CA'}
# {'company_id': 3025557, 'location': 'Tigard, OR'}
# {'company_id': 72483, 'location': 'Warner Robins, GA'}
# {'company_id': 258644, 'location': 'West Rancho Dominguez, CA'}
# {'company_id': 521948, 'location': 'Wheeling, IL'}
# {'company_id': 40658652, 'location': 'Williston, ND'}
# {'company_id': 15220229, 'location': 'Windsor Mill, MD'}
# {'company_id': 808034, 'location': 'San Gabriel, CA'}
# {'company_id': 28978143, 'location': 'Boston, MA'}
# {'company_id': 52950123, 'location': 'Wadesboro, NC'}
# {'company_id': 602239, 'location': 'Lawrenceburg, KY'}
# {'company_id': 232381, 'location': 'Wrentham, MA'}
# {'company_id': 61352, 'location': 'Bridgeport, TX'}
# {'company_id': 6083, 'location': 'Dodgeville, WI'}
# {'company_id': 34683141, 'location': 'Portland, TN'}
# {'company_id': 2193256, 'location': 'Harrisonville, MO'}
# {'company_id': 1945473, 'location': 'Silverdale, WA'}
# {'company_id': 3671, 'location': 'Lake Hiawatha, NJ'}
# {'company_id': 7410, 'location': 'Big Rapids, MI'}
# {'company_id': 71339867, 'location': 'Wytheville, VA'}
# {'company_id': 7032, 'location': 'Columbia, TN'}
# {'company_id': 165380, 'location': 'Newport Beach, CA'}
# {'company_id': 37768, 'location': 'Forest City, NC'}
# {'company_id': 28345, 'location': 'Greater Reno Area'}
# {'company_id': 35583934, 'location': 'Hinesville, GA'}
# {'company_id': 5064123, 'location': 'Bridgeport, CT'}
# {'company_id': 21337, 'location': 'North Bronx, NY'}
# {'company_id': 3677, 'location': 'Monroe, MI'}
# {'company_id': 1082026, 'location': 'Parkersburg, WV'}
# {'company_id': 11777418, 'location': 'Lonoke, AR'}
# {'company_id': 2646, 'location': 'Fairmont, MN'}
# {'company_id': 80607, 'location': 'Rockville Centre, NY'}
# {'company_id': 300543, 'location': 'Urbandale, IA'}
# {'company_id': 157303, 'location': 'Dearborn Heights, MI'}
# {'company_id': 23375, 'location': 'Huber Heights, OH'}
# {'company_id': 71575605, 'location': 'Lebanon, TN'}
# {'company_id': 34902814, 'location': 'Daggett, CA'}
# {'company_id': 27758, 'location': 'Vernon, CA'}
# {'company_id': 2271, 'location': 'Southborough, MA'}
# {'company_id': 166587, 'location': 'Smithfield, NC'}
# {'company_id': 164880, 'location': 'Dorchester, MA'}
# {'company_id': 14542824, 'location': 'Florida, NY'}
# {'company_id': 4060, 'location': 'Pataskala, OH'}
# {'company_id': 28014, 'location': 'Pleasanton, CA'}
# {'company_id': 22523, 'location': 'Deer Park, IL'}
# {'company_id': 1921089, 'location': 'Rochester, NH'}
# {'company_id': 40693052, 'location': 'Waveland, MS'}
# {'company_id': 2712856, 'location': 'Columbus, Ohio, United States'}
# {'company_id': 7795, 'location': 'Hampton, VA'}
# {'company_id': 8667, 'location': 'Hudson, WI'}
# {'company_id': 9185, 'location': 'Yanceyville, NC'}
# {'company_id': 9158, 'location': 'DeSoto, TX'}
# {'company_id': 737010, 'location': 'Normal, IL'}
# {'company_id': 30755, 'location': 'Victor, NY'}
# {'company_id': 7384, 'location': 'Kankakee, IL'}
# {'company_id': 104396, 'location': 'Cranford, NJ'}
# {'company_id': 3681, 'location': 'Sugar Land, TX'}
# {'company_id': 10279209, 'location': 'Hartland, WI'}
# {'company_id': 1414503, 'location': 'Woodbridge, NJ'}
# {'company_id': 2913, 'location': 'West Bridgewater, MA'}
# {'company_id': 27758, 'location': 'Rancho Palos Verdes, CA'}
# {'company_id': 16995, 'location': 'Amesbury, MA'}
# {'company_id': 73731, 'location': 'Boardman, OR'}
# {'company_id': 2247, 'location': 'Cranberry Township, PA'}
# {'company_id': 166360, 'location': 'Glen, MS'}
# {'company_id': 163993, 'location': 'Foster City, CA'}
# {'company_id': 14542824, 'location': 'Lamar, CO'}
# {'company_id': 1805509, 'location': 'Rock Springs, WY'}
# {'company_id': 3706049, 'location': 'Thompson, CT'}
# {'company_id': 7361, 'location': 'Las Vegas, NV'}
# {'company_id': 28978143, 'location': 'Winchester, MA'}
# {'company_id': 1284978, 'location': 'Crane, IN'}
# {'company_id': 7032, 'location': 'Hilo, HI'}
# {'company_id': 1339209, 'location': 'Bridgeville, PA'}
# {'company_id': 18208117, 'location': 'Lacey, WA'}
# {'company_id': 6176, 'location': 'Rancho Cordova, CA'}
# {'company_id': 1945473, 'location': 'Wabasso, MN'}
# {'company_id': 3286848, 'location': 'Richmond Heights, MO'}
# {'company_id': 1211063, 'location': 'Marshall, MI'}
# {'company_id': 12293, 'location': 'Idaho Falls, ID'}
# {'company_id': 1103, 'location': 'Montgomeryville, PA'}
# {'company_id': 28647688, 'location': 'Meridian, ID'}
# {'company_id': 51701268, 'location': 'New Jersey, United States'}
# {'company_id': 2301992, 'location': 'Claymont, DE'}
# {'company_id': 165472, 'location': 'Palmdale, CA'}
# {'company_id': 13181, 'location': 'Pasadena, MD'}
# {'company_id': 1344, 'location': 'Clearwater, FL'}
# {'company_id': 808034, 'location': 'Topeka, KS'}
# {'company_id': 15142330, 'location': 'Rolla, MO'}
# {'company_id': 70696, 'location': 'Ashland, MT'}
# {'company_id': 2254693, 'location': 'Lancaster, WI'}
# {'company_id': 157237, 'location': 'McMinnville, TN'}
# {'company_id': 6104, 'location': 'Mineola, NY'}
# {'company_id': 611131, 'location': 'Schenectady, NY'}
# {'company_id': 8034, 'location': 'Mount Laurel, NJ'}
# {'company_id': 462399, 'location': 'Port Washington, NY'}
# {'company_id': 35646045, 'location': 'Greater Milwaukee'}
# {'company_id': 20009, 'location': 'Drums, PA'}
# {'company_id': 4541, 'location': 'Inglewood, CA'}
# {'company_id': 11861673, 'location': 'Middlesex County, NJ'}
# {'company_id': 43278, 'location': 'St Johns, MI'}
# {'company_id': 1861137, 'location': 'Hillside, NJ'}
# {'company_id': 165158, 'location': 'Los Gatos, CA'}
# {'company_id': 3327, 'location': 'Bloomington, IN'}
# {'company_id': 6104, 'location': 'Great Neck, NY'}
# {'company_id': 90413667, 'location': 'Collins, MS'}
# {'company_id': 28647688, 'location': 'Marrero, LA'}
# {'company_id': 48024, 'location': 'Freeport, TX'}
# {'company_id': 447530, 'location': 'Moscow, ID'}
# {'company_id': 214960, 'location': 'Lakeside, AZ'}
# {'company_id': 1115, 'location': 'Newtown Square, PA'}
# {'company_id': 139348, 'location': 'North Little Rock, AR'}
# {'company_id': 846940, 'location': 'Ridgewood, NJ'}
# {'company_id': 7789, 'location': 'Seabrook, NH'}
# {'company_id': 808034, 'location': 'Bowling Green, KY'}
# {'company_id': 59005249, 'location': 'Lady Lake, FL'}
# {'company_id': 74994575, 'location': 'Anoka, MN'}
# {'company_id': 6176, 'location': 'Huntington Park, CA'}
# {'company_id': 1491, 'location': 'Cary, NC'}
# {'company_id': 37768, 'location': 'Los Lunas, NM'}
# {'company_id': 9391120, 'location': 'Mesquite, TX'}
# {'company_id': 96121422, 'location': 'Rock Island, IL'}
# {'company_id': 4334, 'location': 'Stafford, TX'}
# {'company_id': 18691, 'location': 'Silverton, OR'}
# {'company_id': 2203697, 'location': 'Sunfish Lake, MN'}
# {'company_id': 41004, 'location': 'Banner Elk, NC'}
# {'company_id': 28978381, 'location': 'Greater Colorado Springs Area'}
# {'company_id': 1945473, 'location': 'Greeneville, TN'}
# {'company_id': 18009221, 'location': 'Albemarle, NC'}
# {'company_id': 72801, 'location': 'Collierville, TN'}
# {'company_id': 1185, 'location': 'Fort Smith, AR'}
# {'company_id': 1211063, 'location': 'Clyde, NC'}
# {'company_id': 7099708, 'location': 'Buckeye Lake, OH'}
# {'company_id': 3663581, 'location': 'Maui County, HI'}
# {'company_id': 1511, 'location': 'Cambridge, MN'}
# {'company_id': 28978143, 'location': 'Milton, MA'}
# {'company_id': 7795, 'location': 'Kinnelon, NJ'}
# {'company_id': 4822178, 'location': 'Newberg, OR'}
# {'company_id': 3658, 'location': 'Reading, PA'}
# {'company_id': 7384, 'location': 'Far-A-Field, PA'}
# {'company_id': 1441, 'location': 'Reston, VA'}
# {'company_id': 43093, 'location': 'Rio Rancho, NM'}
# {'company_id': 4035873, 'location': 'San Mateo County, CA'}
# {'company_id': 7587370, 'location': 'Shreveport, LA'}
# {'company_id': 11170816, 'location': 'East Moline, IL'}
# {'company_id': 822071, 'location': 'Springfield, MA'}
# {'company_id': 39472, 'location': 'Dover, NJ'}
# {'company_id': 12446, 'location': 'Williamstown, NY'}
# {'company_id': 808034, 'location': 'Worcester, MA'}
# {'company_id': 162510, 'location': 'Lemont, IL'}
# {'company_id': 25856, 'location': 'Hilton, NY'}
# {'company_id': 1557409, 'location': 'Irvine, California, United States'}
# {'company_id': 253213, 'location': 'Thousand Oaks, California, United States'}
# {'company_id': 3626487, 'location': 'Vernon Hills, IL'}
# {'company_id': 26041, 'location': 'Mansfield, TX'}
# {'company_id': 5034592, 'location': 'Yelm, WA'}
# {'company_id': 1945473, 'location': 'Kula, HI'}
# {'company_id': 48024, 'location': 'Luling, LA'}
# {'company_id': 1943848, 'location': 'Tylertown, MS'}
# {'company_id': 14542824, 'location': 'Cape Girardeau, MO'}
# {'company_id': 3706049, 'location': 'Boscawen, NH'}
# {'company_id': 8479403, 'location': 'Fredericksburg, VA'}
# {'company_id': 19058930, 'location': 'Leeds, NY'}
# {'company_id': 1540702, 'location': 'Medina, OH'}
# {'company_id': 80862575, 'location': 'Brighton, MI'}
# {'company_id': 71131832, 'location': 'Lafayette, LA'}
# {'company_id': 14841964, 'location': 'Conway, AR'}
# {'company_id': 3738912, 'location': 'New Hartford, NY'}
# {'company_id': 157237, 'location': 'Brimfield, OH'}
# {'company_id': 18506580, 'location': 'Orange City, FL'}
# {'company_id': 18506580, 'location': 'Emmett, ID'}
# {'company_id': 4019848, 'location': 'Clinton Township, MI'}
# {'company_id': 19540, 'location': 'Hilton Head Island, SC'}
# {'company_id': 2664556, 'location': 'Leesburg, VA'}
# {'company_id': 75348, 'location': 'Harrison, NY'}
# {'company_id': 6913, 'location': 'Ottawa, OH'}
# {'company_id': 2721914, 'location': 'Port Hope, MI'}
# {'company_id': 1589941, 'location': 'Redwood Valley, CA'}
# {'company_id': 5112, 'location': 'Springfield, OH'}
# {'company_id': 13476, 'location': 'Tarrytown, NY'}
# {'company_id': 28893, 'location': 'Greater Farmington Area'}
# {'company_id': 12951519, 'location': 'Warren, NJ'}
# {'company_id': 20573, 'location': 'Westlake, OH'}
# {'company_id': 165447, 'location': 'Milton, VT'}
# {'company_id': 16726, 'location': 'Westwood, MA'}
# {'company_id': 3242, 'location': 'Exeter, CA'}
# {'company_id': 10420321, 'location': 'Elmwood Park, IL'}
# {'company_id': 15200600, 'location': 'Lewiston, ME'}
# {'company_id': 2247, 'location': 'Irondale, AL'}
# {'company_id': 53713122, 'location': 'Boston Run, PA'}
# {'company_id': 8463119, 'location': 'McKees Rocks, PA'}
# {'company_id': 166774, 'location': 'Colonial Heights, VA'}
# {'company_id': 11056, 'location': 'Lebanon, KY'}
# {'company_id': 2646, 'location': 'North Myrtle Beach, SC'}
# {'company_id': 47843, 'location': 'Pella, IA'}
# {'company_id': 2480405, 'location': 'Blacksburg, SC'}
# {'company_id': 3009549, 'location': 'New Mexico, United States'}
# {'company_id': 25170579, 'location': 'Corona, CA'}
# {'company_id': 81886402, 'location': 'Riverhead, NY'}
# {'company_id': 1463, 'location': 'Coraopolis, PA'}
# {'company_id': 743843, 'location': 'Santa Barbara County, CA'}
# {'company_id': 204770, 'location': 'Elgin, SC'}
# {'company_id': 9308035, 'location': 'Palm Bay, FL'}
# {'company_id': 30755, 'location': 'Strafford County, NH'}
# {'company_id': 9499, 'location': 'Greater Tuscaloosa Area'}
# {'company_id': 72483, 'location': 'Des Moines, WA'}
# {'company_id': 16163783, 'location': 'Englewood, OH'}
# {'company_id': 2743, 'location': 'Fishers, IN'}
# {'company_id': 33711, 'location': 'Flagstaff, AZ'}
# {'company_id': 73202971, 'location': 'Clermont, FL'}
# {'company_id': 35716480, 'location': 'La Marque, TX'}
# {'company_id': 2736008, 'location': 'Davenport, IA'}
# {'company_id': 12820, 'location': 'Mount Airy, NC'}
# {'company_id': 1703, 'location': 'Taunton, MA'}
# {'company_id': 894572, 'location': 'Fort Belvoir, VA'}
# {'company_id': 94355, 'location': 'Fort Worth, TX'}
# {'company_id': 9862, 'location': 'Dedham, MA'}
# {'company_id': 9210946, 'location': 'East Brunswick, NJ'}
# {'company_id': 49042, 'location': 'Lakewood, NJ'}
# {'company_id': 3653, 'location': 'Morrisville, NC'}
# {'company_id': 163883, 'location': 'Teton Village, WY'}
# {'company_id': 16710, 'location': 'Portage, MI'}
# {'company_id': 164880, 'location': 'Bluffton, IN'}
# {'company_id': 4255, 'location': 'Flint, MI'}
# {'company_id': 77153, 'location': 'Huntsville-Decatur-Albertville Area'}
# {'company_id': 28332, 'location': 'Walla Walla, WA'}
# {'company_id': 13074, 'location': 'Burien, WA'}
# {'company_id': 660180, 'location': 'Bryant, AR'}
# {'company_id': 18860134, 'location': 'Ironwood, MI'}
# {'company_id': 2562, 'location': 'Angleton, TX'}
# {'company_id': 18401, 'location': 'Jeffersonville, IN'}
# {'company_id': 20505073, 'location': 'Auburn Hills, MI'}
# {'company_id': 22523, 'location': 'Miramar Beach, FL'}
# {'company_id': 18506580, 'location': 'Port Angeles, WA'}
# {'company_id': 3683648, 'location': 'Portland, Oregon Metropolitan Area'}
# {'company_id': 165725, 'location': 'Yountville, CA'}
# {'company_id': 163139, 'location': 'Overland Park, KS'}
# {'company_id': 334135, 'location': 'Eastpointe, MI'}
# {'company_id': 60951108, 'location': 'Florence, AL'}
# {'company_id': 104396, 'location': 'Sedona, AZ'}
# {'company_id': 1497, 'location': 'Boxborough, MA'}
# {'company_id': 19142259, 'location': 'Norman, OK'}
# {'company_id': 40653509, 'location': 'East Hartford, CT'}
# {'company_id': 2375692, 'location': 'Galesburg, MI'}
# {'company_id': 14571, 'location': 'Greater Hartford'}
# {'company_id': 1943848, 'location': 'Jackson, LA'}
# {'company_id': 1766026, 'location': 'Provo, UT'}
# {'company_id': 25017, 'location': 'Stockton, CA'}
# {'company_id': 829374, 'location': 'Palm Beach Gardens, FL'}
# {'company_id': 808034, 'location': 'Everett, WA'}
# {'company_id': 2646, 'location': 'Laurel, MT'}
# {'company_id': 12434, 'location': 'Belvidere, IL'}
# {'company_id': 2756411, 'location': 'Farmington, CT'}
# {'company_id': 71535981, 'location': 'Natick, MA'}
# {'company_id': 1403, 'location': 'Panama City, FL'}
# {'company_id': 5352294, 'location': 'Greeley, CO'}
# {'company_id': 80862575, 'location': 'Ann Arbor, MI'}
# {'company_id': 10420321, 'location': 'Occoquan, VA'}
# {'company_id': 743843, 'location': 'Raymond, OH'}
# {'company_id': 33227880, 'location': 'Voorhees, NJ'}
# {'company_id': 3493, 'location': 'Waseca, MN'}
# {'company_id': 7587370, 'location': 'Baton Rouge, LA'}
# {'company_id': 1945473, 'location': 'Colton, CA'}
# {'company_id': 14542824, 'location': 'Duluth, MN'}
# {'company_id': 708393, 'location': 'Independence, OH'}
# {'company_id': 77301, 'location': 'Ellisville, MO'}
# {'company_id': 3760423, 'location': 'Biloxi, MS'}
# {'company_id': 407589, 'location': 'Lapeer, MI'}
# {'company_id': 15434, 'location': 'Clarinda, IA'}
# {'company_id': 166714, 'location': 'Boca Raton, FL'}
# {'company_id': 3476, 'location': 'Hernando, MS'}
# {'company_id': 7149222, 'location': 'Terra Bella, CA'}
# {'company_id': 164880, 'location': 'St Regis Falls, NY'}
# {'company_id': 122279, 'location': 'Truckee, CA'}
# {'company_id': 6379951, 'location': 'Grand Rapids, MN'}
# {'company_id': 64980, 'location': 'Delano, CA'}
# {'company_id': 6913, 'location': 'Okemos, MI'}
# {'company_id': 22132, 'location': 'Dulles Town Center, VA'}
# {'company_id': 72092703, 'location': 'Newark, CA'}
# {'company_id': 207350, 'location': 'Oklahoma City, OK'}
# {'company_id': 49455, 'location': 'Sycamore, IL'}
# {'company_id': 9402, 'location': 'Northfield, IL'}
# {'company_id': 21337, 'location': 'New York, New York, United States'}
# {'company_id': 9460096, 'location': 'Brownwood, TX'}
# {'company_id': 10778, 'location': 'Belleville, IL'}
# {'company_id': 165472, 'location': 'Dalton, GA'}
# {'company_id': 20009, 'location': 'Valdese, NC'}
# {'company_id': 14840050, 'location': 'Wilson, NC'}
# {'company_id': 468782, 'location': 'Covington, GA'}
# {'company_id': 23379, 'location': 'Columbia, PA'}
# {'company_id': 808034, 'location': 'Omak, WA'}
# {'company_id': 10769, 'location': 'Athens, TX'}
# {'company_id': 3863, 'location': 'Roanoke, TX'}
# {'company_id': 455602, 'location': 'Watertown, SD'}
# {'company_id': 164200, 'location': 'Attleboro, MA'}
# {'company_id': 7788794, 'location': 'Danville, PA'}
# {'company_id': 26341, 'location': 'Leetsdale, PA'}
# {'company_id': 1511, 'location': 'Londonderry, NH'}
# {'company_id': 88289095, 'location': 'Miller City, OH'}
# {'company_id': 2029, 'location': 'Beaverton, OR'}
# {'company_id': 39540, 'location': 'Cordele, GA'}
# {'company_id': 7032, 'location': 'El Cerrito, CA'}
# {'company_id': 828170, 'location': 'Ayer, MA'}
# {'company_id': 145522, 'location': 'Maricopa County, AZ'}
# {'company_id': 3304, 'location': 'Mountain Pass, CA'}
# {'company_id': 808034, 'location': 'Glendale, CA'}
# {'company_id': 167757, 'location': 'Oak Hall, VA'}
# {'company_id': 22208562, 'location': 'Troy, AL'}
# {'company_id': 75997, 'location': 'Dover, DE'}
# {'company_id': 7471, 'location': 'East Rutherford, NJ'}
# {'company_id': 4324, 'location': 'Apex, NC'}
# {'company_id': 28498, 'location': 'Lebanon, PA'}
# {'company_id': 11518813, 'location': 'Leland, NC'}
# {'company_id': 35504, 'location': 'Middleton, WI'}
# {'company_id': 34218836, 'location': 'La Grande, OR'}
# {'company_id': 102847, 'location': 'Spring House, PA'}
# {'company_id': 11088832, 'location': 'Fredonia, NY'}
# {'company_id': 3037367, 'location': 'Warren, RI'}
# {'company_id': 64883, 'location': 'Lancaster, CA'}
# {'company_id': 2646, 'location': 'Malone, NY'}
# {'company_id': 1403, 'location': 'Alexandria, VA'}
# {'company_id': 48024, 'location': 'Beaumont, TX'}
# {'company_id': 28503, 'location': 'Kansas City, Missouri, United States'}
# {'company_id': 86265278, 'location': 'Pompano Beach, FL'}
# {'company_id': 13151, 'location': 'New Iberia, LA'}
# {'company_id': 28052, 'location': 'Biscoe, NC'}
# {'company_id': 6683229, 'location': 'Rainbow City, AL'}
# {'company_id': 1600946, 'location': 'Thiells, NY'}
# {'company_id': 28647688, 'location': 'Hackensack, NJ'}
# {'company_id': 1016, 'location': 'United, PA'}
# {'company_id': 164376, 'location': 'Westborough, MA'}
# {'company_id': 18506580, 'location': 'Cortlandt Manor, NY'}
# {'company_id': 77318089, 'location': 'Heath, OH'}
# {'company_id': 5274161, 'location': 'Lake Worth, FL'}
# {'company_id': 57978, 'location': 'Jonesboro, AR'}
# {'company_id': 1103, 'location': 'Lake Mary, FL'}
# {'company_id': 35529547, 'location': 'Langhorne, PA'}
# {'company_id': 14991, 'location': 'Miami Lakes, FL'}
# {'company_id': 2430668, 'location': 'Chicago Heights, IL'}
# {'company_id': 15564, 'location': 'Burbank, CA'}
# {'company_id': 2677, 'location': 'Mission, KS'}
# {'company_id': 1769216, 'location': 'Belcamp, MD'}
# {'company_id': 819218, 'location': 'Hollister, CA'}
# {'company_id': 1497977, 'location': 'Denison, TX'}
# {'company_id': 25856, 'location': 'Booneville, MS'}
# {'company_id': 9732, 'location': 'Miramar, FL'}
# {'company_id': 3681, 'location': 'Calvert, AL'}
# {'company_id': 2701, 'location': 'Candler, NC'}
# {'company_id': 15139, 'location': 'Fowler, CA'}
# {'company_id': 1141808, 'location': 'Oakfield, ME'}
# {'company_id': 3135, 'location': 'Renton, WA'}
# {'company_id': 3210501, 'location': 'South San Francisco, CA'}
# {'company_id': 77688, 'location': 'Foxborough, MA'}
# {'company_id': 35504315, 'location': 'Clinton, IA'}
# {'company_id': 79458773, 'location': 'Brandon, FL'}
# {'company_id': 82903338, 'location': 'DeLand, FL'}
# {'company_id': 3056912, 'location': 'Hebron, KY'}
# {'company_id': 28424, 'location': 'Novato, CA'}
# {'company_id': 1025, 'location': 'Spring, TX'}
# {'company_id': 24187, 'location': 'Sterling, OH'}
# {'company_id': 157346, 'location': 'Wauwatosa, WI'}
# {'company_id': 3549, 'location': 'Cleveland Heights, OH'}
# {'company_id': 8936, 'location': 'West Bloomfield Township, MI'}
# {'company_id': 8034, 'location': 'Chanhassen, MN'}
# {'company_id': 51701268, 'location': 'Kansas City Metropolitan Area'}
# {'company_id': 10420321, 'location': 'Park Forest, IL'}
# {'company_id': 77301, 'location': 'Layton, UT'}
# {'company_id': 78124, 'location': 'Minnesota, United States'}
# {'company_id': 629785, 'location': 'Miami-Dade County, FL'}
# {'company_id': 10420321, 'location': 'Schaumburg, IL'}
# {'company_id': 2470025, 'location': 'Dulles, VA'}
# {'company_id': 157346, 'location': 'Burnsville, MN'}
# {'company_id': 937112, 'location': 'Estero, FL'}
# {'company_id': 54472, 'location': 'Pittsburgh, Pennsylvania, United States'}
# {'company_id': 1945473, 'location': 'Euclid, OH'}
# {'company_id': 6176, 'location': 'Spanaway, WA'}
# {'company_id': 6440, 'location': 'Warsaw, IN'}
# {'company_id': 11695727, 'location': 'Wilsonville, OR'}
# {'company_id': 15451, 'location': 'Arvada, CO'}
# {'company_id': 3706049, 'location': 'Centre Hall, PA'}
# {'company_id': 6913, 'location': 'Dowagiac, MI'}
# {'company_id': 6281, 'location': 'Stillwater, OK'}
# {'company_id': 76440728, 'location': 'Lebanon, IN'}
# {'company_id': 602239, 'location': 'Winchester, KY'}
# {'company_id': 6963, 'location': 'Winona, MN'}
# {'company_id': 1907823, 'location': 'Montvale, NJ'}
# {'company_id': 29579, 'location': 'Camelback, California, United States'}
# {'company_id': 1945473, 'location': 'McKeesport, PA'}
# {'company_id': 433995, 'location': 'Orangeburg, NY'}
# {'company_id': 6176, 'location': 'Pewaukee, WI'}
# {'company_id': 1286891, 'location': 'Boylston, MA'}
# {'company_id': 19023, 'location': 'Shiremanstown, PA'}
# {'company_id': 2031248, 'location': 'Harriman, TN'}
# {'company_id': 18281968, 'location': 'Huntersville, NC'}
# {'company_id': 78336991, 'location': 'Williamsport, MD'}
# {'company_id': 410499, 'location': 'Woodbury, MN'}
# {'company_id': 14088, 'location': 'Lynnwood, WA'}
# {'company_id': 16000406, 'location': 'Smyrna, TN'}
# {'company_id': 2403625, 'location': 'Shelton, CT'}
# {'company_id': 14840050, 'location': 'Dunwoody, GA'}
# {'company_id': 2736008, 'location': 'Scottsbluff, NE'}
# {'company_id': 80387, 'location': 'Santa Barbara, CA'}
# {'company_id': 135468, 'location': 'Winston, GA'}
# {'company_id': 46000, 'location': 'Chester, VA'}
# {'company_id': 3672, 'location': 'Fort Detrick, MD'}
# {'company_id': 23499, 'location': 'Paramount, CA'}
# {'company_id': 74464, 'location': 'Sartell, MN'}
# {'company_id': 61252, 'location': 'Fort Washington, PA'}
# {'company_id': 28647688, 'location': 'Garfield Heights, OH'}
# {'company_id': 4453, 'location': 'City of Industry, CA'}
# {'company_id': 59239749, 'location': 'Portsmouth, VA'}
# {'company_id': 18924711, 'location': 'Alameda County, CA'}
# {'company_id': 18506580, 'location': 'Brooklyn Park, MN'}
# {'company_id': 11876, 'location': 'Elko, NV'}
# {'company_id': 20282677, 'location': 'Fountain Valley, CA'}
# {'company_id': 9881525, 'location': 'Hegins, PA'}
# {'company_id': 1224492, 'location': 'Deephaven, MN'}
# {'company_id': 230282, 'location': 'Kingsburg, CA'}
# {'company_id': 32469, 'location': 'Lawrenceburg, IN'}
# {'company_id': 6176, 'location': 'Lombard, IL'}
# {'company_id': 15735, 'location': 'Millwood, WA'}
# {'company_id': 3706049, 'location': 'Cape May Court House, NJ'}
# {'company_id': 6449, 'location': 'Holland, MI'}
# {'company_id': 2408523, 'location': 'Milford, MA'}
# {'company_id': 2252, 'location': 'Antioch, TN'}
# {'company_id': 683310, 'location': 'Escanaba, MI'}
# {'company_id': 157338, 'location': 'Lexington, VA'}
# {'company_id': 237403, 'location': 'Montoursville, PA'}
# {'company_id': 28014, 'location': 'New Haven, CT'}
# {'company_id': 1403, 'location': "O'Fallon, IL"}
# {'company_id': 4128, 'location': 'Kernersville, NC'}
# {'company_id': 2973906, 'location': 'College Park, GA'}
# {'company_id': 2128870, 'location': 'Morristown, NJ'}
# {'company_id': 5343, 'location': 'Ocoee, FL'}
# {'company_id': 217994, 'location': 'Olathe, KS'}
# {'company_id': 2646, 'location': 'Rifle, CO'}
# {'company_id': 10514179, 'location': 'Eureka, CA'}
# {'company_id': 1082026, 'location': 'Frankfort, KY'}
# {'company_id': 104396, 'location': 'Hicksville, NY'}
# {'company_id': 2736008, 'location': 'Louisville, KY'}
# {'company_id': 45091, 'location': 'Riceboro, GA'}
# {'company_id': 2995, 'location': 'Round Hill, VA'}
# {'company_id': 36092044, 'location': 'Secaucus, NJ'}
# {'company_id': 6913, 'location': 'Shafter, CA'}
# {'company_id': 20009, 'location': 'Swansboro, NC'}
# {'company_id': 2640631, 'location': 'Edinboro, PA'}
# {'company_id': 96180361, 'location': 'Terrell, TX'}
# {'company_id': 4030966, 'location': 'Thorofare, NJ'}
# {'company_id': 315817, 'location': 'Calhoun, GA'}
# {'company_id': 661629, 'location': 'Oklahoma City Metropolitan Area'}
# {'company_id': 6176, 'location': 'Toppenish, WA'}
# {'company_id': 35666700, 'location': 'Linthicum, MD'}
# {'company_id': 11695727, 'location': 'Vergennes, VT'}
# {'company_id': 12606850, 'location': 'Columbia, SC'}
# {'company_id': 10096293, 'location': 'Council Bluffs, IA'}
# {'company_id': 12446, 'location': 'Lakeville, MN'}
# {'company_id': 305287, 'location': 'Joplin, MO'}
# {'company_id': 9428125, 'location': 'Painted Post, NY'}
# {'company_id': 2584496, 'location': 'Sun City Center, FL'}
# {'company_id': 808034, 'location': 'Sun City, AZ'}
# {'company_id': 9814, 'location': 'Mansfield, MA'}
# {'company_id': 5618, 'location': 'Commerce, CA'}
# {'company_id': 2926262, 'location': 'Marietta, GA'}
# {'company_id': 808034, 'location': 'Travelers Rest, SC'}
# {'company_id': 3706049, 'location': 'Vernon, TX'}
# {'company_id': 58357, 'location': 'Saddle River, NJ'}
# {'company_id': 17233, 'location': 'Morris County, NJ'}
# {'company_id': 2646, 'location': 'Pineville, LA'}
# {'company_id': 629227, 'location': 'Portsmouth, OH'}
# {'company_id': 9229, 'location': 'Tremont, PA'}
# {'company_id': 2193256, 'location': 'Hope Mills, NC'}
# {'company_id': 227647, 'location': 'Park Ridge, NJ'}
# {'company_id': 861806, 'location': 'Daytona Beach, FL'}
# {'company_id': 2646, 'location': 'Princeton, IN'}
# {'company_id': 167757, 'location': 'Visalia, CA'}
# {'company_id': 12988732, 'location': 'Hartford City, IN'}
# {'company_id': 76452487, 'location': 'Pittsburg, KS'}
# {'company_id': 2972588, 'location': 'Stanly County, NC'}
# {'company_id': 1586, 'location': 'Middletown, DE'}
# {'company_id': 163139, 'location': 'Washington, DC'}
# {'company_id': 21890, 'location': 'Whitmore Lake, MI'}
# {'company_id': 18923058, 'location': 'Hackleburg, AL'}
# {'company_id': 4324, 'location': 'Burlington, WA'}
# {'company_id': 1945473, 'location': 'Clinton, MD'}
# {'company_id': 104405, 'location': 'Chandler, AZ'}
# {'company_id': 11009726, 'location': 'Killeen, TX'}
# {'company_id': 14611, 'location': 'Winter Park, Florida, United States'}
# {'company_id': 1945473, 'location': 'Chester, SC'}
# {'company_id': 46000, 'location': 'Shelby, NC'}
# {'company_id': 18641359, 'location': 'La Puente, CA'}
# {'company_id': 1628878, 'location': 'Glasgow, DE'}
# {'company_id': 3700354, 'location': 'Madisonville, TN'}
# {'company_id': 9643, 'location': 'Collinsville, IL'}
# {'company_id': 808034, 'location': 'Garden Grove, CA'}
# {'company_id': 5996, 'location': 'Bozeman, MT'}
# {'company_id': 6176, 'location': 'Simi Valley, CA'}
# {'company_id': 2646, 'location': 'Creston, IA'}
# {'company_id': 2724823, 'location': 'Streetsboro, OH'}
# {'company_id': 9401140, 'location': 'Cypress, TX'}
# {'company_id': 34727, 'location': 'Lane County, OR'}
# {'company_id': 164200, 'location': 'Selinsgrove, PA'}
# {'company_id': 58756, 'location': 'Rural Hall, NC'}
# {'company_id': 18860134, 'location': 'Mauldin, SC'}
# {'company_id': 2203697, 'location': 'Hilliard, OH'}
# {'company_id': 1441, 'location': 'Bridgeport, AL'}
# {'company_id': 1403, 'location': 'Fort Bragg, North Carolina, United States'}
# {'company_id': 2646, 'location': 'Hayward, WI'}
# {'company_id': 1103, 'location': 'Gurnee, IL'}
# {'company_id': 11240, 'location': 'Hurst, TX'}
# {'company_id': 11240, 'location': 'Richfield, MN'}
# {'company_id': 20009, 'location': 'Rosemead, CA'}
# {'company_id': 8117, 'location': 'Russellville, AR'}
# {'company_id': 2589107, 'location': 'Santa Rosa, CA'}
# {'company_id': 1593346, 'location': 'Newburgh, IN'}
# {'company_id': 2908367, 'location': 'Litchfield Park, AZ'}
# {'company_id': 17902, 'location': 'Shippensburg, PA'}
# {'company_id': 1586, 'location': 'St Georges, DE'}
# {'company_id': 2684081, 'location': 'Suwanee, GA'}
# {'company_id': 660180, 'location': 'Yerington, NV'}
# {'company_id': 4556, 'location': 'College Station, TX'}
# {'company_id': 19142259, 'location': 'Lake Charles, LA'}
# {'company_id': 64272643, 'location': 'Connecticut, United States'}
# {'company_id': 6476, 'location': 'Maywood, IL'}
# {'company_id': 444038, 'location': 'Catskill, NY'}
# {'company_id': 1103, 'location': 'Hanford, CA'}
# {'company_id': 15139, 'location': 'Richfield, UT'}
# {'company_id': 10514179, 'location': 'Clarksburg, WV'}
# {'company_id': 581027, 'location': 'League City, TX'}
# {'company_id': 3706049, 'location': 'Grants Pass, OR'}
# {'company_id': 2396310, 'location': 'Decatur, AL'}
# {'company_id': 18506580, 'location': 'Bakersfield, CA'}
# {'company_id': 887776, 'location': 'Bridgeview, IL'}
# {'company_id': 594846, 'location': 'Lake County, IN'}
# {'company_id': 366025, 'location': 'Queens, NY'}
# {'company_id': 777243, 'location': 'Fort Lauderdale, FL'}
# {'company_id': 8948083, 'location': 'Victorville, CA'}
# {'company_id': 43093, 'location': 'Boulder City, NV'}
# {'company_id': 49105, 'location': 'Groveport, OH'}
# {'company_id': 45593, 'location': 'Morrisville, PA'}
# {'company_id': 15259054, 'location': 'Independence, KY'}
# {'company_id': 1160236, 'location': 'Bellows Falls, VT'}
# {'company_id': 2074192, 'location': 'Corona del Mar, CA'}
# {'company_id': 12709, 'location': 'Greater Harrisburg Area'}
# {'company_id': 2300, 'location': 'Northridge, California, United States'}
# {'company_id': 1703, 'location': 'Claremont, NH'}
# {'company_id': 3348019, 'location': 'Richland, SC'}
# {'company_id': 3476, 'location': 'Westchester County, NY'}
# {'company_id': 7929696, 'location': 'Hutchinson, MN'}
# {'company_id': 166811, 'location': 'Blacksburg, VA'}
# {'company_id': 82792265, 'location': 'Douglasville, GA'}
# {'company_id': 113097, 'location': 'Alice, TX'}
# {'company_id': 11056, 'location': 'Florida, United States'}
# {'company_id': 134081, 'location': 'Guilderland, NY'}
# {'company_id': 127686, 'location': 'Melbourne, FL'}
# {'company_id': 7795, 'location': 'Laurel, MD'}
# {'company_id': 10420321, 'location': 'Lynwood, CA'}
# {'company_id': 2193256, 'location': 'Antigo, WI'}
# {'company_id': 11568, 'location': 'Minneapolis–Saint Paul, WI'}
# {'company_id': 2646, 'location': 'Carmi, IL'}
# {'company_id': 1852454, 'location': 'Franklin, TN'}
# {'company_id': 3671, 'location': 'Hurlburt Field, FL'}
# {'company_id': 1943848, 'location': 'Macon, MS'}
# {'company_id': 80911138, 'location': 'East Aurora, NY'}
# {'company_id': 5153, 'location': 'Cerritos, CA'}
# {'company_id': 7680, 'location': 'Indiana, United States'}
# {'company_id': 9499, 'location': 'Natchez, MS'}
# {'company_id': 283807, 'location': 'North Miami, FL'}
# {'company_id': 2548108, 'location': 'Ogden, UT'}
# {'company_id': 9117, 'location': 'Perryton, TX'}
# {'company_id': 72483, 'location': 'Page, AZ'}
# {'company_id': 64510, 'location': 'Fontana, CA'}
# {'company_id': 6176, 'location': 'Progreso, TX'}
# {'company_id': 18425303, 'location': 'Rosemount, MN'}
# {'company_id': 3866, 'location': 'Lutz, FL'}
# {'company_id': 14790337, 'location': 'Santa Cruz County, CA'}
# {'company_id': 3706049, 'location': 'Sinking Spring, PA'}
# {'company_id': 166551, 'location': 'Dardanelle, AR'}
# {'company_id': 7795, 'location': 'Teterboro, NJ'}
# {'company_id': 2908367, 'location': 'Britton, SD'}
# {'company_id': 61341, 'location': 'Tustin, CA'}
# {'company_id': 22132, 'location': 'Union City, CA'}
# {'company_id': 34424, 'location': 'Clackamas, OR'}
# {'company_id': 23300, 'location': 'Delaware, OH'}
# {'company_id': 10165687, 'location': 'Jackson County, MO'}
# {'company_id': 11056, 'location': 'Narberth, PA'}
# {'company_id': 91359962, 'location': 'Oakdale, MN'}
# {'company_id': 28669777, 'location': 'Caruthersville, MO'}
# {'company_id': 11240, 'location': 'Ocean, NJ'}
# {'company_id': 4060, 'location': 'Boston, Massachusetts, United States'}
# {'company_id': 48658, 'location': 'Pueblo-Cañon City Area'}
# {'company_id': 2430668, 'location': 'Saginaw, MI'}
# {'company_id': 15133237, 'location': 'Fort Kent, ME'}
# {'company_id': 7935, 'location': 'Spencer, IA'}
# {'company_id': 5666, 'location': 'Surry, VA'}
# {'company_id': 8390, 'location': 'Athens, OH'}
# {'company_id': 32478, 'location': 'Lisle, IL'}
# {'company_id': 167757, 'location': 'Waconia, MN'}
# {'company_id': 21667, 'location': 'Deltona, FL'}
# {'company_id': 1603, 'location': 'Wilmington, DE'}
# {'company_id': 18425303, 'location': 'Woodside, NY'}
# {'company_id': 12095, 'location': 'Lakeville, MA'}
# {'company_id': 60059619, 'location': 'Wernersville, PA'}
# {'company_id': 690568, 'location': 'Apache Junction, AZ'}
# {'company_id': 3671, 'location': 'Pompton Lakes, NJ'}
# {'company_id': 601919, 'location': 'Colorado, United States'}
# {'company_id': 23182, 'location': 'Akron, OH'}
# {'company_id': 4031183, 'location': 'Cross Junction, VA'}
# {'company_id': 347410, 'location': 'Metairie, LA'}
# {'company_id': 18009221, 'location': 'Milford, OH'}
# {'company_id': 1211063, 'location': 'Montclair, NJ'}
# {'company_id': 9499, 'location': 'Cornelia, GA'}
# {'company_id': 11758, 'location': 'Alsip, IL'}
# {'company_id': 74306759, 'location': 'South Bend-Mishawaka Region'}
# {'company_id': 9185, 'location': 'Pelham, AL'}
# {'company_id': 24211, 'location': 'Geneva, IL'}
# {'company_id': 6044, 'location': 'Greater St. Louis'}
# {'company_id': 19637, 'location': 'Geismar, LA'}
# {'company_id': 18953305, 'location': 'Healdsburg, CA'}
# {'company_id': 788707, 'location': 'Barberton, OH'}
# {'company_id': 1123, 'location': 'Niceville, FL'}
# {'company_id': 3671, 'location': 'Sandy Springs, GA'}
# {'company_id': 28647688, 'location': 'Apple Valley, CA'}
# {'company_id': 166572, 'location': 'DeKalb, IL'}
# {'company_id': 5121, 'location': 'Framingham, MA'}
# {'company_id': 3706049, 'location': 'Concord, NH'}
# {'company_id': 1074444, 'location': 'Niskayuna, NY'}
# {'company_id': 2432, 'location': 'Cincinnati, OH'}
# {'company_id': 19534, 'location': 'East Orange, NJ'}
# {'company_id': 113097, 'location': 'Crystal City, TX'}
# {'company_id': 6592, 'location': 'Eaton, OH'}
# {'company_id': 808034, 'location': 'Leominster, MA'}
# {'company_id': 2615835, 'location': 'New Brunswick, NJ'}
# {'company_id': 15626530, 'location': 'Elizabethtown, KY'}
# {'company_id': 34867, 'location': 'Lees Summit, MO'}
# {'company_id': 6893381, 'location': 'North Haven, CT'}
# {'company_id': 82302944, 'location': 'Whiting, WI'}
# {'company_id': 6233, 'location': 'Appleton, WI'}
# {'company_id': 7032, 'location': 'Hawthorne, CA'}
# {'company_id': 5098, 'location': 'Midland, TX'}
# {'company_id': 743843, 'location': 'Fresno County, CA'}
# {'company_id': 3706049, 'location': 'Nashua, NH'}
# {'company_id': 2911, 'location': 'Lake Worth, TX'}
# {'company_id': 5064123, 'location': 'Hartford, CT'}
# {'company_id': 1374999, 'location': 'Athol, ID'}
# {'company_id': 1680, 'location': 'Bridgewater, NJ'}
# {'company_id': 166551, 'location': 'Tecumseh, NE'}
# {'company_id': 1608684, 'location': 'Oakland, NJ'}
# {'company_id': 76127808, 'location': 'Coatesville, PA'}
# {'company_id': 15389, 'location': 'Lewis Center, OH'}
# {'company_id': 5323150, 'location': 'Alabama, United States'}
# {'company_id': 77301, 'location': 'Edmond, OK'}
# {'company_id': 88049822, 'location': 'Menlo Park, CA'}
# {'company_id': 10667, 'location': 'Burlingame, CA'}
# {'company_id': 202944, 'location': 'Norwood, MA'}
# {'company_id': 26923, 'location': 'Prior Lake, MN'}
# {'company_id': 14287, 'location': 'Crawford, TX'}
# {'company_id': 2162, 'location': 'Jacksonville, TX'}
# {'company_id': 163787, 'location': 'Kalispell, MT'}
# {'company_id': 815722, 'location': 'Location, WV'}
# {'company_id': 7307421, 'location': 'South Bend, IN'}
# {'company_id': 41102, 'location': 'Broadview, IL'}
# {'company_id': 2646, 'location': 'Crescent City, CA'}
# {'company_id': 6913, 'location': 'Amsterdam, NY'}
# {'company_id': 164376, 'location': 'Brier, WA'}
# {'company_id': 1293049, 'location': 'Edina, MN'}
# {'company_id': 80911138, 'location': 'Florence, KY'}
# {'company_id': 164798, 'location': 'Buffalo, NY'}
# {'company_id': 587493, 'location': 'Big Spring, TX'}
# {'company_id': 167757, 'location': 'Indian Trail, NC'}
# {'company_id': 163348, 'location': 'Lebanon, NH'}
# {'company_id': 3182370, 'location': 'Dermott, AR'}
# {'company_id': 1192815, 'location': 'Greenbrae, CA'}
# {'company_id': 165294, 'location': 'Crown Point, IN'}
# {'company_id': 2251, 'location': 'Reynoldsburg, OH'}
# {'company_id': 4453, 'location': 'Shoemakersville, PA'}
# {'company_id': 87599, 'location': 'St Joseph, MO'}
# {'company_id': 5887, 'location': 'Temple, GA'}
# {'company_id': 14571, 'location': 'Bickleton, WA'}
# {'company_id': 581027, 'location': 'Gary, IN'}
# {'company_id': 2701, 'location': 'East Providence, RI'}
# {'company_id': 139348, 'location': 'Yankton, SD'}
# {'company_id': 1403, 'location': 'Fort Meade, MD'}
# {'company_id': 5064123, 'location': 'Waterford, CT'}
# {'company_id': 9812, 'location': 'Gainesville, VA'}
# {'company_id': 79397629, 'location': 'Chadds Ford, PA'}
# {'company_id': 3356761, 'location': 'Kansas, United States'}
# {'company_id': 10420321, 'location': 'Hoboken, NJ'}
# {'company_id': 8280, 'location': 'Rancho Cucamonga, CA'}
# {'company_id': 165447, 'location': 'Allegan, MI'}
# {'company_id': 71904349, 'location': 'Riverview, FL'}
# {'company_id': 602239, 'location': 'Roanoke Rapids, NC'}
# {'company_id': 74464, 'location': 'St Cloud, MN'}
# {'company_id': 35571114, 'location': 'Gold Canyon, AZ'}
# {'company_id': 1043057, 'location': 'Lincoln, Nebraska Metropolitan Area'}
# {'company_id': 40693052, 'location': 'Granbury, TX'}
# {'company_id': 124802, 'location': 'Tonawanda, NY'}
# {'company_id': 79098, 'location': 'Elwood, IL'}
# {'company_id': 9201883, 'location': 'Sudbury, MA'}
# {'company_id': 166551, 'location': 'Pine Bluff, AR'}
# {'company_id': 7032, 'location': 'Millville, NJ'}
# {'company_id': 1357956, 'location': 'Rockville, CT'}
# {'company_id': 1945473, 'location': 'Vernon, VT'}
# {'company_id': 220336, 'location': 'Breckenridge, CO'}
# {'company_id': 5064123, 'location': 'New Britain, CT'}
# {'company_id': 2972588, 'location': 'Wake County, NC'}
# {'company_id': 15317, 'location': 'Chambersburg, PA'}
# {'company_id': 82565832, 'location': 'Fairfield, NJ'}
# {'company_id': 3573083, 'location': 'Lawrenceville, GA'}
# {'company_id': 9561, 'location': 'Peachtree Corners, GA'}
# {'company_id': 5274161, 'location': 'Weld County, CO'}
# {'company_id': 121618, 'location': 'All Seasons Lake Park, OH'}
# {'company_id': 4029554, 'location': 'El Paso, TX'}
# {'company_id': 14542824, 'location': 'Henderson, NC'}
# {'company_id': 25179038, 'location': 'Fishkill, NY'}
# {'company_id': 2297840, 'location': 'Greater Chattanooga'}
# {'company_id': 41004, 'location': 'Hickory, NC'}
# {'company_id': 18176, 'location': 'Lewiston, ID'}
# {'company_id': 8280, 'location': 'North Brunswick, NJ'}
# {'company_id': 1058190, 'location': 'Spartanburg, SC'}
# {'company_id': 491462, 'location': 'Volusia County, FL'}
# {'company_id': 1945473, 'location': 'Hondo, TX'}
# {'company_id': 7064, 'location': 'Washington, MO'}
# {'company_id': 163535, 'location': 'Lincoln, CA'}
# {'company_id': 4852, 'location': 'St Petersburg, Florida, United States'}
# {'company_id': 10420321, 'location': 'Bartlesville, OK'}
# {'company_id': 1399, 'location': 'Marietta, PA'}
# {'company_id': 1412, 'location': 'Roy, UT'}
# {'company_id': 36995, 'location': 'San Bernardino, CA'}
# {'company_id': 78606, 'location': 'Winchester, VA'}
# {'company_id': 1375914, 'location': 'Muscle Shoals, AL'}
# {'company_id': 72483, 'location': 'Sarasota, FL'}
# {'company_id': 21279, 'location': 'Redmond, WA'}
# {'company_id': 18425303, 'location': 'Stamford, CT'}
# {'company_id': 16157996, 'location': 'Belton, MO'}
# {'company_id': 33229863, 'location': 'Daly City, CA'}
# {'company_id': 71575605, 'location': 'Auburn, WA'}
# {'company_id': 13181, 'location': 'Medical Lake, WA'}
# {'company_id': 31407868, 'location': 'Lawrence, MA'}
# {'company_id': 2660454, 'location': 'Palm Springs, CA'}
# {'company_id': 6913, 'location': 'New Lebanon, OH'}
# {'company_id': 98396367, 'location': 'Englewood Cliffs, NJ'}
# {'company_id': 20573, 'location': 'Waynesville, MO'}
# {'company_id': 2297786, 'location': 'Winter Park, FL'}
# {'company_id': 164880, 'location': 'Freeport, ME'}
# {'company_id': 157353, 'location': 'Mandeville, LA'}
# {'company_id': 10411539, 'location': 'New York, United States'}
# {'company_id': 49223, 'location': 'Moenave, AZ'}
# {'company_id': 80516368, 'location': 'Telluride, CO'}
# {'company_id': 46000, 'location': 'Topsham, ME'}
# {'company_id': 277579, 'location': 'Pinetops, NC'}
# {'company_id': 71904349, 'location': 'Lynchburg, VA'}
# {'company_id': 2155460, 'location': 'Leawood, KS'}
# {'company_id': 3671, 'location': 'Murphysboro, IL'}
# {'company_id': 4023316, 'location': 'Phoenixville, PA'}
# {'company_id': 2074994, 'location': 'Anaheim, CA'}
# {'company_id': 2651, 'location': 'San Luis Obispo County, CA'}
# {'company_id': 25552, 'location': 'Sheboygan Falls, WI'}
# {'company_id': 1259, 'location': 'Troy, MI'}
# {'company_id': 98209783, 'location': 'Cos Cob, CT'}
# {'company_id': 2736008, 'location': 'Aurora, Colorado, United States'}
# {'company_id': 65361091, 'location': 'Patuxent River, MD'}
# {'company_id': 27185258, 'location': 'Mechanicsville, VA'}
# {'company_id': 5618, 'location': 'Gretna, NE'}
# {'company_id': 1235, 'location': 'Fort Morgan, CO'}
# {'company_id': 5064123, 'location': 'Norwich, CT'}
# {'company_id': 24787024, 'location': 'Nokomis, FL'}
# {'company_id': 1297738, 'location': 'Union, NJ'}
# {'company_id': 7410, 'location': 'Wisconsin, United States'}
# {'company_id': 32380, 'location': 'Bargersville, IN'}
# {'company_id': 3748, 'location': 'Katy, TX'}
# {'company_id': 66716570, 'location': 'Manlius, NY'}
# {'company_id': 5127650, 'location': 'Baltimore County, MD'}
# {'company_id': 617793, 'location': 'Middletown, OH'}
# {'company_id': 3625, 'location': 'Downey, CA'}
# {'company_id': 162724, 'location': 'South Dakota, United States'}
# {'company_id': 89877420, 'location': 'Denver City, UT'}
# {'company_id': 11818084, 'location': 'Sulphur, OK'}
# {'company_id': 3764607, 'location': 'Imperial, CA'}
# {'company_id': 497515, 'location': 'Oberlin, OH'}
# {'company_id': 299305, 'location': 'Turners Falls, MA'}
# {'company_id': 4075, 'location': 'Wellesley, MA'}
# {'company_id': 32727, 'location': 'Wisconsin Rapids, WI'}
# {'company_id': 10420321, 'location': 'Madison, CT'}
# {'company_id': 163741, 'location': 'Yaphank, NY'}
# {'company_id': 62923, 'location': 'Dunn, NC'}
# {'company_id': 8359, 'location': 'Glen Burnie, MD'}
# {'company_id': 1103, 'location': 'Irving, TX'}
# {'company_id': 12291, 'location': 'Macon, GA'}
# {'company_id': 1235, 'location': 'Bartonville, TX'}
# {'company_id': 6234, 'location': 'Stilwell, OK'}
# {'company_id': 28209, 'location': 'Dublin, OH'}
# {'company_id': 136115, 'location': 'Henrico, VA'}
# {'company_id': 112755, 'location': 'Farmers Branch, TX'}
# {'company_id': 48467, 'location': 'Canton, MA'}
# {'company_id': 2737970, 'location': 'Greenwood, IN'}
# {'company_id': 166714, 'location': 'Iowa, United States'}
# {'company_id': 165716, 'location': 'Dresden, TN'}
# {'company_id': 93254, 'location': 'Freeland, MI'}
# {'company_id': 22132, 'location': 'Kuna, ID'}
# {'company_id': 13386, 'location': 'Manhattan Beach, CA'}
# {'company_id': 1286891, 'location': 'Roswell, GA'}
# {'company_id': 2664556, 'location': 'Skowhegan, ME'}
# {'company_id': 135342, 'location': 'Stuart, FL'}
# {'company_id': 9170, 'location': 'Ennis, TX'}
# {'company_id': 165944, 'location': 'Mooresville, IN'}
# {'company_id': 2646, 'location': 'Mount Pleasant, WI'}
# {'company_id': 52097, 'location': 'Fairbanks, AK'}
# {'company_id': 162724, 'location': 'West Virginia, United States'}
# {'company_id': 12601, 'location': 'Yakima, WA'}
# {'company_id': 667154, 'location': 'Quakertown, PA'}
# {'company_id': 96180361, 'location': 'Longmont, CO'}
# {'company_id': 479080, 'location': 'Pooler, GA'}
# {'company_id': 3658, 'location': 'Hershey, PA'}
# {'company_id': 13181, 'location': 'Rockville, MD'}
# {'company_id': 10035810, 'location': 'Martinsville, VA'}
# {'company_id': 66278935, 'location': 'Avon Lake, OH'}
# {'company_id': 57978, 'location': 'Carthage, MO'}
# {'company_id': 2736008, 'location': 'Kingston, PA'}
# {'company_id': 11088832, 'location': 'Elizabethtown, PA'}
# {'company_id': 51637411, 'location': 'Mountain Home, TX'}
# {'company_id': 11834, 'location': 'Edgewood, NY'}
# {'company_id': 165422, 'location': 'Bellingham, WA'}
# {'company_id': 2736008, 'location': 'Grand Junction, CO'}
# {'company_id': 81878, 'location': 'Headquarters, NJ'}
# {'company_id': 1867264, 'location': 'Greenfield, MA'}
# {'company_id': 32727, 'location': 'East St Louis, IL'}
# {'company_id': 2121817, 'location': 'Jonesville, MI'}
# {'company_id': 165944, 'location': 'Cottonwood, AZ'}
# {'company_id': 1681, 'location': 'Faison, NC'}
# {'company_id': 6913, 'location': 'Garden City, MI'}
# {'company_id': 217338, 'location': 'Kansas City, KS'}
# {'company_id': 2931, 'location': 'North Reading, MA'}
# {'company_id': 1901345, 'location': 'Excelsior, MN'}
# {'company_id': 33278075, 'location': 'Doral, FL'}
# {'company_id': 483961, 'location': 'Longview, TX'}
# {'company_id': 9185, 'location': 'Moon, PA'}
# {'company_id': 1792592, 'location': 'Northbrook, IL'}
# {'company_id': 71904349, 'location': 'Port Washington, WI'}
# {'company_id': 20573, 'location': 'Federal Way, WA'}
# ...
# {'company_id': 3625, 'location': 'Abo, MO'}
# {'company_id': 71904349, 'location': 'Allendale, NJ'}
# {'company_id': 7427, 'location': 'Solon, OH'}
# {'company_id': 630847, 'location': 'Dakota, IL'}
# {'company_id': 12890, 'location': 'Christiana, DE'}
# {'company_id': 808034, 'location': 'Fleming Island, FL'}
# {'company_id': 5128510, 'location': 'St Clair Shores, MI'}
# {'company_id': 9251256, 'location': 'Sun City, KS'}
# {'company_id': 28332, 'location': 'Jacksonville, AL'}
# {'company_id': 10667641, 'location': 'Lake Wales, FL'}
# {'company_id': 12890, 'location': 'Tulalip, WA'}
# {'company_id': 3264, 'location': 'Mayfield, OH'}
# {'company_id': 164249, 'location': 'Webster City, IA'}
# {'company_id': 808034, 'location': 'West Plains, MO'}
# {'company_id': 65294553, 'location': 'Clyde, NY'}
# {'company_id': 9814, 'location': 'Illinois City, IL'}
# {'company_id': 31439, 'location': 'Orange County, CA'}
# {'company_id': 8390, 'location': 'Van Wert, OH'}
# {'company_id': 18043, 'location': 'Woodinville, WA'}
# {'company_id': 2646, 'location': 'Portage, IN'}
# {'company_id': 22523, 'location': 'Farmington, UT'}
# {'company_id': 79042201, 'location': 'Jarratt, VA'}
# {'company_id': 3195033, 'location': 'Ludlow, MA'}
# {'company_id': 72483, 'location': 'Champaign, IL'}
# {'company_id': 947663, 'location': 'Holdenville, OK'}
# {'company_id': 14287, 'location': 'Nolanville, TX'}
# {'company_id': 824478, 'location': 'Boynton Beach, FL'}
# {'company_id': 1454342, 'location': 'San Antonio, Texas Metropolitan Area'}
# {'company_id': 139348, 'location': 'Walton, KY'}
# {'company_id': 27973, 'location': 'Warsaw, VA'}
# {'company_id': 4872007, 'location': 'West Babylon, NY'}
# {'company_id': 167757, 'location': 'South Salem, NY'}
# {'company_id': 11056, 'location': 'San Clemente, CA'}
# {'company_id': 398606, 'location': 'Lufkin, TX'}
# {'company_id': 134081, 'location': 'Clifton Park, NY'}
# {'company_id': 36990695, 'location': 'Jacksonville, NC'}
# {'company_id': 1441, 'location': 'Red Oak, TX'}
# {'company_id': 71316538, 'location': 'Clearwater, Florida, United States'}
# {'company_id': 2664185, 'location': 'Riviera Beach, FL'}
# {'company_id': 11518813, 'location': 'Supply, NC'}
# {'company_id': 3240, 'location': 'La Crosse, WI'}
# {'company_id': 27108872, 'location': 'Hazlet, NJ'}
# {'company_id': 5461, 'location': 'Kirtland Air Force Base, NM'}
# {'company_id': 9814, 'location': 'Gardner, MA'}
# {'company_id': 2646, 'location': 'Gonzales, TX'}
# {'company_id': 165422, 'location': 'Cottage Grove, OR'}
# {'company_id': 1579375, 'location': 'Johnston, IA'}
# {'company_id': 18348487, 'location': 'Blue Ash, OH'}
# {'company_id': 16263, 'location': 'Galveston, TX'}
# {'company_id': 4918, 'location': 'Brookfield, WI'}
# {'company_id': 2646, 'location': 'Benton, IL'}
# {'company_id': 163139, 'location': 'Atlanta Metropolitan Area'}
# {'company_id': 163640, 'location': 'Greater Jackson Area'}
# {'company_id': 2646, 'location': 'Jasper, IN'}
# {'company_id': 18506580, 'location': 'Baldwin Park, CA'}
# {'company_id': 2589107, 'location': 'Martinez, CA'}
# {'company_id': 3015, 'location': 'Missouri, United States'}
# {'company_id': 122451, 'location': 'Nellis AFB, NV'}
# {'company_id': 1185, 'location': 'North Carolina, United States'}
# {'company_id': 2718193, 'location': 'Ramsey, NJ'}
# {'company_id': 3762, 'location': 'Riverwoods, IL'}
# {'company_id': 61677, 'location': 'Romeo, MI'}
# {'company_id': 17603, 'location': 'Roseburg, OR'}
# {'company_id': 18860134, 'location': 'Rutherford, NJ'}
# {'company_id': 14542824, 'location': 'Maysville, KY'}
# {'company_id': 1945473, 'location': 'Johnson City, TN'}
# {'company_id': 808034, 'location': 'Mesa, AZ'}
# {'company_id': 10678820, 'location': 'Salem, NH'}
# {'company_id': 371545, 'location': 'Santa Clarita, CA'}
# {'company_id': 165422, 'location': 'Sedro-Woolley, WA'}
# {'company_id': 64639449, 'location': 'Seguin, TX'}
# {'company_id': 572263, 'location': 'Staten Island, NY'}
# {'company_id': 209610, 'location': 'Carlsbad, NM'}
# {'company_id': 6176, 'location': 'Rolling Prairie, IN'}
# {'company_id': 164451, 'location': 'Fort Dodge, IA'}
# {'company_id': 7064, 'location': 'Springfield, MO'}
# {'company_id': 9308035, 'location': 'Bloomington–Normal, IL'}
# {'company_id': 1945473, 'location': 'Northport, AL'}
# {'company_id': 64259963, 'location': 'Mandan, ND'}
# {'company_id': 450185, 'location': 'McMinnville, OR'}
# {'company_id': 103486, 'location': 'Mount Prospect, IL'}
# {'company_id': 1464, 'location': 'Arkadelphia, AR'}
# {'company_id': 2949451, 'location': 'Del Mar, CA'}
# {'company_id': 10462531, 'location': 'Norfolk County, MA'}
# {'company_id': 33266522, 'location': 'Sterling Wood, TX'}
# {'company_id': 76171420, 'location': 'Jefferson City, MO'}
# {'company_id': 11229, 'location': 'Trussville, AL'}
# {'company_id': 130095, 'location': 'Jamestown, TN'}
# {'company_id': 718282, 'location': 'Ventura County, CA'}
# {'company_id': 56670, 'location': 'West Greenwich, RI'}
# {'company_id': 4798, 'location': 'Holland, OH'}
# {'company_id': 76500049, 'location': 'Orland Park, IL'}
# {'company_id': 6440, 'location': 'Farmingdale, NJ'}
# {'company_id': 1283753, 'location': 'Bolivia, NC'}
# {'company_id': 28810, 'location': 'Lincolnshire, IL'}
# {'company_id': 2855513, 'location': 'Chattanooga, TN'}
# {'company_id': 10089202, 'location': 'Orlando, Florida, United States'}
# {'company_id': 6592, 'location': 'Alliance, OH'}
# {'company_id': 164754, 'location': 'Scott AFB, IL'}
# {'company_id': 33636, 'location': 'Montgomery, AL'}
# {'company_id': 11056, 'location': 'Pomona, CA'}
# {'company_id': 27549, 'location': 'Steamboat Springs, CO'}
# {'company_id': 89877420, 'location': 'Liberty, NC'}
# {'company_id': 163079, 'location': 'Duarte, CA'}
# {'company_id': 76217848, 'location': 'Williamsport, PA'}
# {'company_id': 20009, 'location': 'South St Paul, MN'}
# {'company_id': 7032, 'location': 'Bellflower, CA'}
# {'company_id': 95724, 'location': 'Stony Point, NC'}
# {'company_id': 163139, 'location': 'Herndon, VA'}
# {'company_id': 30086, 'location': 'Washington, United States'}
# {'company_id': 133340, 'location': 'West Palm Beach, FL'}
# {'company_id': 108340, 'location': 'Lenexa, KS'}
# {'company_id': 15208770, 'location': 'Beaver, PA'}
# {'company_id': 62936276, 'location': 'Washington DC-Baltimore Area'}
# {'company_id': 76440728, 'location': 'Midlothian, TX'}
# {'company_id': 85708, 'location': 'Pflugerville, TX'}
# {'company_id': 9185, 'location': 'St Clairsville, OH'}
# {'company_id': 10420321, 'location': 'Pawtucket, RI'}
# {'company_id': 1016, 'location': 'Rhode Island, United States'}
# {'company_id': 9185, 'location': 'Meridian, MS'}
# {'company_id': 52642826, 'location': 'Fort Pierce, FL'}
# {'company_id': 999245, 'location': 'Brookline, MA'}
# {'company_id': 9229, 'location': 'Danville, VA'}
# {'company_id': 46000, 'location': 'Homewood, IL'}
# {'company_id': 2476, 'location': 'Los Angeles, CA'}
# {'company_id': 2343421, 'location': 'McComb, MS'}
# {'company_id': 2615835, 'location': 'Quantico, VA'}
# {'company_id': 9185, 'location': 'Taylor, MI'}
# {'company_id': 1945473, 'location': 'Dickinson, ND'}
# {'company_id': 2646, 'location': 'Sullivan, IN'}
# {'company_id': 688958, 'location': 'Dauphin County, PA'}
# {'company_id': 18415460, 'location': 'Milford, MI'}
# {'company_id': 4768, 'location': 'Carrollton, TX'}
# {'company_id': 10854676, 'location': 'Clarence, NY'}
# {'company_id': 76500049, 'location': 'Lyons, NY'}
# {'company_id': 28149455, 'location': 'Old Bridge, NJ'}
# {'company_id': 3570660, 'location': 'Ashland, MA'}
# {'company_id': 3671, 'location': 'Casa Grande, AZ'}
# {'company_id': 3677, 'location': 'Chisago City, MN'}
# {'company_id': 3015, 'location': 'Purchase, NY'}
# {'company_id': 25856, 'location': 'Ovid, NY'}
# {'company_id': 3961, 'location': 'Queens County, NY'}
# {'company_id': 5749, 'location': 'Menomonee Falls, WI'}
# {'company_id': 9185, 'location': 'Plainville, CT'}
# {'company_id': 3706049, 'location': 'Bedford, PA'}
# {'company_id': 305287, 'location': 'Cheraw, SC'}
# {'company_id': 2425285, 'location': 'Jackson, OH'}
# {'company_id': 15691, 'location': 'Cape Coral Metropolitan Area'}
# {'company_id': 10420321, 'location': 'Guilford, CT'}
# {'company_id': 2203697, 'location': 'Cleveland, MS'}
# {'company_id': 2193256, 'location': 'De Pere, WI'}
# {'company_id': 2193256, 'location': 'Menomonie, WI'}
# {'company_id': 3714038, 'location': 'Greater Bangor Area'}
# {'company_id': 808034, 'location': 'Fullerton, CA'}
# {'company_id': 157353, 'location': 'Chappaqua, NY'}
# {'company_id': 74064331, 'location': 'American Fork, UT'}
# {'company_id': 5749, 'location': 'Encinitas, CA'}
# {'company_id': 71904349, 'location': 'Monmouth Junction, NJ'}
# {'company_id': 80862575, 'location': 'Muskegon, MI'}
# {'company_id': 82153, 'location': 'Kenner, LA'}
# {'company_id': 1945473, 'location': 'Olympia, WA'}
# {'company_id': 686294, 'location': 'Scarsdale, NY'}
# {'company_id': 1262, 'location': 'Milano, TX'}
# {'company_id': 104405, 'location': 'Soldotna, AK'}
# {'company_id': 2247, 'location': 'Park City, KS'}
# {'company_id': 461332, 'location': 'Stratford, CT'}
# {'company_id': 18860134, 'location': 'Tinton Falls, NJ'}
# {'company_id': 352970, 'location': 'Northlake, TX'}
# {'company_id': 766876, 'location': 'Pharr, TX'}
# {'company_id': 3316709, 'location': 'Costa Mesa, CA'}
# {'company_id': 35504315, 'location': 'Dubuque, IA'}
# {'company_id': 42304017, 'location': 'East Stoneham, ME'}
# {'company_id': 53193, 'location': 'Hudson, NY'}
# {'company_id': 3184, 'location': 'Malvern, PA'}
# {'company_id': 95062508, 'location': 'Gardner, KS'}
# {'company_id': 9499, 'location': 'Cool Spring, NC'}
# {'company_id': 11402317, 'location': 'Camden, NJ'}
# {'company_id': 65294553, 'location': 'Morris, MN'}
# {'company_id': 104895, 'location': 'Dodge Center, MN'}
# {'company_id': 38204, 'location': 'Pensacola Metropolitan Area'}
# {'company_id': 911928, 'location': 'Spring Park, MN'}
# {'company_id': 6176, 'location': 'Harlingen, TX'}
# {'company_id': 6592, 'location': 'Marion, OH'}
# {'company_id': 20573, 'location': 'Johnston, RI'}
# {'company_id': 89863875, 'location': 'Merced, CA'}
# {'company_id': 321986, 'location': 'Franklin, NH'}
# {'company_id': 3500602, 'location': 'Berlin, WI'}
# {'company_id': 11758, 'location': 'Elmsford, NY'}
# {'company_id': 9286450, 'location': 'Gainesville, FL'}
# {'company_id': 164880, 'location': 'York, SC'}
# {'company_id': 278713, 'location': 'Hamilton County, OH'}
# {'company_id': 808034, 'location': 'New Orleans, LA'}
# {'company_id': 1103, 'location': 'Ashburn, VA'}
# {'company_id': 15080, 'location': 'Cross Lanes, WV'}
# {'company_id': 162644, 'location': 'Homewood, AL'}
# {'company_id': 28669777, 'location': 'Kutztown, PA'}
# {'company_id': 37520, 'location': 'Orange, TX'}
# {'company_id': 31065, 'location': 'Auburn, GA'}
# {'company_id': 3196, 'location': 'Evanston, IL'}
# {'company_id': 2059, 'location': 'Fuquay-Varina, NC'}
# {'company_id': 5064123, 'location': 'Meriden, CT'}
# {'company_id': 18707, 'location': 'Red Bank, NJ'}
# {'company_id': 167757, 'location': 'Reno, NV'}
# {'company_id': 71316538, 'location': 'Lake Buena Vista, FL'}
# {'company_id': 17109, 'location': 'Little Elm, TX'}
# {'company_id': 80711640, 'location': 'Tarboro, NC'}
# {'company_id': 3706049, 'location': 'Rusk, TX'}
# {'company_id': 88289095, 'location': 'Corning, NY'}
# {'company_id': 9070, 'location': 'Greater Sacramento'}
# {'company_id': 1183247, 'location': 'Florence County, SC'}
# {'company_id': 35502259, 'location': 'Ozark, MO'}
# {'company_id': 227878, 'location': 'Newport, KY'}
# {'company_id': 4822178, 'location': 'Lancaster, TX'}
# {'company_id': 14736, 'location': 'Philadelphia, Pennsylvania, United States'}
# {'company_id': 30114, 'location': 'Pocomoke City, MD'}
# {'company_id': 34704, 'location': 'Merrillville, IN'}
# {'company_id': 27254190, 'location': 'Glendale, AZ'}
# {'company_id': 2736008, 'location': 'Springville, AL'}
# {'company_id': 8017, 'location': 'Brecksville, OH'}
# {'company_id': 19519, 'location': 'Northern, VA'}
# {'company_id': 15862365, 'location': 'Watertown, MA'}
# {'company_id': 1703, 'location': 'Westfield, MA'}
# {'company_id': 4725, 'location': 'Decorah, IA'}
# {'company_id': 6593, 'location': 'Calabasas, CA'}
# {'company_id': 851980, 'location': 'Westwood, KS'}
# {'company_id': 6250, 'location': 'Wylie, TX'}
# {'company_id': 163883, 'location': 'Calistoga, CA'}
# {'company_id': 30953, 'location': 'Home Park, Florida, United States'}
# {'company_id': 6979, 'location': 'Buras, LA'}
# {'company_id': 10420321, 'location': 'Gardena, CA'}
# {'company_id': 18281, 'location': 'North Salem, NY'}
# {'company_id': 935956, 'location': 'Las Vegas Metropolitan Area'}
# {'company_id': 20088, 'location': 'Conneaut, OH'}
# {'company_id': 74161427, 'location': 'Apopka, FL'}
# {'company_id': 84056, 'location': 'Mooresville, NC'}
# {'company_id': 19023, 'location': 'Lewisberry, PA'}
# {'company_id': 1185, 'location': 'Michigan, United States'}
# {'company_id': 3534, 'location': 'Mount Vernon, IL'}
# {'company_id': 6913, 'location': 'Lake Oswego, OR'}
# {'company_id': 3028, 'location': 'San Francisco, CA'}
# {'company_id': 71904349, 'location': 'Lanham, MD'}
# {'company_id': 27837, 'location': 'Providence, RI'}
# {'company_id': 15473, 'location': 'Arnold, MO'}
# {'company_id': 250099, 'location': 'Macomb, MI'}
# {'company_id': 2918, 'location': 'San Pablo, CA'}
# {'company_id': 1668, 'location': 'Arcata, CA'}
# {'company_id': 1235, 'location': 'Sandy, UT'}
# {'company_id': 157346, 'location': 'Mercedes, TX'}
# {'company_id': 3476, 'location': 'Tewksbury, MA'}
# {'company_id': 84959254, 'location': 'Greater Morgantown Area'}
# {'company_id': 14088, 'location': 'Beckett Ridge, OH'}
# {'company_id': 64515355, 'location': 'Clifton, NJ'}
# {'company_id': 294374, 'location': 'Portland, Maine Metropolitan Area'}
# {'company_id': 157346, 'location': 'Tukwila, WA'}
# {'company_id': 2721914, 'location': 'Warrenton, MO'}
# {'company_id': 79011799, 'location': 'West New York, NJ'}
# {'company_id': 164880, 'location': 'Ruskin, FL'}
# {'company_id': 9895824, 'location': 'Highwood, IL'}
# {'company_id': 450185, 'location': 'Klamath Falls, OR'}
# {'company_id': 686294, 'location': 'La Jolla, California, United States'}
# {'company_id': 8885, 'location': 'Spirit Lake, IA'}
# {'company_id': 1103, 'location': 'Bristol, TN'}
# {'company_id': 2343421, 'location': 'Hinds County, MS'}
# {'company_id': 74081610, 'location': 'Harrington, DE'}
# {'company_id': 2999998, 'location': 'Napa County, CA'}
# {'company_id': 12095, 'location': 'Tomah, WI'}
# {'company_id': 1908498, 'location': 'Kokomo, IN'}
# {'company_id': 167757, 'location': 'White Settlement, TX'}
# {'company_id': 71904349, 'location': 'Stoneham, MA'}
# {'company_id': 22534, 'location': 'Eagan, MN'}
# {'company_id': 11056, 'location': 'Bryn Mawr, PA'}
# {'company_id': 11763611, 'location': 'Mount Kisco, NY'}
# {'company_id': 4156, 'location': 'Residence Park, OH'}
# {'company_id': 3700354, 'location': 'Snow Hill, NC'}
# {'company_id': 12446, 'location': 'Star Lake, NY'}
# {'company_id': 25856, 'location': 'Liverpool, NY'}
# {'company_id': 80862575, 'location': 'Pontiac, MI'}
# {'company_id': 82090049, 'location': 'East Syracuse, NY'}
# {'company_id': 139348, 'location': 'Linthicum Heights, MD'}
# {'company_id': 9814, 'location': 'Freedom, PA'}
# {'company_id': 28498, 'location': 'Manchester, PA'}
# {'company_id': 33190802, 'location': 'Aspen, CO'}
# {'company_id': 20573, 'location': 'Centerville, TN'}
# {'company_id': 23769122, 'location': 'Duncansville, PA'}
# {'company_id': 2664556, 'location': 'Margate, FL'}
# {'company_id': 7795, 'location': 'River Forest, IL'}
# {'company_id': 1335225, 'location': 'Ronkonkoma, NY'}
# {'company_id': 1792, 'location': 'Stanford, CA'}
# {'company_id': 1103, 'location': 'Grand Forks, ND'}
# {'company_id': 10854663, 'location': 'Winamac, IN'}
# {'company_id': 3789, 'location': 'Moline, IL'}
# {'company_id': 468782, 'location': 'Creve Coeur, MO'}
# {'company_id': 922640, 'location': 'Ellenville, NY'}
# {'company_id': 808034, 'location': 'Covington, WA'}
# {'company_id': 11240, 'location': 'Duluth, GA'}
# {'company_id': 3015, 'location': 'Goodland, KS'}
# {'company_id': 5368909, 'location': 'East Longmeadow, MA'}
# {'company_id': 1463, 'location': 'Maitland, FL'}
# Length of the result for 3a-2 :  3431
# Mongo Execution time: 0.31000709533691406
# Avg total time Mongo-Query 3a-2  =  0.40612800121307374

# %% [markdown]
# Optimization

# %%
jobs_collection.create_index(index_definition)
mongo_query_result(mongo_query2,jobs_collection,name)
mongo_query_avg_time(mongo_query2,jobs_collection,x,name)
# Out:
# {'company_id': 3619383, 'location': 'Lehi, UT'}
# {'company_id': 25856, 'location': 'Verona, PA'}
# {'company_id': 2646, 'location': 'Hutchinson, KS'}
# {'company_id': 1392, 'location': 'Bellevue, WA'}
# {'company_id': 4564, 'location': 'Nashville Metropolitan Area'}
# {'company_id': 349545, 'location': 'Tanner, AL'}
# {'company_id': 12820, 'location': 'Daleville, VA'}
# {'company_id': 10667, 'location': 'Eagle Mountain, UT'}
# {'company_id': 3626, 'location': 'Inverness, FL'}
# {'company_id': 97402272, 'location': 'Jacksonville Beach, FL'}
# {'company_id': 164664, 'location': 'Raleigh-Durham-Chapel Hill Area'}
# {'company_id': 2701866, 'location': 'Bagdad, AZ'}
# {'company_id': 13476, 'location': 'Sleepy Hollow, NY'}
# {'company_id': 4768, 'location': 'Shoreview, MN'}
# {'company_id': 333785, 'location': 'Fort Mitchell, KY'}
# {'company_id': 1943848, 'location': 'Columbus, MS'}
# {'company_id': 3706049, 'location': 'Searcy, AR'}
# {'company_id': 209610, 'location': 'St James, LA'}
# {'company_id': 165944, 'location': 'Saint Croix, ND'}
# {'company_id': 437225, 'location': 'Elgin, IL'}
# {'company_id': 7064, 'location': 'Ada, OK'}
# {'company_id': 380752, 'location': 'Flemington, NJ'}
# {'company_id': 1703, 'location': 'Bennington, VT'}
# {'company_id': 82500012, 'location': 'Kentwood, MI'}
# {'company_id': 1557409, 'location': 'Edison, NJ'}
# {'company_id': 718282, 'location': 'Port Hueneme, CA'}
# {'company_id': 2252, 'location': 'Statesville, NC'}
# {'company_id': 1211063, 'location': 'Warrenton, VA'}
# {'company_id': 4307, 'location': 'Radnor, PA'}
# {'company_id': 1103, 'location': 'Basking Ridge, NJ'}
# {'company_id': 2578499, 'location': 'Greater Minneapolis-St. Paul Area'}
# {'company_id': 76815121, 'location': 'Middlesex, NJ'}
# {'company_id': 4128, 'location': 'Ypsilanti, MI'}
# {'company_id': 3706049, 'location': 'Kerrville, TX'}
# {'company_id': 22309011, 'location': 'Brownstown, MI'}
# {'company_id': 10514179, 'location': 'Arkansas, United States'}
# {'company_id': 3612137, 'location': 'Downers Grove, IL'}
# {'company_id': 19024424, 'location': 'Greensburg, PA'}
# {'company_id': 91743578, 'location': 'Greater Boston'}
# {'company_id': 37902046, 'location': 'Lebanon, MO'}
# {'company_id': 1016, 'location': 'Massachusetts, United States'}
# {'company_id': 14510501, 'location': 'Miami-Fort Lauderdale Area'}
# {'company_id': 3706049, 'location': 'Coxsackie, NY'}
# {'company_id': 1075434, 'location': 'Richardson, TX'}
# {'company_id': 19349, 'location': 'Sarasota County, FL'}
# {'company_id': 11227630, 'location': 'Yonkers, NY'}
# {'company_id': 11092, 'location': 'St Augustine, FL'}
# {'company_id': 258644, 'location': 'Cannon Falls, MN'}
# {'company_id': 7720, 'location': 'Hollywood, FL'}
# {'company_id': 59317, 'location': 'Methuen, MA'}
# {'company_id': 1103, 'location': 'Temple Terrace, FL'}
# {'company_id': 2247, 'location': 'New Cumberland, PA'}
# {'company_id': 1984030, 'location': 'New Hyde Park, NY'}
# {'company_id': 20009, 'location': 'Somerset, KY'}
# {'company_id': 1593346, 'location': 'West Chester, OH'}
# {'company_id': 27253457, 'location': 'Bothell, WA'}
# {'company_id': 10420321, 'location': 'Palatine, IL'}
# {'company_id': 66766192, 'location': 'Santa Fe, NM'}
# {'company_id': 1224492, 'location': 'Plymouth, MN'}
# {'company_id': 6250, 'location': 'Temple, TX'}
# {'company_id': 9487, 'location': 'Guthrie, KY'}
# {'company_id': 71904349, 'location': 'Homestead, PA'}
# {'company_id': 18506580, 'location': 'Mequon, WI'}
# {'company_id': 3579761, 'location': 'Lithia Springs, GA'}
# {'company_id': 162724, 'location': 'Kentucky, United States'}
# {'company_id': 167024, 'location': 'Morris Plains, NJ'}
# {'company_id': 28498, 'location': 'Ephrata, PA'}
# {'company_id': 3672, 'location': 'Aurora, CO'}
# {'company_id': 9185, 'location': 'Berlin, NJ'}
# {'company_id': 20573, 'location': 'North Charleston, SC'}
# {'company_id': 10261, 'location': 'North Liberty, NC'}
# {'company_id': 496934, 'location': 'Opelousas, LA'}
# {'company_id': 88016, 'location': 'Patchogue, NY'}
# {'company_id': 3706049, 'location': 'Wallingford, Pennsylvania, United States'}
# {'company_id': 80181, 'location': 'Wilmington, Delaware, United States'}
# {'company_id': 7795, 'location': 'Huntsville, TX'}
# {'company_id': 10420321, 'location': 'Santa Monica, CA'}
# {'company_id': 3242, 'location': 'Dothan, AL'}
# {'company_id': 406004, 'location': 'Waco, TX'}
# {'company_id': 289310, 'location': 'Erlanger, KY'}
# {'company_id': 2633, 'location': 'Wyandotte, MI'}
# {'company_id': 4994, 'location': 'Livermore, CA'}
# {'company_id': 18009221, 'location': 'Coldwater, MI'}
# {'company_id': 1668, 'location': 'Cadillac, MI'}
# {'company_id': 493453, 'location': 'Central, SC'}
# {'company_id': 18062, 'location': 'Annapolis, MD'}
# {'company_id': 165295, 'location': 'Mashantucket, CT'}
# {'company_id': 49648345, 'location': 'Oakland County, MI'}
# {'company_id': 29849, 'location': 'Terre Haute, IN'}
# {'company_id': 60836398, 'location': 'Germantown, TN'}
# {'company_id': 10514179, 'location': 'Mount Shasta, CA'}
# {'company_id': 808034, 'location': 'Farmington, NM'}
# {'company_id': 3215718, 'location': 'Berwyn, PA'}
# {'company_id': 284165, 'location': 'Jackson Township, OH'}
# {'company_id': 31827, 'location': 'San Antonio, TX'}
# {'company_id': 3460, 'location': 'Altoona, PA'}
# {'company_id': 90413667, 'location': 'Kinston, NC'}
# {'company_id': 36995, 'location': 'South El Monte, CA'}
# {'company_id': 13074, 'location': 'Spokane, WA'}
# {'company_id': 2671586, 'location': 'Sonoma, CA'}
# {'company_id': 3260, 'location': 'Cleveland, TN'}
# {'company_id': 49042, 'location': 'Port Charlotte, FL'}
# {'company_id': 1103, 'location': 'West Long Branch, NJ'}
# {'company_id': 28149455, 'location': 'Cedar Grove, NJ'}
# {'company_id': 65787040, 'location': 'Marksville, LA'}
# {'company_id': 7999, 'location': 'Oak Ridge, TN'}
# {'company_id': 11788646, 'location': 'Frederick, MD'}
# {'company_id': 1103, 'location': 'Batavia, NY'}
# {'company_id': 28850513, 'location': 'Shelbyville, IN'}
# {'company_id': 18106262, 'location': 'Charter Oak, CA'}
# {'company_id': 28647688, 'location': 'Las Cruces, NM'}
# {'company_id': 20009, 'location': 'Orangeburg, SC'}
# {'company_id': 69213826, 'location': 'Palm Harbor, FL'}
# {'company_id': 1403, 'location': 'Springfield, VA'}
# {'company_id': 13353, 'location': 'Fond du Lac, WI'}
# {'company_id': 5352294, 'location': 'Racine, WI'}
# {'company_id': 450185, 'location': 'SeaTac, WA'}
# {'company_id': 22112, 'location': 'Boone, NC'}
# {'company_id': 5107, 'location': 'Fremont, CA'}
# {'company_id': 1263534, 'location': 'Cuyahoga Falls, OH'}
# {'company_id': 6104, 'location': 'Huntington, NY'}
# {'company_id': 2106853, 'location': 'Hillsboro, OR'}
# {'company_id': 167757, 'location': 'Springfield, VT'}
# {'company_id': 20009, 'location': 'Escondido, CA'}
# {'company_id': 2943678, 'location': 'Albuquerque-Santa Fe Metropolitan Area'}
# {'company_id': 2651, 'location': 'San Diego County, CA'}
# {'company_id': 3570660, 'location': 'San Rafael, CA'}
# {'company_id': 725927, 'location': 'Verona, WI'}
# {'company_id': 20573, 'location': 'Westminster, CO'}
# {'company_id': 166572, 'location': 'Buena Park, CA'}
# {'company_id': 12192, 'location': 'Woburn, MA'}
# {'company_id': 2268831, 'location': 'Bedford, MA'}
# {'company_id': 49042, 'location': 'Ellicott City, MD'}
# {'company_id': 1441, 'location': 'Seattle, WA'}
# {'company_id': 40658652, 'location': 'Broken Arrow, OK'}
# {'company_id': 2034303, 'location': 'Williamsville, NY'}
# {'company_id': 51701193, 'location': 'Dartmouth, MA'}
# {'company_id': 1013110, 'location': 'Aberdeen, MD'}
# {'company_id': 91534, 'location': 'Bloomingdale, GA'}
# {'company_id': 1945473, 'location': 'Casper, WY'}
# {'company_id': 22523, 'location': 'City Park, UT'}
# {'company_id': 3308308, 'location': 'Littleton, CO'}
# {'company_id': 17233, 'location': 'Garciasville, TX'}
# {'company_id': 16892, 'location': 'Jacksonville, GA'}
# {'company_id': 4591, 'location': 'Manhattan, KS'}
# {'company_id': 18312164, 'location': 'Baltimore, OH'}
# {'company_id': 437225, 'location': 'Perris, CA'}
# {'company_id': 2646, 'location': 'Ponca City, OK'}
# {'company_id': 72483, 'location': 'Santa Cruz, CA'}
# {'company_id': 6176, 'location': 'Virginia Beach, VA'}
# {'company_id': 18312164, 'location': 'Phoenix, OR'}
# {'company_id': 205651, 'location': 'Wall Township, NJ'}
# {'company_id': 6592912, 'location': 'Washington, PA'}
# {'company_id': 1945473, 'location': 'Albuquerque, NM'}
# {'company_id': 3658, 'location': 'Duncannon, PA'}
# {'company_id': 4453, 'location': 'Locust Grove, GA'}
# {'company_id': 28647688, 'location': 'Smith County, TX'}
# {'company_id': 4898, 'location': 'Virginia, United States'}
# {'company_id': 79383535, 'location': 'Princeton, NJ'}
# {'company_id': 7886, 'location': 'Birmingham, AL'}
# {'company_id': 10225139, 'location': 'Hammond, IN'}
# {'company_id': 12699415, 'location': 'San Mateo, CA'}
# {'company_id': 202443, 'location': 'Carbondale, PA'}
# {'company_id': 71575605, 'location': 'Edwardsville, IL'}
# {'company_id': 3771, 'location': 'Boulder, CO'}
# {'company_id': 14606618, 'location': 'Chula Vista, CA'}
# {'company_id': 4167, 'location': 'Gilbert, AZ'}
# {'company_id': 31827, 'location': 'Live Oak, TX'}
# {'company_id': 1103, 'location': 'Avon, MA'}
# {'company_id': 72483, 'location': 'Capistrano Beach, CA'}
# {'company_id': 10408914, 'location': 'Grantsville, UT'}
# {'company_id': 28647688, 'location': 'Gunnison, CO'}
# {'company_id': 1586, 'location': 'Petersburg, VA'}
# {'company_id': 2660, 'location': 'San Francisco County, CA'}
# {'company_id': 79560, 'location': 'Midtown, Louisiana, United States'}
# {'company_id': 1945473, 'location': 'Red Bluff, CA'}
# {'company_id': 7789, 'location': 'Sioux Falls, SD'}
# {'company_id': 2193256, 'location': 'Suamico, WI'}
# {'company_id': 2470561, 'location': 'Los Angeles County, CA'}
# {'company_id': 166774, 'location': 'Salem, VA'}
# {'company_id': 9499, 'location': 'Gainesville, GA'}
# {'company_id': 16075064, 'location': 'Leavenworth, KS'}
# {'company_id': 81954233, 'location': 'Bloomfield Hills, MI'}
# {'company_id': 12787, 'location': 'Butner, NC'}
# {'company_id': 39472, 'location': 'Denville, NJ'}
# {'company_id': 3162, 'location': 'Austin, TX'}
# {'company_id': 21921, 'location': 'Lafayette, Indiana Metropolitan Area'}
# {'company_id': 6979, 'location': 'Texas City, TX'}
# {'company_id': 1931371, 'location': 'Chestnut Hill, MA'}
# {'company_id': 23213, 'location': 'Home, KS'}
# {'company_id': 70560, 'location': 'Fargo-Moorhead'}
# {'company_id': 3493, 'location': 'Jackson, TN'}
# {'company_id': 1274529, 'location': 'Camarillo, CA'}
# {'company_id': 12932, 'location': 'Kent, WA'}
# {'company_id': 1344, 'location': 'Northford, CT'}
# {'company_id': 14571, 'location': 'Augusta, ME'}
# {'company_id': 44399, 'location': 'Notre Dame, IN'}
# {'company_id': 11022681, 'location': 'Pennington, NJ'}
# {'company_id': 18506580, 'location': 'Prosper, TX'}
# {'company_id': 15656, 'location': 'Santa Teresa, NM'}
# {'company_id': 808034, 'location': 'Seneca, SC'}
# {'company_id': 1505, 'location': 'Sterling, VA'}
# {'company_id': 9308035, 'location': 'Brownsville, TX'}
# {'company_id': 95755323, 'location': 'Lyons, KS'}
# {'company_id': 16690, 'location': 'Enon, OH'}
# {'company_id': 162724, 'location': 'Oklahoma, United States'}
# {'company_id': 5242206, 'location': 'Crescent City, FL'}
# {'company_id': 28647688, 'location': 'Marlboro, MA'}
# {'company_id': 45716, 'location': 'Grand Canyon Village, AZ'}
# {'company_id': 11752085, 'location': 'McChord Air Force Base, WA'}
# {'company_id': 6913, 'location': 'Ridgway, PA'}
# {'company_id': 10137, 'location': 'Wilmington, OH'}
# {'company_id': 6176, 'location': 'Mission, TX'}
# {'company_id': 1471368, 'location': 'Wilmington, VT'}
# {'company_id': 56119363, 'location': 'Woodlyn, PA'}
# {'company_id': 2562, 'location': 'Auburn, MI'}
# {'company_id': 1009, 'location': 'Yorktown Heights, NY'}
# {'company_id': 14542824, 'location': 'Le Mars, IA'}
# {'company_id': 1945473, 'location': 'Cordova, AK'}
# {'company_id': 30755, 'location': 'Paramus, NJ'}
# {'company_id': 550530, 'location': 'Stephenville, TX'}
# {'company_id': 1901345, 'location': 'Excelsior, MN'}
# {'company_id': 33278075, 'location': 'Doral, FL'}
# {'company_id': 483961, 'location': 'Longview, TX'}
# {'company_id': 9185, 'location': 'Moon, PA'}
# {'company_id': 777243, 'location': 'Sayreville, NJ'}
# {'company_id': 1867264, 'location': 'Greenfield, MA'}
# {'company_id': 32727, 'location': 'East St Louis, IL'}
# {'company_id': 71904349, 'location': 'Port Washington, WI'}
# {'company_id': 2121817, 'location': 'Jonesville, MI'}
# {'company_id': 34218836, 'location': 'Cottonwood, AZ'}
# {'company_id': 6913, 'location': 'Garden City, MI'}
# {'company_id': 1681, 'location': 'Faison, NC'}
# {'company_id': 217338, 'location': 'Kansas City, KS'}
# {'company_id': 10420321, 'location': 'Northbrook, IL'}
# {'company_id': 6913, 'location': 'Russells Point, OH'}
# {'company_id': 16733, 'location': 'Springfield-Branson, Missouri Area'}
# {'company_id': 2700167, 'location': 'Disputanta, VA'}
# {'company_id': 56042106, 'location': 'Telford, PA'}
# {'company_id': 14317, 'location': 'Niagara Falls, NY'}
# {'company_id': 10769, 'location': 'Beeville, TX'}
# {'company_id': 35561194, 'location': 'Matthews, NC'}
# {'company_id': 20573, 'location': 'Federal Way, WA'}
# {'company_id': 17233, 'location': 'Conshohocken, PA'}
# {'company_id': 3002336, 'location': 'Honolulu, HI'}
# {'company_id': 14542824, 'location': 'Newport, VT'}
# {'company_id': 1353, 'location': 'Bloomfield, CT'}
# {'company_id': 1881, 'location': 'Endicott, NY'}
# {'company_id': 230463, 'location': 'Free Home, GA'}
# {'company_id': 14113, 'location': 'Tucker, GA'}
# {'company_id': 220336, 'location': 'Monterey, CA'}
# {'company_id': 26283799, 'location': 'West Reading, PA'}
# {'company_id': 2343541, 'location': 'Western, NY'}
# {'company_id': 283807, 'location': 'Aventura, FL'}
# {'company_id': 38605, 'location': 'Grand Rapids, MI'}
# {'company_id': 1703, 'location': 'Riverdale Park, MD'}
# {'company_id': 33282143, 'location': 'Moonachie, NJ'}
# {'company_id': 2193256, 'location': 'Stockbridge, GA'}
# {'company_id': 64259963, 'location': 'Davidson, NC'}
# {'company_id': 12890, 'location': 'Ammon, ID'}
# {'company_id': 1851642, 'location': 'Lake County, IL'}
# {'company_id': 3493, 'location': 'Oakdale, CA'}
# {'company_id': 13626, 'location': 'Cherry Hill, NJ'}
# {'company_id': 2496705, 'location': 'Pasadena, TX'}
# {'company_id': 884316, 'location': 'Hesston, KS'}
# {'company_id': 9499, 'location': 'Greater Clarksville Area'}
# {'company_id': 2087, 'location': 'Greensboro, NC'}
# {'company_id': 3743186, 'location': 'Ottawa, KS'}
# {'company_id': 407222, 'location': 'Oregon, United States'}
# {'company_id': 11311, 'location': 'Golden, CO'}
# {'company_id': 162513, 'location': 'Boston Heights, OH'}
# {'company_id': 8437, 'location': 'Bowling Green, OH'}
# {'company_id': 11088832, 'location': 'Columbus, IN'}
# {'company_id': 11056, 'location': 'Dexter, MI'}
# {'company_id': 9185, 'location': 'Jackson, MS'}
# {'company_id': 508963, 'location': 'Lynn, MA'}
# {'company_id': 9570, 'location': 'Baltimore County, MD'}
# {'company_id': 82812960, 'location': 'Mount Vernon, WA'}
# {'company_id': 6913, 'location': 'Niles, MI'}
# {'company_id': 617793, 'location': 'Middletown, OH'}
# {'company_id': 3625, 'location': 'Downey, CA'}
# {'company_id': 162724, 'location': 'South Dakota, United States'}
# {'company_id': 167757, 'location': 'Gretna, NE'}
# {'company_id': 1235, 'location': 'Fort Morgan, CO'}
# {'company_id': 808034, 'location': 'St Joseph, MI'}
# {'company_id': 5064123, 'location': 'Norwich, CT'}
# {'company_id': 24787024, 'location': 'Nokomis, FL'}
# {'company_id': 11818084, 'location': 'Sulphur, OK'}
# {'company_id': 1297738, 'location': 'Union, NJ'}
# {'company_id': 32380, 'location': 'Bargersville, IN'}
# {'company_id': 14392959, 'location': 'Katy, TX'}
# {'company_id': 10420321, 'location': 'Madison, CT'}
# {'company_id': 62923, 'location': 'Dunn, NC'}
# {'company_id': 77499, 'location': 'Glen Burnie, MD'}
# {'company_id': 35504188, 'location': 'Irving, TX'}
# {'company_id': 5968, 'location': 'Macon, GA'}
# {'company_id': 1235, 'location': 'Bartonville, TX'}
# {'company_id': 66716570, 'location': 'Manlius, NY'}
# {'company_id': 89877420, 'location': 'Denver City, UT'}
# {'company_id': 6234, 'location': 'Stilwell, OK'}
# {'company_id': 3764607, 'location': 'Imperial, CA'}
# {'company_id': 497515, 'location': 'Oberlin, OH'}
# {'company_id': 299305, 'location': 'Turners Falls, MA'}
# {'company_id': 4075, 'location': 'Wellesley, MA'}
# {'company_id': 162724, 'location': 'West Virginia, United States'}
# {'company_id': 32727, 'location': 'Wisconsin Rapids, WI'}
# {'company_id': 2664556, 'location': 'Skowhegan, ME'}
# {'company_id': 72092703, 'location': 'Wisconsin, United States'}
# {'company_id': 163741, 'location': 'Yaphank, NY'}
# {'company_id': 12601, 'location': 'Yakima, WA'}
# {'company_id': 9170, 'location': 'Ennis, TX'}
# {'company_id': 3269, 'location': 'Mooresville, IN'}
# {'company_id': 2646, 'location': 'Mount Pleasant, WI'}
# {'company_id': 28209, 'location': 'Dublin, OH'}
# {'company_id': 3781515, 'location': 'Henrico, VA'}
# {'company_id': 884316, 'location': 'Farmers Branch, TX'}
# {'company_id': 28597931, 'location': 'Canton, MA'}
# {'company_id': 2737970, 'location': 'Greenwood, IN'}
# {'company_id': 5499736, 'location': 'Iowa, United States'}
# {'company_id': 165716, 'location': 'Dresden, TN'}
# {'company_id': 93254, 'location': 'Freeland, MI'}
# {'company_id': 22132, 'location': 'Kuna, ID'}
# {'company_id': 66278935, 'location': 'Avon Lake, OH'}
# {'company_id': 57978, 'location': 'Carthage, MO'}
# {'company_id': 2736008, 'location': 'Kingston, PA'}
# {'company_id': 2738186, 'location': 'Elizabethtown, PA'}
# {'company_id': 13386, 'location': 'Manhattan Beach, CA'}
# {'company_id': 11834, 'location': 'Edgewood, NY'}
# {'company_id': 165422, 'location': 'Bellingham, WA'}
# {'company_id': 52097, 'location': 'Fairbanks, AK'}
# {'company_id': 11240, 'location': 'Grand Junction, CO'}
# {'company_id': 81878, 'location': 'Headquarters, NJ'}
# {'company_id': 2646, 'location': 'Martinsville, VA'}
# {'company_id': 96180361, 'location': 'Longmont, CO'}
# {'company_id': 51637411, 'location': 'Mountain Home, TX'}
# {'company_id': 3658, 'location': 'Hershey, PA'}
# {'company_id': 2931, 'location': 'North Reading, MA'}
# {'company_id': 479080, 'location': 'Pooler, GA'}
# {'company_id': 667154, 'location': 'Quakertown, PA'}
# {'company_id': 13181, 'location': 'Rockville, MD'}
# {'company_id': 598372, 'location': 'Arlington Heights, IL'}
# {'company_id': 4167163, 'location': 'Greater Los Angeles, CA'}
# {'company_id': 40760236, 'location': 'Hanover, MA'}
# {'company_id': 74604, 'location': 'Roswell, GA'}
# {'company_id': 213746, 'location': 'Shrewsbury, MA'}
# {'company_id': 135342, 'location': 'Stuart, FL'}
# {'company_id': 2382849, 'location': 'Medford, OR'}
# {'company_id': 766058, 'location': 'Cumming, GA'}
# {'company_id': 988946, 'location': 'Hollywood, MD'}
# {'company_id': 25081, 'location': 'Alhambra, CA'}
# {'company_id': 166714, 'location': 'Greater Macon'}
# {'company_id': 1945473, 'location': 'Baker, WV'}
# {'company_id': 2646, 'location': 'Columbus, NE'}
# {'company_id': 71904349, 'location': 'Coventry, RI'}
# {'company_id': 11440, 'location': 'Souderton, PA'}
# {'company_id': 2910116, 'location': 'Antioch, IL'}
# {'company_id': 7119929, 'location': 'Sulphur Springs, TX'}
# {'company_id': 28647688, 'location': 'Fairfield, OH'}
# {'company_id': 18758749, 'location': 'Bardstown, KY'}
# {'company_id': 284165, 'location': 'North Royalton, OH'}
# {'company_id': 163480, 'location': 'Inwood, NY'}
# {'company_id': 884316, 'location': 'Valley City, OH'}
# {'company_id': 18162919, 'location': 'Wyoming, MN'}
# {'company_id': 162828, 'location': 'Avondale, LA'}
# {'company_id': 163578, 'location': 'Greater Lansing'}
# {'company_id': 2646, 'location': 'Fairfield, IA'}
# {'company_id': 1403, 'location': 'King George, VA'}
# {'company_id': 12273, 'location': 'Middletown, IA'}
# {'company_id': 71700526, 'location': 'Picayune, MS'}
# {'company_id': 2118349, 'location': 'Cypress, CA'}
# {'company_id': 57978, 'location': 'Ozark, AR'}
# {'company_id': 3570660, 'location': 'Park Ridge, IL'}
# {'company_id': 12965, 'location': 'Maiden, NC'}
# {'company_id': 1910700, 'location': 'Tipp City, OH'}
# {'company_id': 203053, 'location': 'Bear, DE'}
# {'company_id': 3671, 'location': 'Greenbrier, AR'}
# {'company_id': 266132, 'location': 'Arden Hills, MN'}
# {'company_id': 165472, 'location': 'Byron, GA'}
# {'company_id': 6592, 'location': 'Norfolk, VA'}
# {'company_id': 2247, 'location': 'Helena, MT'}
# {'company_id': 157237, 'location': 'Lumberton, NC'}
# {'company_id': 2721914, 'location': 'Baldwin City, KS'}
# {'company_id': 132173, 'location': 'Payson, UT'}
# {'company_id': 9759, 'location': 'Concord, NC'}
# {'company_id': 8280, 'location': 'Northampton, MA'}
# {'company_id': 1943848, 'location': 'Decatur, MS'}
# {'company_id': 2430668, 'location': 'Franklin, WI'}
# {'company_id': 9596847, 'location': 'Clovis, CA'}
# {'company_id': 9391120, 'location': 'Grand Prairie, TX'}
# {'company_id': 1478028, 'location': 'Newport News City County, VA'}
# {'company_id': 2748, 'location': 'Piscataway, NJ'}
# {'company_id': 52950123, 'location': 'Hephzibah, GA'}
# {'company_id': 57978, 'location': 'Huntsville, AR'}
# {'company_id': 2193256, 'location': 'Quincy, IL'}
# {'company_id': 142596, 'location': 'Mendota Heights, MN'}
# {'company_id': 14528, 'location': 'San Marino, CA'}
# {'company_id': 164527, 'location': 'Joliet, IL'}
# {'company_id': 10093812, 'location': 'Greater Philadelphia'}
# {'company_id': 9676, 'location': 'Clinton, OK'}
# {'company_id': 5553, 'location': 'Decatur, IL'}
# {'company_id': 10420321, 'location': 'Foxborough (Foxboro), MA'}
# {'company_id': 49648429, 'location': 'Iva, SC'}
# {'company_id': 1557409, 'location': 'Melville, NY'}
# {'company_id': 708393, 'location': 'Mesquite, Texas, United States'}
# {'company_id': 18819143, 'location': 'Moses Lake, WA'}
# {'company_id': 28052, 'location': 'Murray, KY'}
# {'company_id': 28612966, 'location': 'Kermit, TX'}
# {'company_id': 76500049, 'location': 'Peachtree City, GA'}
# {'company_id': 57947, 'location': 'Shaker Heights, OH'}
# {'company_id': 83051748, 'location': 'Germantown, WI'}
# {'company_id': 4723171, 'location': 'Groveland, MI'}
# {'company_id': 5058, 'location': 'Hunt Valley, MD'}
# {'company_id': 932563, 'location': 'Big Sky Meadow Village, MT'}
# {'company_id': 45575, 'location': 'College Park, MD'}
# {'company_id': 165422, 'location': 'Longview, WA'}
# {'company_id': 72416, 'location': 'Jackson, SC'}
# {'company_id': 1286891, 'location': 'Boynton, GA'}
# {'company_id': 1279359, 'location': 'Allentown, PA'}
# {'company_id': 284165, 'location': 'Canton, OH'}
# {'company_id': 92681040, 'location': 'Fair Lawn, NJ'}
# {'company_id': 12669435, 'location': 'Morgan, UT'}
# {'company_id': 6913, 'location': 'Norristown, PA'}
# {'company_id': 15139, 'location': 'Placerville, CA'}
# {'company_id': 4060, 'location': 'South Portland, ME'}
# {'company_id': 77301, 'location': 'Algonquin, IL'}
# {'company_id': 777243, 'location': 'Cleveland, OH'}
# {'company_id': 73974, 'location': 'Brookville, OH'}
# {'company_id': 71904349, 'location': 'Pleasant Prairie, WI'}
# {'company_id': 20894, 'location': 'Pasadena, CA'}
# {'company_id': 2650, 'location': 'Urbana, IL'}
# {'company_id': 46000, 'location': 'Waldorf, MD'}
# {'company_id': 1557409, 'location': 'Newburgh, NY'}
# {'company_id': 332596, 'location': 'Pottstown, PA'}
# {'company_id': 15317, 'location': 'Fairburn, GA'}
# {'company_id': 3617422, 'location': 'Shoreline, WA'}
# {'company_id': 3460, 'location': 'Harrisburg, PA'}
# {'company_id': 10083903, 'location': 'Kenosha, WI'}
# {'company_id': 77301, 'location': 'Abilene, TX'}
# {'company_id': 72758490, 'location': 'Salem, MA'}
# {'company_id': 36995, 'location': 'San Leandro, CA'}
# {'company_id': 481862, 'location': 'Fort Valley, GA'}
# {'company_id': 35640218, 'location': 'South Carolina, United States'}
# {'company_id': 6062532, 'location': 'Alexandria, LA'}
# {'company_id': 163025, 'location': 'Speedway, IN'}
# {'company_id': 77681076, 'location': 'Laguna Niguel, CA'}
# {'company_id': 166360, 'location': 'Sunrise, FL'}
# {'company_id': 436931, 'location': 'Huntington Station, NY'}
# {'company_id': 165034, 'location': 'Elma, NY'}
# {'company_id': 77301, 'location': 'Addison, TX'}
# {'company_id': 1379045, 'location': 'Landover, MD'}
# {'company_id': 7929696, 'location': 'Coon Rapids, MN'}
# {'company_id': 2646, 'location': 'Kingsport, TN'}
# {'company_id': 6233, 'location': 'Richmond, KY'}
# {'company_id': 598372, 'location': 'Streamwood, IL'}
# {'company_id': 2073870, 'location': 'Bergenfield, NJ'}
# {'company_id': 2584457, 'location': 'Sanford, FL'}
# {'company_id': 318785, 'location': 'Union, SC'}
# {'company_id': 11056, 'location': 'Lemoore, CA'}
# {'company_id': 6756178, 'location': 'Chelsea, MI'}
# {'company_id': 708393, 'location': 'Bradenton, FL'}
# {'company_id': 163763, 'location': 'Mecklenburg County, NC'}
# {'company_id': 660180, 'location': 'Queen Creek, AZ'}
# {'company_id': 80607, 'location': 'Smithtown, NY'}
# {'company_id': 1403, 'location': 'Rome, NY'}
# {'company_id': 2073870, 'location': 'Bristol County, MA'}
# {'company_id': 19107, 'location': 'Burlington, VT'}
# {'company_id': 1753550, 'location': 'Germantown, MD'}
# {'company_id': 162828, 'location': 'Atchison, KS'}
# {'company_id': 1268806, 'location': 'Oregon City, OR'}
# {'company_id': 25461, 'location': 'Lyon, MI'}
# {'company_id': 99816187, 'location': 'Petersburg, WV'}
# {'company_id': 10769, 'location': 'Texarkana, TX'}
# {'company_id': 1307665, 'location': 'Carpinteria, CA'}
# {'company_id': 1703, 'location': 'Brighton, CO'}
# {'company_id': 162912, 'location': 'Madison, WI'}
# {'company_id': 323296, 'location': 'Rockwall, TX'}
# {'company_id': 556848, 'location': 'Highlands Ranch, CO'}
# {'company_id': 144266, 'location': 'Prattville, AL'}
# {'company_id': 2646, 'location': 'Thief River Falls, MN'}
# {'company_id': 1837539, 'location': 'Rockford, IL'}
# {'company_id': 906762, 'location': 'Bartow, FL'}
# {'company_id': 3658, 'location': 'Mechanicsburg, PA'}
# {'company_id': 10653459, 'location': 'Palmetto, FL'}
# {'company_id': 11455, 'location': 'Wasco, OR'}
# {'company_id': 585138, 'location': 'Round Rock, TX'}
# {'company_id': 3706049, 'location': 'Cumberland, MD'}
# {'company_id': 48024, 'location': 'Deer Park, TX'}
# {'company_id': 884316, 'location': 'Ooltewah, TN'}
# {'company_id': 15440968, 'location': 'San Dimas, CA'}
# {'company_id': 163883, 'location': 'Westlake Village, CA'}
# {'company_id': 28647688, 'location': 'Fishersville, VA'}
# {'company_id': 259898, 'location': 'Wichita Falls, TX'}
# {'company_id': 1399, 'location': 'Collegeville, PA'}
# {'company_id': 3625, 'location': 'Seymour, IN'}
# {'company_id': 40894, 'location': 'Santa Clara County, CA'}
# {'company_id': 581027, 'location': 'Wilmington, NC'}
# {'company_id': 3706049, 'location': 'Mission Viejo, CA'}
# {'company_id': 163139, 'location': 'Walnut Creek, CA'}
# {'company_id': 581027, 'location': 'Hamilton, OH'}
# {'company_id': 6176, 'location': 'Winter Garden, FL'}
# {'company_id': 2219, 'location': 'Nogales, AZ'}
# {'company_id': 10420321, 'location': 'Round Lake, IL'}
# {'company_id': 16183163, 'location': 'Greater Corpus Christi Area'}
# {'company_id': 14191, 'location': 'Greater Dothan'}
# {'company_id': 8299, 'location': 'Cupertino, CA'}
# {'company_id': 1943848, 'location': 'Dripping Springs, TX'}
# {'company_id': 2875, 'location': 'Getzville, NY'}
# {'company_id': 6487, 'location': 'Matteson, IL'}
# {'company_id': 3180238, 'location': 'Petoskey, MI'}
# {'company_id': 15564, 'location': 'Robstown, TX'}
# {'company_id': 98514983, 'location': 'Hampton Roads, Virginia Metropolitan Area'}
# {'company_id': 21542, 'location': 'St Charles, MO'}
# {'company_id': 8602, 'location': 'Woodburn, OR'}
# {'company_id': 13658, 'location': 'Estacada, OR'}
# {'company_id': 8031, 'location': 'United States'}
# {'company_id': 25856, 'location': 'Vernon, WI'}
# {'company_id': 3252, 'location': 'Brooklyn, OH'}
# {'company_id': 97402272, 'location': 'Syosset, NY'}
# {'company_id': 14542824, 'location': 'Delta, CO'}
# {'company_id': 1703, 'location': 'Dallas, GA'}
# {'company_id': 15259054, 'location': 'Piqua, OH'}
# {'company_id': 2430668, 'location': 'Henderson, CO'}
# {'company_id': 2701866, 'location': 'Claypool, AZ'}
# {'company_id': 3534, 'location': 'Jal, NM'}
# {'company_id': 65294553, 'location': 'Lancaster, PA'}
# {'company_id': 37441, 'location': 'Merriam, KS'}
# {'company_id': 7963, 'location': 'Elmhurst, IL'}
# {'company_id': 2712059, 'location': 'Lindon, UT'}
# {'company_id': 67555, 'location': 'Oneonta, AL'}
# {'company_id': 25039398, 'location': 'Cape Canaveral, FL'}
# {'company_id': 28669777, 'location': 'Cameron, TX'}
# {'company_id': 10967, 'location': 'Tallassee, AL'}
# {'company_id': 1557409, 'location': 'Charleston, South Carolina, United States'}
# {'company_id': 14363, 'location': 'Somerville, NJ'}
# {'company_id': 157353, 'location': 'Upper St Clair, PA'}
# {'company_id': 70518420, 'location': 'Spokane Valley, WA'}
# {'company_id': 3099084, 'location': 'Cedar Lake, IN'}
# {'company_id': 31896, 'location': 'Stockton, IL'}
# {'company_id': 5750, 'location': 'Waldwick, NJ'}
# {'company_id': 660180, 'location': 'Oracle, AZ'}
# {'company_id': 11467712, 'location': 'Neptune, NJ'}
# {'company_id': 380752, 'location': 'West Sacramento, CA'}
# {'company_id': 85123, 'location': 'Moorhead, MN'}
# {'company_id': 602239, 'location': 'Morgantown, KY'}
# {'company_id': 814025, 'location': 'Charlotte, AR'}
# {'company_id': 164113, 'location': 'Hickory Hills, IL'}
# {'company_id': 1307, 'location': 'Merrimack, NH'}
# {'company_id': 2652881, 'location': 'Denver Metropolitan Area'}
# {'company_id': 15941879, 'location': 'Belmar, NJ'}
# {'company_id': 1603, 'location': 'Gaithersburg, MD'}
# {'company_id': 6738, 'location': 'Morgantown, WV'}
# {'company_id': 14459, 'location': 'Billings, MT'}
# {'company_id': 7795, 'location': 'Dover, NH'}
# {'company_id': 164200, 'location': 'Maplewood, MN'}
# {'company_id': 1703, 'location': 'Waterbury, CT'}
# {'company_id': 10341654, 'location': 'White House, TN'}
# {'company_id': 1668, 'location': 'White Marsh Station, MD'}
# {'company_id': 21667, 'location': 'Denison, IA'}
# {'company_id': 11695727, 'location': 'Medford, NY'}
# {'company_id': 435219, 'location': 'Skokie, IL'}
# {'company_id': 166572, 'location': 'Southern Pines, NC'}
# {'company_id': 808034, 'location': 'Indianapolis, IN'}
# {'company_id': 3356761, 'location': 'Riverside, MO'}
# {'company_id': 44580, 'location': 'West Hartford, CT'}
# {'company_id': 2908367, 'location': 'Charleston, IL'}
# {'company_id': 77301, 'location': 'Mentor, OH'}
# {'company_id': 683310, 'location': 'Ames, IA'}
# {'company_id': 777243, 'location': 'Islip, NY'}
# {'company_id': 45091, 'location': 'Plaquemine, LA'}
# {'company_id': 3706049, 'location': 'Washington, NC'}
# {'company_id': 32478, 'location': 'King City, MO'}
# {'company_id': 5343, 'location': 'Cottondale, AL'}
# {'company_id': 74708, 'location': 'Pine Brook, NJ'}
# {'company_id': 5905495, 'location': 'Buffalo-Niagara Falls Area'}
# {'company_id': 856720, 'location': 'National City, CA'}
# {'company_id': 8359, 'location': 'Danvers, MA'}
# {'company_id': 136115, 'location': 'Hoover, AL'}
# {'company_id': 4764, 'location': 'Sausalito, CA'}
# {'company_id': 1302410, 'location': 'Albany, NY'}
# {'company_id': 411814, 'location': 'Chaska, MN'}
# {'company_id': 165697, 'location': 'Glenwood Springs, CO'}
# {'company_id': 71904349, 'location': 'Southampton, NY'}
# {'company_id': 8437, 'location': 'Alamance, NC'}
# {'company_id': 88289095, 'location': 'East Hanover, NJ'}
# {'company_id': 3671, 'location': 'McAllen, TX'}
# {'company_id': 981412, 'location': 'Capitan, NM'}
# {'company_id': 65294553, 'location': 'Melrose Park, IL'}
# {'company_id': 71904349, 'location': 'Naples, FL'}
# {'company_id': 315817, 'location': 'Sun Valley, CA'}
# {'company_id': 79560, 'location': 'Warwick, RI'}
# {'company_id': 3570660, 'location': 'Weatherford, TX'}
# {'company_id': 26873, 'location': 'West Covina, CA'}
# {'company_id': 3242, 'location': 'Franklin, VA'}
# {'company_id': 26923, 'location': 'Rochester, MN'}
# {'company_id': 324747, 'location': 'Yuma, AZ'}
# {'company_id': 580089, 'location': 'Freeburg, IL'}
# {'company_id': 53708, 'location': 'Fremont, NE'}
# {'company_id': 10141, 'location': 'Jackson, NJ'}
# {'company_id': 10420321, 'location': 'Hudson, OH'}
# {'company_id': 80911138, 'location': 'Marengo, IL'}
# {'company_id': 693067, 'location': 'Pleasantville, NJ'}
# {'company_id': 6215, 'location': 'Santa Ana, CA'}
# {'company_id': 5235, 'location': 'Kenilworth, NJ'}
# {'company_id': 1016, 'location': 'Georgia, United States'}
# {'company_id': 3706049, 'location': 'Hamden, CT'}
# {'company_id': 1482552, 'location': 'Addison, IL'}
# {'company_id': 1235, 'location': 'North Las Vegas, NV'}
# {'company_id': 1307, 'location': 'Smithfield, RI'}
# {'company_id': 9401140, 'location': 'Tomball, TX'}
# {'company_id': 316602, 'location': 'Whippleville, NY'}
# {'company_id': 23182, 'location': 'Boardman, OH'}
# {'company_id': 73013724, 'location': 'Burlington, NC'}
# {'company_id': 3626, 'location': 'Dickson, TN'}
# {'company_id': 16240930, 'location': 'Neenah, WI'}
# {'company_id': 254060, 'location': 'Jersey, GA'}
# {'company_id': 164527, 'location': 'Dayton, TN'}
# {'company_id': 5396873, 'location': 'Fort George G. Meade, MD'}
# {'company_id': 11227630, 'location': 'Happy Valley, OR'}
# {'company_id': 28332, 'location': 'Mississippi State, MS'}
# {'company_id': 2857649, 'location': 'Alma, MI'}
# {'company_id': 28647688, 'location': 'Richlands, VA'}
# {'company_id': 11056, 'location': 'Tuscaloosa, AL'}
# {'company_id': 9286, 'location': 'Owings Mills, MD'}
# {'company_id': 66264380, 'location': 'Oak Creek, WI'}
# {'company_id': 3411, 'location': 'Green Bay, WI'}
# {'company_id': 12534, 'location': 'Clinton, NJ'}
# {'company_id': 2560957, 'location': 'Metro Jacksonville'}
# {'company_id': 85672209, 'location': 'Raritan, NJ'}
# {'company_id': 2113831, 'location': 'Fairfax, VA'}
# {'company_id': 74718032, 'location': 'West Columbia, SC'}
# {'company_id': 48915, 'location': 'Waller, TX'}
# {'company_id': 9177279, 'location': 'Damascus, MD'}
# {'company_id': 10854676, 'location': 'Alden, NY'}
# {'company_id': 28647688, 'location': 'St Peters, MO'}
# {'company_id': 6265, 'location': 'Halethorpe, MD'}
# {'company_id': 6381495, 'location': 'Temecula, CA'}
# {'company_id': 1042230, 'location': 'Timonium, MD'}
# {'company_id': 48024, 'location': 'Alvin, TX'}
# {'company_id': 1211063, 'location': 'Madill, OK'}
# {'company_id': 25856, 'location': 'Westland, MI'}
# {'company_id': 3676298, 'location': 'Portland, TX'}
# {'company_id': 71904349, 'location': 'Conover, NC'}
# {'company_id': 10859727, 'location': 'Glenview, IL'}
# {'company_id': 1103, 'location': 'Minnetonka, MN'}
# {'company_id': 1047203, 'location': 'Pleasant Hill, CA'}
# {'company_id': 67539665, 'location': 'Weston, FL'}
# {'company_id': 2203697, 'location': 'Oroville, CA'}
# {'company_id': 808034, 'location': 'Rancho Mirage, CA'}
# {'company_id': 14255, 'location': 'Channahon, IL'}
# {'company_id': 25963, 'location': 'Avenel, NJ'}
# {'company_id': 23279, 'location': 'Devens, MA'}
# {'company_id': 11825945, 'location': 'Elmer, NJ'}
# {'company_id': 936584, 'location': 'Benicia, CA'}
# {'company_id': 72483, 'location': 'Flowood, MS'}
# {'company_id': 17283, 'location': 'Greater Birmingham, Alabama Area'}
# {'company_id': 30507, 'location': 'Milwaukee, WI'}
# {'company_id': 2788204, 'location': 'North Canton, OH'}
# {'company_id': 2646, 'location': 'Marlin, TX'}
# {'company_id': 22309011, 'location': 'Ballwin, MO'}
# {'company_id': 6913, 'location': 'Minerva, OH'}
# {'company_id': 166331, 'location': 'Northville, MI'}
# {'company_id': 15434, 'location': 'Purcell, OK'}
# {'company_id': 2646, 'location': 'Douglas, GA'}
# {'company_id': 25076, 'location': 'Rochester, NY'}
# {'company_id': 14140, 'location': 'Sparrows Point, MD'}
# {'company_id': 11074186, 'location': 'Springdale, AR'}
# {'company_id': 14542824, 'location': 'Albany, OR'}
# {'company_id': 166837, 'location': 'York, PA'}
# {'company_id': 1344, 'location': 'Torrance, CA'}
# {'company_id': 10035810, 'location': 'Bolingbrook, IL'}
# {'company_id': 76640333, 'location': 'Fresno, CA'}
# {'company_id': 9652, 'location': 'Troy, OH'}
# {'company_id': 10954, 'location': 'Tunnel Hill, GA'}
# {'company_id': 166680, 'location': 'Arlington, TX'}
# {'company_id': 1103, 'location': 'Alpharetta, GA'}
# {'company_id': 81480274, 'location': 'Denver, IN'}
# {'company_id': 1666657, 'location': 'Delray Beach, FL'}
# {'company_id': 3570660, 'location': 'Avon, OH'}
# {'company_id': 13309, 'location': 'Alexandria City County, VA'}
# {'company_id': 11818084, 'location': 'Lawton Area'}
# {'company_id': 4167, 'location': 'Palm Desert, CA'}
# {'company_id': 6176, 'location': 'Santa Fe Springs, CA'}
# {'company_id': 2646, 'location': 'Baxter, MN'}
# {'company_id': 2383821, 'location': 'Trenton, OH'}
# {'company_id': 14658457, 'location': 'Cofield, NC'}
# {'company_id': 598521, 'location': 'Walsenburg, CO'}
# {'company_id': 1947704, 'location': 'Loveland, CO'}
# {'company_id': 5755, 'location': 'Alburtis, PA'}
# {'company_id': 17947238, 'location': 'Greater Seattle Area'}
# {'company_id': 18506580, 'location': 'Taylorville, IL'}
# {'company_id': 74031056, 'location': 'Virginia, MN'}
# {'company_id': 3469, 'location': 'Anderson, SC'}
# {'company_id': 15218920, 'location': 'Greater Wilmington Area'}
# {'company_id': 76171420, 'location': 'Mount Pleasant, PA'}
# {'company_id': 74985, 'location': 'Castle Rock, CO'}
# {'company_id': 162787, 'location': 'Morrison, TN'}
# {'company_id': 41004, 'location': 'Raleigh, NC'}
# {'company_id': 570101, 'location': 'Beltsville, MD'}
# {'company_id': 16733, 'location': 'Destin, FL'}
# {'company_id': 5343, 'location': 'Harahan, LA'}
# {'company_id': 48024, 'location': 'La Porte, TX'}
# {'company_id': 3411, 'location': 'Mogadore, OH'}
# {'company_id': 3309115, 'location': 'New Providence, NJ'}
# {'company_id': 62570725, 'location': 'Morristown, TN'}
# {'company_id': 28649423, 'location': 'Nicholasville, KY'}
# {'company_id': 9814, 'location': 'Chelmsford, MA'}
# {'company_id': 164682, 'location': 'El Dorado, AR'}
# {'company_id': 2646, 'location': 'Lexington, NE'}
# {'company_id': 3936609, 'location': 'Madison, TN'}
# {'company_id': 1122744, 'location': 'North East, MD'}
# {'company_id': 86041588, 'location': 'Long Branch, NJ'}
# {'company_id': 16182319, 'location': 'Shawano, WI'}
# {'company_id': 2646, 'location': 'Hopkinsville, KY'}
# {'company_id': 808034, 'location': 'Enumclaw, WA'}
# {'company_id': 1211063, 'location': 'London, OH'}
# {'company_id': 4453, 'location': 'Spring Hill, TN'}
# {'company_id': 1471368, 'location': 'Vermont, United States'}
# {'company_id': 22756, 'location': 'Wakefield, MA'}
# {'company_id': 142755, 'location': 'Naperville, IL'}
# {'company_id': 85153, 'location': 'Portland, ME'}
# {'company_id': 166714, 'location': 'Port Orange, FL'}
# {'company_id': 86017472, 'location': 'Vance, AL'}
# {'company_id': 1344, 'location': 'Ohio, NY'}
# {'company_id': 27020, 'location': 'Greater Richmond Region'}
# {'company_id': 18506580, 'location': 'Lancaster, SC'}
# {'company_id': 2227, 'location': 'Lexington, MA'}
# {'company_id': 167757, 'location': 'Stillwater, MN'}
# {'company_id': 862993, 'location': 'Takoma Park, MD'}
# {'company_id': 4711, 'location': 'Logan, UT'}
# {'company_id': 11229, 'location': 'Sharonville, OH'}
# {'company_id': 33515668, 'location': 'East Norriton, PA'}
# {'company_id': 91161992, 'location': 'Lake Havasu City, AZ'}
# {'company_id': 107365, 'location': 'Lakeland, FL'}
# {'company_id': 8852000, 'location': 'New Century, KS'}
# {'company_id': 104405, 'location': 'Cottleville, MO'}
# {'company_id': 45716, 'location': 'Death Valley, CA'}
# {'company_id': 3240, 'location': 'Cedar Falls, IA'}
# {'company_id': 163139, 'location': 'Austin, Texas Metropolitan Area'}
# {'company_id': 166551, 'location': 'Finney County, KS'}
# {'company_id': 40711210, 'location': 'Glassboro, NJ'}
# {'company_id': 86041588, 'location': 'Amityville, NY'}
# {'company_id': 406004, 'location': 'Manchester, NH'}
# {'company_id': 28893, 'location': 'North Riverside, IL'}
# {'company_id': 6798963, 'location': 'Jeannette, PA'}
# {'company_id': 1557409, 'location': 'Los Angeles Metropolitan Area'}
# {'company_id': 6913, 'location': 'Reedley, CA'}
# {'company_id': 2532, 'location': 'Ripon, WI'}
# {'company_id': 68894323, 'location': 'Salamanca, NY'}
# {'company_id': 3706049, 'location': 'Aberdeen, WA'}
# {'company_id': 89989306, 'location': 'Bal Harbour, FL'}
# {'company_id': 2162, 'location': 'Tolleson, AZ'}
# {'company_id': 10854676, 'location': 'Trenton, GA'}
# {'company_id': 4060, 'location': 'West Jefferson, OH'}
# {'company_id': 3967883, 'location': 'Huntsville, AL'}
# {'company_id': 49105, 'location': 'Lansdale, PA'}
# {'company_id': 2646, 'location': 'Rapid City, SD'}
# {'company_id': 13353, 'location': 'Baraboo, WI'}
# {'company_id': 29331, 'location': 'Greater Fort Wayne'}
# {'company_id': 81929583, 'location': 'Murrysville, PA'}
# {'company_id': 775397, 'location': 'Wixom, MI'}
# {'company_id': 10517709, 'location': 'Bayport, NY'}
# {'company_id': 2743, 'location': 'East Palo Alto, CA'}
# {'company_id': 65361091, 'location': 'Indian Head, MD'}
# {'company_id': 167757, 'location': 'Winchester, TN'}
# {'company_id': 6449530, 'location': 'Brisbane, CA'}
# {'company_id': 17937, 'location': 'Campbell, FL'}
# {'company_id': 2162, 'location': 'La Vergne, TN'}
# {'company_id': 98116883, 'location': "O'Fallon, MO"}
# {'company_id': 49042, 'location': 'Boerne, TX'}
# {'company_id': 1611410, 'location': 'Winn, MI'}
# {'company_id': 164249, 'location': 'Austin Township, MN'}
# {'company_id': 90198358, 'location': 'Beckley, WV'}
# {'company_id': 925902, 'location': 'Wyoming, United States'}
# {'company_id': 598372, 'location': 'Bartlett, IL'}
# {'company_id': 163253, 'location': 'Lino Lakes, MN'}
# {'company_id': 29622, 'location': 'Grand Rapids metropolitan area, MI'}
# {'company_id': 163490, 'location': 'Rothschild, WI'}
# {'company_id': 5112, 'location': 'Elmendorf, TX'}
# {'company_id': 165441, 'location': 'Salisbury, MD'}
# {'company_id': 2664556, 'location': 'Jacksonville, IL'}
# {'company_id': 71575605, 'location': 'Jackson, GA'}
# {'company_id': 28978143, 'location': 'Needham, MA'}
# {'company_id': 2033586, 'location': 'Poughkeepsie, NY'}
# {'company_id': 7032, 'location': 'Riverdale, UT'}
# {'company_id': 1552579, 'location': 'Rochelle, IL'}
# {'company_id': 7795, 'location': 'Williamsburg, VA'}
# {'company_id': 11522, 'location': 'Kaysville, UT'}
# {'company_id': 459969, 'location': 'Orleans, IN'}
# {'company_id': 12446, 'location': 'Corinth, MS'}
# {'company_id': 5294, 'location': 'Fort Mill, SC'}
# {'company_id': 34218836, 'location': 'Maine, United States'}
# {'company_id': 12890, 'location': 'East Grand Forks, MN'}
# {'company_id': 10420321, 'location': 'Kearny, NJ'}
# {'company_id': 164527, 'location': 'Manteca, CA'}
# {'company_id': 7795, 'location': 'Mount Vernon, OH'}
# {'company_id': 1344, 'location': 'McCook, IL'}
# {'company_id': 16157480, 'location': 'New Richmond, WI'}
# {'company_id': 3025562, 'location': 'Birmingham, MI'}
# {'company_id': 808034, 'location': 'Brunswick, GA'}
# {'company_id': 36749, 'location': 'Chicago Ridge, IL'}
# {'company_id': 14542824, 'location': 'Hawaii, United States'}
# {'company_id': 269675, 'location': 'Jupiter, FL'}
# {'company_id': 982614, 'location': 'Emeryville, CA'}
# {'company_id': 3216326, 'location': 'North Naples, FL'}
# {'company_id': 15494986, 'location': 'Broomfield, CO'}
# {'company_id': 80829889, 'location': 'Gibsonia, PA'}
# {'company_id': 44730, 'location': 'Lake Forest, IL'}
# {'company_id': 165416, 'location': 'Touchet, WA'}
# {'company_id': 7795, 'location': 'Wesley Chapel, FL'}
# {'company_id': 808034, 'location': 'Fairfield, CT'}
# {'company_id': 166572, 'location': 'Fort Gratiot, MI'}
# {'company_id': 14070878, 'location': 'Westby, WI'}
# {'company_id': 10769, 'location': 'Tyler, TX'}
# {'company_id': 18036, 'location': 'Scottsdale, AZ'}
# {'company_id': 45970, 'location': 'Bluffton, SC'}
# {'company_id': 6609, 'location': 'Fort Myer Heights, VA'}
# {'company_id': 2073870, 'location': 'Passaic, NJ'}
# {'company_id': 18425303, 'location': 'Maryville, TN'}
# {'company_id': 15979299, 'location': 'Draper, UT'}
# {'company_id': 2981, 'location': 'Mount Pleasant, TN'}
# {'company_id': 9732, 'location': 'Olive Branch, MS'}
# {'company_id': 12534, 'location': 'Fenton, MO'}
# {'company_id': 45346, 'location': 'Cleveland, GA'}
# {'company_id': 162724, 'location': 'New Hampshire, United States'}
# {'company_id': 35504, 'location': 'Loomis, CA'}
# {'company_id': 7929696, 'location': 'Pennsville, NJ'}
# {'company_id': 2646, 'location': 'Ashland, WI'}
# {'company_id': 5574, 'location': 'Nampa, ID'}
# {'company_id': 18506580, 'location': 'Pocatello, ID'}
# {'company_id': 3697729, 'location': 'Winter Haven, FL'}
# {'company_id': 4721, 'location': 'Brea, CA'}
# {'company_id': 13074, 'location': 'Gig Harbor, WA'}
# {'company_id': 71904349, 'location': 'Branford, CT'}
# {'company_id': 7795, 'location': 'Denton, TX'}
# {'company_id': 11229, 'location': 'Lewisville, TX'}
# {'company_id': 18353, 'location': 'Nebraska City, NE'}
# {'company_id': 10420321, 'location': 'Lincoln Park, NJ'}
# {'company_id': 42793, 'location': 'North Adams, MA'}
# {'company_id': 869141, 'location': 'Tennessee, United States'}
# {'company_id': 295604, 'location': 'Turlock, CA'}
# {'company_id': 1103, 'location': 'Arlington, MA'}
# {'company_id': 2252, 'location': 'Cranston, RI'}
# {'company_id': 1680, 'location': 'Norwalk, CA'}
# {'company_id': 10517709, 'location': 'Holbrook, NY'}
# {'company_id': 1286891, 'location': 'Sidney, MT'}
# {'company_id': 963770, 'location': 'Morton Grove, IL'}
# {'company_id': 28974109, 'location': 'Beavercreek, OH'}
# {'company_id': 1945473, 'location': 'Redlands, CA'}
# {'company_id': 3047, 'location': 'New Kensington, PA'}
# {'company_id': 68578869, 'location': 'Huntington Beach, CA'}
# {'company_id': 71904349, 'location': 'Salem, OH'}
# {'company_id': 163139, 'location': 'Rawlins, WY'}
# {'company_id': 85123, 'location': 'Buda, TX'}
# {'company_id': 808034, 'location': 'Fremont, California, United States'}
# {'company_id': 2646, 'location': 'Seminole, TX'}
# {'company_id': 360308, 'location': 'South Beloit, IL'}
# {'company_id': 26923, 'location': 'New Prague, MN'}
# {'company_id': 4674, 'location': 'University Park, IL'}
# {'company_id': 3570660, 'location': 'Woodridge, IL'}
# {'company_id': 10420321, 'location': 'Carrollton, GA'}
# {'company_id': 19107, 'location': 'Colchester, VT'}
# {'company_id': 104405, 'location': 'Sequim, WA'}
# {'company_id': 327513, 'location': 'Wenona, IL'}
# {'company_id': 56670, 'location': 'La Verne, CA'}
# {'company_id': 40707710, 'location': 'Newington, CT'}
# {'company_id': 162224, 'location': 'Oxford, MI'}
# {'company_id': 167757, 'location': 'Waxhaw, NC'}
# {'company_id': 1900, 'location': 'Clear Lake, IA'}
# {'company_id': 18506580, 'location': 'Newton Centre, MA'}
# {'company_id': 7795, 'location': 'Southaven, MS'}
# {'company_id': 162536, 'location': 'Lowell, AR'}
# {'company_id': 65907467, 'location': 'Waycross, GA'}
# {'company_id': 3009549, 'location': 'New Mexico, United States'}
# {'company_id': 140581, 'location': 'Corona, CA'}
# {'company_id': 1463, 'location': 'Coraopolis, PA'}
# {'company_id': 204770, 'location': 'Elgin, SC'}
# {'company_id': 9308035, 'location': 'Palm Bay, FL'}
# {'company_id': 20723, 'location': 'Irondale, AL'}
# {'company_id': 53713122, 'location': 'Boston Run, PA'}
# {'company_id': 47843, 'location': 'Pella, IA'}
# {'company_id': 166774, 'location': 'Colonial Heights, VA'}
# {'company_id': 11056, 'location': 'Lebanon, KY'}
# {'company_id': 30755, 'location': 'Strafford County, NH'}
# {'company_id': 86041588, 'location': 'Riverhead, NY'}
# {'company_id': 2480405, 'location': 'Blacksburg, SC'}
# {'company_id': 2736008, 'location': 'Davenport, IA'}
# {'company_id': 743843, 'location': 'Santa Barbara County, CA'}
# {'company_id': 1703, 'location': 'Taunton, MA'}
# {'company_id': 894572, 'location': 'Fort Belvoir, VA'}
# {'company_id': 9862, 'location': 'Dedham, MA'}
# {'company_id': 3570660, 'location': 'East Brunswick, NJ'}
# {'company_id': 94355, 'location': 'Fort Worth, TX'}
# {'company_id': 49042, 'location': 'Lakewood, NJ'}
# {'company_id': 9499, 'location': 'Greater Tuscaloosa Area'}
# {'company_id': 72483, 'location': 'Des Moines, WA'}
# {'company_id': 16163783, 'location': 'Englewood, OH'}
# {'company_id': 2743, 'location': 'Fishers, IN'}
# {'company_id': 15139, 'location': 'Flagstaff, AZ'}
# {'company_id': 73202971, 'location': 'Clermont, FL'}
# {'company_id': 3653, 'location': 'Morrisville, NC'}
# {'company_id': 35716480, 'location': 'La Marque, TX'}
# {'company_id': 12820, 'location': 'Mount Airy, NC'}
# {'company_id': 660180, 'location': 'Bryant, AR'}
# {'company_id': 18860134, 'location': 'Ironwood, MI'}
# {'company_id': 163883, 'location': 'Teton Village, WY'}
# {'company_id': 28332, 'location': 'Walla Walla, WA'}
# ...
# {'company_id': 2445, 'location': 'Bridgeport, WV'}
# {'company_id': 4872007, 'location': 'Livingston, NJ'}
# {'company_id': 1909139, 'location': 'Keller, TX'}
# {'company_id': 77301, 'location': 'Shorewood, IL'}
# {'company_id': 2381, 'location': 'Battle Creek, MI'}
# {'company_id': 808034, 'location': 'Castro Valley, CA'}
# {'company_id': 164200, 'location': 'Greenville, TX'}
# {'company_id': 2646, 'location': 'Grove City, OH'}
# {'company_id': 1908498, 'location': 'New Port Richey, FL'}
# {'company_id': 4324, 'location': 'Caddo Mills, TX'}
# {'company_id': 165109, 'location': 'Willis, TX'}
# {'company_id': 38015, 'location': 'Tallahassee, FL'}
# {'company_id': 3706049, 'location': 'Easton, PA'}
# {'company_id': 4798, 'location': 'Ashland, VA'}
# {'company_id': 1271305, 'location': 'La Crosse, Wisconsin, United States'}
# {'company_id': 11419, 'location': 'Poway, CA'}
# {'company_id': 2203697, 'location': 'Rosedale, MD'}
# {'company_id': 14542824, 'location': 'Laconia, NH'}
# {'company_id': 65294553, 'location': 'Lorton, VA'}
# {'company_id': 28132450, 'location': 'Gadsden, AL'}
# {'company_id': 18777798, 'location': 'Germany'}
# {'company_id': 96657925, 'location': 'Midland-Odessa Area'}
# {'company_id': 18506580, 'location': 'Big Stone Gap, VA'}
# {'company_id': 26569406, 'location': 'South Milwaukee, WI'}
# {'company_id': 3270028, 'location': 'Lathrop, CA'}
# {'company_id': 2973906, 'location': 'Newport News, VA'}
# {'company_id': 71904349, 'location': 'Waukesha, WI'}
# {'company_id': 917557, 'location': 'Latham, NY'}
# {'company_id': 3711368, 'location': 'Lone Tree, CO'}
# {'company_id': 164880, 'location': 'Watsonville, CA'}
# {'company_id': 164249, 'location': 'West Des Moines, IA'}
# {'company_id': 1320601, 'location': 'Chevy Chase, MD'}
# {'company_id': 140581, 'location': 'Warren, MA'}
# {'company_id': 1087079, 'location': 'Elmira, NY'}
# {'company_id': 6176, 'location': 'East Dennis, MA'}
# {'company_id': 7701, 'location': 'Omaha, NE'}
# {'company_id': 49223, 'location': 'Greater Yuma, AZ Area'}
# {'company_id': 1526, 'location': 'Ankeny, IA'}
# {'company_id': 537246, 'location': 'Concord, CA'}
# {'company_id': 49042, 'location': 'Plantation, FL'}
# {'company_id': 6913, 'location': 'Harrison, MI'}
# {'company_id': 17885819, 'location': 'Valley City, ND'}
# {'company_id': 4181808, 'location': 'Boydton, VA'}
# {'company_id': 5343, 'location': 'Geneva, AL'}
# {'company_id': 18860134, 'location': 'Marina del Rey, CA'}
# {'company_id': 5001, 'location': 'Short Hills, NJ'}
# {'company_id': 15897635, 'location': 'Malden, MA'}
# {'company_id': 2646, 'location': 'Canyon, TX'}
# {'company_id': 77301, 'location': 'Nederland, TX'}
# {'company_id': 2646, 'location': 'Henderson, KY'}
# {'company_id': 922640, 'location': 'New Paltz, NY'}
# {'company_id': 10035810, 'location': 'West Point, VA'}
# {'company_id': 5666, 'location': 'Youngstown, OH'}
# {'company_id': 25371, 'location': 'Mobile Metropolitan Area'}
# {'company_id': 73013724, 'location': 'Lawton, OK'}
# {'company_id': 7600286, 'location': 'Ravenswood, WV'}
# {'company_id': 808034, 'location': 'Greenville, SC'}
# {'company_id': 28149455, 'location': 'Burlington, NJ'}
# {'company_id': 25552, 'location': 'Holton, KS'}
# {'company_id': 242230, 'location': 'Hudson Waterfront, NJ'}
# {'company_id': 2203697, 'location': 'Alameda, CA'}
# {'company_id': 79098, 'location': 'Leetonia, OH'}
# {'company_id': 23441, 'location': 'Monticello, MN'}
# {'company_id': 8621, 'location': 'Hillside, IL'}
# {'company_id': 28149455, 'location': 'Newton, NJ'}
# {'company_id': 8019, 'location': 'Little Chicago, WI'}
# {'company_id': 18009221, 'location': 'Galesburg, IL'}
# {'company_id': 26630, 'location': 'Newton, MA'}
# {'company_id': 28595302, 'location': 'Helotes, TX'}
# {'company_id': 28978143, 'location': 'Peabody, MA'}
# {'company_id': 3706049, 'location': 'Osage Beach, MO'}
# {'company_id': 46000, 'location': 'Rockingham, NC'}
# {'company_id': 96180361, 'location': 'Hialeah, FL'}
# {'company_id': 11169, 'location': 'McCamey, TX'}
# {'company_id': 15533103, 'location': 'Marathon City, WI'}
# {'company_id': 660180, 'location': 'Minden, NV'}
# {'company_id': 1471368, 'location': 'Bridgton, ME'}
# {'company_id': 18270206, 'location': 'Orofino, ID'}
# {'company_id': 64746547, 'location': 'Atlantis, FL'}
# {'company_id': 439853, 'location': 'Campbell, CA'}
# {'company_id': 3025557, 'location': 'Mount Pleasant, MI'}
# {'company_id': 2349382, 'location': 'Newark, NJ'}
# {'company_id': 164860, 'location': 'Lago Vista, TX'}
# {'company_id': 18860134, 'location': 'Bullhead City, AZ'}
# {'company_id': 2073870, 'location': 'North Bergen, NJ'}
# {'company_id': 8860695, 'location': 'Herndon, KS'}
# {'company_id': 163139, 'location': 'San Francisco Bay Area'}
# {'company_id': 30755, 'location': 'San Jose, California, United States'}
# {'company_id': 167757, 'location': 'Seeley Lake, MT'}
# {'company_id': 10147, 'location': 'Aurora, OH'}
# {'company_id': 378234, 'location': 'Chalfont, PA'}
# {'company_id': 2247, 'location': 'Capitol Heights, MD'}
# {'company_id': 1441, 'location': 'Sunnyvale, CA'}
# {'company_id': 7032, 'location': 'Kingstowne, VA'}
# {'company_id': 90413667, 'location': 'Enterprise, AL'}
# {'company_id': 164621, 'location': 'Dodge City, KS'}
# {'company_id': 455780, 'location': 'Towson, MD'}
# {'company_id': 81917457, 'location': 'Madison, NJ'}
# {'company_id': 1447496, 'location': 'Tempe, AZ'}
# {'company_id': 1403, 'location': 'Travis Field, CA'}
# {'company_id': 348709, 'location': 'Twin Falls, ID'}
# {'company_id': 64666, 'location': 'Penns Grove, NJ'}
# {'company_id': 2394593, 'location': 'Utah, United States'}
# {'company_id': 5749, 'location': 'Washington, UT'}
# {'company_id': 60561, 'location': 'Bloomington, IL'}
# {'company_id': 26315, 'location': 'Mankato, MN'}
# {'company_id': 76171420, 'location': 'South Boston, VA'}
# {'company_id': 25567, 'location': 'Acton, MA'}
# {'company_id': 88659237, 'location': 'South Plainfield, NJ'}
# {'company_id': 903710, 'location': 'Gallup, NM'}
# {'company_id': 1940159, 'location': 'Thomasville, GA'}
# {'company_id': 601919, 'location': 'Yukon, OK'}
# {'company_id': 581824, 'location': 'Agoura Hills, CA'}
# {'company_id': 1627, 'location': 'Woodland, CA'}
# {'company_id': 1945473, 'location': 'Paragould, AR'}
# {'company_id': 26923, 'location': 'Lake Elmo, MN'}
# {'company_id': 1471368, 'location': 'Groveland, CA'}
# {'company_id': 2843538, 'location': 'Mounds View, MN'}
# {'company_id': 9750, 'location': 'Wimberley, TX'}
# {'company_id': 9185, 'location': 'Milton, FL'}
# {'company_id': 95985, 'location': 'Falls Church, VA'}
# {'company_id': 162912, 'location': 'Greendale, IN'}
# {'company_id': 3961, 'location': 'Triangle, NC'}
# {'company_id': 31815, 'location': 'Capitola, CA'}
# {'company_id': 1505, 'location': 'Fort Wayne, IN'}
# {'company_id': 383000, 'location': 'Toledo, OH'}
# {'company_id': 2227, 'location': 'West Lebanon, NH'}
# {'company_id': 14542824, 'location': 'Chillicothe, OH'}
# {'company_id': 16263, 'location': 'Glenmont, NY'}
# {'company_id': 11824180, 'location': 'Ambler, PA'}
# {'company_id': 57978, 'location': 'Mount Olive, NC'}
# {'company_id': 3812750, 'location': 'Rancho Santa Margarita, CA'}
# {'company_id': 66278935, 'location': 'Kennesaw, GA'}
# {'company_id': 1183247, 'location': 'Richland County, SC'}
# {'company_id': 2162, 'location': 'Barstow, CA'}
# {'company_id': 14542824, 'location': 'Roseau, MN'}
# {'company_id': 9814, 'location': 'Carlsbad, CA'}
# {'company_id': 8667, 'location': 'South Elgin, IL'}
# {'company_id': 973835, 'location': 'Peoria, IL'}
# {'company_id': 46000, 'location': 'Lexington, NC'}
# {'company_id': 410499, 'location': 'St George, UT'}
# {'company_id': 19287, 'location': 'Bay St Louis, MS'}
# {'company_id': 164200, 'location': 'Hixson, TN'}
# {'company_id': 3558, 'location': 'Albany, GA'}
# {'company_id': 14832, 'location': 'Apollo Beach, FL'}
# {'company_id': 4622, 'location': 'Benson, MN'}
# {'company_id': 1908498, 'location': 'Claremore, OK'}
# {'company_id': 65294553, 'location': 'Eau Claire, WI'}
# {'company_id': 17882, 'location': 'Dallas, Texas, United States'}
# {'company_id': 42881474, 'location': 'Salinas, CA'}
# {'company_id': 3335, 'location': 'Slidell, LA'}
# {'company_id': 2565117, 'location': 'Marshall, TX'}
# {'company_id': 2122794, 'location': 'Pascagoula, MS'}
# {'company_id': 19180, 'location': 'Columbus, GA'}
# {'company_id': 15656, 'location': 'Coral Gables, FL'}
# {'company_id': 2664556, 'location': 'Alpena, MI'}
# {'company_id': 57978, 'location': 'Garner, NC'}
# {'company_id': 5553, 'location': 'Harrold, SD'}
# {'company_id': 3706049, 'location': 'Moreno Valley, CA'}
# {'company_id': 2646, 'location': 'Shenandoah, IA'}
# {'company_id': 26923, 'location': 'Traverse City, MI'}
# {'company_id': 1511, 'location': 'Maple Grove, MN'}
# {'company_id': 25017, 'location': 'Gallatin, TN'}
# {'company_id': 1630, 'location': 'Palo Alto, CA'}
# {'company_id': 96180361, 'location': 'Lorain, OH'}
# {'company_id': 3180238, 'location': 'Bay City, MI'}
# {'company_id': 2646, 'location': 'Bentonville, AR'}
# {'company_id': 54788, 'location': 'Whippany, NJ'}
# {'company_id': 166772, 'location': 'Richmond, VA'}
# {'company_id': 104405, 'location': 'White Pine, TN'}
# {'company_id': 165422, 'location': 'Ketchikan, AK'}
# {'company_id': 601919, 'location': 'Ohio, United States'}
# {'company_id': 11056, 'location': 'Charleston, South Carolina Metropolitan Area'}
# {'company_id': 570550, 'location': 'Evendale, OH'}
# {'company_id': 11227630, 'location': 'Coconut Creek, FL'}
# {'company_id': 708393, 'location': 'Mesa County, CO'}
# {'company_id': 1811706, 'location': 'Manassas, VA'}
# {'company_id': 7396, 'location': 'Osseo, MN'}
# {'company_id': 4802958, 'location': 'Greater Orlando'}
# {'company_id': 61677, 'location': 'Ridgefield, CT'}
# {'company_id': 5120284, 'location': 'Warrenville, IL'}
# {'company_id': 40025, 'location': 'Immokalee, FL'}
# {'company_id': 63532172, 'location': 'Hendersonville, TN'}
# {'company_id': 10974065, 'location': 'Chesterfield Township, MI'}
# {'company_id': 167757, 'location': 'Cicero, IL'}
# {'company_id': 16074090, 'location': 'Belmont, MA'}
# {'company_id': 65294553, 'location': 'Lenhartsville, PA'}
# {'company_id': 3706049, 'location': 'Milan, NM'}
# {'company_id': 13181, 'location': 'Nottingham, MD'}
# {'company_id': 3557082, 'location': 'Whitehall, MI'}
# {'company_id': 88277482, 'location': 'Hazel Crest, IL'}
# {'company_id': 2951796, 'location': 'Windsor, CO'}
# {'company_id': 1867264, 'location': 'Yarmouth, MA'}
# {'company_id': 7357, 'location': 'Detroit, MI'}
# {'company_id': 12659, 'location': 'Guntersville, AL'}
# {'company_id': 37396978, 'location': 'Manhattan, NY'}
# {'company_id': 11152, 'location': 'Warren, OR'}
# {'company_id': 56350, 'location': 'Portland, Oregon, United States'}
# {'company_id': 6738, 'location': 'Core, WV'}
# {'company_id': 6449, 'location': 'Novi, MI'}
# {'company_id': 18506580, 'location': 'Goldsboro, NC'}
# {'company_id': 18312164, 'location': 'Rochester, New York Metropolitan Area'}
# {'company_id': 888619, 'location': 'Warren, OH'}
# {'company_id': 1103, 'location': 'Medford, MA'}
# {'company_id': 1386950, 'location': 'Aiken, SC'}
# {'company_id': 68463, 'location': 'Benton, AR'}
# {'company_id': 85320, 'location': 'Avon, NY'}
# {'company_id': 55170, 'location': 'Youngsville, NC'}
# {'company_id': 16196509, 'location': 'Pensacola, FL'}
# {'company_id': 53959, 'location': 'Cudahy, WI'}
# {'company_id': 3632035, 'location': 'Plover, WI'}
# {'company_id': 4713, 'location': 'St Paul, MN'}
# {'company_id': 21041, 'location': 'Coralville, IA'}
# {'company_id': 1273631, 'location': 'Belmont, CA'}
# {'company_id': 2664556, 'location': 'Keene, NH'}
# {'company_id': 5927, 'location': 'Taneytown, MD'}
# {'company_id': 13920, 'location': 'Blue Bell, PA'}
# {'company_id': 14287, 'location': 'Calera, AL'}
# {'company_id': 166471, 'location': 'Folsom, CA'}
# {'company_id': 2855513, 'location': 'Laredo, TX'}
# {'company_id': 6234, 'location': 'Marshall, MN'}
# {'company_id': 9519975, 'location': 'Media, PA'}
# {'company_id': 3533678, 'location': 'Orchard Park, NY'}
# {'company_id': 28647688, 'location': 'Washington, IA'}
# {'company_id': 162724, 'location': 'Delaware, United States'}
# {'company_id': 15216893, 'location': 'King of Prussia, PA'}
# {'company_id': 18043, 'location': 'Millersville, MD'}
# {'company_id': 570092, 'location': 'Millsboro, PA'}
# {'company_id': 6104, 'location': 'New York, NY'}
# {'company_id': 11648, 'location': 'North Hatfield, MA'}
# {'company_id': 86265278, 'location': 'Flower Mound, TX'}
# {'company_id': 164245, 'location': 'Mundelein, IL'}
# {'company_id': 754041, 'location': 'Greater New Orleans Region'}
# {'company_id': 18425303, 'location': 'North Conway, NH'}
# {'company_id': 166388, 'location': 'Omaha Metropolitan Area'}
# {'company_id': 85833, 'location': 'Redondo Beach, CA'}
# {'company_id': 1642, 'location': 'Swiftwater, PA'}
# {'company_id': 19142259, 'location': 'Kalamazoo, MI'}
# {'company_id': 13499, 'location': 'West Chester, PA'}
# {'company_id': 10420321, 'location': 'Fairfax Station, VA'}
# {'company_id': 71904349, 'location': 'Homer, MI'}
# {'company_id': 7396, 'location': 'Welch, MN'}
# {'company_id': 21444, 'location': 'Conway, SC'}
# {'company_id': 18923058, 'location': 'Erie-Meadville Area'}
# {'company_id': 10420321, 'location': 'Beloit, WI'}
# {'company_id': 167757, 'location': 'East Meadow, NY'}
# {'company_id': 82315512, 'location': 'Colleyville, TX'}
# {'company_id': 164098, 'location': 'Gwinnett County, GA'}
# {'company_id': 18312164, 'location': 'Lakewood, CO'}
# {'company_id': 3706049, 'location': 'Canton, GA'}
# {'company_id': 2107, 'location': 'Georgetown, KY'}
# {'company_id': 23379, 'location': 'Lititz, PA'}
# {'company_id': 11108120, 'location': 'Cedar Hill, TX'}
# {'company_id': 26873, 'location': 'El Monte, CA'}
# {'company_id': 3706049, 'location': 'Oxford, NC'}
# {'company_id': 4674, 'location': 'Eddystone, PA'}
# {'company_id': 31065, 'location': 'Fort Leonard Wood, MO'}
# {'company_id': 5235, 'location': 'Niles, IL'}
# {'company_id': 1211063, 'location': 'Parma, OH'}
# {'company_id': 11818084, 'location': 'Pecos, TX'}
# {'company_id': 31065, 'location': 'Mountain Home, ID'}
# {'company_id': 71555983, 'location': 'Saratoga Springs, NY'}
# {'company_id': 65384923, 'location': 'Bowling Green Metropolitan Area'}
# {'company_id': 80911138, 'location': 'Rosemont, IL'}
# {'company_id': 2649, 'location': 'Chicago, IL'}
# {'company_id': 2547066, 'location': 'Seabrook, TX'}
# {'company_id': 80030090, 'location': 'East Durham, NY'}
# {'company_id': 347410, 'location': 'Farmersburg, IN'}
# {'company_id': 96180361, 'location': 'Beaufort, SC'}
# {'company_id': 808034, 'location': 'Cartersville, GA'}
# {'company_id': 18506580, 'location': 'Davenport, FL'}
# {'company_id': 808034, 'location': 'Florence, SC'}
# {'company_id': 2135088, 'location': 'Los Alamitos, CA'}
# {'company_id': 22523, 'location': 'Rapid City, MI'}
# {'company_id': 3570660, 'location': 'Coral Springs, FL'}
# {'company_id': 14611, 'location': 'Denver, Colorado, United States'}
# {'company_id': 20573, 'location': 'Auburn, MA'}
# {'company_id': 13181, 'location': 'Bel Air, MD'}
# {'company_id': 1375621, 'location': 'Crystal City, MO'}
# {'company_id': 16161886, 'location': 'Humble, TX'}
# {'company_id': 163079, 'location': 'Monrovia, CA'}
# {'company_id': 5064123, 'location': 'Southington, CT'}
# {'company_id': 19850, 'location': 'Glenside, PA'}
# {'company_id': 1104359, 'location': 'Tallapoosa, GA'}
# {'company_id': 1505, 'location': 'Tucson, AZ'}
# {'company_id': 75053811, 'location': 'West Nyack, NY'}
# {'company_id': 206226, 'location': 'Patterson, OH'}
# {'company_id': 3706049, 'location': 'Modesto, CA'}
# {'company_id': 2842641, 'location': 'Myrtle Beach, SC'}
# {'company_id': 96180361, 'location': 'Hanover Park, IL'}
# {'company_id': 89520, 'location': 'Rosharon, TX'}
# {'company_id': 3617422, 'location': 'Tifton, GA'}
# {'company_id': 1211063, 'location': 'Portage, WI'}
# {'company_id': 18425303, 'location': 'Tullahoma, TN'}
# {'company_id': 72483, 'location': 'Twinsburg, OH'}
# {'company_id': 12820, 'location': 'Creedmoor, NC'}
# {'company_id': 13181, 'location': 'Fort Washington, MD'}
# {'company_id': 12890, 'location': 'Wheeling, WV'}
# {'company_id': 7556, 'location': 'Athens, GA'}
# Length of the result for 3a-2 :  3431
# Mongo Execution time: 0.22236084938049316
# Avg total time Mongo-Query 3a-2  =  0.2669060230255127

# %% [markdown]
# ## Query 3b - 1

# %% [markdown]
# Esta consulta recupera informações sobre empresas, incluindo o seu ID, nome, número de empregados e o número de ofertas de emprego em que o título contém "er". Também filtra as empresas com mais de 5 ofertas de emprego e ordena os resultados pela contagem de ofertas por ordem decrescente. A utilização de LEFT JOINs garante que as empresas sem entradas correspondentes nas tabelas benefits ou employee_counts continuam a ser incluídas nos resultados.

# %%
name ="3b-1"

sql_query3 = ("SELECT c.company_id, c.name as company_name, ec.employee_count, COUNT(*) as job_count "
                     "FROM job_postings jp "
                     "LEFT JOIN companies c ON jp.company_id = c.company_id "
                     "LEFT JOIN employee_counts ec ON c.company_id = ec.company_id "
                     "WHERE jp.title LIKE '%er' GROUP BY c.company_id, c.name, ec.employee_count "
                     "HAVING job_count > 5 ORDER BY job_count DESC;")

mongo_query3 = [
    {"$match": {'title': {'$regex': 'er$'}}},
    {'$lookup': {'from': "companies",
                 'localField': "company_id",
                 'foreignField': "company_id",
                 'as': "company"}},
    {'$unwind': "$company"},
    {'$lookup': {'from': "benefits",
                 'localField': "job_id",
                 'foreignField': "job_id",
                 'as': "benefits"}},
    {'$lookup': {'from': "employee_counts",
                 'localField': "company.company_id",
                 'foreignField': "company_id",
                 'as': "employee_counts"}},
    {'$group': {'_id': {'company_id': "$company.company_id",
                        'company_name': "$company.name",
                        'employee_count': {'$ifNull': ["$employee_counts.employee_count", 0]}
                        },
                'job_count': {'$sum': 1}}},
    {'$match': {'job_count': {'$gt': 5}}},
    {'$sort': {'job_count': -1}},
    {'$project': {'_id': 0,
                  'company_id': "$_id.company_id",
                  'company_name': "$_id.company_name",
                  'employee_count': "$_id.employee_count",
                  'job_count': "$job_count"}}
]

# %% [markdown]
# #### Result:

# %% [markdown]
# ##### SQL

# %%
sql_query_result(sql_query3,name)
sql_query_explain(sql_query3)
sql_query_avg_time(sql_query3,x,name)
# Out:
# (163139, 'Cogent Communications', 2258, 59)
# (163139, 'Cogent Communications', 2255, 59)
# (163139, 'Cogent Communications', 2250, 59)
# (10420321, 'The Mom Project', 897, 35)
# (10420321, 'The Mom Project', 902, 35)
# (11056, 'Insight Global', 13096, 30)
# (11056, 'Insight Global', 13698, 30)
# (11056, 'Insight Global', 13787, 30)
# (11056, 'Insight Global', 13801, 30)
# (11056, 'Insight Global', 13804, 30)
# (18860134, 'Jobot', 2148, 27)
# (18860134, 'Jobot', 2781, 27)
# (18860134, 'Jobot', 2783, 27)
# (18860134, 'Jobot', 2774, 27)
# (49042, 'Five Star Senior Living', 2882, 26)
# (49042, 'Five Star Senior Living', 2905, 26)
# (49042, 'Five Star Senior Living', 2904, 26)
# (7795, 'Petco', 15497, 25)
# (7795, 'Petco', 15848, 25)
# (7795, 'Petco', 15841, 25)
# (77301, "Raising Cane's Chicken Fingers", 10158, 24)
# (77301, "Raising Cane's Chicken Fingers", 10861, 24)
# (77301, "Raising Cane's Chicken Fingers", 10863, 24)
# (1103, 'Verizon', 95609, 23)
# (1103, 'Verizon', 92691, 23)
# (1103, 'Verizon', 92690, 23)
# (1103, 'Verizon', 92240, 23)
# (1344, 'Honeywell', 127293, 23)
# (1344, 'Honeywell', 128397, 23)
# (1344, 'Honeywell', 128388, 23)
# (1344, 'Honeywell', 127620, 23)
# (71904349, 'Actalent', 5857, 22)
# (71904349, 'Actalent', 5853, 22)
# (1403, 'Booz Allen Hamilton', 38277, 20)
# (1403, 'Booz Allen Hamilton', 35963, 20)
# (1403, 'Booz Allen Hamilton', 35961, 20)
# (1403, 'Booz Allen Hamilton', 35400, 20)
# (72483, 'Aimbridge Hospitality', 7529, 15)
# (72483, 'Aimbridge Hospitality', 7624, 15)
# (72483, 'Aimbridge Hospitality', 7626, 15)
# (72483, 'Aimbridge Hospitality', 7628, 15)
# (2396310, 'Randstad USA', 8074, 15)
# (2396310, 'Randstad USA', 8089, 15)
# (1681, 'Robert Half', 32197, 14)
# (1681, 'Robert Half', 32147, 14)
# (1681, 'Robert Half', 29381, 14)
# (1681, 'Robert Half', 29389, 14)
# (1681, 'Robert Half', 29388, 14)
# (1681, 'Robert Half', 29372, 14)
# (4060, 'Cushman & Wakefield', 40637, 14)
# (4060, 'Cushman & Wakefield', 40700, 14)
# (4060, 'Cushman & Wakefield', 40688, 14)
# (1557409, 'Crown Castle', 5635, 14)
# (1557409, 'Crown Castle', 5541, 14)
# (25856, 'Tradesmen International', 4968, 14)
# (25856, 'Tradesmen International', 5043, 14)
# (25856, 'Tradesmen International', 5042, 14)
# (25856, 'Tradesmen International', 5044, 14)
# (601919, 'Genesys', 7397, 14)
# (601919, 'Genesys', 7486, 14)
# (18312164, 'Bravado', 184, 13)
# (18312164, 'Bravado', 189, 13)
# (18312164, 'Bravado', 192, 13)
# (65294553, 'Brightpath Associates LLC', 59, 13)
# (65294553, 'Brightpath Associates LLC', 61, 13)
# (65294553, 'Brightpath Associates LLC', 70, 13)
# (65294553, 'Brightpath Associates LLC', 69, 13)
# (3240, 'Farmers Insurance', 53065, 12)
# (3240, 'Farmers Insurance', 53116, 12)
# (3240, 'Farmers Insurance', 53102, 12)
# (5235, 'LHH', 12457, 11)
# (5235, 'LHH', 12904, 11)
# (5235, 'LHH', 13020, 11)
# (5235, 'LHH', 13014, 11)
# (5235, 'LHH', 12986, 11)
# (7587370, 'GrayWolf', 134, 11)
# (20009, 'Bimbo Bakeries USA', 9406, 11)
# (20009, 'Bimbo Bakeries USA', 9537, 11)
# (20009, 'Bimbo Bakeries USA', 9541, 11)
# (20009, 'Bimbo Bakeries USA', 9540, 11)
# (73013724, 'J. Galt', 251, 10)
# (73013724, 'J. Galt', 363, 10)
# (73013724, 'J. Galt', 358, 10)
# (9814, 'Eastridge Workforce Solutions', 950, 9)
# (26923, 'Holiday Stationstores', 1054, 9)
# (26923, 'Holiday Stationstores', 1084, 9)
# (26923, 'Holiday Stationstores', 1085, 9)
# (12890, "Cabela's", 6957, 9)
# (12890, "Cabela's", 7020, 9)
# (12890, "Cabela's", 7010, 9)
# (162724, 'Blackbaud', 3473, 9)
# (163253, 'Creative Circle', 1857, 9)
# (163253, 'Creative Circle', 1866, 9)
# (163253, 'Creative Circle', 1863, 9)
# (167757, 'The Job Network', 73, 9)
# (167757, 'The Job Network', 74, 9)
# (1505, 'Raytheon', 43440, 8)
# (1505, 'Raytheon', 44251, 8)
# (1505, 'Raytheon', 44249, 8)
# (1505, 'Raytheon', 44244, 8)
# (1505, 'Raytheon', 44247, 8)
# (3690, 'Micron Technology', 26043, 8)
# (3690, 'Micron Technology', 26044, 8)
# (1511, 'Mondelēz International', 39265, 8)
# (1511, 'Mondelēz International', 39920, 8)
# (1511, 'Mondelēz International', 39914, 8)
# (2193256, 'GFL Environmental Inc.', 5366, 8)
# (2193256, 'GFL Environmental Inc.', 5579, 8)
# (2193256, 'GFL Environmental Inc.', 5582, 8)
# (1463, 'ADP', 83579, 8)
# (1463, 'ADP', 92657, 8)
# (1463, 'ADP', 92645, 8)
# (76171420, 'Hitachi Energy', 20416, 8)
# (76171420, 'Hitachi Energy', 21428, 8)
# (7929696, 'Flynn Group', 1246, 8)
# (2973906, 'Leidos', 32014, 8)
# (2973906, 'Leidos', 31816, 8)
# (9185, 'Advance Auto Parts', 19759, 8)
# (9185, 'Advance Auto Parts', 20244, 8)
# (9185, 'Advance Auto Parts', 20242, 8)
# (79383535, 'Akkodis', 21144, 7)
# (79383535, 'Akkodis', 21147, 7)
# (79383535, 'Akkodis', 21618, 7)
# (79383535, 'Akkodis', 21617, 7)
# (18043, 'Addison Group', 1955, 7)
# (18043, 'Addison Group', 1950, 7)
# (18043, 'Addison Group', 1911, 7)
# (18043, 'Addison Group', 1907, 7)
# (5343, 'Sysco', 26619, 7)
# (5343, 'Sysco', 26634, 7)
# (5343, 'Sysco', 26979, 7)
# (5343, 'Sysco', 26987, 7)
# (15762, 'Page Southerland Page, Inc.', 1721, 7)
# (15762, 'Page Southerland Page, Inc.', 1755, 7)
# (15762, 'Page Southerland Page, Inc.', 1754, 7)
# (7032, 'Ross Stores, Inc.', 29845, 7)
# (7032, 'Ross Stores, Inc.', 29859, 7)
# (7032, 'Ross Stores, Inc.', 30790, 7)
# (7032, 'Ross Stores, Inc.', 30789, 7)
# (7032, 'Ross Stores, Inc.', 30778, 7)
# (8117, 'The Judge Group', 2309, 6)
# (8117, 'The Judge Group', 2296, 6)
# (8117, 'The Judge Group', 2292, 6)
# (8117, 'The Judge Group', 2286, 6)
# (2562, 'Dow', 43847, 6)
# (2562, 'Dow', 43989, 6)
# (5352294, 'Raas Infotek', 186, 6)
# (5352294, 'Raas Infotek', 185, 6)
# (163883, 'Four Seasons Hotels and Resorts', 30545, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31195, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31207, 6)
# (163883, 'Four Seasons Hotels and Resorts', 31206, 6)
# (4822178, 'FactoryFix', 87, 6)
# (4822178, 'FactoryFix', 95, 6)
# (4822178, 'FactoryFix', 94, 6)
# (26873, 'El Pollo Loco, Inc.', 2626, 6)
# (4167, 'PNC', 66604, 6)
# (4167, 'PNC', 66609, 6)
# (4167, 'PNC', 66942, 6)
# (4167, 'PNC', 66940, 6)
# (2247, 'Johnson Controls', 65962, 6)
# (2247, 'Johnson Controls', 65982, 6)
# (2247, 'Johnson Controls', 65981, 6)
# (2247, 'Johnson Controls', 65702, 6)
# (6765, 'Perkins Coie LLP', 2909, 6)
# (2615835, 'Piper Companies', 187, 6)
# (1025, 'Hewlett Packard Enterprise', 70995, 6)
# (1025, 'Hewlett Packard Enterprise', 72453, 6)
# (1025, 'Hewlett Packard Enterprise', 72445, 6)
# (1025, 'Hewlett Packard Enterprise', 71428, 6)
# (777243, 'Ascendo Resources', 357, 6)
# (777243, 'Ascendo Resources', 329, 6)
# (1943848, 'Healthcare Services Group, Inc', 4159, 6)
# (1943848, 'Healthcare Services Group, Inc', 4160, 6)
# Length of the result for 3b-1 :  174
# SQL Execution time: 1.6443400382995605

# %% [markdown]
# With optimization

# %%
#TODO - PUT INDEX HERE
sql_query_result(sql_query3,name)
sql_query_explain(sql_query3)
sql_query_avg_time(sql_query3,x,name)
#
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mongo_query_result(mongo_query3,jobs_collection,name)
#
# Cell In[2], line 13, in mongo_query_result(query, collection, query_name)
#      11 def mongo_query_result(query,collection,query_name):
#      12     time_i = time.time()
# ---> 13     doc = collection.aggregate(query)
#      14     time_f = time.time()
#      15     result = list(doc)
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\collection.py:2496, in Collection.aggregate(self, pipeline, session, **kwargs)
#    2423 """Perform an aggregation using the aggregation framework on this
#    2424 collection.
#    2425
#    (...)
#    2493     https://docs.mongodb.com/manual/reference/command/aggregate
#    2494 """
#    2495 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2496     return self._aggregate(_CollectionAggregationCommand,
#    2497                            pipeline,
#    2498                            CommandCursor,
#    2499                            session=s,
#    2500                            explicit_session=session is not None,
#    2501                            **kwargs)
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\collection.py:2418, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2412     use_cursor = common.validate_boolean(
#    2413         "useCursor", kwargs.pop("useCursor", True))
#    2415 cmd = aggregation_command(
#    2416     self, cursor_class, pipeline, kwargs, explicit_session,
#    2417     user_fields={'cursor': {'firstBatch': 1}}, use_cursor=use_cursor)
# -> 2418 return self.__database.client._retryable_read(
#    2419     cmd.get_cursor, cmd.get_read_preference(session), session,
#    2420     retryable=not cmd._performs_write)
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\aggregation.py:137, in _AggregationCommand.get_cursor(self, session, server, sock_info, secondary_ok)
#     134     write_concern = None
#     136 # Run command.
# --> 137 result = sock_info.command(
#     138     self._database.name,
#     139     cmd,
#     140     secondary_ok,
#     141     self.get_read_preference(session),
#     142     self._target.codec_options,
#     143     parse_write_concern_error=True,
#     144     read_concern=read_concern,
#     145     write_concern=write_concern,
#     146     collation=self._collation,
#     147     session=session,
#     148     client=self._database.client,
#     149     user_fields=self._user_fields)
#     151 self._process_result(result, session, server, sock_info, secondary_ok)
#     153 # Extract cursor from result or mock/fake one if necessary.
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\pool.py:726, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     724 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     725 except BaseException as error:
# --> 726     self._raise_connection_failure(error)
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\network.py:149, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     147     response_doc = {"ok": 1}
#     148 else:
# --> 149     reply = receive_message(sock_info, request_id)
#     150     sock_info.more_to_come = reply.more_to_come
#     151     unpacked_docs = reply.unpack_response(
#     152         codec_options=codec_options, user_fields=user_fields)
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\network.py:196, in receive_message(sock_info, request_id, max_message_size)
#     193     deadline = None
#     194 # Ignore the response's request id.
#     195 length, _, response_to, op_code = _UNPACK_HEADER(
# --> 196     _receive_data_on_socket(sock_info, 16, deadline))
#     197 # No request_id for exhaust cursor "getMore".
#     198 if request_id is not None:
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\network.py:287, in _receive_data_on_socket(sock_info, length, deadline)
#     285 try:
#     286     wait_for_read(sock_info, deadline)
# --> 287     chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     288 except (IOError, OSError) as exc:
#     289     if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Mongo

# %%
mongo_query_result(mongo_query3,jobs_collection,name)
mongo_query_avg_time(mongo_query3,jobs_collection,x,name)

# %% [markdown]
# With Optimization

# %%
mongo_query_result(mongo_query3,jobs_collection,name)
# WARNING! TAKES A LONG TIME TO COMPUTE 
mongo_query_avg_time(mongo_query3,jobs_collection,x,name)

# %% [markdown]
# ## Query 3b - 2

# %% [markdown]
# Essa consulta calcula os valores médio, mínimo e máximo da coluna max_salary da tabela salaries, considerando apenas as linhas em que os anúncios de emprego correspondentes têm um max_salary maior que 5000. O RIGHT JOIN garante que todas as linhas da tabela job_postings sejam incluídas, e as linhas correspondentes da tabela salaries sejam incluídas com valores NULL se não houver correspondência.

# %%
name = "3b-2"
sql_query4 = ("SELECT avg(jp.max_salary), min(jp.max_salary), max(jp.max_salary) FROM salaries s "
                     "RIGHT JOIN job_postings jp on s.job_id = jp.job_id "
                     "WHERE jp.max_salary > 5000;")

mongo_query4 = [
    {'$lookup': {
            'from': "job_postings",
            'localField': "job_id",
            'foreignField': "job_id",
            'as': "job_posting"
                }
    },
    {'$unwind': "$job_posting"},
    {'$match': { "job_posting.max_salary": { '$gt': 5000 } }},
    {'$group': {
            '_id': None,
            'avg_max_salary': { '$avg': "$max_salary" },
            'min_max_salary': { '$min': "$max_salary" },
            'max_max_salary': { '$max': "$max_salary" }
                }
    }]

# %% [markdown]
# #### Result:

# %% [markdown]
# ##### SQL

# %%
sql_query_result(sql_query4,name)
sql_query_explain(sql_query4)
sql_query_avg_time(sql_query4,x,name)

# %% [markdown]
# With optimization

# %%
sql_query_result(sql_query4,name)
sql_query_explain(sql_query4)
sql_query_avg_time(sql_query4,x,name)

# %% [markdown]
# ##### Mongo

# %%
mongo_query_result(mongo_query4,salaries_collection,name)
mongo_query_avg_time(mongo_query4,salaries_collection,x,name)

# %% [markdown]
# With Optimization

# %%
mongo_query_result(mongo_query4,salaries_collection,name)
mongo_query_avg_time(mongo_query4,salaries_collection,x,name)

# %% [markdown]
# ### UPDATE

# %% [markdown]
# Esta consulta atualiza até 10 linhas na tabela benefits, alterando o valor da coluna type de 'Medical insurance' para 'test'. O LIMIT 10 garante que apenas um máximo de 10 linhas sejam atualizadas, mesmo que haja mais linhas que satisfaçam a condição.

# %%
sql_update = "UPDATE benefits SET type = 'test' WHERE type = 'Medical insurance' LIMIT 10;"
time_i = time.time()
mycursor.execute(sql_update)
resu = mycursor.fetchall()
time_f = time.time()

print("SQL Update time:", (time_f-time_i))

time_i = time.time()
mongo_update = db.benefits.updateMany({ type: 'Medical insurance' },
                                       {'$set': { type: 'test' } })
time_f = time.time()

print("Mongo Update time:", (time_f-time_i))
# Out:
# SQL Update time: 0.2557668685913086
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 10
#       7 print("SQL Update time:", (time_f-time_i))
#       9 time_i = time.time()
# ---> 10 mongo_update = db.benefits.updateMany({ type: 'Medical insurance' },
#      11                                        {'$set': { type: 'test' } })
#      12 time_f = time.time()
#      14 print("Mongo Update time:", (time_f-time_i))
#
# File ~\anaconda3\envs\advanced_databases\lib\site-packages\pymongo\collection.py:3485, in Collection.__call__(self, *args, **kwargs)
#    3479 if "." not in self.__name:
#    3480     raise TypeError("'Collection' object is not callable. If you "
#    3481                     "meant to call the '%s' method on a 'Database' "
#    3482                     "object it is failing because no such method "
#    3483                     "exists." %
#    3484                     self.__name)
# -> 3485 raise TypeError("'Collection' object is not callable. If you meant to "
#    3486                 "call the '%s' method on a 'Collection' object it is "
#    3487                 "failing because no such method exists." %
#    3488                 self.__name.split(".")[-1])
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'updateMany' method on a 'Collection' object it is failing because no such method exists.

# %% [markdown]
# ### INSERTION

# %%
sql_insertion = ("INSERT INTO companies(company_id, name, description, company_size, state, country, city, zip_code, address, url) "
                 "VALUES (1, 'Empresas Empresas', 'Fazemos tudo e mais alguma coisa', 15, 'CA', 'USA', 'Los Angeles', '2625-136', 'Rua 29 de Fevereiro', 'https://www.example.com');")

mongo_insertion = db.companies.insertOne({
    'company_id': 1,
    'name': 'Empresas Empresas',
    'description': 'Fazemos tudo e mais alguma coisa',
    'company_size': 15,
    'state': 'CA',
    'country': 'USA',
    'city': 'Los Angeles',
    'zip_code': '2625-136',
    'address': 'Rua 29 de Fevereiro',
    'url': 'https://www.example.com'
})
